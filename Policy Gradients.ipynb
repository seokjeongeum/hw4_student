# %% [markdown]
# # Policy Gradients
# The goal in policy gradient algorithms is to maximize the expected returns of a policy $\pi_\theta$ with parameters $\theta$. Letting $\tau=((s_0, a_0, r_0), \ldots, (s_T, a_T, r_T) )$ denote a trajectory and $R(\tau)$ the return of $\tau$, this objective can be written as
# $$\max_{\theta} \mathbb E_{\tau \sim \pi_{\theta}}[R(\tau)].$$
#
# Using the REINFORCE trick, we can compute the policy gradient (the gradient of expected policy returns) as
# $$\sum_{t=0}^T \mathbb E_{s_t, a_t \sim \pi(\tau)} \nabla_{\theta} \log \pi_{\theta}(a_t \vert s_t) R(\tau).$$
#
# We can then estimate this with a very simple scheme.
# We first sample a trajectory $\tau = ((s_t, a_t, r_t))_{t=0}^\infty$ from our current policy, compute the discounted return of the trajectory as $R$, then take a stochastic estimate of the policy gradient as
#
# $$\sum_{t=0}^T \mathbb \nabla_{\theta} \log \pi_{\theta}(a_t \vert s_t) R(\tau).$$
# We can then repeat sample more trajectories to average the estimate over multiple samples.
# In practice, we will often use _discounted_ returns $\tilde R(\tau) = \sum_{t=0}^T \gamma^t r_t$ where $\gamma$ is the discount factor and our policy gradient estimate will simply replace the undiscounted returns with $\tilde R(\tau)$.

# %%
#@title imports
# As usual, a bit of setup
import os
import shutil
import time
import numpy as np
import gym
import torch

import deeprl.infrastructure.pytorch_util as ptu

from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import PG_Trainer
from deeprl.infrastructure.trainers import BC_Trainer

from deeprl.agents.pg_agent import PGAgent
from deeprl.policies.MLP_policy import MLPPolicyPG

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))

# %%
pg_base_args_dict = dict(
    env_name = 'Hopper-v2', #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
    exp_name = 'test_pg', #@param
    save_params = False, #@param {type: "boolean"}
    
    ep_len = 200, #@param {type: "integer"}
    discount = 0.95, #@param {type: "number"}

    reward_to_go = True, #@param {type: "boolean"}
    nn_baseline = False, #@param {type: "boolean"}
    dont_standardize_advantages = True, #@param {type: "boolean"}

    # Training
    num_agent_train_steps_per_iter = 1, #@param {type: "integer"})
    n_iter = 100, #@param {type: "integer"})

    # batches & buffers
    batch_size = 1000, #@param {type: "integer"})
    eval_batch_size = 1000, #@param {type: "integer"}
    train_batch_size = 1000, #@param {type: "integer"}
    max_replay_buffer_size = 1000000, #@param {type: "integer"}

    #@markdown network
    n_layers = 2, #@param {type: "integer"}
    size = 64, #@param {type: "integer"}
    learning_rate = 5e-3, #@param {type: "number"}

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# ## Implementing policy gradients
# We will first compute a very naive policy gradient calculation by taking the whole discounted return of a trajectory. Fill out the method <code>_discounted_return</code> in <code>pg_agent.py</code>. Your error should be 1e-6 or lower.

# %%
### Test return computation
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

T = 10
np.random.seed(0)
rewards = np.random.normal(size=T)
discounted_returns = pgagent._discounted_return(rewards)

expected_return = 6.49674307
return_error = rel_error(discounted_returns, expected_return)
print("Error in return estimate is", return_error)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Error in return estimate is 1.3988379013203016e-10

# %% [markdown]
# Next, we'll consider a return estimate with lower variance by taking the discounted reward-to-go at each timestep instead of the entire discounted return. More precisely, instead of taking $\sum_{t'=0}^T \gamma^{t'} r_{t'}$ as the return estimate for all timesteps $t$, we will instead use $\sum_{t'=t}^T \gamma^{t' - t} r_{t'}$ for the return estimate at timestep $t$. Fill out the method <code>_discounted_cumsum</code> in <code>pg_agent.py</code>.   Your error should be 1e-6 or lower.

# %%
### Test reward to go computations
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

T = 10
np.random.seed(0)
rewards = np.random.normal(size=T)
discounted_cumsum = pgagent._discounted_cumsum(rewards)
expected_cumsum = np.array([6.49674307, 4.98177971, 4.82276053, 4.04633952, 1.90046981, 0.03464402,
 1.06518095, 0.12115003, 0.28684973, 0.4105985])

return_error = rel_error(discounted_cumsum, expected_cumsum)
print("Error in return estimate is", return_error)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Error in return estimate is 1.0143652172567337e-08

# %% [markdown]
# Finally, we'll use our return estimates to compute a policy gradient. Fill out the surrogate loss computation in the <code>update</code> method in MLPPolicyPG class in <code>policies/MLP_policy.py</code>.

# %%
### Test policy gradient (check gradients match what we expect)
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicyPG(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))
advs = 1000 * np.random.normal(size=(batch_size,))

first_weight_before = np.array(ptu.to_numpy(next(policy.mean_net.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts, advs)['Training Loss']

print(loss)
expected_loss = -6142.9116
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.mean_net.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 1.035012, 1.0455959, 0.11085394],
                            [-1.1532364, -0.5915445, 0.557522]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.00432252  0.30971584 -0.47518533]
#  [-0.4248946  -0.22236897  0.15482073]]
# -6142.9116
# Loss Error 1.7169178864173362e-09 should be on the order of 1e-6 or lower
# Weight after update [[ 1.0306895   1.3553118  -0.3643314 ]
#  [-1.578131   -0.81391346  0.71234274]]
# Change in weights [[ 1.035012    1.0455959   0.11085394]
#  [-1.1532364  -0.5915445   0.557522  ]]
# Weight Update Error 7.551436028905091e-09 should be on the order of 1e-6 or lower

# %% [markdown]
# We can compare the two return estimators on a simple environment and compare how well they do.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['reward_to_go'] = False
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/full_returns/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/full_returns/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/CartPole/full_returns/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/CartPole/full_returns/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 29.285715103149414
# Eval_StdReturn : 16.32451629638672
# Eval_MaxReturn : 86.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 29.285714285714285
# Train_AverageReturn : 22.0
# Train_StdReturn : 10.642409324645996
# Train_MaxReturn : 51.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 22.0
# Train_EnvstepsSoFar : 1012
# TimeSinceStart : 0.280689001083374
# Training Loss : 9.748507499694824
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 28.2500
# Eval_StdReturn : 13.697880744934082
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 28.25
# Train_AverageReturn : 23.627906799316406
# Train_StdReturn : 11.442522048950195
# Train_MaxReturn : 58.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 23.627906976744185
# Train_EnvstepsSoFar : 2028
# TimeSinceStart : 0.5657415390014648
# Training Loss : 9.987648010253906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1079 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.027027130126953
# Eval_StdReturn : 13.28377628326416
# Eval_MaxReturn : 63.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 27.027027027027028
# Train_AverageReturn : 29.16216278076172
# Train_StdReturn : 17.249385833740234
# Train_MaxReturn : 98.0
# Train_MinReturn : 8.0
# Train_AverageEpLen : 29.16216216216216
# Train_EnvstepsSoFar : 3107
# TimeSinceStart : 0.8402736186981201
# Training Loss : 10.928592681884766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.84375
# Eval_StdReturn : 14.809433937072754
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 31.84375
# Train_AverageReturn : 29.41176414489746
# Train_StdReturn : 14.167314529418945
# Train_MaxReturn : 75.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 29.41176470588235
# Train_EnvstepsSoFar : 4107
# TimeSinceStart : 1.1126244068145752
# Training Loss : 10.722437858581543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1058 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.31999969482422
# Eval_StdReturn : 27.21575927734375
# Eval_MaxReturn : 125.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 40.32
# Train_AverageReturn : 32.06060791015625
# Train_StdReturn : 22.581756591796875
# Train_MaxReturn : 98.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 32.06060606060606
# Train_EnvstepsSoFar : 5165
# TimeSinceStart : 1.386143684387207
# Training Loss : 11.185359001159668
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1042 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.128204345703125
# Eval_StdReturn : 14.0277738571167
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 26.128205128205128
# Train_AverageReturn : 30.647058486938477
# Train_StdReturn : 16.591781616210938
# Train_MaxReturn : 84.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 30.647058823529413
# Train_EnvstepsSoFar : 6207
# TimeSinceStart : 1.6642787456512451
# Training Loss : 10.851187705993652
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 25.049999237060547
# Eval_StdReturn : 15.287168502807617
# Eval_MaxReturn : 84.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 25.05
# Train_AverageReturn : 24.095237731933594
# Train_StdReturn : 10.919204711914062
# Train_MaxReturn : 57.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 24.095238095238095
# Train_EnvstepsSoFar : 7219
# TimeSinceStart : 1.9369235038757324
# Training Loss : 9.761500358581543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1050 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 21.84782600402832
# Eval_StdReturn : 7.703661918640137
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 21.847826086956523
# Train_AverageReturn : 24.418603897094727
# Train_StdReturn : 17.236024856567383
# Train_MaxReturn : 104.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 24.41860465116279
# Train_EnvstepsSoFar : 8269
# TimeSinceStart : 2.2144997119903564
# Training Loss : 9.838366508483887
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1060 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 20.219999313354492
# Eval_StdReturn : 9.61933422088623
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 20.22
# Train_AverageReturn : 20.384614944458008
# Train_StdReturn : 12.580745697021484
# Train_MaxReturn : 86.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 20.384615384615383
# Train_EnvstepsSoFar : 9329
# TimeSinceStart : 2.4979240894317627
# Training Loss : 8.916958808898926
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 23.581396102905273
# Eval_StdReturn : 10.796710014343262
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 23.58139534883721
# Train_AverageReturn : 22.04347801208496
# Train_StdReturn : 10.46725082397461
# Train_MaxReturn : 57.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 22.043478260869566
# Train_EnvstepsSoFar : 10343
# TimeSinceStart : 2.778512716293335
# Training Loss : 9.301702499389648
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.736841201782227
# Eval_StdReturn : 17.958555221557617
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 26.736842105263158
# Train_AverageReturn : 19.921567916870117
# Train_StdReturn : 6.927759170532227
# Train_MaxReturn : 38.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 19.92156862745098
# Train_EnvstepsSoFar : 11359
# TimeSinceStart : 3.0635876655578613
# Training Loss : 8.595572471618652
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 23.744186401367188
# Eval_StdReturn : 9.298894882202148
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 23.74418604651163
# Train_AverageReturn : 22.44444465637207
# Train_StdReturn : 9.083698272705078
# Train_MaxReturn : 56.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 22.444444444444443
# Train_EnvstepsSoFar : 12369
# TimeSinceStart : 3.344763994216919
# Training Loss : 9.202675819396973
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 24.9761905670166
# Eval_StdReturn : 15.09255313873291
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 24.976190476190474
# Train_AverageReturn : 24.452381134033203
# Train_StdReturn : 11.658232688903809
# Train_MaxReturn : 64.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 24.452380952380953
# Train_EnvstepsSoFar : 13396
# TimeSinceStart : 3.6210761070251465
# Training Loss : 9.670610427856445
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.176469802856445
# Eval_StdReturn : 17.550716400146484
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 31.176470588235293
# Train_AverageReturn : 28.714284896850586
# Train_StdReturn : 17.815837860107422
# Train_MaxReturn : 88.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 28.714285714285715
# Train_EnvstepsSoFar : 14401
# TimeSinceStart : 3.9260120391845703
# Training Loss : 10.350377082824707
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1011 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.19355010986328
# Eval_StdReturn : 15.567583084106445
# Eval_MaxReturn : 65.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 33.193548387096776
# Train_AverageReturn : 29.735294342041016
# Train_StdReturn : 15.810102462768555
# Train_MaxReturn : 92.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 29.735294117647058
# Train_EnvstepsSoFar : 15412
# TimeSinceStart : 4.206441640853882
# Training Loss : 10.250404357910156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.89655303955078
# Eval_StdReturn : 16.942794799804688
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 35.89655172413793
# Train_AverageReturn : 39.57692337036133
# Train_StdReturn : 17.78973960876465
# Train_MaxReturn : 95.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 39.57692307692308
# Train_EnvstepsSoFar : 16441
# TimeSinceStart : 4.484328746795654
# Training Loss : 11.268746376037598
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1110 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 49.0000
# Eval_StdReturn : 26.56169891357422
# Eval_MaxReturn : 120.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 49.0
# Train_AverageReturn : 44.400001525878906
# Train_StdReturn : 35.090736389160156
# Train_MaxReturn : 137.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 44.4
# Train_EnvstepsSoFar : 17551
# TimeSinceStart : 4.773204803466797
# Training Loss : 11.600893020629883
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1001 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.52631759643555
# Eval_StdReturn : 36.80727767944336
# Eval_MaxReturn : 177.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 55.526315789473685
# Train_AverageReturn : 43.5217399597168
# Train_StdReturn : 23.8580379486084
# Train_MaxReturn : 138.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 43.52173913043478
# Train_EnvstepsSoFar : 18552
# TimeSinceStart : 5.061681270599365
# Training Loss : 11.457797050476074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 47.272727966308594
# Eval_StdReturn : 21.0738582611084
# Eval_MaxReturn : 100.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 47.27272727272727
# Train_AverageReturn : 41.75
# Train_StdReturn : 22.666513442993164
# Train_MaxReturn : 123.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 41.75
# Train_EnvstepsSoFar : 19554
# TimeSinceStart : 5.369387149810791
# Training Loss : 11.096564292907715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1077 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.7931022644043
# Eval_StdReturn : 18.41921615600586
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 35.793103448275865
# Train_AverageReturn : 51.28571319580078
# Train_StdReturn : 33.38825225830078
# Train_MaxReturn : 133.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 51.285714285714285
# Train_EnvstepsSoFar : 20631
# TimeSinceStart : 5.659768104553223
# Training Loss : 11.529394149780273
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1015 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.04166793823242
# Eval_StdReturn : 14.76617431640625
# Eval_MaxReturn : 74.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 42.041666666666664
# Train_AverageReturn : 36.25
# Train_StdReturn : 13.083864212036133
# Train_MaxReturn : 65.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 36.25
# Train_EnvstepsSoFar : 21646
# TimeSinceStart : 5.979779005050659
# Training Loss : 10.678284645080566
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1042 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.89285659790039
# Eval_StdReturn : 16.303680419921875
# Eval_MaxReturn : 91.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 35.892857142857146
# Train_AverageReturn : 37.21428680419922
# Train_StdReturn : 14.069615364074707
# Train_MaxReturn : 78.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 37.214285714285715
# Train_EnvstepsSoFar : 22688
# TimeSinceStart : 6.2587456703186035
# Training Loss : 10.772427558898926
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1019 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.599998474121094
# Eval_StdReturn : 25.285568237304688
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 40.6
# Train_AverageReturn : 36.39285659790039
# Train_StdReturn : 17.50783348083496
# Train_MaxReturn : 106.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 36.392857142857146
# Train_EnvstepsSoFar : 23707
# TimeSinceStart : 6.529034614562988
# Training Loss : 10.389925003051758
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.66666793823242
# Eval_StdReturn : 19.400745391845703
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 41.666666666666664
# Train_AverageReturn : 35.89285659790039
# Train_StdReturn : 19.317533493041992
# Train_MaxReturn : 104.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 35.892857142857146
# Train_EnvstepsSoFar : 24712
# TimeSinceStart : 6.792886972427368
# Training Loss : 10.532183647155762
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 44.130435943603516
# Eval_StdReturn : 15.255232810974121
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 44.130434782608695
# Train_AverageReturn : 37.33333206176758
# Train_StdReturn : 17.68657112121582
# Train_MaxReturn : 103.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 37.333333333333336
# Train_EnvstepsSoFar : 25720
# TimeSinceStart : 7.062901973724365
# Training Loss : 10.478879928588867
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1037 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.54166793823242
# Eval_StdReturn : 17.387685775756836
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 43.541666666666664
# Train_AverageReturn : 51.849998474121094
# Train_StdReturn : 39.05288314819336
# Train_MaxReturn : 174.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 51.85
# Train_EnvstepsSoFar : 26757
# TimeSinceStart : 7.343119859695435
# Training Loss : 11.09473705291748
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.70833206176758
# Eval_StdReturn : 15.616442680358887
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 41.708333333333336
# Train_AverageReturn : 38.653846740722656
# Train_StdReturn : 17.946378707885742
# Train_MaxReturn : 107.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 38.65384615384615
# Train_EnvstepsSoFar : 27762
# TimeSinceStart : 7.61838436126709
# Training Loss : 10.619898796081543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.040000915527344
# Eval_StdReturn : 17.512235641479492
# Eval_MaxReturn : 80.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 42.04
# Train_AverageReturn : 46.40909194946289
# Train_StdReturn : 22.266279220581055
# Train_MaxReturn : 106.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 46.40909090909091
# Train_EnvstepsSoFar : 28783
# TimeSinceStart : 7.931921005249023
# Training Loss : 11.114814758300781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1081 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.5217399597168
# Eval_StdReturn : 19.92566680908203
# Eval_MaxReturn : 99.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 45.52173913043478
# Train_AverageReturn : 54.04999923706055
# Train_StdReturn : 30.408016204833984
# Train_MaxReturn : 138.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 54.05
# Train_EnvstepsSoFar : 29864
# TimeSinceStart : 8.232303857803345
# Training Loss : 11.040983200073242
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.68421173095703
# Eval_StdReturn : 29.943897247314453
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 52.68421052631579
# Train_AverageReturn : 48.19047546386719
# Train_StdReturn : 15.734763145446777
# Train_MaxReturn : 86.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 48.19047619047619
# Train_EnvstepsSoFar : 30876
# TimeSinceStart : 8.516257524490356
# Training Loss : 10.9463529586792
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1045 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 66.5000
# Eval_StdReturn : 35.00892639160156
# Eval_MaxReturn : 175.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 66.5
# Train_AverageReturn : 45.434783935546875
# Train_StdReturn : 16.314373016357422
# Train_MaxReturn : 79.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 45.43478260869565
# Train_EnvstepsSoFar : 31921
# TimeSinceStart : 8.801830053329468
# Training Loss : 10.755820274353027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.0625
# Eval_StdReturn : 37.327049255371094
# Eval_MaxReturn : 168.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 64.0625
# Train_AverageReturn : 59.29411697387695
# Train_StdReturn : 23.957719802856445
# Train_MaxReturn : 121.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 59.294117647058826
# Train_EnvstepsSoFar : 32929
# TimeSinceStart : 9.100543022155762
# Training Loss : 11.542814254760742
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 61.764705657958984
# Eval_StdReturn : 27.967479705810547
# Eval_MaxReturn : 141.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 61.76470588235294
# Train_AverageReturn : 55.83333206176758
# Train_StdReturn : 26.955209732055664
# Train_MaxReturn : 157.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 55.833333333333336
# Train_EnvstepsSoFar : 33934
# TimeSinceStart : 9.380605459213257
# Training Loss : 11.143712997436523
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1122 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.5625
# Eval_StdReturn : 38.634456634521484
# Eval_MaxReturn : 172.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 65.5625
# Train_AverageReturn : 86.30769348144531
# Train_StdReturn : 38.31124496459961
# Train_MaxReturn : 154.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 86.3076923076923
# Train_EnvstepsSoFar : 35056
# TimeSinceStart : 9.669562339782715
# Training Loss : 11.609508514404297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1053 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.42857360839844
# Eval_StdReturn : 26.029420852661133
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 74.42857142857143
# Train_AverageReturn : 81.0
# Train_StdReturn : 33.53528594970703
# Train_MaxReturn : 125.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 81.0
# Train_EnvstepsSoFar : 36109
# TimeSinceStart : 9.95419430732727
# Training Loss : 11.519268035888672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1078 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.64286041259766
# Eval_StdReturn : 21.95322036743164
# Eval_MaxReturn : 135.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 75.64285714285714
# Train_AverageReturn : 63.411766052246094
# Train_StdReturn : 28.832290649414062
# Train_MaxReturn : 146.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 63.411764705882355
# Train_EnvstepsSoFar : 37187
# TimeSinceStart : 10.24854326248169
# Training Loss : 11.340380668640137
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.69999694824219
# Eval_StdReturn : 32.4839973449707
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 101.7
# Train_AverageReturn : 72.92857360839844
# Train_StdReturn : 23.057270050048828
# Train_MaxReturn : 106.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 72.92857142857143
# Train_EnvstepsSoFar : 38208
# TimeSinceStart : 10.550178050994873
# Training Loss : 11.56374740600586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1053 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.66666412353516
# Eval_StdReturn : 29.519296646118164
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 84.66666666666667
# Train_AverageReturn : 87.75
# Train_StdReturn : 51.410316467285156
# Train_MaxReturn : 181.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 87.75
# Train_EnvstepsSoFar : 39261
# TimeSinceStart : 10.827067852020264
# Training Loss : 11.431988716125488
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1072 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 70.0000
# Eval_StdReturn : 25.52123260498047
# Eval_MaxReturn : 116.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 70.0
# Train_AverageReturn : 107.19999694824219
# Train_StdReturn : 50.69674301147461
# Train_MaxReturn : 200.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 107.2
# Train_EnvstepsSoFar : 40333
# TimeSinceStart : 11.121784687042236
# Training Loss : 11.579239845275879
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.64286041259766
# Eval_StdReturn : 45.736209869384766
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 82.64285714285714
# Train_AverageReturn : 100.5
# Train_StdReturn : 51.892677307128906
# Train_MaxReturn : 200.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 100.5
# Train_EnvstepsSoFar : 41338
# TimeSinceStart : 11.43159008026123
# Training Loss : 11.626072883605957
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1069 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.9000015258789
# Eval_StdReturn : 47.382381439208984
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 101.9
# Train_AverageReturn : 89.08333587646484
# Train_StdReturn : 21.441619873046875
# Train_MaxReturn : 121.0
# Train_MinReturn : 52.0
# Train_AverageEpLen : 89.08333333333333
# Train_EnvstepsSoFar : 42407
# TimeSinceStart : 11.707466125488281
# Training Loss : 11.43665599822998
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.4000015258789
# Eval_StdReturn : 43.909454345703125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 110.4
# Train_AverageReturn : 87.91666412353516
# Train_StdReturn : 45.71735382080078
# Train_MaxReturn : 164.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 87.91666666666667
# Train_EnvstepsSoFar : 43462
# TimeSinceStart : 12.011989831924438
# Training Loss : 11.287755966186523
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1072 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.5999984741211
# Eval_StdReturn : 46.40732955932617
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 109.6
# Train_AverageReturn : 119.11111450195312
# Train_StdReturn : 55.6146354675293
# Train_MaxReturn : 200.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 119.11111111111111
# Train_EnvstepsSoFar : 44534
# TimeSinceStart : 12.331353664398193
# Training Loss : 11.392969131469727
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1067 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 94.90908813476562
# Eval_StdReturn : 31.63558006286621
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 94.9090909090909
# Train_AverageReturn : 118.55555725097656
# Train_StdReturn : 33.41360855102539
# Train_MaxReturn : 177.0
# Train_MinReturn : 81.0
# Train_AverageEpLen : 118.55555555555556
# Train_EnvstepsSoFar : 45601
# TimeSinceStart : 12.637399435043335
# Training Loss : 11.232108116149902
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1179 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 93.18181610107422
# Eval_StdReturn : 43.01335144042969
# Eval_MaxReturn : 170.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 93.18181818181819
# Train_AverageReturn : 107.18181610107422
# Train_StdReturn : 57.57969665527344
# Train_MaxReturn : 200.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 107.18181818181819
# Train_EnvstepsSoFar : 46780
# TimeSinceStart : 12.956377744674683
# Training Loss : 11.453988075256348
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1069 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.500
# Eval_StdReturn : 26.258331298828125
# Eval_MaxReturn : 178.0
# Eval_MinReturn : 94.0
# Eval_AverageEpLen : 133.5
# Train_AverageReturn : 97.18181610107422
# Train_StdReturn : 40.099464416503906
# Train_MaxReturn : 167.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 97.18181818181819
# Train_EnvstepsSoFar : 47849
# TimeSinceStart : 13.25511360168457
# Training Loss : 11.109260559082031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1131 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.36363983154297
# Eval_StdReturn : 27.641447067260742
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 96.36363636363636
# Train_AverageReturn : 102.81818389892578
# Train_StdReturn : 31.5791015625
# Train_MaxReturn : 171.0
# Train_MinReturn : 53.0
# Train_AverageEpLen : 102.81818181818181
# Train_EnvstepsSoFar : 48980
# TimeSinceStart : 13.560835599899292
# Training Loss : 11.12025260925293
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.69999694824219
# Eval_StdReturn : 45.23726272583008
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 101.7
# Train_AverageReturn : 103.5999984741211
# Train_StdReturn : 30.233095169067383
# Train_MaxReturn : 157.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 103.6
# Train_EnvstepsSoFar : 50016
# TimeSinceStart : 13.840886116027832
# Training Loss : 11.020126342773438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 98.81818389892578
# Eval_StdReturn : 31.42037010192871
# Eval_MaxReturn : 188.0
# Eval_MinReturn : 61.0
# Eval_AverageEpLen : 98.81818181818181
# Train_AverageReturn : 112.22222137451172
# Train_StdReturn : 56.16993713378906
# Train_MaxReturn : 200.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 112.22222222222223
# Train_EnvstepsSoFar : 51026
# TimeSinceStart : 14.123397827148438
# Training Loss : 11.117840766906738
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1081 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 83.41666412353516
# Eval_StdReturn : 31.645057678222656
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 83.41666666666667
# Train_AverageReturn : 83.15384674072266
# Train_StdReturn : 32.58797836303711
# Train_MaxReturn : 146.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 83.15384615384616
# Train_EnvstepsSoFar : 52107
# TimeSinceStart : 14.409915685653687
# Training Loss : 10.874619483947754
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.80000305175781
# Eval_StdReturn : 39.974491119384766
# Eval_MaxReturn : 176.0
# Eval_MinReturn : 56.0
# Eval_AverageEpLen : 103.8
# Train_AverageReturn : 93.54545593261719
# Train_StdReturn : 26.7152099609375
# Train_MaxReturn : 159.0
# Train_MinReturn : 62.0
# Train_AverageEpLen : 93.54545454545455
# Train_EnvstepsSoFar : 53136
# TimeSinceStart : 14.746341466903687
# Training Loss : 10.761917114257812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.63636016845703
# Eval_StdReturn : 33.85603713989258
# Eval_MaxReturn : 160.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 92.63636363636364
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 23.066200256347656
# Train_MaxReturn : 126.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 54177
# TimeSinceStart : 15.018078327178955
# Training Loss : 10.71338939666748
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 79.53845977783203
# Eval_StdReturn : 22.134605407714844
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 79.53846153846153
# Train_AverageReturn : 81.15384674072266
# Train_StdReturn : 30.094329833984375
# Train_MaxReturn : 145.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 81.15384615384616
# Train_EnvstepsSoFar : 55232
# TimeSinceStart : 15.300293684005737
# Training Loss : 10.629600524902344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.90908813476562
# Eval_StdReturn : 23.643007278442383
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 95.9090909090909
# Train_AverageReturn : 88.08333587646484
# Train_StdReturn : 29.772634506225586
# Train_MaxReturn : 171.0
# Train_MinReturn : 54.0
# Train_AverageEpLen : 88.08333333333333
# Train_EnvstepsSoFar : 56289
# TimeSinceStart : 15.635361909866333
# Training Loss : 10.489524841308594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.0999984741211
# Eval_StdReturn : 34.24748229980469
# Eval_MaxReturn : 182.0
# Eval_MinReturn : 75.0
# Eval_AverageEpLen : 110.1
# Train_AverageReturn : 93.54545593261719
# Train_StdReturn : 30.158260345458984
# Train_MaxReturn : 159.0
# Train_MinReturn : 48.0
# Train_AverageEpLen : 93.54545454545455
# Train_EnvstepsSoFar : 57318
# TimeSinceStart : 15.954829454421997
# Training Loss : 10.50048542022705
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     1068 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.77777862548828
# Eval_StdReturn : 23.827051162719727
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 77.0
# Eval_AverageEpLen : 113.77777777777777
# Train_AverageReturn : 89.0
# Train_StdReturn : 28.27543067932129
# Train_MaxReturn : 144.0
# Train_MinReturn : 54.0
# Train_AverageEpLen : 89.0
# Train_EnvstepsSoFar : 58386
# TimeSinceStart : 16.230818033218384
# Training Loss : 10.509204864501953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     1060 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.000
# Eval_StdReturn : 35.71492004394531
# Eval_MaxReturn : 173.0
# Eval_MinReturn : 58.0
# Eval_AverageEpLen : 115.0
# Train_AverageReturn : 81.53845977783203
# Train_StdReturn : 27.071460723876953
# Train_MaxReturn : 144.0
# Train_MinReturn : 46.0
# Train_AverageEpLen : 81.53846153846153
# Train_EnvstepsSoFar : 59446
# TimeSinceStart : 16.51382875442505
# Training Loss : 10.332776069641113
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     1033 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.58333587646484
# Eval_StdReturn : 22.998035430908203
# Eval_MaxReturn : 124.0
# Eval_MinReturn : 59.0
# Eval_AverageEpLen : 88.58333333333333
# Train_AverageReturn : 93.90908813476562
# Train_StdReturn : 45.360084533691406
# Train_MaxReturn : 200.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 93.9090909090909
# Train_EnvstepsSoFar : 60479
# TimeSinceStart : 16.80837082862854
# Training Loss : 10.040365219116211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.5000
# Eval_StdReturn : 26.228166580200195
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 84.5
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 27.919599533081055
# Train_MaxReturn : 168.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 61520
# TimeSinceStart : 17.100542068481445
# Training Loss : 10.414929389953613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 87.2500
# Eval_StdReturn : 29.137962341308594
# Eval_MaxReturn : 157.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 87.25
# Train_AverageReturn : 83.66666412353516
# Train_StdReturn : 21.707653045654297
# Train_MaxReturn : 132.0
# Train_MinReturn : 57.0
# Train_AverageEpLen : 83.66666666666667
# Train_EnvstepsSoFar : 62524
# TimeSinceStart : 17.404516458511353
# Training Loss : 10.434540748596191
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     1045 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 81.46154022216797
# Eval_StdReturn : 37.360233306884766
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 81.46153846153847
# Train_AverageReturn : 87.08333587646484
# Train_StdReturn : 34.44187927246094
# Train_MaxReturn : 151.0
# Train_MinReturn : 49.0
# Train_AverageEpLen : 87.08333333333333
# Train_EnvstepsSoFar : 63569
# TimeSinceStart : 17.69585371017456
# Training Loss : 10.335333824157715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 91.38461303710938
# Eval_StdReturn : 37.446449279785156
# Eval_MaxReturn : 190.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 91.38461538461539
# Train_AverageReturn : 96.45454406738281
# Train_StdReturn : 37.23967361450195
# Train_MaxReturn : 200.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 96.45454545454545
# Train_EnvstepsSoFar : 64630
# TimeSinceStart : 18.03844404220581
# Training Loss : 10.252520561218262
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     1073 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.09091186523438
# Eval_StdReturn : 47.607208251953125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 56.0
# Eval_AverageEpLen : 97.0909090909091
# Train_AverageReturn : 89.41666412353516
# Train_StdReturn : 49.6763801574707
# Train_MaxReturn : 200.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 89.41666666666667
# Train_EnvstepsSoFar : 65703
# TimeSinceStart : 18.381999492645264
# Training Loss : 10.41189956665039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 116.22222137451172
# Eval_StdReturn : 50.909019470214844
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 44.0
# Eval_AverageEpLen : 116.22222222222223
# Train_AverageReturn : 96.7272720336914
# Train_StdReturn : 37.736141204833984
# Train_MaxReturn : 200.0
# Train_MinReturn : 59.0
# Train_AverageEpLen : 96.72727272727273
# Train_EnvstepsSoFar : 66767
# TimeSinceStart : 18.69895887374878
# Training Loss : 10.184976577758789
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     1044 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.55555725097656
# Eval_StdReturn : 37.57987594604492
# Eval_MaxReturn : 175.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 123.55555555555556
# Train_AverageReturn : 94.90908813476562
# Train_StdReturn : 28.311431884765625
# Train_MaxReturn : 156.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 94.9090909090909
# Train_EnvstepsSoFar : 67811
# TimeSinceStart : 18.988157510757446
# Training Loss : 10.452993392944336
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.500
# Eval_StdReturn : 56.22943878173828
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 126.5
# Train_AverageReturn : 93.36363983154297
# Train_StdReturn : 24.886186599731445
# Train_MaxReturn : 152.0
# Train_MinReturn : 70.0
# Train_AverageEpLen : 93.36363636363636
# Train_EnvstepsSoFar : 68838
# TimeSinceStart : 19.259790420532227
# Training Loss : 10.455167770385742
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.000
# Eval_StdReturn : 53.0994873046875
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 126.0
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 37.17348098754883
# Train_MaxReturn : 189.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 69879
# TimeSinceStart : 19.549396753311157
# Training Loss : 10.257110595703125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.750
# Eval_StdReturn : 38.79674530029297
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 72.0
# Eval_AverageEpLen : 128.75
# Train_AverageReturn : 131.375
# Train_StdReturn : 39.51245880126953
# Train_MaxReturn : 191.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 131.375
# Train_EnvstepsSoFar : 70930
# TimeSinceStart : 19.888798236846924
# Training Loss : 10.97035026550293
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     1121 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.000
# Eval_StdReturn : 14.329456329345703
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 166.0
# Eval_AverageEpLen : 190.0
# Train_AverageReturn : 124.55555725097656
# Train_StdReturn : 38.032474517822266
# Train_MaxReturn : 200.0
# Train_MinReturn : 84.0
# Train_AverageEpLen : 124.55555555555556
# Train_EnvstepsSoFar : 72051
# TimeSinceStart : 20.20288586616516
# Training Loss : 10.761639595031738
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
# At timestep:     1173 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 157.14285278320312
# Eval_StdReturn : 30.267515182495117
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 120.0
# Eval_AverageEpLen : 157.14285714285714
# Train_AverageReturn : 167.57142639160156
# Train_StdReturn : 36.593746185302734
# Train_MaxReturn : 200.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 167.57142857142858
# Train_EnvstepsSoFar : 73224
# TimeSinceStart : 20.510690450668335
# Training Loss : 10.785236358642578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 70 ************
#
# ...
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     1059 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 48.761905670166016
# Eval_StdReturn : 12.2703857421875
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 48.76190476190476
# Train_AverageReturn : 48.1363639831543
# Train_StdReturn : 18.572452545166016
# Train_MaxReturn : 96.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 48.13636363636363
# Train_EnvstepsSoFar : 79965
# TimeSinceStart : 22.872456312179565
# Training Loss : 6.179939270019531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     1040 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.34782791137695
# Eval_StdReturn : 13.48302936553955
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 45.34782608695652
# Train_AverageReturn : 45.21739196777344
# Train_StdReturn : 12.683287620544434
# Train_MaxReturn : 81.0
# Train_MinReturn : 29.0
# Train_AverageEpLen : 45.21739130434783
# Train_EnvstepsSoFar : 81005
# TimeSinceStart : 23.172945261001587
# Training Loss : 5.956185340881348
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.88461685180664
# Eval_StdReturn : 12.801223754882812
# Eval_MaxReturn : 92.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 38.88461538461539
# Train_AverageReturn : 40.11538314819336
# Train_StdReturn : 8.872285842895508
# Train_MaxReturn : 60.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 40.11538461538461
# Train_EnvstepsSoFar : 82048
# TimeSinceStart : 23.46708917617798
# Training Loss : 5.899107933044434
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.0000
# Eval_StdReturn : 12.606215476989746
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 42.0
# Train_AverageReturn : 47.772727966308594
# Train_StdReturn : 13.937952995300293
# Train_MaxReturn : 88.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 47.77272727272727
# Train_EnvstepsSoFar : 83099
# TimeSinceStart : 23.753178119659424
# Training Loss : 5.919890403747559
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.0000
# Eval_StdReturn : 8.03118896484375
# Eval_MaxReturn : 60.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 37.0
# Train_AverageReturn : 43.565216064453125
# Train_StdReturn : 17.695064544677734
# Train_MaxReturn : 107.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 43.56521739130435
# Train_EnvstepsSoFar : 84101
# TimeSinceStart : 24.039065837860107
# Training Loss : 5.693747520446777
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.7500
# Eval_StdReturn : 13.410971641540527
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 41.75
# Train_AverageReturn : 42.279998779296875
# Train_StdReturn : 14.19160270690918
# Train_MaxReturn : 90.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 42.28
# Train_EnvstepsSoFar : 85158
# TimeSinceStart : 24.326608419418335
# Training Loss : 5.584967136383057
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.74074172973633
# Eval_StdReturn : 10.444181442260742
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 38.74074074074074
# Train_AverageReturn : 37.66666793823242
# Train_StdReturn : 10.756566047668457
# Train_MaxReturn : 58.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 37.666666666666664
# Train_EnvstepsSoFar : 86175
# TimeSinceStart : 24.624999046325684
# Training Loss : 4.876347064971924
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     1025 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.03703689575195
# Eval_StdReturn : 10.758223533630371
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 37.03703703703704
# Train_AverageReturn : 42.70833206176758
# Train_StdReturn : 9.947693824768066
# Train_MaxReturn : 64.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 42.708333333333336
# Train_EnvstepsSoFar : 87200
# TimeSinceStart : 24.915914058685303
# Training Loss : 5.394992828369141
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.93333435058594
# Eval_StdReturn : 6.786915302276611
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 33.93333333333333
# Train_AverageReturn : 34.53333282470703
# Train_StdReturn : 8.00305461883545
# Train_MaxReturn : 57.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 34.53333333333333
# Train_EnvstepsSoFar : 88236
# TimeSinceStart : 25.214465856552124
# Training Loss : 4.902270793914795
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.82758712768555
# Eval_StdReturn : 9.101227760314941
# Eval_MaxReturn : 65.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 34.827586206896555
# Train_AverageReturn : 37.22222137451172
# Train_StdReturn : 8.052298545837402
# Train_MaxReturn : 59.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 37.22222222222222
# Train_EnvstepsSoFar : 89241
# TimeSinceStart : 25.503429174423218
# Training Loss : 5.182760238647461
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     1024 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.33333206176758
# Eval_StdReturn : 7.272474765777588
# Eval_MaxReturn : 51.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 34.333333333333336
# Train_AverageReturn : 36.57143020629883
# Train_StdReturn : 9.56342887878418
# Train_MaxReturn : 55.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 36.57142857142857
# Train_EnvstepsSoFar : 90265
# TimeSinceStart : 25.784947156906128
# Training Loss : 5.2338080406188965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.5625
# Eval_StdReturn : 7.717421531677246
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 31.5625
# Train_AverageReturn : 32.41935348510742
# Train_StdReturn : 6.241247653961182
# Train_MaxReturn : 55.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 32.41935483870968
# Train_EnvstepsSoFar : 91270
# TimeSinceStart : 26.064399003982544
# Training Loss : 4.8337082862854
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     1024 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 29.02857208251953
# Eval_StdReturn : 6.626723766326904
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 29.02857142857143
# Train_AverageReturn : 32.0
# Train_StdReturn : 6.363961219787598
# Train_MaxReturn : 48.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 32.0
# Train_EnvstepsSoFar : 92294
# TimeSinceStart : 26.371749877929688
# Training Loss : 4.841511249542236
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.558822631835938
# Eval_StdReturn : 6.1270432472229
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 30.558823529411764
# Train_AverageReturn : 31.40625
# Train_StdReturn : 7.466003894805908
# Train_MaxReturn : 47.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 31.40625
# Train_EnvstepsSoFar : 93299
# TimeSinceStart : 26.67572855949402
# Training Loss : 5.248834133148193
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     1003 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.393939971923828
# Eval_StdReturn : 6.710188865661621
# Eval_MaxReturn : 45.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 30.393939393939394
# Train_AverageReturn : 31.34375
# Train_StdReturn : 7.078176975250244
# Train_MaxReturn : 47.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 31.34375
# Train_EnvstepsSoFar : 94302
# TimeSinceStart : 26.950917959213257
# Training Loss : 4.448338031768799
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.290321350097656
# Eval_StdReturn : 5.826488971710205
# Eval_MaxReturn : 46.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 32.29032258064516
# Train_AverageReturn : 33.56666564941406
# Train_StdReturn : 6.108373641967773
# Train_MaxReturn : 45.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 33.56666666666667
# Train_EnvstepsSoFar : 95309
# TimeSinceStart : 27.236895084381104
# Training Loss : 5.120711803436279
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 28.5000
# Eval_StdReturn : 6.5042724609375
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 28.5
# Train_AverageReturn : 30.66666603088379
# Train_StdReturn : 6.79869270324707
# Train_MaxReturn : 50.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 30.666666666666668
# Train_EnvstepsSoFar : 96321
# TimeSinceStart : 27.60182809829712
# Training Loss : 4.846698760986328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     1015 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.74193572998047
# Eval_StdReturn : 6.579380035400391
# Eval_MaxReturn : 48.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 32.74193548387097
# Train_AverageReturn : 29.852941513061523
# Train_StdReturn : 6.117151737213135
# Train_MaxReturn : 44.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 29.852941176470587
# Train_EnvstepsSoFar : 97336
# TimeSinceStart : 27.902771711349487
# Training Loss : 4.723265171051025
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.41176414489746
# Eval_StdReturn : 6.005476474761963
# Eval_MaxReturn : 42.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 30.41176470588235
# Train_AverageReturn : 30.81818199157715
# Train_StdReturn : 6.662670612335205
# Train_MaxReturn : 46.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 30.818181818181817
# Train_EnvstepsSoFar : 98353
# TimeSinceStart : 28.19254422187805
# Training Loss : 4.741652488708496
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     1022 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.545454025268555
# Eval_StdReturn : 6.629095077514648
# Eval_MaxReturn : 44.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 30.545454545454547
# Train_AverageReturn : 29.200000762939453
# Train_StdReturn : 5.181285381317139
# Train_MaxReturn : 40.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 29.2
# Train_EnvstepsSoFar : 99375
# TimeSinceStart : 28.514002561569214
# Training Loss : 4.685555458068848
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.606060028076172
# Eval_StdReturn : 5.720454216003418
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 30.606060606060606
# Train_AverageReturn : 32.41935348510742
# Train_StdReturn : 7.495263576507568
# Train_MaxReturn : 49.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 32.41935483870968
# Train_EnvstepsSoFar : 100380
# TimeSinceStart : 28.824312448501587
# Training Loss : 4.661776065826416
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.83871078491211
# Eval_StdReturn : 6.227393627166748
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 32.83870967741935
# Train_AverageReturn : 31.393939971923828
# Train_StdReturn : 5.799369812011719
# Train_MaxReturn : 45.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 31.393939393939394
# Train_EnvstepsSoFar : 101416
# TimeSinceStart : 29.155078649520874
# Training Loss : 4.275518417358398
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 36.39285659790039
# Eval_StdReturn : 8.574626922607422
# Eval_MaxReturn : 57.0
# Eval_MinReturn : 26.0
# Eval_AverageEpLen : 36.392857142857146
# Train_AverageReturn : 32.51612854003906
# Train_StdReturn : 7.665890693664551
# Train_MaxReturn : 51.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 32.516129032258064
# Train_EnvstepsSoFar : 102424
# TimeSinceStart : 29.454736948013306
# Training Loss : 4.199160099029541
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['reward_to_go'] = True
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/return_to_go/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/return_to_go/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/CartPole/return_to_go/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/CartPole/return_to_go/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.578947067260742
# Eval_StdReturn : 15.315337181091309
# Eval_MaxReturn : 69.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 27.57894736842105
# Train_AverageReturn : 22.0
# Train_StdReturn : 10.642409324645996
# Train_MaxReturn : 51.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 22.0
# Train_EnvstepsSoFar : 1012
# TimeSinceStart : 0.3026244640350342
# Training Loss : 6.256053924560547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1026 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 36.31034469604492
# Eval_StdReturn : 20.996065139770508
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 36.310344827586206
# Train_AverageReturn : 27.0
# Train_StdReturn : 15.096182823181152
# Train_MaxReturn : 75.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 27.0
# Train_EnvstepsSoFar : 2038
# TimeSinceStart : 0.583228588104248
# Training Loss : 6.966986656188965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.7931022644043
# Eval_StdReturn : 13.884696006774902
# Eval_MaxReturn : 68.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 34.793103448275865
# Train_AverageReturn : 37.66666793823242
# Train_StdReturn : 21.108186721801758
# Train_MaxReturn : 100.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 37.666666666666664
# Train_EnvstepsSoFar : 3055
# TimeSinceStart : 0.8590435981750488
# Training Loss : 8.056185722351074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1037 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.0476188659668
# Eval_StdReturn : 22.697757720947266
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 50.04761904761905
# Train_AverageReturn : 43.20833206176758
# Train_StdReturn : 24.842805862426758
# Train_MaxReturn : 112.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 43.208333333333336
# Train_EnvstepsSoFar : 4092
# TimeSinceStart : 1.143566370010376
# Training Loss : 8.361367225646973
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 73.64286041259766
# Eval_StdReturn : 34.79246139526367
# Eval_MaxReturn : 158.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 73.64285714285714
# Train_AverageReturn : 48.19047546386719
# Train_StdReturn : 19.318431854248047
# Train_MaxReturn : 85.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 48.19047619047619
# Train_EnvstepsSoFar : 5104
# TimeSinceStart : 1.412604570388794
# Training Loss : 8.359642028808594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.83333206176758
# Eval_StdReturn : 30.592756271362305
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 55.833333333333336
# Train_AverageReturn : 50.349998474121094
# Train_StdReturn : 34.302005767822266
# Train_MaxReturn : 116.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 50.35
# Train_EnvstepsSoFar : 6111
# TimeSinceStart : 1.6881563663482666
# Training Loss : 8.557809829711914
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1020 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 68.80000305175781
# Eval_StdReturn : 42.089111328125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 68.8
# Train_AverageReturn : 63.75
# Train_StdReturn : 27.102813720703125
# Train_MaxReturn : 109.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 63.75
# Train_EnvstepsSoFar : 7131
# TimeSinceStart : 1.9616022109985352
# Training Loss : 8.91220474243164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.46154022216797
# Eval_StdReturn : 25.536144256591797
# Eval_MaxReturn : 160.0
# Eval_MinReturn : 57.0
# Eval_AverageEpLen : 82.46153846153847
# Train_AverageReturn : 62.625
# Train_StdReturn : 35.30027389526367
# Train_MaxReturn : 133.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 62.625
# Train_EnvstepsSoFar : 8133
# TimeSinceStart : 2.2762272357940674
# Training Loss : 8.810626983642578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1025 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.2727279663086
# Eval_StdReturn : 60.83971405029297
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 95.27272727272727
# Train_AverageReturn : 68.33333587646484
# Train_StdReturn : 16.381561279296875
# Train_MaxReturn : 105.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 68.33333333333333
# Train_EnvstepsSoFar : 9158
# TimeSinceStart : 2.578751802444458
# Training Loss : 8.658376693725586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 124.44444274902344
# Eval_StdReturn : 36.44512176513672
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 65.0
# Eval_AverageEpLen : 124.44444444444444
# Train_AverageReturn : 91.81818389892578
# Train_StdReturn : 52.8648681640625
# Train_MaxReturn : 200.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 91.81818181818181
# Train_EnvstepsSoFar : 10168
# TimeSinceStart : 2.861534595489502
# Training Loss : 9.382179260253906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1174 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.750
# Eval_StdReturn : 51.09733200073242
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 29.0
# Eval_AverageEpLen : 128.75
# Train_AverageReturn : 146.75
# Train_StdReturn : 45.43608093261719
# Train_MaxReturn : 200.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 146.75
# Train_EnvstepsSoFar : 11342
# TimeSinceStart : 3.1701414585113525
# Training Loss : 9.982255935668945
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.500
# Eval_StdReturn : 33.713253021240234
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 112.0
# Eval_AverageEpLen : 169.5
# Train_AverageReturn : 149.57142639160156
# Train_StdReturn : 39.601070404052734
# Train_MaxReturn : 200.0
# Train_MinReturn : 93.0
# Train_AverageEpLen : 149.57142857142858
# Train_EnvstepsSoFar : 12389
# TimeSinceStart : 3.4490902423858643
# Training Loss : 10.067048072814941
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1109 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.000
# Eval_StdReturn : 23.3737735748291
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 138.0
# Eval_AverageEpLen : 185.0
# Train_AverageReturn : 158.42857360839844
# Train_StdReturn : 28.489883422851562
# Train_MaxReturn : 200.0
# Train_MinReturn : 117.0
# Train_AverageEpLen : 158.42857142857142
# Train_EnvstepsSoFar : 13498
# TimeSinceStart : 3.7468786239624023
# Training Loss : 9.849106788635254
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.8333282470703
# Eval_StdReturn : 9.788030624389648
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 179.0
# Eval_AverageEpLen : 192.83333333333334
# Train_AverageReturn : 149.0
# Train_StdReturn : 32.872047424316406
# Train_MaxReturn : 191.0
# Train_MinReturn : 78.0
# Train_AverageEpLen : 149.0
# Train_EnvstepsSoFar : 14541
# TimeSinceStart : 4.049174785614014
# Training Loss : 9.738073348999023
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.3333282470703
# Eval_StdReturn : 32.00347137451172
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 119.0
# Eval_AverageEpLen : 178.33333333333334
# Train_AverageReturn : 176.8333282470703
# Train_StdReturn : 27.491918563842773
# Train_MaxReturn : 200.0
# Train_MinReturn : 136.0
# Train_AverageEpLen : 176.83333333333334
# Train_EnvstepsSoFar : 15602
# TimeSinceStart : 4.357422351837158
# Training Loss : 9.77961254119873
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.1666717529297
# Eval_StdReturn : 31.561668395996094
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 106.0
# Eval_AverageEpLen : 171.16666666666666
# Train_AverageReturn : 148.7142791748047
# Train_StdReturn : 49.134552001953125
# Train_MaxReturn : 200.0
# Train_MinReturn : 47.0
# Train_AverageEpLen : 148.71428571428572
# Train_EnvstepsSoFar : 16643
# TimeSinceStart : 4.638666868209839
# Training Loss : 9.780674934387207
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1080 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.8333282470703
# Eval_StdReturn : 25.28778839111328
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 139.0
# Eval_AverageEpLen : 169.83333333333334
# Train_AverageReturn : 180.0
# Train_StdReturn : 29.280254364013672
# Train_MaxReturn : 200.0
# Train_MinReturn : 118.0
# Train_AverageEpLen : 180.0
# Train_EnvstepsSoFar : 17723
# TimeSinceStart : 4.922356367111206
# Training Loss : 9.425920486450195
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1136 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 154.85714721679688
# Eval_StdReturn : 43.05620574951172
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 84.0
# Eval_AverageEpLen : 154.85714285714286
# Train_AverageReturn : 162.2857208251953
# Train_StdReturn : 27.618391036987305
# Train_MaxReturn : 200.0
# Train_MinReturn : 125.0
# Train_AverageEpLen : 162.28571428571428
# Train_EnvstepsSoFar : 18859
# TimeSinceStart : 5.224807500839233
# Training Loss : 9.482621192932129
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1088 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.500
# Eval_StdReturn : 44.73533248901367
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 138.5
# Train_AverageReturn : 136.0
# Train_StdReturn : 18.214006423950195
# Train_MaxReturn : 165.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 136.0
# Train_EnvstepsSoFar : 19947
# TimeSinceStart : 5.531814813613892
# Training Loss : 9.117754936218262
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 104.000
# Eval_StdReturn : 25.16346549987793
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 104.0
# Train_AverageReturn : 130.875
# Train_StdReturn : 21.612712860107422
# Train_MaxReturn : 165.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 130.875
# Train_EnvstepsSoFar : 20994
# TimeSinceStart : 5.795534372329712
# Training Loss : 8.809989929199219
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1100 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.41666412353516
# Eval_StdReturn : 34.138099670410156
# Eval_MaxReturn : 126.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 89.41666666666667
# Train_AverageReturn : 122.22222137451172
# Train_StdReturn : 26.657405853271484
# Train_MaxReturn : 162.0
# Train_MinReturn : 69.0
# Train_AverageEpLen : 122.22222222222223
# Train_EnvstepsSoFar : 22094
# TimeSinceStart : 6.080045461654663
# Training Loss : 8.893975257873535
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.9000015258789
# Eval_StdReturn : 19.09162139892578
# Eval_MaxReturn : 123.0
# Eval_MinReturn : 55.0
# Eval_AverageEpLen : 109.9
# Train_AverageReturn : 96.09091186523438
# Train_StdReturn : 29.361244201660156
# Train_MaxReturn : 135.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 96.0909090909091
# Train_EnvstepsSoFar : 23151
# TimeSinceStart : 6.429536581039429
# Training Loss : 8.240012168884277
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.90908813476562
# Eval_StdReturn : 26.868213653564453
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 42.0
# Eval_AverageEpLen : 97.9090909090909
# Train_AverageReturn : 92.18181610107422
# Train_StdReturn : 32.05625534057617
# Train_MaxReturn : 137.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 92.18181818181819
# Train_EnvstepsSoFar : 24165
# TimeSinceStart : 6.7109599113464355
# Training Loss : 8.196666717529297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1083 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.5000
# Eval_StdReturn : 33.86861801147461
# Eval_MaxReturn : 120.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 89.5
# Train_AverageReturn : 98.45454406738281
# Train_StdReturn : 28.30792808532715
# Train_MaxReturn : 127.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 98.45454545454545
# Train_EnvstepsSoFar : 25248
# TimeSinceStart : 6.9998064041137695
# Training Loss : 8.368048667907715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 102.000
# Eval_StdReturn : 18.718975067138672
# Eval_MaxReturn : 122.0
# Eval_MinReturn : 54.0
# Eval_AverageEpLen : 102.0
# Train_AverageReturn : 92.36363983154297
# Train_StdReturn : 26.867595672607422
# Train_MaxReturn : 121.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 92.36363636363636
# Train_EnvstepsSoFar : 26264
# TimeSinceStart : 7.273475408554077
# Training Loss : 7.945452690124512
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1020 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 99.09091186523438
# Eval_StdReturn : 27.4141788482666
# Eval_MaxReturn : 131.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 99.0909090909091
# Train_AverageReturn : 92.7272720336914
# Train_StdReturn : 30.710054397583008
# Train_MaxReturn : 124.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 92.72727272727273
# Train_EnvstepsSoFar : 27284
# TimeSinceStart : 7.567444324493408
# Training Loss : 8.085885047912598
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1031 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 105.4000015258789
# Eval_StdReturn : 14.270248413085938
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 74.0
# Eval_AverageEpLen : 105.4
# Train_AverageReturn : 103.0999984741211
# Train_StdReturn : 30.217378616333008
# Train_MaxReturn : 146.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 103.1
# Train_EnvstepsSoFar : 28315
# TimeSinceStart : 7.871122360229492
# Training Loss : 8.143121719360352
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1127 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.0000
# Eval_StdReturn : 26.242460250854492
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 51.0
# Eval_AverageEpLen : 84.0
# Train_AverageReturn : 93.91666412353516
# Train_StdReturn : 27.369260787963867
# Train_MaxReturn : 128.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 93.91666666666667
# Train_EnvstepsSoFar : 29442
# TimeSinceStart : 8.204410552978516
# Training Loss : 7.983991622924805
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1023 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 114.88888549804688
# Eval_StdReturn : 10.48220157623291
# Eval_MaxReturn : 134.0
# Eval_MinReturn : 100.0
# Eval_AverageEpLen : 114.88888888888889
# Train_AverageReturn : 102.30000305175781
# Train_StdReturn : 12.704723358154297
# Train_MaxReturn : 117.0
# Train_MinReturn : 77.0
# Train_AverageEpLen : 102.3
# Train_EnvstepsSoFar : 30465
# TimeSinceStart : 8.541931867599487
# Training Loss : 8.034558296203613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1073 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 121.55555725097656
# Eval_StdReturn : 12.455352783203125
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 103.0
# Eval_AverageEpLen : 121.55555555555556
# Train_AverageReturn : 119.22222137451172
# Train_StdReturn : 8.189123153686523
# Train_MaxReturn : 132.0
# Train_MinReturn : 108.0
# Train_AverageEpLen : 119.22222222222223
# Train_EnvstepsSoFar : 31538
# TimeSinceStart : 8.857245445251465
# Training Loss : 8.0447359085083
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1127 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.85714721679688
# Eval_StdReturn : 25.77057456970215
# Eval_MaxReturn : 193.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 142.85714285714286
# Train_AverageReturn : 125.22222137451172
# Train_StdReturn : 15.309967041015625
# Train_MaxReturn : 142.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 125.22222222222223
# Train_EnvstepsSoFar : 32665
# TimeSinceStart : 9.157011985778809
# Training Loss : 8.460410118103027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1134 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 155.42857360839844
# Eval_StdReturn : 17.186847686767578
# Eval_MaxReturn : 182.0
# Eval_MinReturn : 122.0
# Eval_AverageEpLen : 155.42857142857142
# Train_AverageReturn : 141.75
# Train_StdReturn : 10.437313079833984
# Train_MaxReturn : 155.0
# Train_MinReturn : 123.0
# Train_AverageEpLen : 141.75
# Train_EnvstepsSoFar : 33799
# TimeSinceStart : 9.467099666595459
# Training Loss : 8.515644073486328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.000
# Eval_StdReturn : 30.02776527404785
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 170.0
# Train_AverageReturn : 146.85714721679688
# Train_StdReturn : 11.764699935913086
# Train_MaxReturn : 166.0
# Train_MinReturn : 132.0
# Train_AverageEpLen : 146.85714285714286
# Train_EnvstepsSoFar : 34827
# TimeSinceStart : 9.769704818725586
# Training Loss : 8.483649253845215
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1063 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.500
# Eval_StdReturn : 26.06242561340332
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 140.0
# Eval_AverageEpLen : 179.5
# Train_AverageReturn : 151.85714721679688
# Train_StdReturn : 15.39414119720459
# Train_MaxReturn : 172.0
# Train_MinReturn : 134.0
# Train_AverageEpLen : 151.85714285714286
# Train_EnvstepsSoFar : 35890
# TimeSinceStart : 10.0452880859375
# Training Loss : 8.523860931396484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.8333282470703
# Eval_StdReturn : 16.856420516967773
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 154.0
# Eval_AverageEpLen : 184.83333333333334
# Train_AverageReturn : 171.3333282470703
# Train_StdReturn : 25.675323486328125
# Train_MaxReturn : 200.0
# Train_MinReturn : 133.0
# Train_AverageEpLen : 171.33333333333334
# Train_EnvstepsSoFar : 36918
# TimeSinceStart : 10.352803230285645
# Training Loss : 8.57982349395752
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1142 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 190.3333282470703
# Train_StdReturn : 21.615324020385742
# Train_MaxReturn : 200.0
# Train_MinReturn : 142.0
# Train_AverageEpLen : 190.33333333333334
# Train_EnvstepsSoFar : 38060
# TimeSinceStart : 10.662394762039185
# Training Loss : 8.961383819580078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1176 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 196.0
# Train_StdReturn : 6.855654716491699
# Train_MaxReturn : 200.0
# Train_MinReturn : 181.0
# Train_AverageEpLen : 196.0
# Train_EnvstepsSoFar : 39236
# TimeSinceStart : 10.97944974899292
# Training Loss : 8.77636432647705
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1198 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 199.6666717529297
# Train_StdReturn : 0.745356023311615
# Train_MaxReturn : 200.0
# Train_MinReturn : 198.0
# Train_AverageEpLen : 199.66666666666666
# Train_EnvstepsSoFar : 40434
# TimeSinceStart : 11.28423261642456
# Training Loss : 8.923416137695312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 41434
# TimeSinceStart : 11.577451705932617
# Training Loss : 8.957884788513184
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 42434
# TimeSinceStart : 11.85044813156128
# Training Loss : 8.528759002685547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 43434
# TimeSinceStart : 12.12698221206665
# Training Loss : 9.006901741027832
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 44434
# TimeSinceStart : 12.405272960662842
# Training Loss : 9.091992378234863
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 45434
# TimeSinceStart : 12.691868305206299
# Training Loss : 8.559118270874023
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 46434
# TimeSinceStart : 12.985801935195923
# Training Loss : 8.924735069274902
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1186 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 197.6666717529297
# Train_StdReturn : 5.217492580413818
# Train_MaxReturn : 200.0
# Train_MinReturn : 186.0
# Train_AverageEpLen : 197.66666666666666
# Train_EnvstepsSoFar : 47620
# TimeSinceStart : 13.304446697235107
# Training Loss : 8.914989471435547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 194.3333282470703
# Eval_StdReturn : 10.979778289794922
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 170.0
# Eval_AverageEpLen : 194.33333333333334
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 48620
# TimeSinceStart : 13.62076473236084
# Training Loss : 9.00706672668457
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1189 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 198.1666717529297
# Train_StdReturn : 4.099457740783691
# Train_MaxReturn : 200.0
# Train_MinReturn : 189.0
# Train_AverageEpLen : 198.16666666666666
# Train_EnvstepsSoFar : 49809
# TimeSinceStart : 14.02374815940857
# Training Loss : 9.110485076904297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 50809
# TimeSinceStart : 14.29237151145935
# Training Loss : 9.039423942565918
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1111 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.8333282470703
# Eval_StdReturn : 16.02515411376953
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 157.0
# Eval_AverageEpLen : 192.83333333333334
# Train_AverageReturn : 185.1666717529297
# Train_StdReturn : 33.16834259033203
# Train_MaxReturn : 200.0
# Train_MinReturn : 111.0
# Train_AverageEpLen : 185.16666666666666
# Train_EnvstepsSoFar : 51920
# TimeSinceStart : 14.612240314483643
# Training Loss : 9.133000373840332
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1199 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 191.3333282470703
# Eval_StdReturn : 12.47219181060791
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 170.0
# Eval_AverageEpLen : 191.33333333333334
# Train_AverageReturn : 199.8333282470703
# Train_StdReturn : 0.3726779818534851
# Train_MaxReturn : 200.0
# Train_MinReturn : 199.0
# Train_AverageEpLen : 199.83333333333334
# Train_EnvstepsSoFar : 53119
# TimeSinceStart : 14.959894180297852
# Training Loss : 9.412109375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     1171 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 195.1666717529297
# Train_StdReturn : 10.807662963867188
# Train_MaxReturn : 200.0
# Train_MinReturn : 171.0
# Train_AverageEpLen : 195.16666666666666
# Train_EnvstepsSoFar : 54290
# TimeSinceStart : 15.268958330154419
# Training Loss : 9.134928703308105
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     1099 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.2857208251953
# Eval_StdReturn : 47.5235710144043
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 88.0
# Eval_AverageEpLen : 165.28571428571428
# Train_AverageReturn : 183.1666717529297
# Train_StdReturn : 26.333860397338867
# Train_MaxReturn : 200.0
# Train_MinReturn : 130.0
# Train_AverageEpLen : 183.16666666666666
# Train_EnvstepsSoFar : 55389
# TimeSinceStart : 15.580415725708008
# Training Loss : 9.126344680786133
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     1183 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 197.3333282470703
# Eval_StdReturn : 5.527708053588867
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 185.0
# Eval_AverageEpLen : 197.33333333333334
# Train_AverageReturn : 197.1666717529297
# Train_StdReturn : 6.335525989532471
# Train_MaxReturn : 200.0
# Train_MinReturn : 183.0
# Train_AverageEpLen : 197.16666666666666
# Train_EnvstepsSoFar : 56572
# TimeSinceStart : 15.913405418395996
# Training Loss : 8.927558898925781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     1129 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.2857208251953
# Eval_StdReturn : 43.14664077758789
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 81.0
# Eval_AverageEpLen : 158.28571428571428
# Train_AverageReturn : 188.1666717529297
# Train_StdReturn : 22.674631118774414
# Train_MaxReturn : 200.0
# Train_MinReturn : 138.0
# Train_AverageEpLen : 188.16666666666666
# Train_EnvstepsSoFar : 57701
# TimeSinceStart : 16.225571393966675
# Training Loss : 9.07132625579834
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.1666717529297
# Eval_StdReturn : 22.799243927001953
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 132.0
# Eval_AverageEpLen : 178.16666666666666
# Train_AverageReturn : 169.0
# Train_StdReturn : 48.768157958984375
# Train_MaxReturn : 200.0
# Train_MinReturn : 70.0
# Train_AverageEpLen : 169.0
# Train_EnvstepsSoFar : 58715
# TimeSinceStart : 16.53904104232788
# Training Loss : 8.573555946350098
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.85714721679688
# Eval_StdReturn : 31.966182708740234
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 120.0
# Eval_AverageEpLen : 168.85714285714286
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 59715
# TimeSinceStart : 16.845070362091064
# Training Loss : 8.912052154541016
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     1175 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 188.000
# Eval_StdReturn : 19.899747848510742
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 146.0
# Eval_AverageEpLen : 188.0
# Train_AverageReturn : 167.85714721679688
# Train_StdReturn : 50.20082092285156
# Train_MaxReturn : 200.0
# Train_MinReturn : 87.0
# Train_AverageEpLen : 167.85714285714286
# Train_EnvstepsSoFar : 60890
# TimeSinceStart : 17.156683921813965
# Training Loss : 8.57256031036377
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     1195 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.500
# Eval_StdReturn : 25.12468910217285
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 140.0
# Eval_AverageEpLen : 182.5
# Train_AverageReturn : 199.1666717529297
# Train_StdReturn : 1.8633898496627808
# Train_MaxReturn : 200.0
# Train_MinReturn : 195.0
# Train_AverageEpLen : 199.16666666666666
# Train_EnvstepsSoFar : 62085
# TimeSinceStart : 17.485702753067017
# Training Loss : 8.492654800415039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.3333282470703
# Eval_StdReturn : 24.910951614379883
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 133.0
# Eval_AverageEpLen : 178.33333333333334
# Train_AverageReturn : 181.1666717529297
# Train_StdReturn : 42.112613677978516
# Train_MaxReturn : 200.0
# Train_MinReturn : 87.0
# Train_AverageEpLen : 181.16666666666666
# Train_EnvstepsSoFar : 63172
# TimeSinceStart : 17.792555332183838
# Training Loss : 8.62319278717041
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.000
# Eval_StdReturn : 38.73413848876953
# Eval_MaxReturn : 196.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 172.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 64172
# TimeSinceStart : 18.069857597351074
# Training Loss : 8.952890396118164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     1096 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.500
# Eval_StdReturn : 21.746646881103516
# Eval_MaxReturn : 198.0
# Eval_MinReturn : 139.0
# Eval_AverageEpLen : 172.5
# Train_AverageReturn : 182.6666717529297
# Train_StdReturn : 21.257678985595703
# Train_MaxReturn : 200.0
# Train_MinReturn : 138.0
# Train_AverageEpLen : 182.66666666666666
# Train_EnvstepsSoFar : 65268
# TimeSinceStart : 18.36573362350464
# Training Loss : 8.372591018676758
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     1113 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.6666717529297
# Eval_StdReturn : 4.818943977355957
# Eval_MaxReturn : 181.0
# Eval_MinReturn : 166.0
# Eval_AverageEpLen : 171.66666666666666
# Train_AverageReturn : 185.5
# Train_StdReturn : 11.236102104187012
# Train_MaxReturn : 199.0
# Train_MinReturn : 169.0
# Train_AverageEpLen : 185.5
# Train_EnvstepsSoFar : 66381
# TimeSinceStart : 18.6984646320343
# Training Loss : 8.553945541381836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.3333282470703
# Eval_StdReturn : 12.697331428527832
# Eval_MaxReturn : 187.0
# Eval_MinReturn : 147.0
# Eval_AverageEpLen : 172.33333333333334
# Train_AverageReturn : 175.8333282470703
# Train_StdReturn : 8.78287410736084
# Train_MaxReturn : 194.0
# Train_MinReturn : 165.0
# Train_AverageEpLen : 175.83333333333334
# Train_EnvstepsSoFar : 67436
# TimeSinceStart : 19.01537847518921
# Training Loss : 8.335963249206543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     1065 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.6666717529297
# Eval_StdReturn : 21.304668426513672
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 134.0
# Eval_AverageEpLen : 174.66666666666666
# Train_AverageReturn : 152.14285278320312
# Train_StdReturn : 54.67939758300781
# Train_MaxReturn : 184.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 152.14285714285714
# Train_EnvstepsSoFar : 68501
# TimeSinceStart : 19.33364701271057
# Training Loss : 8.311871528625488
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     1126 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.3333282470703
# Eval_StdReturn : 40.68442153930664
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 174.33333333333334
# Train_AverageReturn : 187.6666717529297
# Train_StdReturn : 10.624918937683105
# Train_MaxReturn : 200.0
# Train_MinReturn : 167.0
# Train_AverageEpLen : 187.66666666666666
# Train_EnvstepsSoFar : 69627
# TimeSinceStart : 19.654189825057983
# Training Loss : 8.567466735839844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     1174 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.6666717529297
# Eval_StdReturn : 7.453559875488281
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 180.0
# Eval_AverageEpLen : 196.66666666666666
# Train_AverageReturn : 167.7142791748047
# Train_StdReturn : 44.49627685546875
# Train_MaxReturn : 200.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 167.71428571428572
# Train_EnvstepsSoFar : 70801
# TimeSinceStart : 19.98211121559143
# Training Loss : 8.149275779724121
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     1151 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.1666717529297
# Eval_StdReturn : 40.118228912353516
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 92.0
# Eval_AverageEpLen : 171.16666666666666
# Train_AverageReturn : 191.8333282470703
# Train_StdReturn : 18.26122283935547
# Train_MaxReturn : 200.0
# Train_MinReturn : 151.0
# Train_AverageEpLen : 191.83333333333334
# Train_EnvstepsSoFar : 71952
# TimeSinceStart : 20.304028511047363
# Training Loss : 8.08228874206543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     1189 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 198.1666717529297
# Train_StdReturn : 4.099457740783691
# Train_MaxReturn : 200.0
# Train_MinReturn : 189.0
# Train_AverageEpLen : 198.16666666666666
# Train_EnvstepsSoFar : 73141
# TimeSinceStart : 20.63048267364502
# Training Loss : 8.077061653137207
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.1666717529297
# Eval_StdReturn : 43.12159729003906
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 172.16666666666666
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 74141
# TimeSinceStart : 20.921025037765503
# Training Loss : 8.371787071228027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 75141
# TimeSinceStart : 21.20461630821228
# Training Loss : 8.103306770324707
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 70 ************
#
# Collecting data to be used for training...
# At timestep:     1128 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 188.0
# Train_StdReturn : 26.832815170288086
# Train_MaxReturn : 200.0
# Train_MinReturn : 128.0
# Train_AverageEpLen : 188.0
# Train_EnvstepsSoFar : 76269
# TimeSinceStart : 21.517319440841675
# Training Loss : 8.152381896972656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 71 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# ...
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 100.500
# Eval_StdReturn : 23.001087188720703
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 100.5
# Train_AverageReturn : 105.0999984741211
# Train_StdReturn : 26.609960556030273
# Train_MaxReturn : 134.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 105.1
# Train_EnvstepsSoFar : 83293
# TimeSinceStart : 24.86165428161621
# Training Loss : 6.417284965515137
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.33333587646484
# Eval_StdReturn : 27.62346076965332
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 29.0
# Eval_AverageEpLen : 88.33333333333333
# Train_AverageReturn : 98.81818389892578
# Train_StdReturn : 26.051761627197266
# Train_MaxReturn : 127.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 98.81818181818181
# Train_EnvstepsSoFar : 84380
# TimeSinceStart : 25.174756288528442
# Training Loss : 6.224637985229492
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     1100 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 106.9000015258789
# Eval_StdReturn : 5.9405388832092285
# Eval_MaxReturn : 113.0
# Eval_MinReturn : 96.0
# Eval_AverageEpLen : 106.9
# Train_AverageReturn : 91.66666412353516
# Train_StdReturn : 28.639522552490234
# Train_MaxReturn : 119.0
# Train_MinReturn : 40.0
# Train_AverageEpLen : 91.66666666666667
# Train_EnvstepsSoFar : 85480
# TimeSinceStart : 25.521368503570557
# Training Loss : 6.449061393737793
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     1071 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.66666412353516
# Eval_StdReturn : 8.151346206665039
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 111.66666666666667
# Train_AverageReturn : 107.0999984741211
# Train_StdReturn : 6.236185073852539
# Train_MaxReturn : 118.0
# Train_MinReturn : 99.0
# Train_AverageEpLen : 107.1
# Train_EnvstepsSoFar : 86551
# TimeSinceStart : 25.82473611831665
# Training Loss : 6.338110446929932
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.000
# Eval_StdReturn : 6.912147045135498
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 115.0
# Train_AverageReturn : 115.66666412353516
# Train_StdReturn : 5.96284818649292
# Train_MaxReturn : 124.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 115.66666666666667
# Train_EnvstepsSoFar : 87592
# TimeSinceStart : 26.137205362319946
# Training Loss : 6.3447265625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     1046 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.55555725097656
# Eval_StdReturn : 10.92510986328125
# Eval_MaxReturn : 142.0
# Eval_MinReturn : 107.0
# Eval_AverageEpLen : 123.55555555555556
# Train_AverageReturn : 116.22222137451172
# Train_StdReturn : 7.00440788269043
# Train_MaxReturn : 129.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 116.22222222222223
# Train_EnvstepsSoFar : 88638
# TimeSinceStart : 26.492013216018677
# Training Loss : 6.085250377655029
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     1059 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.77777862548828
# Eval_StdReturn : 10.453896522521973
# Eval_MaxReturn : 135.0
# Eval_MinReturn : 105.0
# Eval_AverageEpLen : 120.77777777777777
# Train_AverageReturn : 117.66666412353516
# Train_StdReturn : 8.550503730773926
# Train_MaxReturn : 131.0
# Train_MinReturn : 106.0
# Train_AverageEpLen : 117.66666666666667
# Train_EnvstepsSoFar : 89697
# TimeSinceStart : 26.826024770736694
# Training Loss : 6.458822250366211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     1013 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.22222137451172
# Eval_StdReturn : 9.040375709533691
# Eval_MaxReturn : 136.0
# Eval_MinReturn : 109.0
# Eval_AverageEpLen : 123.22222222222223
# Train_AverageReturn : 112.55555725097656
# Train_StdReturn : 5.559998512268066
# Train_MaxReturn : 121.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 112.55555555555556
# Train_EnvstepsSoFar : 90710
# TimeSinceStart : 27.16572904586792
# Training Loss : 6.114260196685791
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.88888549804688
# Eval_StdReturn : 7.109374523162842
# Eval_MaxReturn : 133.0
# Eval_MinReturn : 109.0
# Eval_AverageEpLen : 123.88888888888889
# Train_AverageReturn : 120.77777862548828
# Train_StdReturn : 7.0518364906311035
# Train_MaxReturn : 129.0
# Train_MinReturn : 110.0
# Train_AverageEpLen : 120.77777777777777
# Train_EnvstepsSoFar : 91797
# TimeSinceStart : 27.56490683555603
# Training Loss : 6.407732009887695
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 117.000
# Eval_StdReturn : 6.863753318786621
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 104.0
# Eval_AverageEpLen : 117.0
# Train_AverageReturn : 115.88888549804688
# Train_StdReturn : 7.014975547790527
# Train_MaxReturn : 132.0
# Train_MinReturn : 108.0
# Train_AverageEpLen : 115.88888888888889
# Train_EnvstepsSoFar : 92840
# TimeSinceStart : 27.9488308429718
# Training Loss : 6.340376377105713
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     1078 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.11111450195312
# Eval_StdReturn : 7.263981819152832
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 104.0
# Eval_AverageEpLen : 115.11111111111111
# Train_AverageReturn : 119.77777862548828
# Train_StdReturn : 9.246954917907715
# Train_MaxReturn : 135.0
# Train_MinReturn : 110.0
# Train_AverageEpLen : 119.77777777777777
# Train_EnvstepsSoFar : 93918
# TimeSinceStart : 28.29815649986267
# Training Loss : 5.783600807189941
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.80000305175781
# Eval_StdReturn : 9.130169868469238
# Eval_MaxReturn : 123.0
# Eval_MinReturn : 96.0
# Eval_AverageEpLen : 109.8
# Train_AverageReturn : 104.30000305175781
# Train_StdReturn : 21.410511016845703
# Train_MaxReturn : 121.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 104.3
# Train_EnvstepsSoFar : 94961
# TimeSinceStart : 28.672029495239258
# Training Loss : 5.937997817993164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.000
# Eval_StdReturn : 8.820430755615234
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 100.0
# Eval_AverageEpLen : 109.0
# Train_AverageReturn : 117.88888549804688
# Train_StdReturn : 8.047697067260742
# Train_MaxReturn : 131.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 117.88888888888889
# Train_EnvstepsSoFar : 96022
# TimeSinceStart : 29.011115789413452
# Training Loss : 5.985374450683594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     1092 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.22222137451172
# Eval_StdReturn : 9.964133262634277
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 101.0
# Eval_AverageEpLen : 111.22222222222223
# Train_AverageReturn : 109.19999694824219
# Train_StdReturn : 5.095095634460449
# Train_MaxReturn : 115.0
# Train_MinReturn : 101.0
# Train_AverageEpLen : 109.2
# Train_EnvstepsSoFar : 97114
# TimeSinceStart : 29.322651147842407
# Training Loss : 6.097095012664795
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     1066 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.55555725097656
# Eval_StdReturn : 10.034507751464844
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 98.0
# Eval_AverageEpLen : 113.55555555555556
# Train_AverageReturn : 106.5999984741211
# Train_StdReturn : 5.7827324867248535
# Train_MaxReturn : 114.0
# Train_MinReturn : 96.0
# Train_AverageEpLen : 106.6
# Train_EnvstepsSoFar : 98180
# TimeSinceStart : 29.672279119491577
# Training Loss : 6.0082621574401855
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.11111450195312
# Eval_StdReturn : 8.748897552490234
# Eval_MaxReturn : 136.0
# Eval_MinReturn : 103.0
# Eval_AverageEpLen : 115.11111111111111
# Train_AverageReturn : 111.88888549804688
# Train_StdReturn : 8.999313354492188
# Train_MaxReturn : 125.0
# Train_MinReturn : 100.0
# Train_AverageEpLen : 111.88888888888889
# Train_EnvstepsSoFar : 99187
# TimeSinceStart : 30.048895597457886
# Training Loss : 5.622732162475586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     1023 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 119.55555725097656
# Eval_StdReturn : 7.617393970489502
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 119.55555555555556
# Train_AverageReturn : 113.66666412353516
# Train_StdReturn : 6.73300313949585
# Train_MaxReturn : 124.0
# Train_MinReturn : 102.0
# Train_AverageEpLen : 113.66666666666667
# Train_EnvstepsSoFar : 100210
# TimeSinceStart : 30.36175012588501
# Training Loss : 5.76061487197876
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.44444274902344
# Eval_StdReturn : 10.393492698669434
# Eval_MaxReturn : 143.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 120.44444444444444
# Train_AverageReturn : 113.44444274902344
# Train_StdReturn : 9.58135986328125
# Train_MaxReturn : 128.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 113.44444444444444
# Train_EnvstepsSoFar : 101231
# TimeSinceStart : 30.663265705108643
# Training Loss : 5.9516987800598145
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     1115 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 127.000
# Eval_StdReturn : 10.828204154968262
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 117.0
# Eval_AverageEpLen : 127.0
# Train_AverageReturn : 123.88888549804688
# Train_StdReturn : 6.740333557128906
# Train_MaxReturn : 136.0
# Train_MinReturn : 112.0
# Train_AverageEpLen : 123.88888888888889
# Train_EnvstepsSoFar : 102346
# TimeSinceStart : 30.989715099334717
# Training Loss : 6.170619964599609
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.750
# Eval_StdReturn : 7.066647052764893
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 123.0
# Eval_AverageEpLen : 133.75
# Train_AverageReturn : 128.625
# Train_StdReturn : 9.109576225280762
# Train_MaxReturn : 144.0
# Train_MinReturn : 114.0
# Train_AverageEpLen : 128.625
# Train_EnvstepsSoFar : 103375
# TimeSinceStart : 31.278914213180542
# Training Loss : 5.742019176483154
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 145.875
# Eval_StdReturn : 11.569761276245117
# Eval_MaxReturn : 168.0
# Eval_MinReturn : 130.0
# Eval_AverageEpLen : 145.875
# Train_AverageReturn : 133.0
# Train_StdReturn : 14.534441947937012
# Train_MaxReturn : 160.0
# Train_MinReturn : 117.0
# Train_AverageEpLen : 133.0
# Train_EnvstepsSoFar : 104439
# TimeSinceStart : 31.62425184249878
# Training Loss : 6.3213725090026855
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.875
# Eval_StdReturn : 9.292974472045898
# Eval_MaxReturn : 157.0
# Eval_MinReturn : 132.0
# Eval_AverageEpLen : 142.875
# Train_AverageReturn : 142.85714721679688
# Train_StdReturn : 8.998866081237793
# Train_MaxReturn : 156.0
# Train_MinReturn : 133.0
# Train_AverageEpLen : 142.85714285714286
# Train_EnvstepsSoFar : 105439
# TimeSinceStart : 31.98225975036621
# Training Loss : 5.8683180809021
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.625
# Eval_StdReturn : 4.12121057510376
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 133.0
# Eval_AverageEpLen : 138.625
# Train_AverageReturn : 143.42857360839844
# Train_StdReturn : 13.499811172485352
# Train_MaxReturn : 164.0
# Train_MinReturn : 128.0
# Train_AverageEpLen : 143.42857142857142
# Train_EnvstepsSoFar : 106443
# TimeSinceStart : 32.30252504348755
# Training Loss : 6.343074798583984
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...

# %% [markdown]
# We should see the reward to go estimator outperforming the full returns estimator, with some runs reaching the maximum reward of 200. There will likely however be high variance between runs.

# %%
### Visualize Policy Gradient results on CartPole
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/CartPole
# Out:
# Launching TensorBoard...

# %% [markdown]
# We can also compare our estimators on a more complex task, though you will probably see that they don't perform well (not getting much above 200 returns). Note that on this more complex task, we use a much larger batch size to reduce variance in the policy gradients.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = False
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/full_returns/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/full_returns/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/Hopper/full_returns/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/full_returns/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 61.34284210205078
# Eval_StdReturn : 57.76802444458008
# Eval_MaxReturn : 203.46633911132812
# Eval_MinReturn : 7.391658306121826
# Eval_AverageEpLen : 39.96153846153846
# Train_AverageReturn : 9.657980918884277
# Train_StdReturn : 5.853752613067627
# Train_MaxReturn : 87.45542907714844
# Train_MinReturn : 3.010934352874756
# Train_AverageEpLen : 13.215323645970939
# Train_EnvstepsSoFar : 10004
# TimeSinceStart : 5.833483934402466
# Training Loss : 34.30583572387695
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 72.8387222290039
# Eval_StdReturn : 11.639814376831055
# Eval_MaxReturn : 97.1689453125
# Eval_MinReturn : 56.68820571899414
# Eval_AverageEpLen : 45.65217391304348
# Train_AverageReturn : 54.50438690185547
# Train_StdReturn : 46.97917175292969
# Train_MaxReturn : 214.8564910888672
# Train_MinReturn : 5.630634784698486
# Train_AverageEpLen : 37.95454545454545
# Train_EnvstepsSoFar : 20024
# TimeSinceStart : 12.509424686431885
# Training Loss : 90.11448669433594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.79875183105469
# Eval_StdReturn : 9.179817199707031
# Eval_MaxReturn : 83.30668640136719
# Eval_MinReturn : 52.27299499511719
# Eval_AverageEpLen : 38.074074074074076
# Train_AverageReturn : 75.83659362792969
# Train_StdReturn : 19.88337516784668
# Train_MaxReturn : 161.70582580566406
# Train_MinReturn : 12.983553886413574
# Train_AverageEpLen : 47.97129186602871
# Train_EnvstepsSoFar : 30050
# TimeSinceStart : 18.98942756652832
# Training Loss : 99.64437866210938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.26776123046875
# Eval_StdReturn : 5.455423831939697
# Eval_MaxReturn : 68.46729278564453
# Eval_MinReturn : 44.55207061767578
# Eval_AverageEpLen : 31.09090909090909
# Train_AverageReturn : 60.45672607421875
# Train_StdReturn : 8.498207092285156
# Train_MaxReturn : 108.87381744384766
# Train_MinReturn : 46.84237289428711
# Train_AverageEpLen : 37.10740740740741
# Train_EnvstepsSoFar : 40069
# TimeSinceStart : 25.3966703414917
# Training Loss : 101.54632568359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.14884567260742
# Eval_StdReturn : 14.536172866821289
# Eval_MaxReturn : 114.81080627441406
# Eval_MinReturn : 46.10413360595703
# Eval_AverageEpLen : 36.06896551724138
# Train_AverageReturn : 53.69095993041992
# Train_StdReturn : 6.895584583282471
# Train_MaxReturn : 111.23048400878906
# Train_MinReturn : 41.2711181640625
# Train_AverageEpLen : 31.85987261146497
# Train_EnvstepsSoFar : 50073
# TimeSinceStart : 31.217076539993286
# Training Loss : 102.345458984375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 66.40575408935547
# Eval_StdReturn : 14.012945175170898
# Eval_MaxReturn : 102.32240295410156
# Eval_MinReturn : 47.63692855834961
# Eval_AverageEpLen : 38.370370370370374
# Train_AverageReturn : 57.791053771972656
# Train_StdReturn : 9.75520133972168
# Train_MaxReturn : 95.34403228759766
# Train_MinReturn : 43.168800354003906
# Train_AverageEpLen : 33.29235880398671
# Train_EnvstepsSoFar : 60094
# TimeSinceStart : 37.081870317459106
# Training Loss : 107.87123107910156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.18193817138672
# Eval_StdReturn : 18.406030654907227
# Eval_MaxReturn : 144.75587463378906
# Eval_MinReturn : 52.41750717163086
# Eval_AverageEpLen : 42.75
# Train_AverageReturn : 73.6001205444336
# Train_StdReturn : 17.074445724487305
# Train_MaxReturn : 141.6881866455078
# Train_MinReturn : 44.51664733886719
# Train_AverageEpLen : 41.84937238493724
# Train_EnvstepsSoFar : 70096
# TimeSinceStart : 43.122567653656006
# Training Loss : 117.74435424804688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.56478118896484
# Eval_StdReturn : 16.24689292907715
# Eval_MaxReturn : 127.049560546875
# Eval_MinReturn : 51.87811279296875
# Eval_AverageEpLen : 40.8
# Train_AverageReturn : 73.12445831298828
# Train_StdReturn : 19.1035099029541
# Train_MaxReturn : 150.7434539794922
# Train_MinReturn : 40.20240020751953
# Train_AverageEpLen : 41.95397489539749
# Train_EnvstepsSoFar : 80123
# TimeSinceStart : 49.00830149650574
# Training Loss : 118.02587127685547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.60832595825195
# Eval_StdReturn : 12.78835678100586
# Eval_MaxReturn : 96.92974853515625
# Eval_MinReturn : 41.38473129272461
# Eval_AverageEpLen : 37.925925925925924
# Train_AverageReturn : 66.75045776367188
# Train_StdReturn : 16.8109130859375
# Train_MaxReturn : 148.28884887695312
# Train_MinReturn : 38.72220230102539
# Train_AverageEpLen : 39.27843137254902
# Train_EnvstepsSoFar : 90139
# TimeSinceStart : 54.96883845329285
# Training Loss : 115.3628921508789
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 70.6897201538086
# Eval_StdReturn : 21.061437606811523
# Eval_MaxReturn : 119.20489501953125
# Eval_MinReturn : 40.22705078125
# Eval_AverageEpLen : 40.64
# Train_AverageReturn : 62.521148681640625
# Train_StdReturn : 14.302528381347656
# Train_MaxReturn : 141.4912567138672
# Train_MinReturn : 2.505439519882202
# Train_AverageEpLen : 37.52808988764045
# Train_EnvstepsSoFar : 100159
# TimeSinceStart : 60.50982427597046
# Training Loss : 113.41656494140625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.72830200195312
# Eval_StdReturn : 101.2148208618164
# Eval_MaxReturn : 419.26318359375
# Eval_MinReturn : 53.33070373535156
# Eval_AverageEpLen : 62.5625
# Train_AverageReturn : 79.50749969482422
# Train_StdReturn : 20.759700775146484
# Train_MaxReturn : 136.48928833007812
# Train_MinReturn : 39.988800048828125
# Train_AverageEpLen : 45.34841628959276
# Train_EnvstepsSoFar : 110181
# TimeSinceStart : 65.95977449417114
# Training Loss : 122.65408325195312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 100.9259033203125
# Eval_StdReturn : 64.81307983398438
# Eval_MaxReturn : 336.34124755859375
# Eval_MinReturn : 53.857574462890625
# Eval_AverageEpLen : 53.94736842105263
# Train_AverageReturn : 87.85633087158203
# Train_StdReturn : 41.448543548583984
# Train_MaxReturn : 359.8594665527344
# Train_MinReturn : 41.30039596557617
# Train_AverageEpLen : 48.25961538461539
# Train_EnvstepsSoFar : 120219
# TimeSinceStart : 71.4570381641388
# Training Loss : 124.69749450683594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 116.55146026611328
# Eval_StdReturn : 97.16775512695312
# Eval_MaxReturn : 386.087646484375
# Eval_MinReturn : 58.04243850708008
# Eval_AverageEpLen : 56.77777777777778
# Train_AverageReturn : 83.85308837890625
# Train_StdReturn : 47.06863021850586
# Train_MaxReturn : 463.83221435546875
# Train_MinReturn : 41.60636520385742
# Train_AverageEpLen : 45.96330275229358
# Train_EnvstepsSoFar : 130239
# TimeSinceStart : 76.91370368003845
# Training Loss : 122.63763427734375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 204.91986083984375
# Eval_StdReturn : 160.1432647705078
# Eval_MaxReturn : 515.173828125
# Eval_MinReturn : 64.34879302978516
# Eval_AverageEpLen : 92.54545454545455
# Train_AverageReturn : 101.98881530761719
# Train_StdReturn : 63.95039367675781
# Train_MaxReturn : 401.3299255371094
# Train_MinReturn : -0.7637780904769897
# Train_AverageEpLen : 54.743169398907106
# Train_EnvstepsSoFar : 140257
# TimeSinceStart : 82.93642377853394
# Training Loss : 126.5986328125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10121 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 198.77099609375
# Eval_StdReturn : 75.02861785888672
# Eval_MaxReturn : 339.498291015625
# Eval_MinReturn : 81.3260498046875
# Eval_AverageEpLen : 94.18181818181819
# Train_AverageReturn : 130.47779846191406
# Train_StdReturn : 88.97893524169922
# Train_MaxReturn : 489.1891784667969
# Train_MinReturn : 26.927461624145508
# Train_AverageEpLen : 65.72077922077922
# Train_EnvstepsSoFar : 150378
# TimeSinceStart : 89.2263855934143
# Training Loss : 129.74615478515625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 151.02232360839844
# Eval_StdReturn : 63.62441635131836
# Eval_MaxReturn : 301.20953369140625
# Eval_MinReturn : 73.92129516601562
# Eval_AverageEpLen : 77.0
# Train_AverageReturn : 157.64385986328125
# Train_StdReturn : 82.51495361328125
# Train_MaxReturn : 423.39263916015625
# Train_MinReturn : 48.743492126464844
# Train_AverageEpLen : 78.1953125
# Train_EnvstepsSoFar : 160387
# TimeSinceStart : 94.50832319259644
# Training Loss : 132.91526794433594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 148.4532928466797
# Eval_StdReturn : 46.44544219970703
# Eval_MaxReturn : 263.10675048828125
# Eval_MinReturn : 103.23312377929688
# Eval_AverageEpLen : 77.6923076923077
# Train_AverageReturn : 193.73773193359375
# Train_StdReturn : 96.61676025390625
# Train_MaxReturn : 508.4932861328125
# Train_MinReturn : 23.19651985168457
# Train_AverageEpLen : 91.07272727272728
# Train_EnvstepsSoFar : 170405
# TimeSinceStart : 99.7089033126831
# Training Loss : 134.00503540039062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 132.44972229003906
# Eval_StdReturn : 92.28352355957031
# Eval_MaxReturn : 429.04010009765625
# Eval_MinReturn : 50.0208740234375
# Eval_AverageEpLen : 66.73333333333333
# Train_AverageReturn : 160.7360382080078
# Train_StdReturn : 65.63431549072266
# Train_MaxReturn : 403.4249572753906
# Train_MinReturn : 43.00182342529297
# Train_AverageEpLen : 81.53658536585365
# Train_EnvstepsSoFar : 180434
# TimeSinceStart : 105.13382840156555
# Training Loss : 132.0499267578125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.6850814819336
# Eval_StdReturn : 43.64430236816406
# Eval_MaxReturn : 204.81356811523438
# Eval_MinReturn : 49.66583251953125
# Eval_AverageEpLen : 61.94117647058823
# Train_AverageReturn : 133.06134033203125
# Train_StdReturn : 60.63391876220703
# Train_MaxReturn : 401.79827880859375
# Train_MinReturn : 25.172122955322266
# Train_AverageEpLen : 70.6056338028169
# Train_EnvstepsSoFar : 190460
# TimeSinceStart : 110.58648633956909
# Training Loss : 129.01602172851562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 175.801513671875
# Eval_StdReturn : 69.69620513916016
# Eval_MaxReturn : 297.37640380859375
# Eval_MinReturn : 96.45301818847656
# Eval_AverageEpLen : 88.66666666666667
# Train_AverageReturn : 135.91876220703125
# Train_StdReturn : 63.768211364746094
# Train_MaxReturn : 340.86431884765625
# Train_MinReturn : 24.55970001220703
# Train_AverageEpLen : 72.8695652173913
# Train_EnvstepsSoFar : 200516
# TimeSinceStart : 116.35182476043701
# Training Loss : 128.35552978515625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10082 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 132.6117706298828
# Eval_StdReturn : 80.0926513671875
# Eval_MaxReturn : 368.0348205566406
# Eval_MinReturn : 49.18930435180664
# Eval_AverageEpLen : 72.71428571428571
# Train_AverageReturn : 122.8770980834961
# Train_StdReturn : 61.640193939208984
# Train_MaxReturn : 353.1871337890625
# Train_MinReturn : 25.387046813964844
# Train_AverageEpLen : 67.66442953020135
# Train_EnvstepsSoFar : 210598
# TimeSinceStart : 121.95240950584412
# Training Loss : 126.66471099853516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10045 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.32748413085938
# Eval_StdReturn : 48.5049934387207
# Eval_MaxReturn : 190.63265991210938
# Eval_MinReturn : 54.316192626953125
# Eval_AverageEpLen : 66.73333333333333
# Train_AverageReturn : 127.89488983154297
# Train_StdReturn : 51.22077560424805
# Train_MaxReturn : 326.254638671875
# Train_MinReturn : 47.580848693847656
# Train_AverageEpLen : 71.24113475177305
# Train_EnvstepsSoFar : 220643
# TimeSinceStart : 127.50958442687988
# Training Loss : 128.3690185546875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10080 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 137.46624755859375
# Eval_StdReturn : 35.832252502441406
# Eval_MaxReturn : 182.0637664794922
# Eval_MinReturn : 52.15396499633789
# Eval_AverageEpLen : 76.28571428571429
# Train_AverageReturn : 115.59746551513672
# Train_StdReturn : 52.010982513427734
# Train_MaxReturn : 275.57574462890625
# Train_MinReturn : 45.76895523071289
# Train_AverageEpLen : 65.45454545454545
# Train_EnvstepsSoFar : 230723
# TimeSinceStart : 133.55074834823608
# Training Loss : 126.66673278808594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10057 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 105.37964630126953
# Eval_StdReturn : 47.69868087768555
# Eval_MaxReturn : 198.20225524902344
# Eval_MinReturn : 46.58237075805664
# Eval_AverageEpLen : 59.5
# Train_AverageReturn : 125.21554565429688
# Train_StdReturn : 52.72380447387695
# Train_MaxReturn : 244.4689483642578
# Train_MinReturn : 45.863895416259766
# Train_AverageEpLen : 69.84027777777777
# Train_EnvstepsSoFar : 240780
# TimeSinceStart : 139.56167602539062
# Training Loss : 128.59214782714844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.20051574707031
# Eval_StdReturn : 55.82847595214844
# Eval_MaxReturn : 204.64027404785156
# Eval_MinReturn : 51.47978973388672
# Eval_AverageEpLen : 66.625
# Train_AverageReturn : 107.16484832763672
# Train_StdReturn : 51.38314437866211
# Train_MaxReturn : 213.2846221923828
# Train_MinReturn : 42.42761993408203
# Train_AverageEpLen : 60.48795180722892
# Train_EnvstepsSoFar : 250821
# TimeSinceStart : 145.68034887313843
# Training Loss : 126.55868530273438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 102.35558319091797
# Eval_StdReturn : 49.62649917602539
# Eval_MaxReturn : 203.98214721679688
# Eval_MinReturn : 44.343502044677734
# Eval_AverageEpLen : 57.578947368421055
# Train_AverageReturn : 107.60930633544922
# Train_StdReturn : 46.90092849731445
# Train_MaxReturn : 214.7907257080078
# Train_MinReturn : 47.76762771606445
# Train_AverageEpLen : 60.696969696969695
# Train_EnvstepsSoFar : 260836
# TimeSinceStart : 151.8425109386444
# Training Loss : 127.33331298828125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.19929504394531
# Eval_StdReturn : 43.962928771972656
# Eval_MaxReturn : 207.43727111816406
# Eval_MinReturn : 45.06171417236328
# Eval_AverageEpLen : 65.375
# Train_AverageReturn : 103.29776000976562
# Train_StdReturn : 42.084014892578125
# Train_MaxReturn : 211.3787384033203
# Train_MinReturn : 46.86158752441406
# Train_AverageEpLen : 58.96470588235294
# Train_EnvstepsSoFar : 270860
# TimeSinceStart : 157.2466037273407
# Training Loss : 125.19420623779297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.4448699951172
# Eval_StdReturn : 33.79231643676758
# Eval_MaxReturn : 199.25296020507812
# Eval_MinReturn : 55.85523223876953
# Eval_AverageEpLen : 74.42857142857143
# Train_AverageReturn : 107.54593658447266
# Train_StdReturn : 41.752262115478516
# Train_MaxReturn : 213.25833129882812
# Train_MinReturn : 42.196083068847656
# Train_AverageEpLen : 62.04938271604938
# Train_EnvstepsSoFar : 280912
# TimeSinceStart : 162.8007893562317
# Training Loss : 124.52289581298828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10045 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.76519775390625
# Eval_StdReturn : 34.040103912353516
# Eval_MaxReturn : 212.3780517578125
# Eval_MinReturn : 78.973876953125
# Eval_AverageEpLen : 99.81818181818181
# Train_AverageReturn : 121.34859466552734
# Train_StdReturn : 42.652950286865234
# Train_MaxReturn : 230.72555541992188
# Train_MinReturn : 41.951908111572266
# Train_AverageEpLen : 70.7394366197183
# Train_EnvstepsSoFar : 290957
# TimeSinceStart : 169.0090651512146
# Training Loss : 124.44713592529297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10101 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.16049194335938
# Eval_StdReturn : 11.704108238220215
# Eval_MaxReturn : 202.3361053466797
# Eval_MinReturn : 166.59005737304688
# Eval_AverageEpLen : 112.11111111111111
# Train_AverageReturn : 148.34048461914062
# Train_StdReturn : 51.033199310302734
# Train_MaxReturn : 229.697265625
# Train_MinReturn : 45.17575454711914
# Train_AverageEpLen : 87.83478260869565
# Train_EnvstepsSoFar : 301058
# TimeSinceStart : 175.26202297210693
# Training Loss : 122.32464599609375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.17091369628906
# Eval_StdReturn : 28.880231857299805
# Eval_MaxReturn : 200.47979736328125
# Eval_MinReturn : 92.8042221069336
# Eval_AverageEpLen : 106.2
# Train_AverageReturn : 168.4975128173828
# Train_StdReturn : 43.99125289916992
# Train_MaxReturn : 220.02243041992188
# Train_MinReturn : 48.32231903076172
# Train_AverageEpLen : 102.63265306122449
# Train_EnvstepsSoFar : 311116
# TimeSinceStart : 181.24547624588013
# Training Loss : 119.15794372558594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.77529907226562
# Eval_StdReturn : 40.27349853515625
# Eval_MaxReturn : 200.43743896484375
# Eval_MinReturn : 76.69893646240234
# Eval_AverageEpLen : 96.27272727272727
# Train_AverageReturn : 166.0697479248047
# Train_StdReturn : 39.13092803955078
# Train_MaxReturn : 212.37103271484375
# Train_MinReturn : 45.17279815673828
# Train_AverageEpLen : 104.48958333333333
# Train_EnvstepsSoFar : 321147
# TimeSinceStart : 186.87267971038818
# Training Loss : 117.37763214111328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 160.63961791992188
# Eval_StdReturn : 55.653778076171875
# Eval_MaxReturn : 219.9619140625
# Eval_MinReturn : 50.830284118652344
# Eval_AverageEpLen : 99.0909090909091
# Train_AverageReturn : 159.91285705566406
# Train_StdReturn : 47.77665710449219
# Train_MaxReturn : 217.71392822265625
# Train_MinReturn : 37.122657775878906
# Train_AverageEpLen : 100.31
# Train_EnvstepsSoFar : 331178
# TimeSinceStart : 192.523503780365
# Training Loss : 117.17728424072266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 155.76739501953125
# Eval_StdReturn : 52.028663635253906
# Eval_MaxReturn : 224.58091735839844
# Eval_MinReturn : 44.38044738769531
# Eval_AverageEpLen : 92.27272727272727
# Train_AverageReturn : 164.5234832763672
# Train_StdReturn : 50.77728271484375
# Train_MaxReturn : 224.9844970703125
# Train_MinReturn : 40.91332244873047
# Train_AverageEpLen : 99.56435643564356
# Train_EnvstepsSoFar : 341234
# TimeSinceStart : 198.0655665397644
# Training Loss : 119.47754669189453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 106.44357299804688
# Eval_StdReturn : 26.704055786132812
# Eval_MaxReturn : 144.2659454345703
# Eval_MinReturn : 53.361228942871094
# Eval_AverageEpLen : 62.8125
# Train_AverageReturn : 144.85687255859375
# Train_StdReturn : 47.32915496826172
# Train_MaxReturn : 225.98666381835938
# Train_MinReturn : 47.3035888671875
# Train_AverageEpLen : 85.86324786324786
# Train_EnvstepsSoFar : 351280
# TimeSinceStart : 204.15423226356506
# Training Loss : 121.7261734008789
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10048 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 85.04267120361328
# Eval_StdReturn : 21.860349655151367
# Eval_MaxReturn : 123.8735122680664
# Eval_MinReturn : 48.22300720214844
# Eval_AverageEpLen : 50.15
# Train_AverageReturn : 109.6600570678711
# Train_StdReturn : 35.59393310546875
# Train_MaxReturn : 217.54116821289062
# Train_MinReturn : 40.73545837402344
# Train_AverageEpLen : 64.8258064516129
# Train_EnvstepsSoFar : 361328
# TimeSinceStart : 209.80016207695007
# Training Loss : 122.255859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 79.91705322265625
# Eval_StdReturn : 25.023515701293945
# Eval_MaxReturn : 159.440185546875
# Eval_MinReturn : 48.16783905029297
# Eval_AverageEpLen : 46.5
# Train_AverageReturn : 87.51367950439453
# Train_StdReturn : 22.226329803466797
# Train_MaxReturn : 145.6975860595703
# Train_MinReturn : 44.686180114746094
# Train_AverageEpLen : 51.43076923076923
# Train_EnvstepsSoFar : 371357
# TimeSinceStart : 215.32120537757874
# Training Loss : 121.13758850097656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 78.07624053955078
# Eval_StdReturn : 23.193626403808594
# Eval_MaxReturn : 160.80946350097656
# Eval_MinReturn : 52.345088958740234
# Eval_AverageEpLen : 45.04347826086956
# Train_AverageReturn : 76.78861236572266
# Train_StdReturn : 20.859352111816406
# Train_MaxReturn : 170.81544494628906
# Train_MinReturn : 45.38503646850586
# Train_AverageEpLen : 44.72767857142857
# Train_EnvstepsSoFar : 381376
# TimeSinceStart : 221.4014434814453
# Training Loss : 119.18047332763672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 68.47340393066406
# Eval_StdReturn : 12.537069320678711
# Eval_MaxReturn : 102.92738342285156
# Eval_MinReturn : 50.65650939941406
# Eval_AverageEpLen : 39.76923076923077
# Train_AverageReturn : 69.42176818847656
# Train_StdReturn : 17.47374153137207
# Train_MaxReturn : 145.87442016601562
# Train_MinReturn : 41.475074768066406
# Train_AverageEpLen : 40.38306451612903
# Train_EnvstepsSoFar : 391391
# TimeSinceStart : 226.96304273605347
# Training Loss : 116.71923065185547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10032 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.74612426757812
# Eval_StdReturn : 17.78304100036621
# Eval_MaxReturn : 127.4739761352539
# Eval_MinReturn : 48.12754440307617
# Eval_AverageEpLen : 37.407407407407405
# Train_AverageReturn : 66.48234558105469
# Train_StdReturn : 17.06211280822754
# Train_MaxReturn : 183.1233367919922
# Train_MinReturn : 40.12174987792969
# Train_AverageEpLen : 38.58461538461538
# Train_EnvstepsSoFar : 401423
# TimeSinceStart : 232.68127512931824
# Training Loss : 114.80848693847656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 68.58518981933594
# Eval_StdReturn : 24.109203338623047
# Eval_MaxReturn : 127.22840118408203
# Eval_MinReturn : 43.34394836425781
# Eval_AverageEpLen : 39.26923076923077
# Train_AverageReturn : 62.350799560546875
# Train_StdReturn : 15.576594352722168
# Train_MaxReturn : 151.4542694091797
# Train_MinReturn : 38.56489944458008
# Train_AverageEpLen : 36.13357400722022
# Train_EnvstepsSoFar : 411432
# TimeSinceStart : 247.97564268112183
# Training Loss : 112.85972595214844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.53818130493164
# Eval_StdReturn : 11.219778060913086
# Eval_MaxReturn : 92.22510528564453
# Eval_MinReturn : 44.812007904052734
# Eval_AverageEpLen : 34.6551724137931
# Train_AverageReturn : 61.754798889160156
# Train_StdReturn : 15.031362533569336
# Train_MaxReturn : 131.7734832763672
# Train_MinReturn : 41.34135055541992
# Train_AverageEpLen : 35.81071428571428
# Train_EnvstepsSoFar : 421459
# TimeSinceStart : 253.934889793396
# Training Loss : 112.879150390625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.71318054199219
# Eval_StdReturn : 16.22252655029297
# Eval_MaxReturn : 108.33300018310547
# Eval_MinReturn : 47.89210891723633
# Eval_AverageEpLen : 38.0
# Train_AverageReturn : 62.23384475708008
# Train_StdReturn : 17.9135684967041
# Train_MaxReturn : 175.0672149658203
# Train_MinReturn : 38.17311096191406
# Train_AverageEpLen : 35.84587813620072
# Train_EnvstepsSoFar : 431460
# TimeSinceStart : 260.26940393447876
# Training Loss : 113.3410873413086
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.38231658935547
# Eval_StdReturn : 17.311023712158203
# Eval_MaxReturn : 115.9361572265625
# Eval_MinReturn : 44.94029235839844
# Eval_AverageEpLen : 37.925925925925924
# Train_AverageReturn : 62.013580322265625
# Train_StdReturn : 14.339262008666992
# Train_MaxReturn : 136.03076171875
# Train_MinReturn : 39.90241622924805
# Train_AverageEpLen : 35.95340501792115
# Train_EnvstepsSoFar : 441491
# TimeSinceStart : 265.81183671951294
# Training Loss : 112.58897399902344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.82584762573242
# Eval_StdReturn : 15.86113452911377
# Eval_MaxReturn : 111.3555908203125
# Eval_MinReturn : 40.31525421142578
# Eval_AverageEpLen : 37.148148148148145
# Train_AverageReturn : 65.20848083496094
# Train_StdReturn : 18.361042022705078
# Train_MaxReturn : 173.25384521484375
# Train_MinReturn : 39.90314865112305
# Train_AverageEpLen : 37.661654135338345
# Train_EnvstepsSoFar : 451509
# TimeSinceStart : 271.4599645137787
# Training Loss : 113.83496856689453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 73.08026123046875
# Eval_StdReturn : 23.930145263671875
# Eval_MaxReturn : 170.57423400878906
# Eval_MinReturn : 43.41078567504883
# Eval_AverageEpLen : 41.875
# Train_AverageReturn : 68.35446166992188
# Train_StdReturn : 20.211427688598633
# Train_MaxReturn : 181.96841430664062
# Train_MinReturn : 39.87798309326172
# Train_AverageEpLen : 39.29019607843137
# Train_EnvstepsSoFar : 461528
# TimeSinceStart : 277.0767171382904
# Training Loss : 115.33529663085938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 83.57228088378906
# Eval_StdReturn : 20.636613845825195
# Eval_MaxReturn : 122.97232055664062
# Eval_MinReturn : 43.28515625
# Eval_AverageEpLen : 48.19047619047619
# Train_AverageReturn : 75.06311798095703
# Train_StdReturn : 24.677425384521484
# Train_MaxReturn : 191.4409942626953
# Train_MinReturn : 46.49309158325195
# Train_AverageEpLen : 42.97854077253219
# Train_EnvstepsSoFar : 471542
# TimeSinceStart : 282.8610804080963
# Training Loss : 117.76271057128906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.35469818115234
# Eval_StdReturn : 25.682876586914062
# Eval_MaxReturn : 157.20425415039062
# Eval_MinReturn : 52.12364959716797
# Eval_AverageEpLen : 47.36363636363637
# Train_AverageReturn : 84.88060760498047
# Train_StdReturn : 28.429418563842773
# Train_MaxReturn : 194.29649353027344
# Train_MinReturn : 47.78889846801758
# Train_AverageEpLen : 48.13461538461539
# Train_EnvstepsSoFar : 481554
# TimeSinceStart : 289.1392683982849
# Training Loss : 119.17806243896484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.4383773803711
# Eval_StdReturn : 38.45194625854492
# Eval_MaxReturn : 180.69659423828125
# Eval_MinReturn : 41.428775787353516
# Eval_AverageEpLen : 51.45
# Train_AverageReturn : 87.14571380615234
# Train_StdReturn : 28.972047805786133
# Train_MaxReturn : 210.03952026367188
# Train_MinReturn : 43.61486053466797
# Train_AverageEpLen : 49.77114427860697
# Train_EnvstepsSoFar : 491558
# TimeSinceStart : 295.03894233703613
# Training Loss : 119.17215728759766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10079 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 108.81947326660156
# Eval_StdReturn : 43.111507415771484
# Eval_MaxReturn : 187.2569122314453
# Eval_MinReturn : 55.58137512207031
# Eval_AverageEpLen : 58.44444444444444
# Train_AverageReturn : 95.16844940185547
# Train_StdReturn : 33.63816833496094
# Train_MaxReturn : 188.71131896972656
# Train_MinReturn : 43.466796875
# Train_AverageEpLen : 53.04736842105263
# Train_EnvstepsSoFar : 501637
# TimeSinceStart : 301.34341621398926
# Training Loss : 120.2445068359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10051 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.07502746582031
# Eval_StdReturn : 40.683101654052734
# Eval_MaxReturn : 209.0104522705078
# Eval_MinReturn : 44.42851257324219
# Eval_AverageEpLen : 51.05
# Train_AverageReturn : 92.7994613647461
# Train_StdReturn : 34.53230285644531
# Train_MaxReturn : 196.10337829589844
# Train_MinReturn : 44.721805572509766
# Train_AverageEpLen : 52.348958333333336
# Train_EnvstepsSoFar : 511688
# TimeSinceStart : 307.38193583488464
# Training Loss : 119.49261474609375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.63473510742188
# Eval_StdReturn : 37.557594299316406
# Eval_MaxReturn : 175.87095642089844
# Eval_MinReturn : 36.912559509277344
# Eval_AverageEpLen : 48.04761904761905
# Train_AverageReturn : 94.03138732910156
# Train_StdReturn : 35.23387908935547
# Train_MaxReturn : 201.79254150390625
# Train_MinReturn : 27.806468963623047
# Train_AverageEpLen : 52.921052631578945
# Train_EnvstepsSoFar : 521743
# TimeSinceStart : 313.93600702285767
# Training Loss : 118.99224090576172
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 78.4754409790039
# Eval_StdReturn : 29.865360260009766
# Eval_MaxReturn : 190.7450408935547
# Eval_MinReturn : 47.028873443603516
# Eval_AverageEpLen : 45.65217391304348
# Train_AverageReturn : 92.79976654052734
# Train_StdReturn : 37.93548583984375
# Train_MaxReturn : 196.64938354492188
# Train_MinReturn : 17.721681594848633
# Train_AverageEpLen : 52.09326424870466
# Train_EnvstepsSoFar : 531797
# TimeSinceStart : 322.4184739589691
# Training Loss : 119.02448272705078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 79.93560791015625
# Eval_StdReturn : 21.104639053344727
# Eval_MaxReturn : 124.99737548828125
# Eval_MinReturn : 49.0492057800293
# Eval_AverageEpLen : 46.90909090909091
# Train_AverageReturn : 91.02725982666016
# Train_StdReturn : 34.437644958496094
# Train_MaxReturn : 199.47557067871094
# Train_MinReturn : 43.442779541015625
# Train_AverageEpLen : 51.577319587628864
# Train_EnvstepsSoFar : 541803
# TimeSinceStart : 328.9077658653259
# Training Loss : 120.19953155517578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 94.77247619628906
# Eval_StdReturn : 42.33101272583008
# Eval_MaxReturn : 179.16021728515625
# Eval_MinReturn : 44.29521942138672
# Eval_AverageEpLen : 52.1
# Train_AverageReturn : 89.34286499023438
# Train_StdReturn : 34.84932327270508
# Train_MaxReturn : 195.66371154785156
# Train_MinReturn : 41.949073791503906
# Train_AverageEpLen : 50.2713567839196
# Train_EnvstepsSoFar : 551807
# TimeSinceStart : 335.99782514572144
# Training Loss : 120.1963119506836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 90.33361053466797
# Eval_StdReturn : 41.88145446777344
# Eval_MaxReturn : 192.54367065429688
# Eval_MinReturn : 46.466670989990234
# Eval_AverageEpLen : 50.3
# Train_AverageReturn : 91.93407440185547
# Train_StdReturn : 33.962806701660156
# Train_MaxReturn : 208.1493682861328
# Train_MinReturn : 37.97972106933594
# Train_AverageEpLen : 51.70618556701031
# Train_EnvstepsSoFar : 561838
# TimeSinceStart : 342.8262839317322
# Training Loss : 121.07260131835938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 99.9919662475586
# Eval_StdReturn : 37.870750427246094
# Eval_MaxReturn : 191.37294006347656
# Eval_MinReturn : 56.63937759399414
# Eval_AverageEpLen : 54.89473684210526
# Train_AverageReturn : 96.55642700195312
# Train_StdReturn : 43.088069915771484
# Train_MaxReturn : 215.46730041503906
# Train_MinReturn : 43.341819763183594
# Train_AverageEpLen : 53.026455026455025
# Train_EnvstepsSoFar : 571860
# TimeSinceStart : 349.761750459671
# Training Loss : 121.78365325927734
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10074 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 85.21820068359375
# Eval_StdReturn : 21.454059600830078
# Eval_MaxReturn : 138.9476318359375
# Eval_MinReturn : 49.424129486083984
# Eval_AverageEpLen : 49.523809523809526
# Train_AverageReturn : 100.45771026611328
# Train_StdReturn : 40.66342544555664
# Train_MaxReturn : 201.450927734375
# Train_MinReturn : 43.88512420654297
# Train_AverageEpLen : 54.75
# Train_EnvstepsSoFar : 581934
# TimeSinceStart : 356.31853795051575
# Training Loss : 124.6630859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.17869567871094
# Eval_StdReturn : 38.505985260009766
# Eval_MaxReturn : 192.6708526611328
# Eval_MinReturn : 56.657073974609375
# Eval_AverageEpLen : 57.0
# Train_AverageReturn : 102.63964080810547
# Train_StdReturn : 42.499855041503906
# Train_MaxReturn : 200.97511291503906
# Train_MinReturn : 43.434471130371094
# Train_AverageEpLen : 55.74444444444445
# Train_EnvstepsSoFar : 591968
# TimeSinceStart : 362.1208152770996
# Training Loss : 124.75827026367188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 108.57705688476562
# Eval_StdReturn : 50.468475341796875
# Eval_MaxReturn : 195.88523864746094
# Eval_MinReturn : 59.9570426940918
# Eval_AverageEpLen : 58.8235294117647
# Train_AverageReturn : 101.78348541259766
# Train_StdReturn : 44.29875183105469
# Train_MaxReturn : 204.818115234375
# Train_MinReturn : 41.976898193359375
# Train_AverageEpLen : 55.611111111111114
# Train_EnvstepsSoFar : 601978
# TimeSinceStart : 367.5975043773651
# Training Loss : 124.94353485107422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 85.9083251953125
# Eval_StdReturn : 36.86066818237305
# Eval_MaxReturn : 174.25843811035156
# Eval_MinReturn : 48.480281829833984
# Eval_AverageEpLen : 48.80952380952381
# Train_AverageReturn : 102.65299987792969
# Train_StdReturn : 44.49030685424805
# Train_MaxReturn : 251.45181274414062
# Train_MinReturn : 45.452850341796875
# Train_AverageEpLen : 56.37078651685393
# Train_EnvstepsSoFar : 612012
# TimeSinceStart : 372.9569797515869
# Training Loss : 127.31871795654297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10035 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 80.3984375
# Eval_StdReturn : 24.64051055908203
# Eval_MaxReturn : 158.0923614501953
# Eval_MinReturn : 46.49562454223633
# Eval_AverageEpLen : 46.72727272727273
# Train_AverageReturn : 88.823974609375
# Train_StdReturn : 36.342247009277344
# Train_MaxReturn : 200.39109802246094
# Train_MinReturn : 43.27705764770508
# Train_AverageEpLen : 50.68181818181818
# Train_EnvstepsSoFar : 622047
# TimeSinceStart : 378.09044456481934
# Training Loss : 125.61515045166016
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.17049407958984
# Eval_StdReturn : 21.34424591064453
# Eval_MaxReturn : 139.8181915283203
# Eval_MinReturn : 52.922950744628906
# Eval_AverageEpLen : 47.80952380952381
# Train_AverageReturn : 82.16277313232422
# Train_StdReturn : 32.66424560546875
# Train_MaxReturn : 225.01698303222656
# Train_MinReturn : 47.426307678222656
# Train_AverageEpLen : 47.995215311004785
# Train_EnvstepsSoFar : 632078
# TimeSinceStart : 383.64506578445435
# Training Loss : 124.29407501220703
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# ...
# Train_EnvstepsSoFar : 792344
# TimeSinceStart : 538.809522151947
# Training Loss : 119.38953399658203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     10101 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 129.21302795410156
# Eval_StdReturn : 17.406476974487305
# Eval_MaxReturn : 153.65000915527344
# Eval_MinReturn : 96.25511932373047
# Eval_AverageEpLen : 87.25
# Train_AverageReturn : 160.4609375
# Train_StdReturn : 15.105732917785645
# Train_MaxReturn : 180.38906860351562
# Train_MinReturn : 50.61509704589844
# Train_AverageEpLen : 105.21875
# Train_EnvstepsSoFar : 802445
# TimeSinceStart : 545.0268607139587
# Training Loss : 117.3483657836914
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.96768188476562
# Eval_StdReturn : 12.80911636352539
# Eval_MaxReturn : 110.19210052490234
# Eval_MinReturn : 53.47475051879883
# Eval_AverageEpLen : 65.9375
# Train_AverageReturn : 129.64378356933594
# Train_StdReturn : 19.052751541137695
# Train_MaxReturn : 158.39161682128906
# Train_MinReturn : 52.124473571777344
# Train_AverageEpLen : 87.82456140350877
# Train_EnvstepsSoFar : 812457
# TimeSinceStart : 551.4001264572144
# Training Loss : 116.59030151367188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 78.97235107421875
# Eval_StdReturn : 13.512177467346191
# Eval_MaxReturn : 91.64228057861328
# Eval_MinReturn : 52.19784927368164
# Eval_AverageEpLen : 54.526315789473685
# Train_AverageReturn : 94.39277648925781
# Train_StdReturn : 16.512182235717773
# Train_MaxReturn : 120.83855438232422
# Train_MinReturn : 50.64543151855469
# Train_AverageEpLen : 64.56129032258065
# Train_EnvstepsSoFar : 822464
# TimeSinceStart : 557.4779059886932
# Training Loss : 112.43074798583984
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.34941864013672
# Eval_StdReturn : 3.005128860473633
# Eval_MaxReturn : 79.78280639648438
# Eval_MinReturn : 68.22137451171875
# Eval_AverageEpLen : 54.05263157894737
# Train_AverageReturn : 81.19548034667969
# Train_StdReturn : 11.618936538696289
# Train_MaxReturn : 95.33128356933594
# Train_MinReturn : 50.67783737182617
# Train_AverageEpLen : 56.353932584269664
# Train_EnvstepsSoFar : 832495
# TimeSinceStart : 564.2297041416168
# Training Loss : 108.83489990234375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.29725646972656
# Eval_StdReturn : 3.4514007568359375
# Eval_MaxReturn : 77.48660278320312
# Eval_MinReturn : 60.06401443481445
# Eval_AverageEpLen : 50.25
# Train_AverageReturn : 74.42285919189453
# Train_StdReturn : 4.8421244621276855
# Train_MaxReturn : 85.53079223632812
# Train_MinReturn : 50.53894805908203
# Train_AverageEpLen : 53.22872340425532
# Train_EnvstepsSoFar : 842502
# TimeSinceStart : 570.9470736980438
# Training Loss : 106.46160125732422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.998680114746094
# Eval_StdReturn : 3.4188692569732666
# Eval_MaxReturn : 68.91613006591797
# Eval_MinReturn : 54.97907257080078
# Eval_AverageEpLen : 46.54545454545455
# Train_AverageReturn : 68.0041275024414
# Train_StdReturn : 3.455622911453247
# Train_MaxReturn : 77.629150390625
# Train_MinReturn : 52.19157028198242
# Train_AverageEpLen : 49.40394088669951
# Train_EnvstepsSoFar : 852531
# TimeSinceStart : 579.0929646492004
# Training Loss : 104.06047821044922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 60.064842224121094
# Eval_StdReturn : 3.8131847381591797
# Eval_MaxReturn : 67.73102569580078
# Eval_MinReturn : 49.455169677734375
# Eval_AverageEpLen : 44.82608695652174
# Train_AverageReturn : 63.361392974853516
# Train_StdReturn : 3.2375667095184326
# Train_MaxReturn : 71.44032287597656
# Train_MinReturn : 50.25006103515625
# Train_AverageEpLen : 46.70232558139535
# Train_EnvstepsSoFar : 862572
# TimeSinceStart : 590.92014336586
# Training Loss : 101.96748352050781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10005 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 56.3996467590332
# Eval_StdReturn : 2.192653179168701
# Eval_MaxReturn : 60.416053771972656
# Eval_MinReturn : 51.49522399902344
# Eval_AverageEpLen : 42.583333333333336
# Train_AverageReturn : 59.02674865722656
# Train_StdReturn : 3.3696279525756836
# Train_MaxReturn : 66.29071044921875
# Train_MinReturn : 50.052703857421875
# Train_AverageEpLen : 44.269911504424776
# Train_EnvstepsSoFar : 872577
# TimeSinceStart : 604.1884293556213
# Training Loss : 100.07115936279297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 54.1476936340332
# Eval_StdReturn : 2.9333131313323975
# Eval_MaxReturn : 59.414283752441406
# Eval_MinReturn : 47.43920135498047
# Eval_AverageEpLen : 41.2
# Train_AverageReturn : 55.460330963134766
# Train_StdReturn : 3.08774471282959
# Train_MaxReturn : 64.92639923095703
# Train_MinReturn : 46.79151153564453
# Train_AverageEpLen : 42.15966386554622
# Train_EnvstepsSoFar : 882611
# TimeSinceStart : 617.1493575572968
# Training Loss : 97.49762725830078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.51275634765625
# Eval_StdReturn : 3.0552239418029785
# Eval_MaxReturn : 59.36747741699219
# Eval_MinReturn : 45.55546951293945
# Eval_AverageEpLen : 39.92307692307692
# Train_AverageReturn : 53.72182846069336
# Train_StdReturn : 3.340498685836792
# Train_MaxReturn : 63.02396011352539
# Train_MinReturn : 44.62579345703125
# Train_AverageEpLen : 40.94285714285714
# Train_EnvstepsSoFar : 892642
# TimeSinceStart : 632.654317855835
# Training Loss : 96.72447967529297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.5723876953125
# Eval_StdReturn : 2.7650094032287598
# Eval_MaxReturn : 59.05357360839844
# Eval_MinReturn : 47.70762634277344
# Eval_AverageEpLen : 39.73076923076923
# Train_AverageReturn : 52.7530403137207
# Train_StdReturn : 3.207972288131714
# Train_MaxReturn : 62.98200225830078
# Train_MinReturn : 44.470970153808594
# Train_AverageEpLen : 40.136
# Train_EnvstepsSoFar : 902676
# TimeSinceStart : 640.271817445755
# Training Loss : 97.04573059082031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 53.399932861328125
# Eval_StdReturn : 3.1769862174987793
# Eval_MaxReturn : 62.15003967285156
# Eval_MinReturn : 48.97187423706055
# Eval_AverageEpLen : 40.12
# Train_AverageReturn : 52.691036224365234
# Train_StdReturn : 3.2511613368988037
# Train_MaxReturn : 63.56587600708008
# Train_MinReturn : 44.868202209472656
# Train_AverageEpLen : 39.83730158730159
# Train_EnvstepsSoFar : 912715
# TimeSinceStart : 648.4657781124115
# Training Loss : 97.63885498046875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 59.067378997802734
# Eval_StdReturn : 3.305288791656494
# Eval_MaxReturn : 66.58672332763672
# Eval_MinReturn : 54.000328063964844
# Eval_AverageEpLen : 44.04347826086956
# Train_AverageReturn : 52.9904899597168
# Train_StdReturn : 3.143190622329712
# Train_MaxReturn : 60.81620407104492
# Train_MinReturn : 46.548526763916016
# Train_AverageEpLen : 39.833333333333336
# Train_EnvstepsSoFar : 922753
# TimeSinceStart : 658.1583068370819
# Training Loss : 98.12468719482422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.84480285644531
# Eval_StdReturn : 1.756399393081665
# Eval_MaxReturn : 86.26348114013672
# Eval_MinReturn : 80.55104064941406
# Eval_AverageEpLen : 66.375
# Train_AverageReturn : 61.021236419677734
# Train_StdReturn : 4.325355052947998
# Train_MaxReturn : 87.54222869873047
# Train_MinReturn : 50.1452751159668
# Train_AverageEpLen : 45.46818181818182
# Train_EnvstepsSoFar : 932756
# TimeSinceStart : 668.4994466304779
# Training Loss : 103.23365020751953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.06053924560547
# Eval_StdReturn : 5.334883213043213
# Eval_MaxReturn : 112.71131134033203
# Eval_MinReturn : 95.91822052001953
# Eval_AverageEpLen : 70.86666666666666
# Train_AverageReturn : 81.46809387207031
# Train_StdReturn : 3.519188642501831
# Train_MaxReturn : 89.6049575805664
# Train_MinReturn : 66.88075256347656
# Train_AverageEpLen : 65.09740259740259
# Train_EnvstepsSoFar : 942781
# TimeSinceStart : 675.6109089851379
# Training Loss : 110.99079895019531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10060 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.88005065917969
# Eval_StdReturn : 7.378532409667969
# Eval_MaxReturn : 138.60369873046875
# Eval_MinReturn : 112.70563507080078
# Eval_AverageEpLen : 78.6923076923077
# Train_AverageReturn : 99.00820922851562
# Train_StdReturn : 4.042395114898682
# Train_MaxReturn : 110.07518005371094
# Train_MinReturn : 93.35530853271484
# Train_AverageEpLen : 70.34965034965035
# Train_EnvstepsSoFar : 952841
# TimeSinceStart : 682.8638026714325
# Training Loss : 117.03866577148438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10048 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 85.12016296386719
# Eval_StdReturn : 10.5054292678833
# Eval_MaxReturn : 103.48033905029297
# Eval_MinReturn : 66.02912902832031
# Eval_AverageEpLen : 52.05
# Train_AverageReturn : 127.36668395996094
# Train_StdReturn : 7.316851615905762
# Train_MaxReturn : 144.04315185546875
# Train_MinReturn : 112.90815734863281
# Train_AverageEpLen : 79.11811023622047
# Train_EnvstepsSoFar : 962889
# TimeSinceStart : 690.1501562595367
# Training Loss : 121.62213897705078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.33499145507812
# Eval_StdReturn : 6.655646324157715
# Eval_MaxReturn : 86.18893432617188
# Eval_MinReturn : 54.780948638916016
# Eval_AverageEpLen : 39.80769230769231
# Train_AverageReturn : 86.3634262084961
# Train_StdReturn : 13.487738609313965
# Train_MaxReturn : 141.52178955078125
# Train_MinReturn : 57.70920944213867
# Train_AverageEpLen : 52.83684210526316
# Train_EnvstepsSoFar : 972928
# TimeSinceStart : 696.6020312309265
# Training Loss : 117.57892608642578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 56.53646469116211
# Eval_StdReturn : 4.523766994476318
# Eval_MaxReturn : 66.97274780273438
# Eval_MinReturn : 45.855865478515625
# Eval_AverageEpLen : 34.333333333333336
# Train_AverageReturn : 62.91539001464844
# Train_StdReturn : 6.224359512329102
# Train_MaxReturn : 87.93882751464844
# Train_MinReturn : 47.136512756347656
# Train_AverageEpLen : 38.16793893129771
# Train_EnvstepsSoFar : 982928
# TimeSinceStart : 703.219428062439
# Training Loss : 108.267822265625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 53.945865631103516
# Eval_StdReturn : 3.077104330062866
# Eval_MaxReturn : 59.36167907714844
# Eval_MinReturn : 47.75359344482422
# Eval_AverageEpLen : 32.96774193548387
# Train_AverageReturn : 55.441036224365234
# Train_StdReturn : 4.616694450378418
# Train_MaxReturn : 70.92462158203125
# Train_MinReturn : 42.530033111572266
# Train_AverageEpLen : 33.707070707070706
# Train_EnvstepsSoFar : 992939
# TimeSinceStart : 711.6468198299408
# Training Loss : 102.81739044189453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 51.30232238769531
# Eval_StdReturn : 4.804129600524902
# Eval_MaxReturn : 61.60268020629883
# Eval_MinReturn : 44.288211822509766
# Eval_AverageEpLen : 31.53125
# Train_AverageReturn : 52.77962875366211
# Train_StdReturn : 4.1729512214660645
# Train_MaxReturn : 68.55164337158203
# Train_MinReturn : 42.606510162353516
# Train_AverageEpLen : 32.247588424437296
# Train_EnvstepsSoFar : 1002968
# TimeSinceStart : 720.5128455162048
# Training Loss : 100.44264221191406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = True
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/return_to_go/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/return_to_go/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/Hopper/return_to_go/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/return_to_go/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.36431121826172
# Eval_StdReturn : 56.17051696777344
# Eval_MaxReturn : 247.20230102539062
# Eval_MinReturn : 17.86540985107422
# Eval_AverageEpLen : 61.64705882352941
# Train_AverageReturn : 9.657980918884277
# Train_StdReturn : 5.853752613067627
# Train_MaxReturn : 87.45542907714844
# Train_MinReturn : 3.010934352874756
# Train_AverageEpLen : 13.215323645970939
# Train_EnvstepsSoFar : 10004
# TimeSinceStart : 7.556540489196777
# Training Loss : 18.090417861938477
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.83673095703125
# Eval_StdReturn : 12.586797714233398
# Eval_MaxReturn : 109.0075912475586
# Eval_MinReturn : 55.418758392333984
# Eval_AverageEpLen : 44.95652173913044
# Train_AverageReturn : 86.47571563720703
# Train_StdReturn : 52.808433532714844
# Train_MaxReturn : 252.57847595214844
# Train_MinReturn : 6.542727947235107
# Train_AverageEpLen : 54.5
# Train_EnvstepsSoFar : 20032
# TimeSinceStart : 14.870397567749023
# Training Loss : 102.84622192382812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.26393127441406
# Eval_StdReturn : 14.384303092956543
# Eval_MaxReturn : 124.45768737792969
# Eval_MinReturn : 65.53836059570312
# Eval_AverageEpLen : 51.2
# Train_AverageReturn : 79.29029846191406
# Train_StdReturn : 17.705259323120117
# Train_MaxReturn : 178.68356323242188
# Train_MinReturn : 55.416194915771484
# Train_AverageEpLen : 47.72380952380952
# Train_EnvstepsSoFar : 30054
# TimeSinceStart : 21.71048355102539
# Training Loss : 98.99420928955078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 122.05274963378906
# Eval_StdReturn : 34.17659378051758
# Eval_MaxReturn : 192.69754028320312
# Eval_MinReturn : 78.61380004882812
# Eval_AverageEpLen : 63.9375
# Train_AverageReturn : 87.70250701904297
# Train_StdReturn : 19.83871078491211
# Train_MaxReturn : 171.647216796875
# Train_MinReturn : 59.1412353515625
# Train_AverageEpLen : 50.55555555555556
# Train_EnvstepsSoFar : 40064
# TimeSinceStart : 27.836355924606323
# Training Loss : 106.54765319824219
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10053 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 204.439208984375
# Eval_StdReturn : 37.101280212402344
# Eval_MaxReturn : 253.41506958007812
# Eval_MinReturn : 127.92462158203125
# Eval_AverageEpLen : 101.27272727272727
# Train_AverageReturn : 117.80029296875
# Train_StdReturn : 33.66783142089844
# Train_MaxReturn : 235.24740600585938
# Train_MinReturn : 75.37960815429688
# Train_AverageEpLen : 63.22641509433962
# Train_EnvstepsSoFar : 50117
# TimeSinceStart : 34.497721433639526
# Training Loss : 124.14750671386719
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10069 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.0036163330078
# Eval_StdReturn : 37.31689453125
# Eval_MaxReturn : 233.3486328125
# Eval_MinReturn : 117.33634185791016
# Eval_AverageEpLen : 86.58333333333333
# Train_AverageReturn : 208.6101531982422
# Train_StdReturn : 29.25820541381836
# Train_MaxReturn : 249.9329833984375
# Train_MinReturn : 90.5279769897461
# Train_AverageEpLen : 97.75728155339806
# Train_EnvstepsSoFar : 60186
# TimeSinceStart : 41.11054277420044
# Training Loss : 158.02334594726562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10085 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.2112579345703
# Eval_StdReturn : 33.942020416259766
# Eval_MaxReturn : 214.28639221191406
# Eval_MinReturn : 108.93885803222656
# Eval_AverageEpLen : 83.0
# Train_AverageReturn : 173.1794891357422
# Train_StdReturn : 36.93601989746094
# Train_MaxReturn : 234.86814880371094
# Train_MinReturn : 75.32490539550781
# Train_AverageEpLen : 84.74789915966386
# Train_EnvstepsSoFar : 70271
# TimeSinceStart : 47.30220127105713
# Training Loss : 147.06393432617188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 206.2492218017578
# Eval_StdReturn : 4.504377841949463
# Eval_MaxReturn : 216.28648376464844
# Eval_MinReturn : 199.9722137451172
# Eval_AverageEpLen : 93.36363636363636
# Train_AverageReturn : 163.3338623046875
# Train_StdReturn : 40.198360443115234
# Train_MaxReturn : 223.3988037109375
# Train_MinReturn : 90.04806518554688
# Train_AverageEpLen : 79.8015873015873
# Train_EnvstepsSoFar : 80326
# TimeSinceStart : 53.754024028778076
# Training Loss : 145.29591369628906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 204.27976989746094
# Eval_StdReturn : 4.998895168304443
# Eval_MaxReturn : 212.77279663085938
# Eval_MinReturn : 197.0357208251953
# Eval_AverageEpLen : 90.66666666666667
# Train_AverageReturn : 206.16336059570312
# Train_StdReturn : 4.555065155029297
# Train_MaxReturn : 219.765380859375
# Train_MinReturn : 186.3317108154297
# Train_AverageEpLen : 92.72222222222223
# Train_EnvstepsSoFar : 90340
# TimeSinceStart : 60.082003355026245
# Training Loss : 163.37661743164062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.0690460205078
# Eval_StdReturn : 15.982505798339844
# Eval_MaxReturn : 213.99923706054688
# Eval_MinReturn : 157.10484313964844
# Eval_AverageEpLen : 87.66666666666667
# Train_AverageReturn : 206.90914916992188
# Train_StdReturn : 5.859936714172363
# Train_MaxReturn : 219.076904296875
# Train_MinReturn : 183.79141235351562
# Train_AverageEpLen : 91.88990825688073
# Train_EnvstepsSoFar : 100356
# TimeSinceStart : 65.79342985153198
# Training Loss : 164.42431640625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.14268493652344
# Eval_StdReturn : 13.083434104919434
# Eval_MaxReturn : 181.98880004882812
# Eval_MinReturn : 130.31094360351562
# Eval_AverageEpLen : 75.35714285714286
# Train_AverageReturn : 193.99728393554688
# Train_StdReturn : 16.571006774902344
# Train_MaxReturn : 224.73898315429688
# Train_MinReturn : 142.82159423828125
# Train_AverageEpLen : 87.10434782608695
# Train_EnvstepsSoFar : 110373
# TimeSinceStart : 71.84390258789062
# Training Loss : 160.8509521484375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 144.3070526123047
# Eval_StdReturn : 10.669608116149902
# Eval_MaxReturn : 158.67929077148438
# Eval_MinReturn : 122.81687927246094
# Eval_AverageEpLen : 71.42857142857143
# Train_AverageReturn : 157.71237182617188
# Train_StdReturn : 16.06005096435547
# Train_MaxReturn : 212.83847045898438
# Train_MinReturn : 125.53199768066406
# Train_AverageEpLen : 75.37593984962406
# Train_EnvstepsSoFar : 120398
# TimeSinceStart : 77.53936696052551
# Training Loss : 145.61428833007812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 129.10482788085938
# Eval_StdReturn : 10.885734558105469
# Eval_MaxReturn : 142.73403930664062
# Eval_MinReturn : 106.74630737304688
# Eval_AverageEpLen : 66.375
# Train_AverageReturn : 141.75428771972656
# Train_StdReturn : 13.924164772033691
# Train_MaxReturn : 185.65760803222656
# Train_MinReturn : 112.24581909179688
# Train_AverageEpLen : 70.16083916083916
# Train_EnvstepsSoFar : 130431
# TimeSinceStart : 83.73175978660583
# Training Loss : 136.98663330078125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 131.15924072265625
# Eval_StdReturn : 12.579503059387207
# Eval_MaxReturn : 152.03494262695312
# Eval_MinReturn : 106.46399688720703
# Eval_AverageEpLen : 67.06666666666666
# Train_AverageReturn : 135.6493682861328
# Train_StdReturn : 13.899126052856445
# Train_MaxReturn : 170.03207397460938
# Train_MinReturn : 102.7052993774414
# Train_AverageEpLen : 68.31292517006803
# Train_EnvstepsSoFar : 140473
# TimeSinceStart : 89.55581021308899
# Training Loss : 133.49945068359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 160.5057830810547
# Eval_StdReturn : 26.911827087402344
# Eval_MaxReturn : 206.50494384765625
# Eval_MinReturn : 121.12100219726562
# Eval_AverageEpLen : 77.28571428571429
# Train_AverageReturn : 140.72903442382812
# Train_StdReturn : 16.893959045410156
# Train_MaxReturn : 183.30081176757812
# Train_MinReturn : 107.34491729736328
# Train_AverageEpLen : 70.42957746478874
# Train_EnvstepsSoFar : 150474
# TimeSinceStart : 95.46870231628418
# Training Loss : 134.3763885498047
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.23988342285156
# Eval_StdReturn : 13.821915626525879
# Eval_MaxReturn : 208.15460205078125
# Eval_MinReturn : 162.81732177734375
# Eval_AverageEpLen : 89.83333333333333
# Train_AverageReturn : 159.322998046875
# Train_StdReturn : 20.895280838012695
# Train_MaxReturn : 206.96322631835938
# Train_MinReturn : 113.98733520507812
# Train_AverageEpLen : 77.57364341085271
# Train_EnvstepsSoFar : 160481
# TimeSinceStart : 101.43049931526184
# Training Loss : 142.79656982421875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10080 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.0395965576172
# Eval_StdReturn : 7.807274341583252
# Eval_MaxReturn : 198.05001831054688
# Eval_MinReturn : 173.552490234375
# Eval_AverageEpLen : 90.25
# Train_AverageReturn : 186.1184844970703
# Train_StdReturn : 12.82113265991211
# Train_MaxReturn : 220.02017211914062
# Train_MinReturn : 144.523681640625
# Train_AverageEpLen : 88.42105263157895
# Train_EnvstepsSoFar : 170561
# TimeSinceStart : 107.67125344276428
# Training Loss : 149.53250122070312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10082 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.99305725097656
# Eval_StdReturn : 57.91738510131836
# Eval_MaxReturn : 182.29969787597656
# Eval_MinReturn : 20.244380950927734
# Eval_AverageEpLen : 74.78571428571429
# Train_AverageReturn : 184.14556884765625
# Train_StdReturn : 18.007041931152344
# Train_MaxReturn : 212.64462280273438
# Train_MinReturn : 21.34878158569336
# Train_AverageEpLen : 88.43859649122807
# Train_EnvstepsSoFar : 180643
# TimeSinceStart : 113.58394074440002
# Training Loss : 148.27227783203125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10087 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.28430938720703
# Eval_StdReturn : 57.36798858642578
# Eval_MaxReturn : 186.53367614746094
# Eval_MinReturn : 37.688114166259766
# Eval_AverageEpLen : 59.0
# Train_AverageReturn : 137.84701538085938
# Train_StdReturn : 59.590240478515625
# Train_MaxReturn : 197.0916290283203
# Train_MinReturn : 21.167911529541016
# Train_AverageEpLen : 70.53846153846153
# Train_EnvstepsSoFar : 190730
# TimeSinceStart : 119.72626543045044
# Training Loss : 132.91636657714844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10084 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.8157196044922
# Eval_StdReturn : 49.65580368041992
# Eval_MaxReturn : 181.96588134765625
# Eval_MinReturn : 38.878997802734375
# Eval_AverageEpLen : 71.6
# Train_AverageReturn : 121.21953582763672
# Train_StdReturn : 59.90015411376953
# Train_MaxReturn : 189.8613739013672
# Train_MinReturn : 19.32893180847168
# Train_AverageEpLen : 63.42138364779874
# Train_EnvstepsSoFar : 200814
# TimeSinceStart : 125.74382019042969
# Training Loss : 126.03559875488281
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.79136657714844
# Eval_StdReturn : 2.5379014015197754
# Eval_MaxReturn : 176.3705291748047
# Eval_MinReturn : 167.86158752441406
# Eval_AverageEpLen : 84.33333333333333
# Train_AverageReturn : 144.4740753173828
# Train_StdReturn : 51.891483306884766
# Train_MaxReturn : 196.19973754882812
# Train_MinReturn : 4.444263935089111
# Train_AverageEpLen : 73.63970588235294
# Train_EnvstepsSoFar : 210829
# TimeSinceStart : 131.71083664894104
# Training Loss : 133.6937255859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.52601623535156
# Eval_StdReturn : 9.268611907958984
# Eval_MaxReturn : 178.94073486328125
# Eval_MinReturn : 143.31655883789062
# Eval_AverageEpLen : 83.75
# Train_AverageReturn : 164.255615234375
# Train_StdReturn : 29.957271575927734
# Train_MaxReturn : 227.2300262451172
# Train_MinReturn : 40.370506286621094
# Train_AverageEpLen : 81.869918699187
# Train_EnvstepsSoFar : 220899
# TimeSinceStart : 137.42057824134827
# Training Loss : 140.1352081298828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10030 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.0236358642578
# Eval_StdReturn : 9.277571678161621
# Eval_MaxReturn : 197.02590942382812
# Eval_MinReturn : 159.53997802734375
# Eval_AverageEpLen : 85.66666666666667
# Train_AverageReturn : 168.177734375
# Train_StdReturn : 22.50513458251953
# Train_MaxReturn : 212.59645080566406
# Train_MinReturn : 0.44603729248046875
# Train_AverageEpLen : 85.0
# Train_EnvstepsSoFar : 230929
# TimeSinceStart : 143.31909704208374
# Training Loss : 138.65673828125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.93629455566406
# Eval_StdReturn : 25.496623992919922
# Eval_MaxReturn : 260.92633056640625
# Eval_MinReturn : 165.4231719970703
# Eval_AverageEpLen : 91.27272727272727
# Train_AverageReturn : 172.09140014648438
# Train_StdReturn : 22.381210327148438
# Train_MaxReturn : 236.6116943359375
# Train_MinReturn : -0.29730987548828125
# Train_AverageEpLen : 85.58119658119658
# Train_EnvstepsSoFar : 240942
# TimeSinceStart : 149.13865637779236
# Training Loss : 140.688232421875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 175.60169982910156
# Eval_StdReturn : 7.3120903968811035
# Eval_MaxReturn : 196.47398376464844
# Eval_MinReturn : 165.28260803222656
# Eval_AverageEpLen : 88.08333333333333
# Train_AverageReturn : 177.44017028808594
# Train_StdReturn : 31.945026397705078
# Train_MaxReturn : 382.90728759765625
# Train_MinReturn : -0.913358747959137
# Train_AverageEpLen : 87.85087719298245
# Train_EnvstepsSoFar : 250957
# TimeSinceStart : 154.76404213905334
# Training Loss : 142.37696838378906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10079 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.3333282470703
# Eval_StdReturn : 15.574833869934082
# Eval_MaxReturn : 220.08993530273438
# Eval_MinReturn : 150.7626190185547
# Eval_AverageEpLen : 86.25
# Train_AverageReturn : 177.14840698242188
# Train_StdReturn : 37.814327239990234
# Train_MaxReturn : 364.30908203125
# Train_MinReturn : -1.1914527416229248
# Train_AverageEpLen : 87.64347826086957
# Train_EnvstepsSoFar : 261036
# TimeSinceStart : 160.72947764396667
# Training Loss : 143.21168518066406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10077 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.84796142578125
# Eval_StdReturn : 32.5770263671875
# Eval_MaxReturn : 268.97467041015625
# Eval_MinReturn : 169.46058654785156
# Eval_AverageEpLen : 91.27272727272727
# Train_AverageReturn : 179.5467071533203
# Train_StdReturn : 27.694791793823242
# Train_MaxReturn : 351.2984619140625
# Train_MinReturn : 152.27540588378906
# Train_AverageEpLen : 88.39473684210526
# Train_EnvstepsSoFar : 271113
# TimeSinceStart : 166.78414225578308
# Training Loss : 142.8909149169922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10072 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.31915283203125
# Eval_StdReturn : 34.118839263916016
# Eval_MaxReturn : 291.7703857421875
# Eval_MinReturn : 167.24093627929688
# Eval_AverageEpLen : 91.18181818181819
# Train_AverageReturn : 183.47959899902344
# Train_StdReturn : 39.251590728759766
# Train_MaxReturn : 337.37786865234375
# Train_MinReturn : -0.8156740069389343
# Train_AverageEpLen : 89.92857142857143
# Train_EnvstepsSoFar : 281185
# TimeSinceStart : 173.0864381790161
# Training Loss : 144.37368774414062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.51510620117188
# Eval_StdReturn : 6.560184955596924
# Eval_MaxReturn : 177.78936767578125
# Eval_MinReturn : 152.57965087890625
# Eval_AverageEpLen : 84.75
# Train_AverageReturn : 175.39271545410156
# Train_StdReturn : 31.912214279174805
# Train_MaxReturn : 352.0589599609375
# Train_MinReturn : -1.1975889205932617
# Train_AverageEpLen : 86.97391304347826
# Train_EnvstepsSoFar : 291187
# TimeSinceStart : 179.00739526748657
# Training Loss : 141.92324829101562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10077 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 154.95286560058594
# Eval_StdReturn : 32.05672836303711
# Eval_MaxReturn : 223.83267211914062
# Eval_MinReturn : 87.80384063720703
# Eval_AverageEpLen : 79.53846153846153
# Train_AverageReturn : 173.6129150390625
# Train_StdReturn : 36.808380126953125
# Train_MaxReturn : 324.9952087402344
# Train_MinReturn : -0.3622729778289795
# Train_AverageEpLen : 86.12820512820512
# Train_EnvstepsSoFar : 301264
# TimeSinceStart : 184.79288268089294
# Training Loss : 141.50274658203125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 160.38780212402344
# Eval_StdReturn : 16.92824363708496
# Eval_MaxReturn : 177.56228637695312
# Eval_MinReturn : 111.71296691894531
# Eval_AverageEpLen : 80.76923076923077
# Train_AverageReturn : 160.4190673828125
# Train_StdReturn : 41.50575256347656
# Train_MaxReturn : 394.06207275390625
# Train_MinReturn : 0.33934396505355835
# Train_AverageEpLen : 81.06451612903226
# Train_EnvstepsSoFar : 311316
# TimeSinceStart : 190.71297192573547
# Training Loss : 136.07550048828125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.6927032470703
# Eval_StdReturn : 11.271190643310547
# Eval_MaxReturn : 197.0837860107422
# Eval_MinReturn : 146.44424438476562
# Eval_AverageEpLen : 84.91666666666667
# Train_AverageReturn : 155.30519104003906
# Train_StdReturn : 44.394630432128906
# Train_MaxReturn : 356.7838134765625
# Train_MinReturn : 0.06137019395828247
# Train_AverageEpLen : 78.484375
# Train_EnvstepsSoFar : 321362
# TimeSinceStart : 196.89835810661316
# Training Loss : 135.44198608398438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.947265625
# Eval_StdReturn : 64.84497833251953
# Eval_MaxReturn : 352.4820556640625
# Eval_MinReturn : 60.170066833496094
# Eval_AverageEpLen : 81.3076923076923
# Train_AverageReturn : 158.45980834960938
# Train_StdReturn : 40.746803283691406
# Train_MaxReturn : 318.45098876953125
# Train_MinReturn : 66.90827178955078
# Train_AverageEpLen : 78.95275590551181
# Train_EnvstepsSoFar : 331389
# TimeSinceStart : 202.76084804534912
# Training Loss : 137.8265380859375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 205.1999053955078
# Eval_StdReturn : 48.39838790893555
# Eval_MaxReturn : 333.51080322265625
# Eval_MinReturn : 162.85125732421875
# Eval_AverageEpLen : 98.9090909090909
# Train_AverageReturn : 167.1393280029297
# Train_StdReturn : 44.96125411987305
# Train_MaxReturn : 335.2262878417969
# Train_MinReturn : 60.278289794921875
# Train_AverageEpLen : 83.45
# Train_EnvstepsSoFar : 341403
# TimeSinceStart : 208.2695825099945
# Training Loss : 138.7310791015625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10065 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.3259735107422
# Eval_StdReturn : 29.854930877685547
# Eval_MaxReturn : 259.4062805175781
# Eval_MinReturn : 137.6710662841797
# Eval_AverageEpLen : 88.5
# Train_AverageReturn : 174.56170654296875
# Train_StdReturn : 39.46796798706055
# Train_MaxReturn : 298.9599609375
# Train_MinReturn : 62.549537658691406
# Train_AverageEpLen : 87.52173913043478
# Train_EnvstepsSoFar : 351468
# TimeSinceStart : 214.08848667144775
# Training Loss : 139.12094116210938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.79676818847656
# Eval_StdReturn : 42.529178619384766
# Eval_MaxReturn : 279.4601135253906
# Eval_MinReturn : 119.74311065673828
# Eval_AverageEpLen : 91.41666666666667
# Train_AverageReturn : 172.20489501953125
# Train_StdReturn : 37.82205581665039
# Train_MaxReturn : 273.6336364746094
# Train_MinReturn : 54.7629280090332
# Train_AverageEpLen : 87.08695652173913
# Train_EnvstepsSoFar : 361483
# TimeSinceStart : 219.68904781341553
# Training Loss : 137.85205078125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10091 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 187.52383422851562
# Eval_StdReturn : 47.42853546142578
# Eval_MaxReturn : 310.01422119140625
# Eval_MinReturn : 121.16920471191406
# Eval_AverageEpLen : 95.27272727272727
# Train_AverageReturn : 186.9031982421875
# Train_StdReturn : 47.85887145996094
# Train_MaxReturn : 304.351806640625
# Train_MinReturn : 47.09166717529297
# Train_AverageEpLen : 92.57798165137615
# Train_EnvstepsSoFar : 371574
# TimeSinceStart : 226.06382966041565
# Training Loss : 142.72911071777344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10044 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 187.9133758544922
# Eval_StdReturn : 46.487430572509766
# Eval_MaxReturn : 294.53680419921875
# Eval_MinReturn : 121.07410430908203
# Eval_AverageEpLen : 96.0909090909091
# Train_AverageReturn : 184.28599548339844
# Train_StdReturn : 42.81718444824219
# Train_MaxReturn : 292.87445068359375
# Train_MinReturn : 0.5014382600784302
# Train_AverageEpLen : 93.0
# Train_EnvstepsSoFar : 381618
# TimeSinceStart : 232.55033349990845
# Training Loss : 139.78189086914062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10069 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.44595336914062
# Eval_StdReturn : 21.00322723388672
# Eval_MaxReturn : 220.29055786132812
# Eval_MinReturn : 152.70181274414062
# Eval_AverageEpLen : 91.0
# Train_AverageReturn : 174.9929962158203
# Train_StdReturn : 42.47376251220703
# Train_MaxReturn : 304.647216796875
# Train_MinReturn : 42.452613830566406
# Train_AverageEpLen : 89.10619469026548
# Train_EnvstepsSoFar : 391687
# TimeSinceStart : 238.72634315490723
# Training Loss : 137.36399841308594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10083 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 159.76181030273438
# Eval_StdReturn : 35.769901275634766
# Eval_MaxReturn : 196.35140991210938
# Eval_MinReturn : 48.719451904296875
# Eval_AverageEpLen : 83.46153846153847
# Train_AverageReturn : 164.31900024414062
# Train_StdReturn : 45.57578659057617
# Train_MaxReturn : 278.9263000488281
# Train_MinReturn : 42.386077880859375
# Train_AverageEpLen : 84.73109243697479
# Train_EnvstepsSoFar : 401770
# TimeSinceStart : 246.18978810310364
# Training Loss : 133.56773376464844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.75808715820312
# Eval_StdReturn : 50.949790954589844
# Eval_MaxReturn : 345.1854553222656
# Eval_MinReturn : 166.47064208984375
# Eval_AverageEpLen : 105.1
# Train_AverageReturn : 171.53692626953125
# Train_StdReturn : 48.51543045043945
# Train_MaxReturn : 278.1392517089844
# Train_MinReturn : 38.42551803588867
# Train_AverageEpLen : 87.73684210526316
# Train_EnvstepsSoFar : 411772
# TimeSinceStart : 252.58869099617004
# Training Loss : 136.3153839111328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.1751708984375
# Eval_StdReturn : 48.89059829711914
# Eval_MaxReturn : 274.27783203125
# Eval_MinReturn : 45.26303482055664
# Eval_AverageEpLen : 85.08333333333333
# Train_AverageReturn : 169.3013153076172
# Train_StdReturn : 47.998348236083984
# Train_MaxReturn : 324.6148681640625
# Train_MinReturn : 41.12431335449219
# Train_AverageEpLen : 85.20338983050847
# Train_EnvstepsSoFar : 421826
# TimeSinceStart : 258.526061296463
# Training Loss : 138.41233825683594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10049 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.1299591064453
# Eval_StdReturn : 17.345125198364258
# Eval_MaxReturn : 227.14222717285156
# Eval_MinReturn : 166.8240966796875
# Eval_AverageEpLen : 89.58333333333333
# Train_AverageReturn : 173.01193237304688
# Train_StdReturn : 29.945348739624023
# Train_MaxReturn : 261.14306640625
# Train_MinReturn : 48.9022331237793
# Train_AverageEpLen : 85.88888888888889
# Train_EnvstepsSoFar : 431875
# TimeSinceStart : 264.9348587989807
# Training Loss : 140.83245849609375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10079 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.02809143066406
# Eval_StdReturn : 34.06072998046875
# Eval_MaxReturn : 211.14007568359375
# Eval_MinReturn : 58.445716857910156
# Eval_AverageEpLen : 81.0
# Train_AverageReturn : 178.8577117919922
# Train_StdReturn : 17.916379928588867
# Train_MaxReturn : 252.33572387695312
# Train_MinReturn : 49.99270248413086
# Train_AverageEpLen : 86.14529914529915
# Train_EnvstepsSoFar : 441954
# TimeSinceStart : 270.9313323497772
# Training Loss : 145.78929138183594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.75999450683594
# Eval_StdReturn : 17.121368408203125
# Eval_MaxReturn : 209.505859375
# Eval_MinReturn : 140.17044067382812
# Eval_AverageEpLen : 83.66666666666667
# Train_AverageReturn : 179.79135131835938
# Train_StdReturn : 12.359647750854492
# Train_MaxReturn : 218.50477600097656
# Train_MinReturn : 153.5248260498047
# Train_AverageEpLen : 86.24137931034483
# Train_EnvstepsSoFar : 451958
# TimeSinceStart : 276.5734374523163
# Training Loss : 146.4315643310547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.5817108154297
# Eval_StdReturn : 10.983595848083496
# Eval_MaxReturn : 198.01165771484375
# Eval_MinReturn : 164.3974609375
# Eval_AverageEpLen : 84.83333333333333
# Train_AverageReturn : 175.92750549316406
# Train_StdReturn : 18.508758544921875
# Train_MaxReturn : 202.17893981933594
# Train_MinReturn : 17.081924438476562
# Train_AverageEpLen : 84.15126050420169
# Train_EnvstepsSoFar : 461972
# TimeSinceStart : 282.9240081310272
# Training Loss : 146.2763214111328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10078 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.73983764648438
# Eval_StdReturn : 6.889638900756836
# Eval_MaxReturn : 187.8304901123047
# Eval_MinReturn : 163.91848754882812
# Eval_AverageEpLen : 82.76923076923077
# Train_AverageReturn : 175.745361328125
# Train_StdReturn : 11.008323669433594
# Train_MaxReturn : 208.5366973876953
# Train_MinReturn : 155.8077392578125
# Train_AverageEpLen : 83.98333333333333
# Train_EnvstepsSoFar : 472050
# TimeSinceStart : 289.018187046051
# Training Loss : 145.99307250976562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.34388732910156
# Eval_StdReturn : 7.191957950592041
# Eval_MaxReturn : 189.34722900390625
# Eval_MinReturn : 161.23968505859375
# Eval_AverageEpLen : 84.33333333333333
# Train_AverageReturn : 170.15106201171875
# Train_StdReturn : 16.198469161987305
# Train_MaxReturn : 194.93417358398438
# Train_MinReturn : 19.504823684692383
# Train_AverageEpLen : 83.12396694214875
# Train_EnvstepsSoFar : 482108
# TimeSinceStart : 295.1947431564331
# Training Loss : 141.16554260253906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.11732482910156
# Eval_StdReturn : 11.744905471801758
# Eval_MaxReturn : 196.64288330078125
# Eval_MinReturn : 141.16075134277344
# Eval_AverageEpLen : 83.5
# Train_AverageReturn : 168.70372009277344
# Train_StdReturn : 15.672958374023438
# Train_MaxReturn : 200.21202087402344
# Train_MinReturn : 16.971263885498047
# Train_AverageEpLen : 83.09917355371901
# Train_EnvstepsSoFar : 492163
# TimeSinceStart : 301.2647113800049
# Training Loss : 140.88204956054688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.14637756347656
# Eval_StdReturn : 6.378379821777344
# Eval_MaxReturn : 174.36109924316406
# Eval_MinReturn : 147.5765380859375
# Eval_AverageEpLen : 83.91666666666667
# Train_AverageReturn : 169.48147583007812
# Train_StdReturn : 6.172852516174316
# Train_MaxReturn : 186.69825744628906
# Train_MinReturn : 138.82684326171875
# Train_AverageEpLen : 83.675
# Train_EnvstepsSoFar : 502204
# TimeSinceStart : 307.806024312973
# Training Loss : 139.56336975097656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10065 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 164.59042358398438
# Eval_StdReturn : 8.531434059143066
# Eval_MaxReturn : 171.9368438720703
# Eval_MinReturn : 139.14657592773438
# Eval_AverageEpLen : 82.23076923076923
# Train_AverageReturn : 168.3480987548828
# Train_StdReturn : 8.163657188415527
# Train_MaxReturn : 184.4119110107422
# Train_MinReturn : 129.7427978515625
# Train_AverageEpLen : 83.18181818181819
# Train_EnvstepsSoFar : 512269
# TimeSinceStart : 313.97663402557373
# Training Loss : 139.69532775878906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 166.15170288085938
# Eval_StdReturn : 8.75718879699707
# Eval_MaxReturn : 176.0164794921875
# Eval_MinReturn : 148.2119903564453
# Eval_AverageEpLen : 82.23076923076923
# Train_AverageReturn : 165.51844787597656
# Train_StdReturn : 11.324548721313477
# Train_MaxReturn : 179.20687866210938
# Train_MinReturn : 106.36543273925781
# Train_AverageEpLen : 82.10655737704919
# Train_EnvstepsSoFar : 522286
# TimeSinceStart : 319.6696181297302
# Training Loss : 138.8854217529297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10071 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 152.68495178222656
# Eval_StdReturn : 13.2738618850708
# Eval_MaxReturn : 173.74317932128906
# Eval_MinReturn : 132.01788330078125
# Eval_AverageEpLen : 77.6923076923077
# Train_AverageReturn : 161.2201690673828
# Train_StdReturn : 15.408629417419434
# Train_MaxReturn : 176.5750274658203
# Train_MinReturn : 90.85020446777344
# Train_AverageEpLen : 80.568
# Train_EnvstepsSoFar : 532357
# TimeSinceStart : 325.6078636646271
# Training Loss : 136.80545043945312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 159.6624298095703
# Eval_StdReturn : 12.573097229003906
# Eval_MaxReturn : 175.81723022460938
# Eval_MinReturn : 136.9400177001953
# Eval_AverageEpLen : 80.0
# Train_AverageReturn : 157.56150817871094
# Train_StdReturn : 20.021499633789062
# Train_MaxReturn : 178.36636352539062
# Train_MinReturn : 76.41588592529297
# Train_AverageEpLen : 78.74803149606299
# Train_EnvstepsSoFar : 542358
# TimeSinceStart : 331.69406390190125
# Training Loss : 136.4945831298828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.353271484375
# Eval_StdReturn : 10.041483879089355
# Eval_MaxReturn : 174.3303680419922
# Eval_MinReturn : 133.9407196044922
# Eval_AverageEpLen : 83.15384615384616
# Train_AverageReturn : 157.11093139648438
# Train_StdReturn : 23.286184310913086
# Train_MaxReturn : 180.79652404785156
# Train_MinReturn : 81.24563598632812
# Train_AverageEpLen : 78.3515625
# Train_EnvstepsSoFar : 552387
# TimeSinceStart : 337.8625454902649
# Training Loss : 136.7477264404297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.3035430908203
# Eval_StdReturn : 2.2275967597961426
# Eval_MaxReturn : 173.96490478515625
# Eval_MinReturn : 167.38131713867188
# Eval_AverageEpLen : 83.91666666666667
# Train_AverageReturn : 169.1606903076172
# Train_StdReturn : 10.032872200012207
# Train_MaxReturn : 176.75674438476562
# Train_MinReturn : 89.62830352783203
# Train_AverageEpLen : 83.48333333333333
# Train_EnvstepsSoFar : 562405
# TimeSinceStart : 343.7737019062042
# Training Loss : 140.64173889160156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 157.57882690429688
# Eval_StdReturn : 38.9445686340332
# Eval_MaxReturn : 174.69322204589844
# Eval_MinReturn : 22.967910766601562
# Eval_AverageEpLen : 79.0
# Train_AverageReturn : 169.72940063476562
# Train_StdReturn : 2.9920828342437744
# Train_MaxReturn : 176.2111053466797
# Train_MinReturn : 157.7582244873047
# Train_AverageEpLen : 84.25210084033614
# Train_EnvstepsSoFar : 572431
# TimeSinceStart : 349.88634729385376
# Training Loss : 139.87461853027344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10063 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 153.1816864013672
# Eval_StdReturn : 38.709068298339844
# Eval_MaxReturn : 171.5585479736328
# Eval_MinReturn : 20.410017013549805
# Eval_AverageEpLen : 77.76923076923077
# Train_AverageReturn : 162.81126403808594
# Train_StdReturn : 24.30588150024414
# Train_MaxReturn : 174.40362548828125
# Train_MinReturn : 16.91813087463379
# Train_AverageEpLen : 81.8130081300813
# Train_EnvstepsSoFar : 582494
# TimeSinceStart : 356.2589716911316
# Training Loss : 138.04881286621094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.16537475585938
# Eval_StdReturn : 50.783042907714844
# Eval_MaxReturn : 169.4044189453125
# Eval_MinReturn : 21.142440795898438
# Eval_AverageEpLen : 74.28571428571429
# Train_AverageReturn : 153.06491088867188
# Train_StdReturn : 35.87660598754883
# Train_MaxReturn : 172.8966827392578
# Train_MinReturn : 16.762537002563477
# Train_AverageEpLen : 78.296875
# Train_EnvstepsSoFar : 592516
# TimeSinceStart : 362.6547737121582
# Training Loss : 134.2310333251953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.509521484375
# Eval_StdReturn : 3.588151454925537
# Eval_MaxReturn : 175.0445098876953
# Eval_MinReturn : 160.4492950439453
# Eval_AverageEpLen : 83.75
# Train_AverageReturn : 161.49200439453125
# Train_StdReturn : 25.524490356445312
# Train_MaxReturn : 175.8443145751953
# Train_MinReturn : 20.885841369628906
# Train_AverageEpLen : 81.52032520325203
# Train_EnvstepsSoFar : 602543
# TimeSinceStart : 368.7220575809479
# Training Loss : 137.20484924316406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.806396484375
# Eval_StdReturn : 1.6702905893325806
# Eval_MaxReturn : 176.0490264892578
# Eval_MinReturn : 170.60520935058594
# Eval_AverageEpLen : 84.41666666666667
# Train_AverageReturn : 169.26089477539062
# Train_StdReturn : 13.629918098449707
# Train_MaxReturn : 175.5407257080078
# Train_MinReturn : 22.830219268798828
# Train_AverageEpLen : 83.64166666666667
# Train_EnvstepsSoFar : 612580
# TimeSinceStart : 374.8148808479309
# Training Loss : 141.58384704589844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 163.35826110839844
# Eval_StdReturn : 13.886222839355469
# Eval_MaxReturn : 175.64849853515625
# Eval_MinReturn : 130.51513671875
# Eval_AverageEpLen : 81.38461538461539
# Train_AverageReturn : 170.66445922851562
# Train_StdReturn : 7.782901287078857
# Train_MaxReturn : 177.6671142578125
# Train_MinReturn : 104.91329956054688
# Train_AverageEpLen : 83.55
# Train_EnvstepsSoFar : 622606
# TimeSinceStart : 381.4918510913849
# Training Loss : 143.23316955566406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 156.07510375976562
# Eval_StdReturn : 15.032646179199219
# Eval_MaxReturn : 178.38516235351562
# Eval_MinReturn : 133.61874389648438
# Eval_AverageEpLen : 77.35714285714286
# Train_AverageReturn : 164.30020141601562
# Train_StdReturn : 13.844522476196289
# Train_MaxReturn : 178.1857147216797
# Train_MinReturn : 105.5585708618164
# Train_AverageEpLen : 80.8225806451613
# Train_EnvstepsSoFar : 632628
# TimeSinceStart : 388.2284469604492
# Training Loss : 141.29058837890625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# ...
# Train_AverageEpLen : 160.85714285714286
# Train_EnvstepsSoFar : 793668
# TimeSinceStart : 492.1943349838257
# Training Loss : 149.7958984375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     10103 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 231.47952270507812
# Eval_StdReturn : 82.59664916992188
# Eval_MaxReturn : 342.3869934082031
# Eval_MinReturn : 77.82827758789062
# Eval_AverageEpLen : 128.375
# Train_AverageReturn : 310.7716979980469
# Train_StdReturn : 105.92312622070312
# Train_MaxReturn : 493.0082702636719
# Train_MinReturn : 78.18142700195312
# Train_AverageEpLen : 155.43076923076924
# Train_EnvstepsSoFar : 803771
# TimeSinceStart : 501.4109537601471
# Training Loss : 150.10191345214844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10097 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 258.9481506347656
# Eval_StdReturn : 64.63662719726562
# Eval_MaxReturn : 369.61767578125
# Eval_MinReturn : 188.8498992919922
# Eval_AverageEpLen : 143.0
# Train_AverageReturn : 262.1663818359375
# Train_StdReturn : 84.8627700805664
# Train_MaxReturn : 502.7666015625
# Train_MinReturn : 74.01201629638672
# Train_AverageEpLen : 138.31506849315068
# Train_EnvstepsSoFar : 813868
# TimeSinceStart : 509.77806091308594
# Training Loss : 140.82696533203125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 195.40042114257812
# Eval_StdReturn : 83.58086395263672
# Eval_MaxReturn : 316.8783264160156
# Eval_MinReturn : 81.85273742675781
# Eval_AverageEpLen : 115.55555555555556
# Train_AverageReturn : 215.57127380371094
# Train_StdReturn : 84.44960021972656
# Train_MaxReturn : 365.9031066894531
# Train_MinReturn : 73.93838500976562
# Train_AverageEpLen : 120.65060240963855
# Train_EnvstepsSoFar : 823882
# TimeSinceStart : 517.9729721546173
# Training Loss : 128.68356323242188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10120 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 222.87017822265625
# Eval_StdReturn : 64.11894226074219
# Eval_MaxReturn : 318.4258728027344
# Eval_MinReturn : 81.16068267822266
# Eval_AverageEpLen : 125.5
# Train_AverageReturn : 211.55369567871094
# Train_StdReturn : 73.65422821044922
# Train_MaxReturn : 363.3144226074219
# Train_MinReturn : 71.93876647949219
# Train_AverageEpLen : 121.92771084337349
# Train_EnvstepsSoFar : 834002
# TimeSinceStart : 525.8882882595062
# Training Loss : 124.30328369140625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10044 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 238.708251953125
# Eval_StdReturn : 91.72937774658203
# Eval_MaxReturn : 380.7875061035156
# Eval_MinReturn : 114.04801940917969
# Eval_AverageEpLen : 133.5
# Train_AverageReturn : 185.6288604736328
# Train_StdReturn : 75.65770721435547
# Train_MaxReturn : 362.7256774902344
# Train_MinReturn : 75.74296569824219
# Train_AverageEpLen : 112.85393258426966
# Train_EnvstepsSoFar : 844046
# TimeSinceStart : 533.5416758060455
# Training Loss : 115.80772399902344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10086 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 135.8726043701172
# Eval_StdReturn : 50.90944290161133
# Eval_MaxReturn : 244.9383087158203
# Eval_MinReturn : 90.85777282714844
# Eval_AverageEpLen : 85.41666666666667
# Train_AverageReturn : 183.59945678710938
# Train_StdReturn : 85.9555892944336
# Train_MaxReturn : 376.39117431640625
# Train_MinReturn : 69.97478485107422
# Train_AverageEpLen : 108.45161290322581
# Train_EnvstepsSoFar : 854132
# TimeSinceStart : 540.9387807846069
# Training Loss : 118.87100982666016
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10073 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 189.1366729736328
# Eval_StdReturn : 73.11878967285156
# Eval_MaxReturn : 347.62554931640625
# Eval_MinReturn : 64.57151794433594
# Eval_AverageEpLen : 100.9
# Train_AverageReturn : 178.51620483398438
# Train_StdReturn : 84.75154876708984
# Train_MaxReturn : 416.178466796875
# Train_MinReturn : 76.55986785888672
# Train_AverageEpLen : 106.03157894736842
# Train_EnvstepsSoFar : 864205
# TimeSinceStart : 547.995964050293
# Training Loss : 117.15257263183594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.25018310546875
# Eval_StdReturn : 71.3072738647461
# Eval_MaxReturn : 272.21697998046875
# Eval_MinReturn : 62.262229919433594
# Eval_AverageEpLen : 95.81818181818181
# Train_AverageReturn : 202.86874389648438
# Train_StdReturn : 73.1973648071289
# Train_MaxReturn : 390.31060791015625
# Train_MinReturn : 84.26707458496094
# Train_AverageEpLen : 109.23913043478261
# Train_EnvstepsSoFar : 874255
# TimeSinceStart : 554.636483669281
# Training Loss : 132.36904907226562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 149.3488311767578
# Eval_StdReturn : 81.06403350830078
# Eval_MaxReturn : 235.07015991210938
# Eval_MinReturn : 40.211029052734375
# Eval_AverageEpLen : 83.23076923076923
# Train_AverageReturn : 189.9368896484375
# Train_StdReturn : 73.14903259277344
# Train_MaxReturn : 365.51751708984375
# Train_MinReturn : 40.28237533569336
# Train_AverageEpLen : 97.62135922330097
# Train_EnvstepsSoFar : 884310
# TimeSinceStart : 561.9652564525604
# Training Loss : 136.70962524414062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.47945404052734
# Eval_StdReturn : 77.73416900634766
# Eval_MaxReturn : 244.01803588867188
# Eval_MinReturn : 37.78106689453125
# Eval_AverageEpLen : 75.28571428571429
# Train_AverageReturn : 145.17526245117188
# Train_StdReturn : 86.2374038696289
# Train_MaxReturn : 334.7529296875
# Train_MinReturn : 33.75395202636719
# Train_AverageEpLen : 81.42276422764228
# Train_EnvstepsSoFar : 894325
# TimeSinceStart : 568.8286550045013
# Training Loss : 122.9543685913086
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10008 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.38317108154297
# Eval_StdReturn : 75.61002349853516
# Eval_MaxReturn : 257.07147216796875
# Eval_MinReturn : 36.957916259765625
# Eval_AverageEpLen : 67.11764705882354
# Train_AverageReturn : 139.96788024902344
# Train_StdReturn : 85.51629638671875
# Train_MaxReturn : 316.9975280761719
# Train_MinReturn : 34.70235824584961
# Train_AverageEpLen : 82.0327868852459
# Train_EnvstepsSoFar : 904333
# TimeSinceStart : 575.8803725242615
# Training Loss : 117.68185424804688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10064 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 119.00265502929688
# Eval_StdReturn : 81.57588195800781
# Eval_MaxReturn : 262.3474426269531
# Eval_MinReturn : 38.88634490966797
# Eval_AverageEpLen : 78.6923076923077
# Train_AverageReturn : 127.68389129638672
# Train_StdReturn : 86.57815551757812
# Train_MaxReturn : 273.4241027832031
# Train_MinReturn : 35.17911148071289
# Train_AverageEpLen : 79.24409448818898
# Train_EnvstepsSoFar : 914397
# TimeSinceStart : 583.1161704063416
# Training Loss : 110.12126159667969
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.38490295410156
# Eval_StdReturn : 81.41136169433594
# Eval_MaxReturn : 278.17840576171875
# Eval_MinReturn : 42.08271408081055
# Eval_AverageEpLen : 106.2
# Train_AverageReturn : 141.90084838867188
# Train_StdReturn : 89.77271270751953
# Train_MaxReturn : 289.22216796875
# Train_MinReturn : 36.35054397583008
# Train_AverageEpLen : 87.3913043478261
# Train_EnvstepsSoFar : 924447
# TimeSinceStart : 591.6411085128784
# Training Loss : 112.80435180664062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10080 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.16290283203125
# Eval_StdReturn : 82.25379180908203
# Eval_MaxReturn : 289.35076904296875
# Eval_MinReturn : 60.579307556152344
# Eval_AverageEpLen : 111.22222222222223
# Train_AverageReturn : 148.41058349609375
# Train_StdReturn : 86.68092346191406
# Train_MaxReturn : 295.362060546875
# Train_MinReturn : 39.5250244140625
# Train_AverageEpLen : 92.4770642201835
# Train_EnvstepsSoFar : 934527
# TimeSinceStart : 599.7157113552094
# Training Loss : 111.76302337646484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10123 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.1316375732422
# Eval_StdReturn : 71.6358642578125
# Eval_MaxReturn : 257.8959655761719
# Eval_MinReturn : 64.5390396118164
# Eval_AverageEpLen : 102.5
# Train_AverageReturn : 159.08668518066406
# Train_StdReturn : 79.40657043457031
# Train_MaxReturn : 275.8941650390625
# Train_MinReturn : 41.392478942871094
# Train_AverageEpLen : 97.33653846153847
# Train_EnvstepsSoFar : 944650
# TimeSinceStart : 606.8353114128113
# Training Loss : 115.63490295410156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 203.82362365722656
# Eval_StdReturn : 49.6532096862793
# Eval_MaxReturn : 257.9207763671875
# Eval_MinReturn : 101.16744995117188
# Eval_AverageEpLen : 112.7
# Train_AverageReturn : 191.7566375732422
# Train_StdReturn : 67.6471939086914
# Train_MaxReturn : 270.2571105957031
# Train_MinReturn : 46.849971771240234
# Train_AverageEpLen : 110.1978021978022
# Train_EnvstepsSoFar : 954678
# TimeSinceStart : 614.2706835269928
# Training Loss : 124.48310089111328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 203.2420654296875
# Eval_StdReturn : 31.972013473510742
# Eval_MaxReturn : 256.7134704589844
# Eval_MinReturn : 127.41876983642578
# Eval_AverageEpLen : 107.8
# Train_AverageReturn : 200.5816192626953
# Train_StdReturn : 56.573211669921875
# Train_MaxReturn : 275.89849853515625
# Train_MinReturn : 58.285400390625
# Train_AverageEpLen : 111.37777777777778
# Train_EnvstepsSoFar : 964702
# TimeSinceStart : 621.9881107807159
# Training Loss : 128.87562561035156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 215.17311096191406
# Eval_StdReturn : 37.76028060913086
# Eval_MaxReturn : 251.02935791015625
# Eval_MinReturn : 130.33335876464844
# Eval_AverageEpLen : 118.33333333333333
# Train_AverageReturn : 212.50408935546875
# Train_StdReturn : 40.311275482177734
# Train_MaxReturn : 287.63018798828125
# Train_MinReturn : 81.47236633300781
# Train_AverageEpLen : 113.98863636363636
# Train_EnvstepsSoFar : 974733
# TimeSinceStart : 629.6221966743469
# Training Loss : 134.8254852294922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10129 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 217.77728271484375
# Eval_StdReturn : 20.422073364257812
# Eval_MaxReturn : 248.23001098632812
# Eval_MinReturn : 177.173583984375
# Eval_AverageEpLen : 115.55555555555556
# Train_AverageReturn : 215.6549530029297
# Train_StdReturn : 43.719581604003906
# Train_MaxReturn : 298.51239013671875
# Train_MinReturn : 75.4019775390625
# Train_AverageEpLen : 117.77906976744185
# Train_EnvstepsSoFar : 984862
# TimeSinceStart : 636.1312322616577
# Training Loss : 131.75753784179688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 206.0035858154297
# Eval_StdReturn : 21.702348709106445
# Eval_MaxReturn : 234.16392517089844
# Eval_MinReturn : 174.0355987548828
# Eval_AverageEpLen : 109.8
# Train_AverageReturn : 213.82138061523438
# Train_StdReturn : 35.6099853515625
# Train_MaxReturn : 289.3956298828125
# Train_MinReturn : 94.86112976074219
# Train_AverageEpLen : 114.07954545454545
# Train_EnvstepsSoFar : 994901
# TimeSinceStart : 642.4884920120239
# Training Loss : 134.4961700439453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 201.19920349121094
# Eval_StdReturn : 41.77073669433594
# Eval_MaxReturn : 247.2769775390625
# Eval_MinReturn : 113.82162475585938
# Eval_AverageEpLen : 111.9
# Train_AverageReturn : 222.3878173828125
# Train_StdReturn : 28.886653900146484
# Train_MaxReturn : 286.54302978515625
# Train_MinReturn : 147.14828491210938
# Train_AverageEpLen : 119.17857142857143
# Train_EnvstepsSoFar : 1004912
# TimeSinceStart : 648.6110751628876
# Training Loss : 135.22068786621094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...

# %%
### Visualize Policy Gradient results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-ee206549b2abdb01" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ee206549b2abdb01");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Variance Reduction with a Value Function Baseline
# We can further reduce the policy gradient variance by including state-dependent baselines. In this section, we will train a value function network to predict the value of the policy at a state, then use the value function as a baseline by subtracting it from our reward-to-go estimate.
#
# Implement the value function baseline loss in the update method of the MLPPolicyPG class in <code>policies/MLP_policy.py</code>.

# %%
# Test value function gradient
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicyPG(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25,
            nn_baseline=True)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))
advs = 1000 * np.random.normal(size=(batch_size,))
qvals = advs

first_weight_before = np.array(ptu.to_numpy(next(policy.baseline.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts, advs, qvals=qvals)['Baseline Loss']

print(loss)
expected_loss = 0.925361
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.baseline.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 0.38988823,  0.70297027,  0.2609921 ],
                            [-1.0340402,  -0.84166795,  0.7254925 ]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.23799711  0.02138712  0.22824688]
#  [ 0.34642333 -0.39140946 -0.25141457]]
# 0.925361
# Loss Error 1.2076536367060315e-08 should be on the order of 1e-6 or lower
# Weight after update [[ 0.15189111  0.72435737  0.489239  ]
#  [-0.68761694 -1.2330774   0.47407794]]
# Change in weights [[ 0.38988823  0.70297027  0.2609921 ]
#  [-1.0340402  -0.84166795  0.7254925 ]]
# Weight Update Error 1.8727660770522845e-08 should be on the order of 1e-6 or lower

# %% [markdown]
# In the estimate_advantage function in <code>agents/pg_agent.py</code>, fill out the advantage estimate using the baseline and test your implementation below.

# %%
### Test return computation
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['nn_baseline'] = True
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

obs_dim = 4
N = 10
np.random.seed(0)
obs = np.random.normal(size=(N, obs_dim))
qs = np.random.normal(size=N)

baseline_advantages = pgagent.estimate_advantage(obs, qs)
expected_advantages = np.array([-0.44662586, -0.89629588, -1.14574752,  2.43957172, -0.06601728,
       -0.00501807, -0.74720337,  1.27468092, -1.20184486,  0.25312274])

advantage_error = rel_error(expected_advantages, baseline_advantages)
print("Advantage error", advantage_error, "should be on the order of 1e-6 or lower")
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Advantage error 3.6888988344448045e-07 should be on the order of 1e-6 or lower

# %% [markdown]
# ## Train your policies!
# In this section, we will train our policies using the reward-to-go estimator and learning a value function baseline. On Hopper, you should see your methods get over 300 rewards consistently, and sometimes over 400. Returns will tend to oscillate during training. You should also see that using a value function baseline greatly improves performance over our earlier experiments without it.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = True
pg_args['nn_baseline'] = True
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/with_baseline/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/with_baseline/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Clearing old results at logs/policy_gradient/Hopper/with_baseline/
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/with_baseline/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.84849548339844
# Eval_StdReturn : 33.547855377197266
# Eval_MaxReturn : 155.4940185546875
# Eval_MinReturn : 29.384666442871094
# Eval_AverageEpLen : 58.5
# Train_AverageReturn : 9.403343200683594
# Train_StdReturn : 4.718483924865723
# Train_MaxReturn : 46.106727600097656
# Train_MinReturn : 2.846346378326416
# Train_AverageEpLen : 12.939276485788113
# Train_EnvstepsSoFar : 10015
# TimeSinceStart : 6.8784401416778564
# Training Loss : 3.9577796459198
# Baseline Loss : 1.0592422485351562
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.52185821533203
# Eval_StdReturn : 52.784881591796875
# Eval_MaxReturn : 207.3875732421875
# Eval_MinReturn : 49.420433044433594
# Eval_AverageEpLen : 59.111111111111114
# Train_AverageReturn : 97.38761138916016
# Train_StdReturn : 51.84263610839844
# Train_MaxReturn : 263.6323547363281
# Train_MinReturn : 5.4555816650390625
# Train_AverageEpLen : 60.44578313253012
# Train_EnvstepsSoFar : 20049
# TimeSinceStart : 13.645504236221313
# Training Loss : -14.395066261291504
# Baseline Loss : 1.2495510578155518
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 154.86862182617188
# Eval_StdReturn : 59.43190383911133
# Eval_MaxReturn : 214.60768127441406
# Eval_MinReturn : 57.70475387573242
# Eval_AverageEpLen : 73.57142857142857
# Train_AverageReturn : 109.16539764404297
# Train_StdReturn : 44.80699920654297
# Train_MaxReturn : 247.84918212890625
# Train_MinReturn : 54.69504165649414
# Train_AverageEpLen : 57.94219653179191
# Train_EnvstepsSoFar : 30073
# TimeSinceStart : 20.192677974700928
# Training Loss : -8.466607093811035
# Baseline Loss : 1.0519475936889648
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.2843017578125
# Eval_StdReturn : 16.108142852783203
# Eval_MaxReturn : 207.7852020263672
# Eval_MinReturn : 144.90432739257812
# Eval_AverageEpLen : 85.91666666666667
# Train_AverageReturn : 138.61468505859375
# Train_StdReturn : 58.83147430419922
# Train_MaxReturn : 219.96075439453125
# Train_MinReturn : 20.248825073242188
# Train_AverageEpLen : 68.21768707482993
# Train_EnvstepsSoFar : 40101
# TimeSinceStart : 26.540894985198975
# Training Loss : 0.04974088817834854
# Baseline Loss : 1.0686315298080444
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10081 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 181.00526428222656
# Eval_StdReturn : 21.687156677246094
# Eval_MaxReturn : 207.7041015625
# Eval_MinReturn : 136.44358825683594
# Eval_AverageEpLen : 82.6923076923077
# Train_AverageReturn : 186.64569091796875
# Train_StdReturn : 29.183874130249023
# Train_MaxReturn : 214.93048095703125
# Train_MinReturn : 45.535240173339844
# Train_AverageEpLen : 84.71428571428571
# Train_EnvstepsSoFar : 50182
# TimeSinceStart : 33.39398789405823
# Training Loss : 8.81011962890625
# Baseline Loss : 1.0044746398925781
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 177.49363708496094
# Eval_StdReturn : 18.7716007232666
# Eval_MaxReturn : 210.1418914794922
# Eval_MinReturn : 144.29176330566406
# Eval_AverageEpLen : 81.0
# Train_AverageReturn : 188.60247802734375
# Train_StdReturn : 17.285001754760742
# Train_MaxReturn : 213.0032958984375
# Train_MinReturn : 127.2325439453125
# Train_AverageEpLen : 84.9322033898305
# Train_EnvstepsSoFar : 60204
# TimeSinceStart : 39.35457921028137
# Training Loss : 7.446449279785156
# Baseline Loss : 0.9286069869995117
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.8250274658203
# Eval_StdReturn : 18.03797721862793
# Eval_MaxReturn : 208.41139221191406
# Eval_MinReturn : 150.87249755859375
# Eval_AverageEpLen : 83.66666666666667
# Train_AverageReturn : 182.4478759765625
# Train_StdReturn : 26.72918128967285
# Train_MaxReturn : 221.31520080566406
# Train_MinReturn : 22.284727096557617
# Train_AverageEpLen : 82.66115702479338
# Train_EnvstepsSoFar : 70206
# TimeSinceStart : 45.32371735572815
# Training Loss : 2.8451266288757324
# Baseline Loss : 0.8878705501556396
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 195.0240936279297
# Eval_StdReturn : 8.2108736038208
# Eval_MaxReturn : 205.46986389160156
# Eval_MinReturn : 181.4990234375
# Eval_AverageEpLen : 87.16666666666667
# Train_AverageReturn : 186.92764282226562
# Train_StdReturn : 20.2882137298584
# Train_MaxReturn : 215.34487915039062
# Train_MinReturn : 101.64033508300781
# Train_AverageEpLen : 84.29411764705883
# Train_EnvstepsSoFar : 80237
# TimeSinceStart : 51.31864309310913
# Training Loss : 0.009693406522274017
# Baseline Loss : 0.8594197630882263
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.7256317138672
# Eval_StdReturn : 7.4699602127075195
# Eval_MaxReturn : 201.5693817138672
# Eval_MinReturn : 176.160888671875
# Eval_AverageEpLen : 86.25
# Train_AverageReturn : 191.70248413085938
# Train_StdReturn : 8.85874080657959
# Train_MaxReturn : 210.2108612060547
# Train_MinReturn : 173.30128479003906
# Train_AverageEpLen : 86.34482758620689
# Train_EnvstepsSoFar : 90253
# TimeSinceStart : 57.09963393211365
# Training Loss : -0.8511717915534973
# Baseline Loss : 0.8118973970413208
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10084 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 186.8716583251953
# Eval_StdReturn : 6.461989879608154
# Eval_MaxReturn : 202.28199768066406
# Eval_MinReturn : 177.33547973632812
# Eval_AverageEpLen : 84.91666666666667
# Train_AverageReturn : 190.4232635498047
# Train_StdReturn : 9.88088321685791
# Train_MaxReturn : 212.63160705566406
# Train_MinReturn : 144.91021728515625
# Train_AverageEpLen : 86.1880341880342
# Train_EnvstepsSoFar : 100337
# TimeSinceStart : 62.91306114196777
# Training Loss : 1.376469373703003
# Baseline Loss : 0.7493181824684143
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.7637939453125
# Eval_StdReturn : 8.391009330749512
# Eval_MaxReturn : 201.6374053955078
# Eval_MinReturn : 174.5752410888672
# Eval_AverageEpLen : 85.58333333333333
# Train_AverageReturn : 187.32424926757812
# Train_StdReturn : 7.65865421295166
# Train_MaxReturn : 209.7080535888672
# Train_MinReturn : 170.9979248046875
# Train_AverageEpLen : 85.27118644067797
# Train_EnvstepsSoFar : 110399
# TimeSinceStart : 68.53890419006348
# Training Loss : 3.740941047668457
# Baseline Loss : 0.6973870396614075
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10060 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 180.3326416015625
# Eval_StdReturn : 4.392510414123535
# Eval_MaxReturn : 186.06324768066406
# Eval_MinReturn : 172.5973663330078
# Eval_AverageEpLen : 83.75
# Train_AverageReturn : 183.13189697265625
# Train_StdReturn : 8.623514175415039
# Train_MaxReturn : 206.4049835205078
# Train_MinReturn : 138.16506958007812
# Train_AverageEpLen : 84.53781512605042
# Train_EnvstepsSoFar : 120459
# TimeSinceStart : 74.23219108581543
# Training Loss : 2.943596124649048
# Baseline Loss : 0.650490403175354
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10049 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.9476776123047
# Eval_StdReturn : 7.360119342803955
# Eval_MaxReturn : 201.1749267578125
# Eval_MinReturn : 173.40762329101562
# Eval_AverageEpLen : 86.41666666666667
# Train_AverageReturn : 181.29417419433594
# Train_StdReturn : 6.815148830413818
# Train_MaxReturn : 201.43922424316406
# Train_MinReturn : 162.4883270263672
# Train_AverageEpLen : 84.4453781512605
# Train_EnvstepsSoFar : 130508
# TimeSinceStart : 79.83061027526855
# Training Loss : 0.08448338508605957
# Baseline Loss : 0.6149272918701172
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 175.25437927246094
# Eval_StdReturn : 11.364452362060547
# Eval_MaxReturn : 184.93190002441406
# Eval_MinReturn : 146.18814086914062
# Eval_AverageEpLen : 84.0
# Train_AverageReturn : 181.1742706298828
# Train_StdReturn : 8.771733283996582
# Train_MaxReturn : 203.82069396972656
# Train_MinReturn : 149.28297424316406
# Train_AverageEpLen : 84.99152542372882
# Train_EnvstepsSoFar : 140537
# TimeSinceStart : 85.76346063613892
# Training Loss : -2.328068494796753
# Baseline Loss : 0.5828776955604553
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.7435302734375
# Eval_StdReturn : 15.833901405334473
# Eval_MaxReturn : 195.66139221191406
# Eval_MinReturn : 146.85525512695312
# Eval_AverageEpLen : 84.58333333333333
# Train_AverageReturn : 175.36480712890625
# Train_StdReturn : 15.130143165588379
# Train_MaxReturn : 208.67530822753906
# Train_MinReturn : 108.8730697631836
# Train_AverageEpLen : 83.55833333333334
# Train_EnvstepsSoFar : 150564
# TimeSinceStart : 91.52814650535583
# Training Loss : -4.035148620605469
# Baseline Loss : 0.5423622727394104
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10036 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 189.16571044921875
# Eval_StdReturn : 11.106934547424316
# Eval_MaxReturn : 210.95751953125
# Eval_MinReturn : 171.10801696777344
# Eval_AverageEpLen : 92.27272727272727
# Train_AverageReturn : 175.23434448242188
# Train_StdReturn : 18.837650299072266
# Train_MaxReturn : 237.223388671875
# Train_MinReturn : 114.51676940917969
# Train_AverageEpLen : 85.05084745762711
# Train_EnvstepsSoFar : 160600
# TimeSinceStart : 97.60987687110901
# Training Loss : -1.1082725524902344
# Baseline Loss : 0.5665173530578613
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.15525817871094
# Eval_StdReturn : 54.35259246826172
# Eval_MaxReturn : 247.12379455566406
# Eval_MinReturn : 74.01860046386719
# Eval_AverageEpLen : 84.91666666666667
# Train_AverageReturn : 189.0971221923828
# Train_StdReturn : 21.59180450439453
# Train_MaxReturn : 283.33819580078125
# Train_MinReturn : 133.8543701171875
# Train_AverageEpLen : 92.05504587155963
# Train_EnvstepsSoFar : 170634
# TimeSinceStart : 104.10614776611328
# Training Loss : 2.4791364669799805
# Baseline Loss : 0.7046722173690796
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10063 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.319580078125
# Eval_StdReturn : 49.46982955932617
# Eval_MaxReturn : 240.70394897460938
# Eval_MinReturn : 62.33882522583008
# Eval_AverageEpLen : 91.83333333333333
# Train_AverageReturn : 198.83653259277344
# Train_StdReturn : 48.322853088378906
# Train_MaxReturn : 306.64569091796875
# Train_MinReturn : 56.39400100708008
# Train_AverageEpLen : 96.75961538461539
# Train_EnvstepsSoFar : 180697
# TimeSinceStart : 110.67830562591553
# Training Loss : -0.47224298119544983
# Baseline Loss : 0.9725647568702698
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 247.7016143798828
# Eval_StdReturn : 61.2884521484375
# Eval_MaxReturn : 335.20538330078125
# Eval_MinReturn : 133.87306213378906
# Eval_AverageEpLen : 111.0
# Train_AverageReturn : 190.3480224609375
# Train_StdReturn : 69.64881896972656
# Train_MaxReturn : 339.2190246582031
# Train_MinReturn : 45.216922760009766
# Train_AverageEpLen : 93.4766355140187
# Train_EnvstepsSoFar : 190699
# TimeSinceStart : 118.50015640258789
# Training Loss : -7.916046619415283
# Baseline Loss : 1.3272802829742432
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10078 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 241.8209686279297
# Eval_StdReturn : 79.50953674316406
# Eval_MaxReturn : 352.21075439453125
# Eval_MinReturn : 86.0824203491211
# Eval_AverageEpLen : 116.22222222222223
# Train_AverageReturn : 232.05410766601562
# Train_StdReturn : 66.23548126220703
# Train_MaxReturn : 391.02130126953125
# Train_MinReturn : 64.29804992675781
# Train_AverageEpLen : 106.08421052631579
# Train_EnvstepsSoFar : 200777
# TimeSinceStart : 125.50061464309692
# Training Loss : -5.821746826171875
# Baseline Loss : 1.5037686824798584
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10159 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 271.969970703125
# Eval_StdReturn : 105.06661987304688
# Eval_MaxReturn : 397.2513732910156
# Eval_MinReturn : 132.00857543945312
# Eval_AverageEpLen : 128.375
# Train_AverageReturn : 253.09597778320312
# Train_StdReturn : 68.42362976074219
# Train_MaxReturn : 452.4434509277344
# Train_MinReturn : 111.87968444824219
# Train_AverageEpLen : 119.51764705882353
# Train_EnvstepsSoFar : 210936
# TimeSinceStart : 131.11735320091248
# Training Loss : -4.9670000076293945
# Baseline Loss : 1.3729933500289917
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 367.2544860839844
# Eval_StdReturn : 101.69634246826172
# Eval_MaxReturn : 516.4033203125
# Eval_MinReturn : 148.7810821533203
# Eval_AverageEpLen : 159.28571428571428
# Train_AverageReturn : 313.8164978027344
# Train_StdReturn : 105.46625518798828
# Train_MaxReturn : 544.7198486328125
# Train_MinReturn : 100.5582275390625
# Train_AverageEpLen : 145.46376811594203
# Train_EnvstepsSoFar : 220973
# TimeSinceStart : 137.2511715888977
# Training Loss : -4.004427909851074
# Baseline Loss : 1.2649648189544678
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 295.2909240722656
# Eval_StdReturn : 167.0323028564453
# Eval_MaxReturn : 535.3878173828125
# Eval_MinReturn : 115.11264038085938
# Eval_AverageEpLen : 133.25
# Train_AverageReturn : 333.98773193359375
# Train_StdReturn : 134.65655517578125
# Train_MaxReturn : 555.832275390625
# Train_MinReturn : 80.16912841796875
# Train_AverageEpLen : 154.0
# Train_EnvstepsSoFar : 230983
# TimeSinceStart : 143.36683177947998
# Training Loss : -1.4697870016098022
# Baseline Loss : 1.1381727457046509
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10093 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 345.06756591796875
# Eval_StdReturn : 159.4366912841797
# Eval_MaxReturn : 549.0988159179688
# Eval_MinReturn : 96.23382568359375
# Eval_AverageEpLen : 144.75
# Train_AverageReturn : 297.1959533691406
# Train_StdReturn : 154.67123413085938
# Train_MaxReturn : 584.658935546875
# Train_MinReturn : 78.94977569580078
# Train_AverageEpLen : 138.26027397260273
# Train_EnvstepsSoFar : 241076
# TimeSinceStart : 149.46932411193848
# Training Loss : 0.5241267681121826
# Baseline Loss : 1.0799825191497803
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10036 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 309.918701171875
# Eval_StdReturn : 191.7300567626953
# Eval_MaxReturn : 611.4340209960938
# Eval_MinReturn : 100.46575164794922
# Eval_AverageEpLen : 128.55555555555554
# Train_AverageReturn : 276.28656005859375
# Train_StdReturn : 165.40354919433594
# Train_MaxReturn : 588.1610717773438
# Train_MinReturn : 79.88304901123047
# Train_AverageEpLen : 125.45
# Train_EnvstepsSoFar : 251112
# TimeSinceStart : 155.12004494667053
# Training Loss : 1.9708458185195923
# Baseline Loss : 1.0362529754638672
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10081 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 458.5643005371094
# Eval_StdReturn : 110.02729034423828
# Eval_MaxReturn : 573.9412231445312
# Eval_MinReturn : 239.99810791015625
# Eval_AverageEpLen : 182.66666666666666
# Train_AverageReturn : 354.3525695800781
# Train_StdReturn : 164.38560485839844
# Train_MaxReturn : 617.87548828125
# Train_MinReturn : 98.19676208496094
# Train_AverageEpLen : 152.74242424242425
# Train_EnvstepsSoFar : 261193
# TimeSinceStart : 160.48570561408997
# Training Loss : 2.751025676727295
# Baseline Loss : 0.9953875541687012
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 336.322021484375
# Eval_StdReturn : 134.21630859375
# Eval_MaxReturn : 538.552490234375
# Eval_MinReturn : 105.19029998779297
# Eval_AverageEpLen : 155.42857142857142
# Train_AverageReturn : 406.50726318359375
# Train_StdReturn : 124.76542663574219
# Train_MaxReturn : 593.4310302734375
# Train_MinReturn : 83.13602447509766
# Train_AverageEpLen : 179.82142857142858
# Train_EnvstepsSoFar : 271263
# TimeSinceStart : 166.5908088684082
# Training Loss : 3.6205368041992188
# Baseline Loss : 0.9636627435684204
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10100 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 403.13665771484375
# Eval_StdReturn : 143.3899383544922
# Eval_MaxReturn : 533.1415405273438
# Eval_MinReturn : 123.47340393066406
# Eval_AverageEpLen : 169.57142857142858
# Train_AverageReturn : 378.5982666015625
# Train_StdReturn : 131.703369140625
# Train_MaxReturn : 536.712646484375
# Train_MinReturn : -1.3776757717132568
# Train_AverageEpLen : 171.1864406779661
# Train_EnvstepsSoFar : 281363
# TimeSinceStart : 172.58809614181519
# Training Loss : 3.145127296447754
# Baseline Loss : 0.9562262892723083
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 393.698486328125
# Eval_StdReturn : 91.25862884521484
# Eval_MaxReturn : 452.77313232421875
# Eval_MinReturn : 191.1584014892578
# Eval_AverageEpLen : 174.5
# Train_AverageReturn : 415.39434814453125
# Train_StdReturn : 105.53984069824219
# Train_MaxReturn : 580.8565063476562
# Train_MinReturn : 202.97390747070312
# Train_AverageEpLen : 182.3272727272727
# Train_EnvstepsSoFar : 291391
# TimeSinceStart : 178.39821887016296
# Training Loss : 1.6012351512908936
# Baseline Loss : 0.9284270405769348
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 382.4577331542969
# Eval_StdReturn : 77.6551513671875
# Eval_MaxReturn : 465.39337158203125
# Eval_MinReturn : 244.32122802734375
# Eval_AverageEpLen : 180.5
# Train_AverageReturn : 387.0302734375
# Train_StdReturn : 90.31938171386719
# Train_MaxReturn : 526.5684204101562
# Train_MinReturn : 182.48309326171875
# Train_AverageEpLen : 179.67857142857142
# Train_EnvstepsSoFar : 301453
# TimeSinceStart : 184.47978472709656
# Training Loss : 1.619500756263733
# Baseline Loss : 0.9321649074554443
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10093 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 297.32061767578125
# Eval_StdReturn : 95.58130645751953
# Eval_MaxReturn : 433.5751647949219
# Eval_MinReturn : 152.81832885742188
# Eval_AverageEpLen : 152.42857142857142
# Train_AverageReturn : 378.2369689941406
# Train_StdReturn : 114.5322494506836
# Train_MaxReturn : 582.987548828125
# Train_MinReturn : 130.48342895507812
# Train_AverageEpLen : 177.0701754385965
# Train_EnvstepsSoFar : 311546
# TimeSinceStart : 190.54792308807373
# Training Loss : 0.025683917105197906
# Baseline Loss : 0.8773080110549927
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 413.576171875
# Eval_StdReturn : 101.64790344238281
# Eval_MaxReturn : 542.3818969726562
# Eval_MinReturn : 238.58811950683594
# Eval_AverageEpLen : 191.66666666666666
# Train_AverageReturn : 366.17315673828125
# Train_StdReturn : 95.46015167236328
# Train_MaxReturn : 574.0761108398438
# Train_MinReturn : 144.73004150390625
# Train_AverageEpLen : 176.52631578947367
# Train_EnvstepsSoFar : 321608
# TimeSinceStart : 196.5716257095337
# Training Loss : -1.2305573225021362
# Baseline Loss : 0.9039856195449829
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10068 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 422.34417724609375
# Eval_StdReturn : 105.76724243164062
# Eval_MaxReturn : 587.0089111328125
# Eval_MinReturn : 226.04843139648438
# Eval_AverageEpLen : 163.28571428571428
# Train_AverageReturn : 393.2658386230469
# Train_StdReturn : 113.34235382080078
# Train_MaxReturn : 563.3011474609375
# Train_MinReturn : 143.85223388671875
# Train_AverageEpLen : 173.58620689655172
# Train_EnvstepsSoFar : 331676
# TimeSinceStart : 202.9200918674469
# Training Loss : -6.573639869689941
# Baseline Loss : 0.8977835774421692
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 483.203857421875
# Eval_StdReturn : 53.32716369628906
# Eval_MaxReturn : 578.156982421875
# Eval_MinReturn : 410.2432861328125
# Eval_AverageEpLen : 184.16666666666666
# Train_AverageReturn : 440.4006042480469
# Train_StdReturn : 121.78116607666016
# Train_MaxReturn : 582.68408203125
# Train_MinReturn : 91.1437759399414
# Train_AverageEpLen : 166.7
# Train_EnvstepsSoFar : 341678
# TimeSinceStart : 209.01805782318115
# Training Loss : -16.09438705444336
# Baseline Loss : 0.999060332775116
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10176 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 371.1190185546875
# Eval_StdReturn : 79.88312530517578
# Eval_MaxReturn : 429.6312255859375
# Eval_MinReturn : 165.30557250976562
# Eval_AverageEpLen : 140.75
# Train_AverageReturn : 421.8343505859375
# Train_StdReturn : 123.00492095947266
# Train_MaxReturn : 591.9842529296875
# Train_MinReturn : 122.19998168945312
# Train_AverageEpLen : 159.0
# Train_EnvstepsSoFar : 351854
# TimeSinceStart : 215.0822241306305
# Training Loss : -13.900301933288574
# Baseline Loss : 0.9759082198143005
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 465.0348205566406
# Eval_StdReturn : 84.92379760742188
# Eval_MaxReturn : 565.74072265625
# Eval_MinReturn : 366.7445373535156
# Eval_AverageEpLen : 168.85714285714286
# Train_AverageReturn : 425.0263671875
# Train_StdReturn : 99.70136260986328
# Train_MaxReturn : 597.2307739257812
# Train_MinReturn : -1.888563632965088
# Train_AverageEpLen : 156.421875
# Train_EnvstepsSoFar : 361865
# TimeSinceStart : 221.14462065696716
# Training Loss : -10.114912986755371
# Baseline Loss : 0.8635588884353638
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10149 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 447.38946533203125
# Eval_StdReturn : 56.50361251831055
# Eval_MaxReturn : 552.06494140625
# Eval_MinReturn : 398.36871337890625
# Eval_AverageEpLen : 163.85714285714286
# Train_AverageReturn : 418.69390869140625
# Train_StdReturn : 71.30067443847656
# Train_MaxReturn : 583.3065185546875
# Train_MinReturn : 148.85186767578125
# Train_AverageEpLen : 153.77272727272728
# Train_EnvstepsSoFar : 372014
# TimeSinceStart : 227.1484670639038
# Training Loss : -3.003769874572754
# Baseline Loss : 0.7117125391960144
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10095 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 402.4248046875
# Eval_StdReturn : 16.754606246948242
# Eval_MaxReturn : 427.79058837890625
# Eval_MinReturn : 380.2430114746094
# Eval_AverageEpLen : 148.71428571428572
# Train_AverageReturn : 403.911376953125
# Train_StdReturn : 65.49569702148438
# Train_MaxReturn : 580.5130004882812
# Train_MinReturn : -0.7182880640029907
# Train_AverageEpLen : 148.4558823529412
# Train_EnvstepsSoFar : 382109
# TimeSinceStart : 232.96381545066833
# Training Loss : 4.381958961486816
# Baseline Loss : 0.5849988460540771
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10147 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 386.13104248046875
# Eval_StdReturn : 106.835205078125
# Eval_MaxReturn : 555.32763671875
# Eval_MinReturn : 141.27499389648438
# Eval_AverageEpLen : 142.875
# Train_AverageReturn : 400.61834716796875
# Train_StdReturn : 66.40415954589844
# Train_MaxReturn : 611.32568359375
# Train_MinReturn : -1.572566270828247
# Train_AverageEpLen : 147.05797101449275
# Train_EnvstepsSoFar : 392256
# TimeSinceStart : 239.2795853614807
# Training Loss : 11.095726013183594
# Baseline Loss : 0.5371792912483215
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10106 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 324.695068359375
# Eval_StdReturn : 124.24610137939453
# Eval_MaxReturn : 425.41796875
# Eval_MinReturn : 97.59537506103516
# Eval_AverageEpLen : 125.375
# Train_AverageReturn : 372.7093811035156
# Train_StdReturn : 92.13689422607422
# Train_MaxReturn : 438.5751037597656
# Train_MinReturn : -2.149834156036377
# Train_AverageEpLen : 138.43835616438355
# Train_EnvstepsSoFar : 402362
# TimeSinceStart : 244.98511242866516
# Training Loss : 15.670746803283691
# Baseline Loss : 0.5128280520439148
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 309.7565002441406
# Eval_StdReturn : 145.37921142578125
# Eval_MaxReturn : 416.5098876953125
# Eval_MinReturn : -1.2616703510284424
# Eval_AverageEpLen : 118.0
# Train_AverageReturn : 361.4322509765625
# Train_StdReturn : 106.28166961669922
# Train_MaxReturn : 567.9690551757812
# Train_MinReturn : -1.699978232383728
# Train_AverageEpLen : 136.0810810810811
# Train_EnvstepsSoFar : 412432
# TimeSinceStart : 250.68846464157104
# Training Loss : 14.153075218200684
# Baseline Loss : 0.5401338934898376
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10109 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 393.07183837890625
# Eval_StdReturn : 14.42122745513916
# Eval_MaxReturn : 417.86187744140625
# Eval_MinReturn : 370.5233154296875
# Eval_AverageEpLen : 144.28571428571428
# Train_AverageReturn : 328.2546081542969
# Train_StdReturn : 128.10836791992188
# Train_MaxReturn : 439.95599365234375
# Train_MinReturn : -1.4926488399505615
# Train_AverageEpLen : 124.80246913580247
# Train_EnvstepsSoFar : 422541
# TimeSinceStart : 256.0678291320801
# Training Loss : 11.327014923095703
# Baseline Loss : 0.467062383890152
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10072 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 389.8631286621094
# Eval_StdReturn : 15.482940673828125
# Eval_MaxReturn : 417.8377685546875
# Eval_MinReturn : 368.2706604003906
# Eval_AverageEpLen : 143.42857142857142
# Train_AverageReturn : 361.8844909667969
# Train_StdReturn : 103.4114761352539
# Train_MaxReturn : 486.7840270996094
# Train_MinReturn : -1.2790526151657104
# Train_AverageEpLen : 136.1081081081081
# Train_EnvstepsSoFar : 432613
# TimeSinceStart : 261.4002525806427
# Training Loss : 2.468024253845215
# Baseline Loss : 0.3928300142288208
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10074 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 379.6621398925781
# Eval_StdReturn : 7.525507926940918
# Eval_MaxReturn : 388.9593200683594
# Eval_MinReturn : 366.93756103515625
# Eval_AverageEpLen : 140.0
# Train_AverageReturn : 387.21429443359375
# Train_StdReturn : 60.56966018676758
# Train_MaxReturn : 447.2972717285156
# Train_MinReturn : -1.9773198366165161
# Train_AverageEpLen : 143.9142857142857
# Train_EnvstepsSoFar : 442687
# TimeSinceStart : 267.2253053188324
# Training Loss : -7.053885459899902
# Baseline Loss : 0.34190183877944946
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10083 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 387.1694641113281
# Eval_StdReturn : 7.219425201416016
# Eval_MaxReturn : 395.67034912109375
# Eval_MinReturn : 375.85040283203125
# Eval_AverageEpLen : 143.28571428571428
# Train_AverageReturn : 370.4164123535156
# Train_StdReturn : 68.8920669555664
# Train_MaxReturn : 444.07159423828125
# Train_MinReturn : -2.4857194423675537
# Train_AverageEpLen : 138.12328767123287
# Train_EnvstepsSoFar : 452770
# TimeSinceStart : 272.83867835998535
# Training Loss : -13.165871620178223
# Baseline Loss : 0.3799472451210022
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10119 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 404.626953125
# Eval_StdReturn : 18.163917541503906
# Eval_MaxReturn : 433.5106506347656
# Eval_MinReturn : 372.14996337890625
# Eval_AverageEpLen : 151.0
# Train_AverageReturn : 383.5601806640625
# Train_StdReturn : 19.37213706970215
# Train_MaxReturn : 426.9866027832031
# Train_MinReturn : 335.18829345703125
# Train_AverageEpLen : 142.5211267605634
# Train_EnvstepsSoFar : 462889
# TimeSinceStart : 278.6316249370575
# Training Loss : -15.332147598266602
# Baseline Loss : 0.3530253469944
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10062 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 383.58404541015625
# Eval_StdReturn : 14.884604454040527
# Eval_MaxReturn : 400.28509521484375
# Eval_MinReturn : 357.4158935546875
# Eval_AverageEpLen : 143.14285714285714
# Train_AverageReturn : 378.94561767578125
# Train_StdReturn : 20.932397842407227
# Train_MaxReturn : 424.527099609375
# Train_MinReturn : 270.4693908691406
# Train_AverageEpLen : 141.71830985915494
# Train_EnvstepsSoFar : 472951
# TimeSinceStart : 285.1130576133728
# Training Loss : -12.105114936828613
# Baseline Loss : 0.3068973422050476
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 379.12884521484375
# Eval_StdReturn : 18.53026008605957
# Eval_MaxReturn : 413.25921630859375
# Eval_MinReturn : 345.76397705078125
# Eval_AverageEpLen : 141.375
# Train_AverageReturn : 376.9378662109375
# Train_StdReturn : 24.456783294677734
# Train_MaxReturn : 432.37603759765625
# Train_MinReturn : 271.9067077636719
# Train_AverageEpLen : 141.04225352112675
# Train_EnvstepsSoFar : 482965
# TimeSinceStart : 291.19964480400085
# Training Loss : -5.9772047996521
# Baseline Loss : 0.268555223941803
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10103 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 374.42254638671875
# Eval_StdReturn : 19.892499923706055
# Eval_MaxReturn : 414.7171630859375
# Eval_MinReturn : 342.5352783203125
# Eval_AverageEpLen : 139.875
# Train_AverageReturn : 373.59918212890625
# Train_StdReturn : 31.35904884338379
# Train_MaxReturn : 415.11138916015625
# Train_MinReturn : 255.79661560058594
# Train_AverageEpLen : 140.31944444444446
# Train_EnvstepsSoFar : 493068
# TimeSinceStart : 297.26469373703003
# Training Loss : -0.16291552782058716
# Baseline Loss : 0.28885766863822937
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 386.74798583984375
# Eval_StdReturn : 12.721463203430176
# Eval_MaxReturn : 406.88104248046875
# Eval_MinReturn : 370.5542907714844
# Eval_AverageEpLen : 144.85714285714286
# Train_AverageReturn : 368.9615478515625
# Train_StdReturn : 51.07600784301758
# Train_MaxReturn : 420.925048828125
# Train_MinReturn : -2.223656177520752
# Train_AverageEpLen : 138.91666666666666
# Train_EnvstepsSoFar : 503070
# TimeSinceStart : 303.36714220046997
# Training Loss : 5.918425559997559
# Baseline Loss : 0.2887606620788574
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10126 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 379.9134521484375
# Eval_StdReturn : 13.831287384033203
# Eval_MaxReturn : 395.0940246582031
# Eval_MinReturn : 357.8138427734375
# Eval_AverageEpLen : 141.75
# Train_AverageReturn : 380.3865051269531
# Train_StdReturn : 18.06641960144043
# Train_MaxReturn : 418.93450927734375
# Train_MinReturn : 342.36279296875
# Train_AverageEpLen : 142.61971830985917
# Train_EnvstepsSoFar : 513196
# TimeSinceStart : 309.1408975124359
# Training Loss : 8.384276390075684
# Baseline Loss : 0.26211026310920715
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10128 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 379.00830078125
# Eval_StdReturn : 24.037124633789062
# Eval_MaxReturn : 415.768310546875
# Eval_MinReturn : 349.4205322265625
# Eval_AverageEpLen : 140.75
# Train_AverageReturn : 381.3897399902344
# Train_StdReturn : 24.57293128967285
# Train_MaxReturn : 422.866455078125
# Train_MinReturn : 241.2541046142578
# Train_AverageEpLen : 142.64788732394365
# Train_EnvstepsSoFar : 523324
# TimeSinceStart : 314.56283164024353
# Training Loss : 6.457373142242432
# Baseline Loss : 0.24029794335365295
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10124 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 379.11474609375
# Eval_StdReturn : 11.522089958190918
# Eval_MaxReturn : 400.0978088378906
# Eval_MinReturn : 364.0224304199219
# Eval_AverageEpLen : 141.0
# Train_AverageReturn : 380.692626953125
# Train_StdReturn : 17.0578556060791
# Train_MaxReturn : 416.1206359863281
# Train_MinReturn : 333.29461669921875
# Train_AverageEpLen : 142.59154929577466
# Train_EnvstepsSoFar : 533448
# TimeSinceStart : 320.0112864971161
# Training Loss : 2.6899850368499756
# Baseline Loss : 0.19134677946567535
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10099 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 366.1700744628906
# Eval_StdReturn : 15.0141019821167
# Eval_MaxReturn : 392.5809326171875
# Eval_MinReturn : 340.97296142578125
# Eval_AverageEpLen : 135.0
# Train_AverageReturn : 377.8272705078125
# Train_StdReturn : 18.82660484313965
# Train_MaxReturn : 425.9427795410156
# Train_MinReturn : 332.3818664550781
# Train_AverageEpLen : 140.26388888888889
# Train_EnvstepsSoFar : 543547
# TimeSinceStart : 325.30868887901306
# Training Loss : -3.6949996948242188
# Baseline Loss : 0.18477265536785126
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10061 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 367.7769775390625
# Eval_StdReturn : 18.84659767150879
# Eval_MaxReturn : 404.9132385253906
# Eval_MinReturn : 349.75811767578125
# Eval_AverageEpLen : 134.5
# Train_AverageReturn : 380.1885986328125
# Train_StdReturn : 31.006845474243164
# Train_MaxReturn : 583.6943969726562
# Train_MinReturn : 337.3917541503906
# Train_AverageEpLen : 141.70422535211267
# Train_EnvstepsSoFar : 553608
# TimeSinceStart : 330.88019251823425
# Training Loss : -6.640238285064697
# Baseline Loss : 0.20795387029647827
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10125 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 367.99755859375
# Eval_StdReturn : 14.220653533935547
# Eval_MaxReturn : 395.1189880371094
# Eval_MinReturn : 348.5777587890625
# Eval_AverageEpLen : 135.125
# Train_AverageReturn : 384.5163269042969
# Train_StdReturn : 34.91204833984375
# Train_MaxReturn : 616.919921875
# Train_MinReturn : 308.42437744140625
# Train_AverageEpLen : 142.6056338028169
# Train_EnvstepsSoFar : 563733
# TimeSinceStart : 336.68692660331726
# Training Loss : -7.549034595489502
# Baseline Loss : 0.2208091765642166
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10100 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 383.0452880859375
# Eval_StdReturn : 73.51138305664062
# Eval_MaxReturn : 571.2044677734375
# Eval_MinReturn : 335.1754150390625
# Eval_AverageEpLen : 142.375
# Train_AverageReturn : 367.25360107421875
# Train_StdReturn : 37.52118682861328
# Train_MaxReturn : 572.2000122070312
# Train_MinReturn : 257.0899963378906
# Train_AverageEpLen : 138.35616438356163
# Train_EnvstepsSoFar : 573833
# TimeSinceStart : 343.1337261199951
# Training Loss : -5.917388439178467
# Baseline Loss : 0.35619354248046875
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10005 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 403.0749816894531
# Eval_StdReturn : 54.40262985229492
# Eval_MaxReturn : 499.752197265625
# Eval_MinReturn : 351.142822265625
# Eval_AverageEpLen : 143.57142857142858
# Train_AverageReturn : 382.2741394042969
# Train_StdReturn : 41.5711784362793
# Train_MaxReturn : 584.95068359375
# Train_MinReturn : 261.96051025390625
# Train_AverageEpLen : 140.91549295774647
# Train_EnvstepsSoFar : 583838
# TimeSinceStart : 351.6500754356384
# Training Loss : 1.2356328964233398
# Baseline Loss : 0.21116743981838226
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10095 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 367.0596923828125
# Eval_StdReturn : 18.225805282592773
# Eval_MaxReturn : 407.0292663574219
# Eval_MinReturn : 346.73504638671875
# Eval_AverageEpLen : 135.875
# Train_AverageReturn : 387.8122863769531
# Train_StdReturn : 36.49140167236328
# Train_MaxReturn : 561.6242065429688
# Train_MinReturn : 334.19512939453125
# Train_AverageEpLen : 142.18309859154928
# Train_EnvstepsSoFar : 593933
# TimeSinceStart : 360.4331159591675
# Training Loss : 5.483441352844238
# Baseline Loss : 0.2534867525100708
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10043 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 371.01995849609375
# Eval_StdReturn : 35.57754898071289
# Eval_MaxReturn : 426.671875
# Eval_MinReturn : 304.61871337890625
# Eval_AverageEpLen : 139.375
# Train_AverageReturn : 394.8440856933594
# Train_StdReturn : 51.884925842285156
# Train_MaxReturn : 597.5479736328125
# Train_MinReturn : 286.4049072265625
# Train_AverageEpLen : 145.55072463768116
# Train_EnvstepsSoFar : 603976
# TimeSinceStart : 370.57058787345886
# Training Loss : 6.408023834228516
# Baseline Loss : 0.323858380317688
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10143 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 377.861083984375
# Eval_StdReturn : 50.744808197021484
# Eval_MaxReturn : 477.45318603515625
# Eval_MinReturn : 292.80096435546875
# Eval_AverageEpLen : 143.14285714285714
# Train_AverageReturn : 380.767822265625
# Train_StdReturn : 39.155311584472656
# Train_MaxReturn : 565.3157958984375
# Train_MinReturn : 333.67132568359375
# Train_AverageEpLen : 142.85915492957747
# Train_EnvstepsSoFar : 614119
# TimeSinceStart : 379.7827219963074
# Training Loss : 4.18716287612915
# Baseline Loss : 0.3265083134174347
# Initial_DataCollection_AverageReturn : 9.403343200683594
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10084 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 393.68023681640625
# Eval_StdReturn : 27.70785903930664
# Eval_MaxReturn : 443.606201171875
# Eval_MinReturn : 363.04705810546875
# Eval_AverageEpLen : 146.85714285714286
# Train_AverageReturn : 400.6827392578125
# Train_StdReturn : 48.50172805786133
# Train_MaxReturn : 562.0449829101562
# Train_MinReturn : 299.0565490722656
# Train_AverageEpLen : 148.2941176470588
# Train_EnvstepsSoFar : 624203
# TimeSinceStart : 388.86944603919983
# Training Loss : -1.4506475925445557
# Baseline Loss : 0.35036829113960266
# Initial_DataCollection_AverageReturn : 9.403343200683594
# ...
#
# Collecting data to be used for training...
# At timestep:     10092 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 308.5857238769531
# Eval_StdReturn : 21.86810302734375
# Eval_MaxReturn : 340.4955749511719
# Eval_MinReturn : 278.6634521484375
# Eval_AverageEpLen : 146.71428571428572
# Train_AverageReturn : 302.3858337402344
# Train_StdReturn : 25.58565330505371
# Train_MaxReturn : 370.549560546875
# Train_MinReturn : 262.4116516113281
# Train_AverageEpLen : 144.17142857142858
# Train_EnvstepsSoFar : 804622
# TimeSinceStart : 502.6691982746124
# Training Loss : 1.4147756099700928
# Baseline Loss : 0.11135257035493851
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10053 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 304.23114013671875
# Eval_StdReturn : 22.452632904052734
# Eval_MaxReturn : 336.9469299316406
# Eval_MinReturn : 271.5651550292969
# Eval_AverageEpLen : 144.28571428571428
# Train_AverageReturn : 296.7701110839844
# Train_StdReturn : 45.10883712768555
# Train_MaxReturn : 367.77703857421875
# Train_MinReturn : 72.66167449951172
# Train_AverageEpLen : 141.59154929577466
# Train_EnvstepsSoFar : 814675
# TimeSinceStart : 509.842613697052
# Training Loss : 4.045261859893799
# Baseline Loss : 0.18701176345348358
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 318.20611572265625
# Eval_StdReturn : 16.941112518310547
# Eval_MaxReturn : 335.64044189453125
# Eval_MinReturn : 290.81927490234375
# Eval_AverageEpLen : 146.57142857142858
# Train_AverageReturn : 300.7490234375
# Train_StdReturn : 51.80094909667969
# Train_MaxReturn : 377.24029541015625
# Train_MinReturn : 66.45816040039062
# Train_AverageEpLen : 141.04225352112675
# Train_EnvstepsSoFar : 824689
# TimeSinceStart : 516.4043531417847
# Training Loss : 3.028514862060547
# Baseline Loss : 0.20781174302101135
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 313.0838928222656
# Eval_StdReturn : 23.504419326782227
# Eval_MaxReturn : 348.35894775390625
# Eval_MinReturn : 284.6737365722656
# Eval_AverageEpLen : 143.42857142857142
# Train_AverageReturn : 300.1321105957031
# Train_StdReturn : 61.86591720581055
# Train_MaxReturn : 375.2301025390625
# Train_MinReturn : 60.972103118896484
# Train_AverageEpLen : 139.25
# Train_EnvstepsSoFar : 834715
# TimeSinceStart : 522.9231901168823
# Training Loss : 0.3388363718986511
# Baseline Loss : 0.24213062226772308
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10087 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 271.4893493652344
# Eval_StdReturn : 78.29348754882812
# Eval_MaxReturn : 351.60882568359375
# Eval_MinReturn : 78.6526870727539
# Eval_AverageEpLen : 125.625
# Train_AverageReturn : 293.6348876953125
# Train_StdReturn : 71.9743423461914
# Train_MaxReturn : 401.57220458984375
# Train_MinReturn : 64.62716674804688
# Train_AverageEpLen : 134.49333333333334
# Train_EnvstepsSoFar : 844802
# TimeSinceStart : 530.4259233474731
# Training Loss : -2.105665922164917
# Baseline Loss : 0.2816997170448303
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10108 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 331.9877014160156
# Eval_StdReturn : 23.367591857910156
# Eval_MaxReturn : 367.3308410644531
# Eval_MinReturn : 298.44189453125
# Eval_AverageEpLen : 145.85714285714286
# Train_AverageReturn : 308.21533203125
# Train_StdReturn : 47.437828063964844
# Train_MaxReturn : 379.46356201171875
# Train_MinReturn : 79.48844909667969
# Train_AverageEpLen : 140.38888888888889
# Train_EnvstepsSoFar : 854910
# TimeSinceStart : 537.6215889453888
# Training Loss : -3.0987792015075684
# Baseline Loss : 0.21676436066627502
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 328.73529052734375
# Eval_StdReturn : 33.54032516479492
# Eval_MaxReturn : 388.43865966796875
# Eval_MinReturn : 274.9287109375
# Eval_AverageEpLen : 140.625
# Train_AverageReturn : 308.2708435058594
# Train_StdReturn : 37.19273376464844
# Train_MaxReturn : 388.2686462402344
# Train_MinReturn : 67.91938781738281
# Train_AverageEpLen : 139.66666666666666
# Train_EnvstepsSoFar : 864966
# TimeSinceStart : 545.7210555076599
# Training Loss : -2.5302000045776367
# Baseline Loss : 0.15884196758270264
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10088 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 288.47900390625
# Eval_StdReturn : 16.422555923461914
# Eval_MaxReturn : 323.59515380859375
# Eval_MinReturn : 266.4805603027344
# Eval_AverageEpLen : 132.0
# Train_AverageReturn : 283.19439697265625
# Train_StdReturn : 77.77336120605469
# Train_MaxReturn : 391.49609375
# Train_MinReturn : 63.92756652832031
# Train_AverageEpLen : 127.69620253164557
# Train_EnvstepsSoFar : 875054
# TimeSinceStart : 552.3020806312561
# Training Loss : -0.4175635874271393
# Baseline Loss : 0.2486364096403122
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10116 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 291.29803466796875
# Eval_StdReturn : 32.20156478881836
# Eval_MaxReturn : 354.0453796386719
# Eval_MinReturn : 263.04425048828125
# Eval_AverageEpLen : 132.875
# Train_AverageReturn : 299.1135559082031
# Train_StdReturn : 38.12788772583008
# Train_MaxReturn : 387.93511962890625
# Train_MinReturn : 74.40986633300781
# Train_AverageEpLen : 134.88
# Train_EnvstepsSoFar : 885170
# TimeSinceStart : 559.4034123420715
# Training Loss : 2.439121723175049
# Baseline Loss : 0.1454206109046936
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10125 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 323.3457336425781
# Eval_StdReturn : 46.422847747802734
# Eval_MaxReturn : 434.64739990234375
# Eval_MinReturn : 282.7926330566406
# Eval_AverageEpLen : 140.375
# Train_AverageReturn : 298.6323547363281
# Train_StdReturn : 39.78940200805664
# Train_MaxReturn : 385.9620056152344
# Train_MinReturn : 68.6800308227539
# Train_AverageEpLen : 135.0
# Train_EnvstepsSoFar : 895295
# TimeSinceStart : 565.477602481842
# Training Loss : 2.564920425415039
# Baseline Loss : 0.15056635439395905
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10101 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 317.6175231933594
# Eval_StdReturn : 58.42536544799805
# Eval_MaxReturn : 432.63055419921875
# Eval_MinReturn : 248.6154022216797
# Eval_AverageEpLen : 142.125
# Train_AverageReturn : 299.5958557128906
# Train_StdReturn : 43.031986236572266
# Train_MaxReturn : 423.91973876953125
# Train_MinReturn : 73.98322296142578
# Train_AverageEpLen : 134.68
# Train_EnvstepsSoFar : 905396
# TimeSinceStart : 572.078031539917
# Training Loss : 0.7663717269897461
# Baseline Loss : 0.15170246362686157
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 318.42144775390625
# Eval_StdReturn : 42.45362854003906
# Eval_MaxReturn : 365.40167236328125
# Eval_MinReturn : 251.8905029296875
# Eval_AverageEpLen : 139.375
# Train_AverageReturn : 295.1092529296875
# Train_StdReturn : 32.56211471557617
# Train_MaxReturn : 402.0512390136719
# Train_MinReturn : 244.7413787841797
# Train_AverageEpLen : 133.41333333333333
# Train_EnvstepsSoFar : 915402
# TimeSinceStart : 579.590927362442
# Training Loss : -0.2215791642665863
# Baseline Loss : 0.13199491798877716
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10091 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 306.10198974609375
# Eval_StdReturn : 52.873291015625
# Eval_MaxReturn : 379.650390625
# Eval_MinReturn : 221.108642578125
# Eval_AverageEpLen : 130.5
# Train_AverageReturn : 290.4503479003906
# Train_StdReturn : 36.12046432495117
# Train_MaxReturn : 397.0873718261719
# Train_MinReturn : 238.41268920898438
# Train_AverageEpLen : 131.05194805194805
# Train_EnvstepsSoFar : 925493
# TimeSinceStart : 585.7457728385925
# Training Loss : -1.7710474729537964
# Baseline Loss : 0.12385871261358261
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 280.4825439453125
# Eval_StdReturn : 84.50495147705078
# Eval_MaxReturn : 401.3251953125
# Eval_MinReturn : 97.55572509765625
# Eval_AverageEpLen : 126.0
# Train_AverageReturn : 298.8656311035156
# Train_StdReturn : 57.764198303222656
# Train_MaxReturn : 522.6136474609375
# Train_MinReturn : 65.17787170410156
# Train_AverageEpLen : 131.81578947368422
# Train_EnvstepsSoFar : 935511
# TimeSinceStart : 591.6959986686707
# Training Loss : -4.9161057472229
# Baseline Loss : 0.162065327167511
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 273.2669677734375
# Eval_StdReturn : 39.026126861572266
# Eval_MaxReturn : 367.97979736328125
# Eval_MinReturn : 239.0071563720703
# Eval_AverageEpLen : 122.55555555555556
# Train_AverageReturn : 304.2409362792969
# Train_StdReturn : 55.064430236816406
# Train_MaxReturn : 490.5792236328125
# Train_MinReturn : 235.6533966064453
# Train_AverageEpLen : 135.28378378378378
# Train_EnvstepsSoFar : 945522
# TimeSinceStart : 597.5965554714203
# Training Loss : -2.7931902408599854
# Baseline Loss : 0.16169705986976624
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10034 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 329.112548828125
# Eval_StdReturn : 41.34437561035156
# Eval_MaxReturn : 396.1708984375
# Eval_MinReturn : 247.7646026611328
# Eval_AverageEpLen : 140.75
# Train_AverageReturn : 307.6249694824219
# Train_StdReturn : 55.927818298339844
# Train_MaxReturn : 468.24114990234375
# Train_MinReturn : 230.93687438964844
# Train_AverageEpLen : 133.78666666666666
# Train_EnvstepsSoFar : 955556
# TimeSinceStart : 603.5272524356842
# Training Loss : -0.7663992047309875
# Baseline Loss : 0.1386614441871643
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10131 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 324.9773864746094
# Eval_StdReturn : 62.86754608154297
# Eval_MaxReturn : 434.5997619628906
# Eval_MinReturn : 240.7283477783203
# Eval_AverageEpLen : 142.85714285714286
# Train_AverageReturn : 317.1706848144531
# Train_StdReturn : 56.05509948730469
# Train_MaxReturn : 450.6060485839844
# Train_MinReturn : 180.13819885253906
# Train_AverageEpLen : 135.08
# Train_EnvstepsSoFar : 965687
# TimeSinceStart : 609.3123209476471
# Training Loss : -1.3874666690826416
# Baseline Loss : 0.20873863995075226
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 330.080810546875
# Eval_StdReturn : 39.72172927856445
# Eval_MaxReturn : 373.1061096191406
# Eval_MinReturn : 244.28338623046875
# Eval_AverageEpLen : 131.375
# Train_AverageReturn : 335.4538879394531
# Train_StdReturn : 59.7119026184082
# Train_MaxReturn : 456.5247497558594
# Train_MinReturn : 76.56936645507812
# Train_AverageEpLen : 137.15068493150685
# Train_EnvstepsSoFar : 975699
# TimeSinceStart : 615.7914552688599
# Training Loss : -6.118687629699707
# Baseline Loss : 0.3647516667842865
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10072 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 364.3719482421875
# Eval_StdReturn : 19.5061092376709
# Eval_MaxReturn : 387.80712890625
# Eval_MinReturn : 330.2160949707031
# Eval_AverageEpLen : 138.875
# Train_AverageReturn : 337.6981506347656
# Train_StdReturn : 61.47853469848633
# Train_MaxReturn : 583.7455444335938
# Train_MinReturn : 82.08961486816406
# Train_AverageEpLen : 137.97260273972603
# Train_EnvstepsSoFar : 985771
# TimeSinceStart : 622.6265599727631
# Training Loss : -4.38967227935791
# Baseline Loss : 0.4126163721084595
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10134 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 328.47589111328125
# Eval_StdReturn : 77.22579193115234
# Eval_MaxReturn : 457.3880615234375
# Eval_MinReturn : 164.17147827148438
# Eval_AverageEpLen : 134.75
# Train_AverageReturn : 334.44073486328125
# Train_StdReturn : 56.114097595214844
# Train_MaxReturn : 423.4631042480469
# Train_MinReturn : 76.38459777832031
# Train_AverageEpLen : 135.12
# Train_EnvstepsSoFar : 995905
# TimeSinceStart : 628.8219139575958
# Training Loss : 1.3701903820037842
# Baseline Loss : 0.3496139943599701
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10117 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 337.19189453125
# Eval_StdReturn : 36.884456634521484
# Eval_MaxReturn : 378.12884521484375
# Eval_MinReturn : 251.36984252929688
# Eval_AverageEpLen : 131.0
# Train_AverageReturn : 339.4229431152344
# Train_StdReturn : 53.91234588623047
# Train_MaxReturn : 399.2554626464844
# Train_MinReturn : 71.22801971435547
# Train_AverageEpLen : 133.1184210526316
# Train_EnvstepsSoFar : 1006022
# TimeSinceStart : 636.0719511508942
# Training Loss : -0.9742357134819031
# Baseline Loss : 0.48425915837287903
# Initial_DataCollection_AverageReturn : 17.71956443786621
# Done logging...

# %%
# Plot learning curves
### Visualize Policy Gradient results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 838534), started 0:35:55 ago. (Use '!kill 838534' to kill it.)
#       <iframe id="tensorboard-frame-4913b6253a023734" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4913b6253a023734");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
