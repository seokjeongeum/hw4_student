# %% [markdown]
# # Deep Q Networks
# Previously, we trained policies using policy gradient algorithms, which directly estimated the gradient of the returns for the policy and performed stochastic gradient ascent. In this section, we will now implement deep Q-learning, which does not explicitly optimize a policy, but simply infers the policy from a learned Q function that is trained via dynamic programming.
#
# We will assume discrete action spaces for this notebook as to enable us to easily select actions that maximize the Q-function at given states.

# %%
# As usual, a bit of setup
import os
import shutil
import time
import torch
import numpy as np

import deeprl.infrastructure.pytorch_util as ptu

from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import PG_Trainer
from deeprl.infrastructure.trainers import DQN_Trainer

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))

# %%
dqn_base_args_dict = dict(
    env_name = 'LunarLander-v3', #@param 
    exp_name = 'test_dqn', #@param
    save_params = False, #@param {type: "boolean"}
    
    ## PDF will tell you how to set ep_len
    ## and discount for each environment
    ep_len = 200, #@param {type: "integer"}
    # discount = 0.95, #@param {type: "number"}

    # Training
    num_agent_train_steps_per_iter = 1, #@param {type: "integer"})
    num_critic_updates_per_agent_update = 1, #@param {type: "integer"}
  
    #@markdown Q-learning parameters
    double_q = False, #@param {type: "boolean"}

    # batches & buffers
    batch_size = 32, #@param {type: "integer"})
    batch_size_initial=1000,

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1000, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# ## DQN updates
# Recall in Q-learning, we attempt to solve the optimal state-action values (which we refer to as Q-values $Q(s,a)$), by finding solutions to the Bellman equation given by
# $$Q(s,a) = r(s,a) + \gamma \mathbb{E}_{s' \sim p(s'\vert s,a)}[\max_{a'}Q(s', a')].$$
#
# Regular tabular Q-learning would take sample transitions $(s, a, r, s')$ and perform updates according to
# $$Q(s,a) \leftarrow Q(s,a) + \alpha (r(s,a) + \gamma \max_{a'} Q(s', a') - Q(s,a)),$$
# where $\alpha$ is a stepsize parameter.
#
# This can be interpreted as updating $Q(s,a)$ by taking one gradient step on a squared Bellman error objective
# $$(r(s, a) +\gamma \max_{a'} \tilde Q(s', a') - Q(s,a))^2,$$
# where $\tilde Q$ is a copy of $Q$, but is not differentiated when taking the gradient step.
#
# Adapting this update to the setting where we use a neural network with parameters $\theta$ to approximate $Q(s,a)$, we then train $\theta$ with the loss function
# $$\min_{\theta} \mathbb{E}_{s, a, s' \sim D} [L(Q_{\theta}(s,a), r(s,a) + \gamma \max_{a'} Q_{\tilde \theta}(s', a'))]$$
# where $D$ is our replay buffer containing past transitions we've experienced, $L$ is some loss function capturing how far the predicted Q-values are from the target values, and $\tilde \theta$ are the target Q function parameters, which are usually a delayed copy of $\theta$ for stability reasons.
#
# We note our previous policy gradient algorithms were _on-policy_ algoritms, which meant they updated the policy using only the data collected from the most recent policy, and discard all the data after using it just once. In contrast, DQN uses _off-policy_ updates by sampling data from all past interactions, allowing for data reuse over time.

# %% [markdown]
# Fill out the missing components for the basic Q-learning update in <code>critics/dqn_critic.py</code> (not including the double_q section).

# %%
#### Test DQN updates
dqn_args = dict(dqn_base_args_dict)

env_str = 'LunarLander'
dqn_args['env_name'] = '{}-v3'.format(env_str)
dqn_args['double_q'] = False
dqntrainer = DQN_Trainer(dqn_args)
dqnagent = dqntrainer.rl_trainer.agent
critic = dqnagent.critic

ob_dim = critic.ob_dim
ac_dim = 6
N = 5

np.random.seed(0)
obs = np.random.normal(size=(N, ob_dim))
acts = np.random.choice(ac_dim, size=(N,))
next_obs = np.random.normal(size=(N, ob_dim))
rewards = np.random.normal(size=N)
terminals = np.zeros(N)
terminals[0] = 1

first_weight_before = np.array(ptu.to_numpy(next(critic.q_net.parameters())))
print("Weight before update (first row)", first_weight_before[0])


loss = critic.update(obs, acts, next_obs, rewards, terminals)['Training Loss']
expected_loss = 0.9408444
loss_error = rel_error(loss, expected_loss)
print("Initial loss", loss)
print("Initial Loss Error", loss_error, "should be on the order of 1e-6 or lower")

for i in range(4):
    loss = critic.update(obs, acts, next_obs, rewards, terminals)['Training Loss']
    print(loss)

expected_loss = 0.7889254
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")


first_weight_after = np.array(ptu.to_numpy(next(critic.q_net.parameters())))
print("Weight after update (first row)", first_weight_after.shape)
# Test DQN gradient
print(first_weight_after[0])
weight_change_partial = first_weight_after[0] - first_weight_before[0]
expected_weight_change = np.array([-0.00491365, -0.00500049, -0.00499149, -0.00491229, -0.00490125,  0.00489534,
 -0.00282785, -0.00171614,  0.00485604])


updated_weight_error = rel_error(weight_change_partial, expected_weight_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# LunarLander-v3
# Weight before update (first row) [ 0.07646339 -0.07932477  0.09140956 -0.01702595  0.1423959   0.07935759
#  -0.03831156 -0.2694876   0.0761048 ]
# Initial loss 0.9408444
# Initial Loss Error 8.831612855468697e-09 should be on the order of 1e-6 or lower
# 0.9007309
# 0.8621321
# 0.82467556
# 0.7889254
# Loss Error 5.904878045285727e-09 should be on the order of 1e-6 or lower
# Weight after update (first row) (64, 9)
# [ 0.07154974 -0.08432526  0.08641808 -0.02193824  0.13749465  0.08425292
#  -0.04113941 -0.27120373  0.08096085]
# Weight Update Error 8.937585787696078e-07 should be on the order of 1e-6 or lower
# /usr/local/envs/hw4/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/envs/hw4/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Environment '<class 'deeprl.envs.box2d.lunar_lander.LunarLander'>' has deprecated methods '_step' and '_reset' rather than 'step' and 'reset'. Compatibility code invoked. Set _gym_disable_underscore_compat = True to disable this behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# Implement the missing components in the get_action method of <code>policies/argmax_policy.py</code> and the step_env method in <code>agents/dqn_agent.py</code> to allow our agent to interact with the environment.

# %%
### Test argmax policy
dqn_args = dict(dqn_base_args_dict)

env_str = 'LunarLander'
dqn_args['env_name'] = '{}-v3'.format(env_str)
dqn_args['double_q'] = False
dqntrainer = DQN_Trainer(dqn_args)
dqnagent = dqntrainer.rl_trainer.agent
actor = dqnagent.actor

ob_dim = critic.ob_dim
ac_dim = 6
N = 5

np.random.seed(0)
obs = np.random.normal(size=(N, ob_dim))

actions = actor.get_action(obs)
correct_actions = np.array([1, 0, 1, 0, 1])

assert np.all(correct_actions == actions)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# LunarLander-v3
# /usr/local/envs/hw4/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# We can now test our DQN implementation on the LunarLander environment. These experiments can take a while to run (over 10 minutes per seed) on CPU, so start early.

# %%
dqn_args = dict(dqn_base_args_dict)

env_str = 'LunarLander'
dqn_args['env_name'] = '{}-v3'.format(env_str)
dqn_args['double_q'] = False

# Delete all previous logs
remove_folder('logs/dqn/{}/vanilla_dqn'.format(env_str))

for seed in range(3):
    print("Running DQN experiment with seed", seed)
    dqn_args['seed'] = seed
    dqn_args['logdir'] = 'logs/dqn/{}/vanilla_dqn/seed{}'.format(env_str, seed)
    dqntrainer = DQN_Trainer(dqn_args)
    dqntrainer.run_training_loop()
# Out:
# Clearing old results at logs/dqn/LunarLander/vanilla_dqn
# Running DQN experiment with seed 0
# ########################
# logging outputs to  logs/dqn/LunarLander/vanilla_dqn/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# LunarLander-v3
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 1
# mean reward (100 episodes) nan
# best mean reward -inf
# running time 0.000832
# Train_EnvstepsSoFar : 1
# TimeSinceStart : 0.0008318424224853516
# Done logging...
#
#
#
#
# ********** Iteration 1000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 1001
# mean reward (100 episodes) -361.461461
# best mean reward -inf
# running time 0.246353
# Train_EnvstepsSoFar : 1001
# Train_AverageReturn : -361.46146136915615
# TimeSinceStart : 0.2463531494140625
# Done logging...
#
#
#
#
# ********** Iteration 2000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 2001
# mean reward (100 episodes) -352.133762
# best mean reward -inf
# running time 1.489939
# Train_EnvstepsSoFar : 2001
# Train_AverageReturn : -352.13376161853625
# TimeSinceStart : 1.4899389743804932
# Training Loss : 0.34106168150901794
# Done logging...
#
#
#
#
# ********** Iteration 3000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 3001
# mean reward (100 episodes) -284.922182
# best mean reward -inf
# running time 2.622097
# Train_EnvstepsSoFar : 3001
# Train_AverageReturn : -284.9221822718759
# TimeSinceStart : 2.6220967769622803
# Training Loss : 3.1434097290039062
# Done logging...
#
#
#
#
# ********** Iteration 4000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 4001
# mean reward (100 episodes) -270.930461
# best mean reward -inf
# running time 3.766876
# Train_EnvstepsSoFar : 4001
# Train_AverageReturn : -270.93046057628857
# TimeSinceStart : 3.766876220703125
# Training Loss : 0.21825674176216125
# Done logging...
#
#
#
#
# ********** Iteration 5000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 5001
# mean reward (100 episodes) -282.339758
# best mean reward -inf
# running time 4.895241
# Train_EnvstepsSoFar : 5001
# Train_AverageReturn : -282.3397576789751
# TimeSinceStart : 4.895241022109985
# Training Loss : 0.3508138656616211
# Done logging...
#
#
#
#
# ********** Iteration 6000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 6001
# mean reward (100 episodes) -284.493357
# best mean reward -inf
# running time 6.018627
# Train_EnvstepsSoFar : 6001
# Train_AverageReturn : -284.49335705273097
# TimeSinceStart : 6.018627166748047
# Training Loss : 0.4839029014110565
# Done logging...
#
#
#
#
# ********** Iteration 7000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 7001
# mean reward (100 episodes) -271.630793
# best mean reward -inf
# running time 7.233045
# Train_EnvstepsSoFar : 7001
# Train_AverageReturn : -271.6307932881305
# TimeSinceStart : 7.233044624328613
# Training Loss : 0.2359020859003067
# Done logging...
#
#
#
#
# ********** Iteration 8000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 8001
# mean reward (100 episodes) -263.532278
# best mean reward -inf
# running time 8.408081
# Train_EnvstepsSoFar : 8001
# Train_AverageReturn : -263.532277949405
# TimeSinceStart : 8.408080816268921
# Training Loss : 0.6177546977996826
# Done logging...
#
#
#
#
# ********** Iteration 9000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 9001
# mean reward (100 episodes) -254.862277
# best mean reward -inf
# running time 9.573280
# Train_EnvstepsSoFar : 9001
# Train_AverageReturn : -254.86227728137692
# TimeSinceStart : 9.573280334472656
# Training Loss : 4.048434734344482
# Done logging...
#
#
#
#
# ********** Iteration 10000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 10001
# mean reward (100 episodes) -236.926131
# best mean reward -inf
# running time 10.736724
# Train_EnvstepsSoFar : 10001
# Train_AverageReturn : -236.92613140382164
# TimeSinceStart : 10.736724138259888
# Training Loss : 0.8788527250289917
# Done logging...
#
#
#
#
# ********** Iteration 11000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 11001
# mean reward (100 episodes) -225.243636
# best mean reward -inf
# running time 11.883077
# Train_EnvstepsSoFar : 11001
# Train_AverageReturn : -225.2436355315652
# TimeSinceStart : 11.883076906204224
# Training Loss : 0.3035602867603302
# Done logging...
#
#
#
#
# ********** Iteration 12000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 12001
# mean reward (100 episodes) -224.180995
# best mean reward -inf
# running time 14.002740
# Train_EnvstepsSoFar : 12001
# Train_AverageReturn : -224.18099455990406
# TimeSinceStart : 14.002739906311035
# Training Loss : 3.851994276046753
# Done logging...
#
#
#
#
# ********** Iteration 13000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 13001
# mean reward (100 episodes) -221.552837
# best mean reward -inf
# running time 15.272027
# Train_EnvstepsSoFar : 13001
# Train_AverageReturn : -221.55283692354118
# TimeSinceStart : 15.272027015686035
# Training Loss : 1.3513193130493164
# Done logging...
#
#
#
#
# ********** Iteration 14000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 14001
# mean reward (100 episodes) -224.175661
# best mean reward -inf
# running time 16.562972
# Train_EnvstepsSoFar : 14001
# Train_AverageReturn : -224.17566096261683
# TimeSinceStart : 16.56297206878662
# Training Loss : 0.4048989713191986
# Done logging...
#
#
#
#
# ********** Iteration 15000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 15001
# mean reward (100 episodes) -221.148584
# best mean reward -inf
# running time 18.030512
# Train_EnvstepsSoFar : 15001
# Train_AverageReturn : -221.14858393868894
# TimeSinceStart : 18.0305118560791
# Training Loss : 0.428972065448761
# Done logging...
#
#
#
#
# ********** Iteration 16000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 16001
# mean reward (100 episodes) -215.188231
# best mean reward -215.188231
# running time 19.893677
# Train_EnvstepsSoFar : 16001
# Train_AverageReturn : -215.1882306414679
# Train_BestReturn : -215.1882306414679
# TimeSinceStart : 19.893677473068237
# Training Loss : 0.3115946054458618
# Done logging...
#
#
#
#
# ********** Iteration 17000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 17001
# mean reward (100 episodes) -204.536219
# best mean reward -204.536219
# running time 21.532434
# Train_EnvstepsSoFar : 17001
# Train_AverageReturn : -204.53621878182742
# Train_BestReturn : -204.53621878182742
# TimeSinceStart : 21.53243374824524
# Training Loss : 0.3979825973510742
# Done logging...
#
#
#
#
# ********** Iteration 18000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 18001
# mean reward (100 episodes) -200.411549
# best mean reward -200.411549
# running time 23.614792
# Train_EnvstepsSoFar : 18001
# Train_AverageReturn : -200.41154909756608
# Train_BestReturn : -200.41154909756608
# TimeSinceStart : 23.614792346954346
# Training Loss : 0.7876801490783691
# Done logging...
#
#
#
#
# ********** Iteration 19000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 19001
# mean reward (100 episodes) -195.902337
# best mean reward -195.902337
# running time 25.215383
# Train_EnvstepsSoFar : 19001
# Train_AverageReturn : -195.9023367397296
# Train_BestReturn : -195.9023367397296
# TimeSinceStart : 25.215383291244507
# Training Loss : 5.292743682861328
# Done logging...
#
#
#
#
# ********** Iteration 20000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 20001
# mean reward (100 episodes) -194.641958
# best mean reward -194.641958
# running time 28.745353
# Train_EnvstepsSoFar : 20001
# Train_AverageReturn : -194.6419583708535
# Train_BestReturn : -194.6419583708535
# TimeSinceStart : 28.745352745056152
# Training Loss : 0.6515927910804749
# Done logging...
#
#
#
#
# ********** Iteration 21000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 21001
# mean reward (100 episodes) -189.375238
# best mean reward -189.375238
# running time 30.581036
# Train_EnvstepsSoFar : 21001
# Train_AverageReturn : -189.37523828828918
# Train_BestReturn : -189.37523828828918
# TimeSinceStart : 30.581035614013672
# Training Loss : 0.5156311392784119
# Done logging...
#
#
#
#
# ********** Iteration 22000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 22001
# mean reward (100 episodes) -187.033237
# best mean reward -187.033237
# running time 33.793606
# Train_EnvstepsSoFar : 22001
# Train_AverageReturn : -187.03323709270506
# Train_BestReturn : -187.03323709270506
# TimeSinceStart : 33.79360604286194
# Training Loss : 0.3548519015312195
# Done logging...
#
#
#
#
# ********** Iteration 23000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 23001
# mean reward (100 episodes) -184.708636
# best mean reward -184.708636
# running time 36.619382
# Train_EnvstepsSoFar : 23001
# Train_AverageReturn : -184.70863552156615
# Train_BestReturn : -184.70863552156615
# TimeSinceStart : 36.61938166618347
# Training Loss : 0.23067927360534668
# Done logging...
#
#
#
#
# ********** Iteration 24000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 24001
# mean reward (100 episodes) -179.504947
# best mean reward -179.504947
# running time 38.543313
# Train_EnvstepsSoFar : 24001
# Train_AverageReturn : -179.50494715535405
# Train_BestReturn : -179.50494715535405
# TimeSinceStart : 38.54331302642822
# Training Loss : 0.5949657559394836
# Done logging...
#
#
#
#
# ********** Iteration 25000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 25001
# mean reward (100 episodes) -175.318607
# best mean reward -175.318607
# running time 40.237834
# Train_EnvstepsSoFar : 25001
# Train_AverageReturn : -175.3186069576846
# Train_BestReturn : -175.3186069576846
# TimeSinceStart : 40.237834215164185
# Training Loss : 3.52001953125
# Done logging...
#
#
#
#
# ********** Iteration 26000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 26001
# mean reward (100 episodes) -173.625197
# best mean reward -173.625197
# running time 42.961785
# Train_EnvstepsSoFar : 26001
# Train_AverageReturn : -173.625196790016
# Train_BestReturn : -173.625196790016
# TimeSinceStart : 42.961785078048706
# Training Loss : 0.9711663722991943
# Done logging...
#
#
#
#
# ********** Iteration 27000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 27001
# mean reward (100 episodes) -171.494720
# best mean reward -171.494720
# running time 44.877372
# Train_EnvstepsSoFar : 27001
# Train_AverageReturn : -171.49472010916662
# Train_BestReturn : -171.49472010916662
# TimeSinceStart : 44.87737154960632
# Training Loss : 3.33207106590271
# Done logging...
#
#
#
#
# ********** Iteration 28000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 28001
# mean reward (100 episodes) -169.906744
# best mean reward -169.906744
# running time 46.588186
# Train_EnvstepsSoFar : 28001
# Train_AverageReturn : -169.90674362754515
# Train_BestReturn : -169.90674362754515
# TimeSinceStart : 46.58818578720093
# Training Loss : 0.6604125499725342
# Done logging...
#
#
#
#
# ********** Iteration 29000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 29001
# mean reward (100 episodes) -169.972382
# best mean reward -169.906744
# running time 48.190624
# Train_EnvstepsSoFar : 29001
# Train_AverageReturn : -169.97238244568663
# Train_BestReturn : -169.90674362754515
# TimeSinceStart : 48.19062399864197
# Training Loss : 0.8002731800079346
# Done logging...
#
#
#
#
# ********** Iteration 30000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 30001
# mean reward (100 episodes) -169.455436
# best mean reward -169.455436
# running time 50.046282
# Train_EnvstepsSoFar : 30001
# Train_AverageReturn : -169.45543565801233
# Train_BestReturn : -169.45543565801233
# TimeSinceStart : 50.046282052993774
# Training Loss : 0.9034601449966431
# Done logging...
#
#
#
#
# ********** Iteration 31000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 31001
# mean reward (100 episodes) -167.870477
# best mean reward -167.870477
# running time 52.111053
# Train_EnvstepsSoFar : 31001
# Train_AverageReturn : -167.8704773813128
# Train_BestReturn : -167.8704773813128
# TimeSinceStart : 52.11105298995972
# Training Loss : 0.4326559007167816
# Done logging...
#
#
#
#
# ********** Iteration 32000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 32001
# mean reward (100 episodes) -168.954612
# best mean reward -167.870477
# running time 53.952680
# Train_EnvstepsSoFar : 32001
# Train_AverageReturn : -168.9546118325344
# Train_BestReturn : -167.8704773813128
# TimeSinceStart : 53.9526801109314
# Training Loss : 0.6767966747283936
# Done logging...
#
#
#
#
# ********** Iteration 33000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 33001
# mean reward (100 episodes) -167.081891
# best mean reward -167.081891
# running time 56.402775
# Train_EnvstepsSoFar : 33001
# Train_AverageReturn : -167.08189137612737
# Train_BestReturn : -167.08189137612737
# TimeSinceStart : 56.402775049209595
# Training Loss : 0.4553430676460266
# Done logging...
#
#
#
#
# ********** Iteration 34000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 34001
# mean reward (100 episodes) -169.447214
# best mean reward -167.081891
# running time 58.372024
# Train_EnvstepsSoFar : 34001
# Train_AverageReturn : -169.44721447342155
# Train_BestReturn : -167.08189137612737
# TimeSinceStart : 58.37202429771423
# Training Loss : 0.7683423161506653
# Done logging...
#
#
#
#
# ********** Iteration 35000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 35001
# mean reward (100 episodes) -168.936939
# best mean reward -167.081891
# running time 61.632591
# Train_EnvstepsSoFar : 35001
# Train_AverageReturn : -168.9369387667667
# Train_BestReturn : -167.08189137612737
# TimeSinceStart : 61.632590532302856
# Training Loss : 0.3701759874820709
# Done logging...
#
#
#
#
# ********** Iteration 36000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 36001
# mean reward (100 episodes) -168.083326
# best mean reward -167.081891
# running time 63.751945
# Train_EnvstepsSoFar : 36001
# Train_AverageReturn : -168.0833255391921
# Train_BestReturn : -167.08189137612737
# TimeSinceStart : 63.75194525718689
# Training Loss : 0.44563961029052734
# Done logging...
#
#
#
#
# ********** Iteration 37000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 37001
# mean reward (100 episodes) -166.906699
# best mean reward -166.906699
# running time 65.624076
# Train_EnvstepsSoFar : 37001
# Train_AverageReturn : -166.90669861050793
# Train_BestReturn : -166.90669861050793
# TimeSinceStart : 65.62407636642456
# Training Loss : 0.9377503991127014
# Done logging...
#
#
#
#
# ********** Iteration 38000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 38001
# mean reward (100 episodes) -164.310713
# best mean reward -164.310713
# running time 68.881839
# Train_EnvstepsSoFar : 38001
# Train_AverageReturn : -164.31071310007113
# Train_BestReturn : -164.31071310007113
# TimeSinceStart : 68.88183879852295
# Training Loss : 0.22608105838298798
# Done logging...
#
#
#
#
# ********** Iteration 39000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 39001
# mean reward (100 episodes) -163.596907
# best mean reward -163.596907
# running time 70.789692
# Train_EnvstepsSoFar : 39001
# Train_AverageReturn : -163.59690683979642
# Train_BestReturn : -163.59690683979642
# TimeSinceStart : 70.78969168663025
# Training Loss : 0.9582963585853577
# Done logging...
#
#
#
#
# ********** Iteration 40000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 40001
# mean reward (100 episodes) -161.566521
# best mean reward -161.566521
# running time 73.111977
# Train_EnvstepsSoFar : 40001
# Train_AverageReturn : -161.5665209384231
# Train_BestReturn : -161.5665209384231
# TimeSinceStart : 73.11197686195374
# Training Loss : 1.576583981513977
# Done logging...
#
#
#
#
# ********** Iteration 41000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 41001
# mean reward (100 episodes) -160.765515
# best mean reward -160.765515
# running time 75.744474
# Train_EnvstepsSoFar : 41001
# Train_AverageReturn : -160.76551492938563
# Train_BestReturn : -160.76551492938563
# TimeSinceStart : 75.74447441101074
# Training Loss : 0.4398576617240906
# Done logging...
#
#
#
#
# ********** Iteration 42000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 42001
# mean reward (100 episodes) -163.313176
# best mean reward -160.765515
# running time 77.712240
# Train_EnvstepsSoFar : 42001
# Train_AverageReturn : -163.3131759475027
# Train_BestReturn : -160.76551492938563
# TimeSinceStart : 77.71224045753479
# Training Loss : 0.374114990234375
# Done logging...
#
#
#
#
# ********** Iteration 43000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 43001
# mean reward (100 episodes) -160.919422
# best mean reward -160.765515
# running time 79.939240
# Train_EnvstepsSoFar : 43001
# Train_AverageReturn : -160.91942160501657
# Train_BestReturn : -160.76551492938563
# TimeSinceStart : 79.9392397403717
# Training Loss : 0.31762516498565674
# Done logging...
#
#
#
#
# ********** Iteration 44000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 44001
# mean reward (100 episodes) -157.343132
# best mean reward -157.343132
# running time 81.801514
# Train_EnvstepsSoFar : 44001
# Train_AverageReturn : -157.34313181955054
# Train_BestReturn : -157.34313181955054
# TimeSinceStart : 81.801513671875
# Training Loss : 0.2392120659351349
# Done logging...
#
#
#
#
# ********** Iteration 45000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 45001
# mean reward (100 episodes) -155.844457
# best mean reward -155.844457
# running time 83.670129
# Train_EnvstepsSoFar : 45001
# Train_AverageReturn : -155.84445747806762
# Train_BestReturn : -155.84445747806762
# TimeSinceStart : 83.67012882232666
# Training Loss : 0.5361930727958679
# Done logging...
#
#
#
#
# ********** Iteration 46000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 46001
# mean reward (100 episodes) -151.857102
# best mean reward -151.857102
# running time 85.715992
# Train_EnvstepsSoFar : 46001
# Train_AverageReturn : -151.85710156108578
# Train_BestReturn : -151.85710156108578
# TimeSinceStart : 85.71599245071411
# Training Loss : 0.2616400122642517
# Done logging...
#
#
#
#
# ********** Iteration 47000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 47001
# mean reward (100 episodes) -150.246561
# best mean reward -150.246561
# running time 87.978588
# Train_EnvstepsSoFar : 47001
# Train_AverageReturn : -150.24656132907495
# Train_BestReturn : -150.24656132907495
# TimeSinceStart : 87.97858810424805
# Training Loss : 2.5267155170440674
# Done logging...
#
#
#
#
# ********** Iteration 48000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 48001
# mean reward (100 episodes) -147.226842
# best mean reward -147.226842
# running time 89.891551
# Train_EnvstepsSoFar : 48001
# Train_AverageReturn : -147.22684159532045
# Train_BestReturn : -147.22684159532045
# TimeSinceStart : 89.89155077934265
# Training Loss : 0.3350748121738434
# Done logging...
#
#
#
#
# ********** Iteration 49000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 49001
# mean reward (100 episodes) -148.074585
# best mean reward -147.226842
# running time 91.682146
# Train_EnvstepsSoFar : 49001
# Train_AverageReturn : -148.07458529051016
# Train_BestReturn : -147.22684159532045
# TimeSinceStart : 91.68214559555054
# Training Loss : 0.3332221806049347
# Done logging...
#
#
#
#
# ********** Iteration 50000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 50001
# mean reward (100 episodes) -147.104410
# best mean reward -147.104410
# running time 94.286118
# Train_EnvstepsSoFar : 50001
# Train_AverageReturn : -147.10440972292636
# Train_BestReturn : -147.10440972292636
# TimeSinceStart : 94.28611779212952
# Training Loss : 0.33558008074760437
# Done logging...
#
#
#
#
# ********** Iteration 51000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 51001
# mean reward (100 episodes) -144.360017
# best mean reward -144.360017
# running time 95.930952
# Train_EnvstepsSoFar : 51001
# Train_AverageReturn : -144.36001696730253
# Train_BestReturn : -144.36001696730253
# TimeSinceStart : 95.93095183372498
# Training Loss : 0.22784337401390076
# Done logging...
#
#
#
#
# ********** Iteration 52000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 52001
# mean reward (100 episodes) -141.829321
# best mean reward -141.829321
# running time 98.240479
# Train_EnvstepsSoFar : 52001
# Train_AverageReturn : -141.82932129214893
# Train_BestReturn : -141.82932129214893
# TimeSinceStart : 98.24047923088074
# Training Loss : 9.578021049499512
# Done logging...
#
#
#
#
# ********** Iteration 53000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 53001
# mean reward (100 episodes) -136.850465
# best mean reward -136.850465
# running time 100.329660
# Train_EnvstepsSoFar : 53001
# Train_AverageReturn : -136.8504651048513
# Train_BestReturn : -136.8504651048513
# TimeSinceStart : 100.32965993881226
# Training Loss : 1.1998422145843506
# Done logging...
#
#
#
#
# ********** Iteration 54000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 54001
# mean reward (100 episodes) -134.379551
# best mean reward -134.379551
# running time 102.353297
# Train_EnvstepsSoFar : 54001
# Train_AverageReturn : -134.37955103926296
# Train_BestReturn : -134.37955103926296
# TimeSinceStart : 102.3532965183258
# Training Loss : 0.4481203556060791
# Done logging...
#
#
#
#
# ********** Iteration 55000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 55001
# mean reward (100 episodes) -131.906161
# best mean reward -131.906161
# running time 104.658194
# Train_EnvstepsSoFar : 55001
# Train_AverageReturn : -131.90616100646105
# Train_BestReturn : -131.90616100646105
# TimeSinceStart : 104.65819382667542
# Training Loss : 0.4272646903991699
# Done logging...
#
#
#
#
# ********** Iteration 56000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 56001
# mean reward (100 episodes) -129.516942
# best mean reward -129.516942
# running time 108.211931
# Train_EnvstepsSoFar : 56001
# Train_AverageReturn : -129.51694224249923
# Train_BestReturn : -129.51694224249923
# TimeSinceStart : 108.21193075180054
# Training Loss : 3.1203866004943848
# Done logging...
#
#
#
#
# ********** Iteration 57000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 57001
# mean reward (100 episodes) -124.218849
# best mean reward -124.218849
# running time 110.648519
# Train_EnvstepsSoFar : 57001
# Train_AverageReturn : -124.21884916812053
# Train_BestReturn : -124.21884916812053
# TimeSinceStart : 110.64851927757263
# Training Loss : 0.41414734721183777
# Done logging...
#
#
#
#
# ********** Iteration 58000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 58001
# mean reward (100 episodes) -122.188697
# best mean reward -122.188697
# running time 112.617145
# Train_EnvstepsSoFar : 58001
# Train_AverageReturn : -122.1886965491103
# Train_BestReturn : -122.1886965491103
# TimeSinceStart : 112.61714506149292
# Training Loss : 0.34086307883262634
# Done logging...
#
#
#
#
# ********** Iteration 59000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 59001
# mean reward (100 episodes) -118.066478
# best mean reward -118.066478
# running time 115.632491
# Train_EnvstepsSoFar : 59001
# Train_AverageReturn : -118.0664782884504
# Train_BestReturn : -118.0664782884504
# TimeSinceStart : 115.63249135017395
# Training Loss : 0.32762759923934937
# Done logging...
#
#
#
#
# ********** Iteration 60000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 60001
# mean reward (100 episodes) -119.687920
# best mean reward -118.066478
# running time 118.250049
# Train_EnvstepsSoFar : 60001
# Train_AverageReturn : -119.68791993191984
# Train_BestReturn : -118.0664782884504
# TimeSinceStart : 118.2500491142273
# Training Loss : 0.3681733012199402
# Done logging...
#
#
#
#
# ********** Iteration 61000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 61001
# mean reward (100 episodes) -117.164435
# best mean reward -117.164435
# running time 120.349274
# Train_EnvstepsSoFar : 61001
# Train_AverageReturn : -117.16443498448817
# Train_BestReturn : -117.16443498448817
# TimeSinceStart : 120.34927415847778
# Training Loss : 0.28821179270744324
# Done logging...
#
#
#
#
# ********** Iteration 62000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 62001
# mean reward (100 episodes) -114.977522
# best mean reward -114.977522
# running time 122.630129
# Train_EnvstepsSoFar : 62001
# Train_AverageReturn : -114.97752232022256
# Train_BestReturn : -114.97752232022256
# TimeSinceStart : 122.63012909889221
# Training Loss : 0.28705236315727234
# Done logging...
#
#
#
#
# ********** Iteration 63000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 63001
# mean reward (100 episodes) -112.721713
# best mean reward -112.721713
# running time 125.194358
# Train_EnvstepsSoFar : 63001
# Train_AverageReturn : -112.72171312594057
# Train_BestReturn : -112.72171312594057
# TimeSinceStart : 125.19435834884644
# Training Loss : 2.4144861698150635
# Done logging...
#
#
#
#
# ********** Iteration 64000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 64001
# mean reward (100 episodes) -112.939973
# best mean reward -112.721713
# running time 127.681979
# Train_EnvstepsSoFar : 64001
# Train_AverageReturn : -112.93997283693606
# Train_BestReturn : -112.72171312594057
# TimeSinceStart : 127.68197894096375
# Training Loss : 0.29629403352737427
# Done logging...
#
#
#
#
# ********** Iteration 65000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 65001
# mean reward (100 episodes) -110.816895
# best mean reward -110.816895
# running time 130.071133
# Train_EnvstepsSoFar : 65001
# Train_AverageReturn : -110.81689515284488
# Train_BestReturn : -110.81689515284488
# TimeSinceStart : 130.0711326599121
# Training Loss : 0.33473965525627136
# Done logging...
#
#
#
#
# ********** Iteration 66000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 66001
# mean reward (100 episodes) -110.875768
# best mean reward -110.816895
# running time 132.400634
# Train_EnvstepsSoFar : 66001
# Train_AverageReturn : -110.8757684414182
# Train_BestReturn : -110.81689515284488
# TimeSinceStart : 132.40063405036926
# Training Loss : 0.21093806624412537
# Done logging...
#
#
#
#
# ********** Iteration 67000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 67001
# mean reward (100 episodes) -105.838803
# best mean reward -105.838803
# running time 134.516645
# Train_EnvstepsSoFar : 67001
# Train_AverageReturn : -105.83880280576054
# Train_BestReturn : -105.83880280576054
# TimeSinceStart : 134.5166449546814
# Training Loss : 0.21750383079051971
# Done logging...
#
#
#
#
# ********** Iteration 68000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 68001
# mean reward (100 episodes) -105.853194
# best mean reward -105.838803
# running time 136.413171
# Train_EnvstepsSoFar : 68001
# Train_AverageReturn : -105.85319403255518
# Train_BestReturn : -105.83880280576054
# TimeSinceStart : 136.41317081451416
# Training Loss : 0.21619857847690582
# Done logging...
#
#
#
#
# ********** Iteration 69000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 69001
# mean reward (100 episodes) -104.466989
# best mean reward -104.466989
# running time 138.577857
# Train_EnvstepsSoFar : 69001
# Train_AverageReturn : -104.46698949670059
# Train_BestReturn : -104.46698949670059
# TimeSinceStart : 138.57785654067993
# Training Loss : 0.2752370834350586
# Done logging...
#
#
#
#
# ********** Iteration 70000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 70001
# mean reward (100 episodes) -96.760438
# best mean reward -96.760438
# running time 140.949854
# Train_EnvstepsSoFar : 70001
# Train_AverageReturn : -96.76043754351004
# Train_BestReturn : -96.76043754351004
# TimeSinceStart : 140.9498541355133
# Training Loss : 0.19754815101623535
# Done logging...
#
#
#
#
# ********** Iteration 71000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 71001
# mean reward (100 episodes) -94.156201
# best mean reward -94.156201
# running time 143.051274
# Train_EnvstepsSoFar : 71001
# Train_AverageReturn : -94.1562012477602
# Train_BestReturn : -94.1562012477602
# TimeSinceStart : 143.051274061203
# Training Loss : 0.2181725949048996
# Done logging...
#
#
#
#
# ********** Iteration 72000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 72001
# mean reward (100 episodes) -90.732350
# best mean reward -90.732350
# running time 145.237024
# Train_EnvstepsSoFar : 72001
# Train_AverageReturn : -90.73235047914092
# Train_BestReturn : -90.73235047914092
# TimeSinceStart : 145.23702359199524
# Training Loss : 0.28227585554122925
# Done logging...
#
#
#
#
# ********** Iteration 73000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 73001
# mean reward (100 episodes) -91.358473
# best mean reward -90.732350
# running time 147.833331
# Train_EnvstepsSoFar : 73001
# Train_AverageReturn : -91.35847290996725
# Train_BestReturn : -90.73235047914092
# TimeSinceStart : 147.83333134651184
# Training Loss : 0.25243034958839417
# Done logging...
#
#
#
#
# ********** Iteration 74000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 74001
# mean reward (100 episodes) -89.817956
# best mean reward -89.817956
# running time 149.771388
# Train_EnvstepsSoFar : 74001
# Train_AverageReturn : -89.81795563553618
# Train_BestReturn : -89.81795563553618
# TimeSinceStart : 149.77138805389404
# Training Loss : 0.15509536862373352
# Done logging...
#
#
#
#
# ********** Iteration 75000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 75001
# mean reward (100 episodes) -92.072107
# best mean reward -89.817956
# running time 152.034753
# Train_EnvstepsSoFar : 75001
# Train_AverageReturn : -92.07210744139832
# Train_BestReturn : -89.81795563553618
# TimeSinceStart : 152.03475332260132
# Training Loss : 0.12174538522958755
# Done logging...
#
#
#
#
# ********** Iteration 76000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 76001
# mean reward (100 episodes) -91.179845
# best mean reward -89.817956
# running time 153.747972
# Train_EnvstepsSoFar : 76001
# Train_AverageReturn : -91.17984450509039
# Train_BestReturn : -89.81795563553618
# TimeSinceStart : 153.74797177314758
# Training Loss : 0.2972659170627594
# Done logging...
#
#
#
#
# ********** Iteration 77000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 77001
# mean reward (100 episodes) -89.179042
# best mean reward -89.179042
# running time 155.920911
# Train_EnvstepsSoFar : 77001
# Train_AverageReturn : -89.17904220640763
# Train_BestReturn : -89.17904220640763
# TimeSinceStart : 155.9209110736847
# Training Loss : 0.253263920545578
# Done logging...
#
#
#
#
# ********** Iteration 78000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 78001
# mean reward (100 episodes) -83.496229
# best mean reward -83.496229
# running time 158.305913
# Train_EnvstepsSoFar : 78001
# Train_AverageReturn : -83.49622906795037
# Train_BestReturn : -83.49622906795037
# TimeSinceStart : 158.30591297149658
# Training Loss : 0.1979290097951889
# Done logging...
#
#
#
#
# ********** Iteration 79000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 79001
# mean reward (100 episodes) -80.189969
# best mean reward -80.189969
# running time 160.312690
# Train_EnvstepsSoFar : 79001
# Train_AverageReturn : -80.18996860289575
# Train_BestReturn : -80.18996860289575
# TimeSinceStart : 160.31269025802612
# Training Loss : 0.28120407462120056
# Done logging...
#
#
#
#
# ********** Iteration 80000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 80001
# mean reward (100 episodes) -82.919698
# best mean reward -80.189969
# running time 161.957088
# Train_EnvstepsSoFar : 80001
# Train_AverageReturn : -82.91969787197777
# Train_BestReturn : -80.18996860289575
# TimeSinceStart : 161.95708751678467
# Training Loss : 0.09126440435647964
# Done logging...
#
#
#
#
# ********** Iteration 81000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 81001
# mean reward (100 episodes) -80.031842
# best mean reward -80.031842
# running time 163.837312
# Train_EnvstepsSoFar : 81001
# Train_AverageReturn : -80.03184233730357
# Train_BestReturn : -80.03184233730357
# TimeSinceStart : 163.8373122215271
# Training Loss : 0.263685405254364
# Done logging...
#
#
#
#
# ********** Iteration 82000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 82001
# mean reward (100 episodes) -76.654479
# best mean reward -76.654479
# running time 166.226030
# Train_EnvstepsSoFar : 82001
# Train_AverageReturn : -76.65447877750714
# Train_BestReturn : -76.65447877750714
# TimeSinceStart : 166.22603011131287
# Training Loss : 0.15953700244426727
# Done logging...
#
#
#
#
# ********** Iteration 83000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 83001
# mean reward (100 episodes) -76.247564
# best mean reward -76.247564
# running time 169.089411
# Train_EnvstepsSoFar : 83001
# Train_AverageReturn : -76.24756412869517
# Train_BestReturn : -76.24756412869517
# TimeSinceStart : 169.08941078186035
# Training Loss : 0.16204723715782166
# Done logging...
#
#
#
#
# ********** Iteration 84000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 84001
# mean reward (100 episodes) -74.847975
# best mean reward -74.847975
# running time 172.254912
# Train_EnvstepsSoFar : 84001
# Train_AverageReturn : -74.84797459700476
# Train_BestReturn : -74.84797459700476
# TimeSinceStart : 172.25491189956665
# Training Loss : 0.3667357563972473
# Done logging...
#
#
#
#
# ********** Iteration 85000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 85001
# mean reward (100 episodes) -72.836079
# best mean reward -72.836079
# running time 174.885471
# Train_EnvstepsSoFar : 85001
# Train_AverageReturn : -72.8360789690663
# Train_BestReturn : -72.8360789690663
# TimeSinceStart : 174.8854706287384
# Training Loss : 0.14690954983234406
# Done logging...
#
#
#
#
# ********** Iteration 86000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 86001
# mean reward (100 episodes) -70.544474
# best mean reward -70.544474
# running time 177.597400
# Train_EnvstepsSoFar : 86001
# Train_AverageReturn : -70.54447419879136
# Train_BestReturn : -70.54447419879136
# TimeSinceStart : 177.59739995002747
# Training Loss : 0.13372835516929626
# Done logging...
#
#
#
#
# ********** Iteration 87000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 87001
# mean reward (100 episodes) -65.086712
# best mean reward -65.086712
# running time 180.054233
# Train_EnvstepsSoFar : 87001
# Train_AverageReturn : -65.08671155448894
# Train_BestReturn : -65.08671155448894
# TimeSinceStart : 180.05423307418823
# Training Loss : 0.22103582322597504
# Done logging...
#
#
#
#
# ********** Iteration 88000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 88001
# mean reward (100 episodes) -58.836947
# best mean reward -58.836947
# running time 182.190275
# Train_EnvstepsSoFar : 88001
# Train_AverageReturn : -58.8369466936717
# Train_BestReturn : -58.8369466936717
# TimeSinceStart : 182.19027543067932
# Training Loss : 0.08210542798042297
# Done logging...
#
#
#
#
# ********** Iteration 89000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 89001
# mean reward (100 episodes) -58.643387
# best mean reward -58.643387
# running time 185.135464
# Train_EnvstepsSoFar : 89001
# Train_AverageReturn : -58.64338650006292
# Train_BestReturn : -58.64338650006292
# TimeSinceStart : 185.13546419143677
# Training Loss : 0.10639005154371262
# Done logging...
#
#
#
#
# ********** Iteration 90000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 90001
# mean reward (100 episodes) -51.885544
# best mean reward -51.885544
# running time 187.116559
# Train_EnvstepsSoFar : 90001
# Train_AverageReturn : -51.88554425270433
# Train_BestReturn : -51.88554425270433
# TimeSinceStart : 187.1165590286255
# Training Loss : 0.18864355981349945
# Done logging...
#
#
#
#
# ********** Iteration 91000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 91001
# mean reward (100 episodes) -52.225764
# best mean reward -51.885544
# running time 189.072907
# Train_EnvstepsSoFar : 91001
# Train_AverageReturn : -52.225764376721436
# Train_BestReturn : -51.88554425270433
# TimeSinceStart : 189.07290744781494
# Training Loss : 0.12093140929937363
# Done logging...
#
#
#
#
# ********** Iteration 92000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 92001
# mean reward (100 episodes) -46.460009
# best mean reward -46.460009
# running time 191.085125
# Train_EnvstepsSoFar : 92001
# Train_AverageReturn : -46.4600088749724
# Train_BestReturn : -46.4600088749724
# TimeSinceStart : 191.08512544631958
# Training Loss : 0.987576425075531
# Done logging...
#
#
#
#
# ********** Iteration 93000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 93001
# mean reward (100 episodes) -44.360884
# best mean reward -44.360884
# running time 193.209852
# Train_EnvstepsSoFar : 93001
# Train_AverageReturn : -44.36088366330712
# Train_BestReturn : -44.36088366330712
# TimeSinceStart : 193.20985198020935
# Training Loss : 0.12212458997964859
# Done logging...
#
#
#
#
# ********** Iteration 94000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 94001
# mean reward (100 episodes) -44.469638
# best mean reward -44.360884
# running time 196.127425
# Train_EnvstepsSoFar : 94001
# Train_AverageReturn : -44.46963808338643
# Train_BestReturn : -44.36088366330712
# TimeSinceStart : 196.1274254322052
# Training Loss : 0.20107929408550262
# Done logging...
#
#
#
#
# ********** Iteration 95000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 95001
# mean reward (100 episodes) -43.154109
# best mean reward -43.154109
# running time 198.498730
# Train_EnvstepsSoFar : 95001
# Train_AverageReturn : -43.15410936030669
# Train_BestReturn : -43.15410936030669
# TimeSinceStart : 198.4987301826477
# Training Loss : 0.7196794152259827
# Done logging...
#
#
#
#
# ********** Iteration 96000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 96001
# mean reward (100 episodes) -40.171669
# best mean reward -40.171669
# running time 200.591350
# Train_EnvstepsSoFar : 96001
# Train_AverageReturn : -40.17166897739281
# Train_BestReturn : -40.17166897739281
# TimeSinceStart : 200.59134984016418
# Training Loss : 0.20270518958568573
# Done logging...
#
#
#
#
# ********** Iteration 97000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 97001
# mean reward (100 episodes) -42.555947
# best mean reward -40.171669
# running time 202.957280
# Train_EnvstepsSoFar : 97001
# Train_AverageReturn : -42.55594692870633
# Train_BestReturn : -40.17166897739281
# TimeSinceStart : 202.957279920578
# Training Loss : 0.303692489862442
# Done logging...
#
#
#
#
# ********** Iteration 98000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 98001
# mean reward (100 episodes) -37.001640
# best mean reward -37.001640
# running time 204.808951
# Train_EnvstepsSoFar : 98001
# Train_AverageReturn : -37.00163968379307
# Train_BestReturn : -37.00163968379307
# TimeSinceStart : 204.80895113945007
# Training Loss : 0.08506284654140472
# Done logging...
#
#
#
#
# ********** Iteration 99000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 99001
# mean reward (100 episodes) -34.024979
# best mean reward -34.024979
# running time 207.775471
# Train_EnvstepsSoFar : 99001
# Train_AverageReturn : -34.02497896919612
# Train_BestReturn : -34.02497896919612
# TimeSinceStart : 207.77547097206116
# Training Loss : 0.412884920835495
# Done logging...
#
#
#
#
# ********** Iteration 100000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 100001
# mean reward (100 episodes) -33.912456
# best mean reward -33.912456
# running time 209.957424
# Train_EnvstepsSoFar : 100001
# Train_AverageReturn : -33.912456027560964
# Train_BestReturn : -33.912456027560964
# TimeSinceStart : 209.95742392539978
# Training Loss : 3.0969398021698
# Done logging...
#
#
#
#
# ********** Iteration 101000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 101001
# mean reward (100 episodes) -33.667150
# best mean reward -33.667150
# running time 211.987861
# Train_EnvstepsSoFar : 101001
# Train_AverageReturn : -33.66715024643047
# Train_BestReturn : -33.66715024643047
# TimeSinceStart : 211.98786067962646
# Training Loss : 0.15595658123493195
# Done logging...
#
#
#
#
# ********** Iteration 102000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 102001
# mean reward (100 episodes) -30.185669
# best mean reward -30.185669
# running time 214.343667
# Train_EnvstepsSoFar : 102001
# Train_AverageReturn : -30.185668976257613
# Train_BestReturn : -30.185668976257613
# TimeSinceStart : 214.34366726875305
# Training Loss : 0.36739298701286316
# Done logging...
#
#
#
#
# ********** Iteration 103000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 103001
# mean reward (100 episodes) -28.301444
# best mean reward -28.301444
# running time 216.275886
# Train_EnvstepsSoFar : 103001
# Train_AverageReturn : -28.301444072232474
# Train_BestReturn : -28.301444072232474
# TimeSinceStart : 216.27588629722595
# Training Loss : 0.1194552481174469
# Done logging...
#
#
#
#
# ********** Iteration 104000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 104001
# mean reward (100 episodes) -22.466965
# best mean reward -22.466965
# running time 218.484784
# Train_EnvstepsSoFar : 104001
# Train_AverageReturn : -22.466964833361462
# Train_BestReturn : -22.466964833361462
# TimeSinceStart : 218.48478364944458
# Training Loss : 0.6443411111831665
# Done logging...
#
#
#
#
# ********** Iteration 105000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 105001
# mean reward (100 episodes) -19.841346
# best mean reward -19.841346
# running time 220.537088
# Train_EnvstepsSoFar : 105001
# Train_AverageReturn : -19.841346354556748
# Train_BestReturn : -19.841346354556748
# TimeSinceStart : 220.53708791732788
# Training Loss : 0.10642405599355698
# Done logging...
#
#
#
#
# ********** Iteration 106000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 106001
# mean reward (100 episodes) -17.377436
# best mean reward -17.377436
# running time 222.966985
# Train_EnvstepsSoFar : 106001
# Train_AverageReturn : -17.37743625442559
# Train_BestReturn : -17.37743625442559
# TimeSinceStart : 222.9669852256775
# Training Loss : 0.1510556936264038
# Done logging...
#
#
#
#
# ********** Iteration 107000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 107001
# mean reward (100 episodes) -16.642514
# best mean reward -16.642514
# running time 225.143097
# Train_EnvstepsSoFar : 107001
# Train_AverageReturn : -16.642514130893556
# Train_BestReturn : -16.642514130893556
# TimeSinceStart : 225.1430971622467
# Training Loss : 0.15630123019218445
# Done logging...
#
#
#
#
# ********** Iteration 108000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 108001
# mean reward (100 episodes) -14.472618
# best mean reward -14.472618
# running time 227.176589
# Train_EnvstepsSoFar : 108001
# Train_AverageReturn : -14.472618357344786
# Train_BestReturn : -14.472618357344786
# TimeSinceStart : 227.17658853530884
# Training Loss : 0.07038480043411255
# Done logging...
#
#
#
#
# ********** Iteration 109000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 109001
# mean reward (100 episodes) -12.202958
# best mean reward -12.202958
# running time 229.176114
# Train_EnvstepsSoFar : 109001
# Train_AverageReturn : -12.202958225914333
# Train_BestReturn : -12.202958225914333
# TimeSinceStart : 229.17611384391785
# Training Loss : 0.14414352178573608
# Done logging...
#
#
#
#
# ********** Iteration 110000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 110001
# mean reward (100 episodes) -12.208340
# best mean reward -12.202958
# running time 231.166240
# Train_EnvstepsSoFar : 110001
# Train_AverageReturn : -12.208340282494987
# Train_BestReturn : -12.202958225914333
# TimeSinceStart : 231.1662404537201
# Training Loss : 0.20286549627780914
# Done logging...
#
#
#
#
# ********** Iteration 111000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 111001
# mean reward (100 episodes) -8.341238
# best mean reward -8.341238
# running time 232.909542
# Train_EnvstepsSoFar : 111001
# Train_AverageReturn : -8.341237556746963
# Train_BestReturn : -8.341237556746963
# TimeSinceStart : 232.9095423221588
# Training Loss : 0.2858434319496155
# Done logging...
#
#
#
#
# ********** Iteration 112000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 112001
# mean reward (100 episodes) -8.131214
# best mean reward -8.131214
# running time 234.804144
# Train_EnvstepsSoFar : 112001
# Train_AverageReturn : -8.131213670779662
# Train_BestReturn : -8.131213670779662
# TimeSinceStart : 234.8041443824768
# Training Loss : 0.2201274186372757
# Done logging...
#
#
#
#
# ********** Iteration 113000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 113001
# mean reward (100 episodes) -3.371795
# best mean reward -3.371795
# running time 236.599043
# Train_EnvstepsSoFar : 113001
# Train_AverageReturn : -3.371794710341457
# Train_BestReturn : -3.371794710341457
# TimeSinceStart : 236.59904313087463
# Training Loss : 1.070257306098938
# Done logging...
#
#
#
#
# ********** Iteration 114000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 114001
# mean reward (100 episodes) 2.480984
# best mean reward 2.480984
# running time 238.319070
# Train_EnvstepsSoFar : 114001
# Train_AverageReturn : 2.480983632414607
# Train_BestReturn : 2.480983632414607
# TimeSinceStart : 238.31906962394714
# Training Loss : 0.25317245721817017
# Done logging...
#
#
#
#
# ********** Iteration 115000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 115001
# mean reward (100 episodes) 7.841939
# best mean reward 7.841939
# running time 240.467547
# Train_EnvstepsSoFar : 115001
# Train_AverageReturn : 7.84193945470432
# Train_BestReturn : 7.84193945470432
# TimeSinceStart : 240.46754693984985
# Training Loss : 0.21449699997901917
# Done logging...
#
#
#
#
# ********** Iteration 116000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 116001
# mean reward (100 episodes) 8.446964
# best mean reward 8.446964
# running time 242.683283
# Train_EnvstepsSoFar : 116001
# Train_AverageReturn : 8.446964222672289
# Train_BestReturn : 8.446964222672289
# TimeSinceStart : 242.68328332901
# Training Loss : 0.1449529081583023
# Done logging...
#
#
#
#
# ********** Iteration 117000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 117001
# mean reward (100 episodes) 7.885403
# best mean reward 8.446964
# running time 244.835514
# Train_EnvstepsSoFar : 117001
# Train_AverageReturn : 7.885403185642885
# Train_BestReturn : 8.446964222672289
# TimeSinceStart : 244.83551383018494
# Training Loss : 0.17309018969535828
# Done logging...
#
#
#
#
# ********** Iteration 118000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 118001
# mean reward (100 episodes) 7.923549
# best mean reward 8.446964
# running time 246.928757
# Train_EnvstepsSoFar : 118001
# Train_AverageReturn : 7.923548966196087
# Train_BestReturn : 8.446964222672289
# TimeSinceStart : 246.92875719070435
# Training Loss : 0.4728156328201294
# Done logging...
#
#
#
#
# ********** Iteration 119000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 119001
# mean reward (100 episodes) 10.812583
# best mean reward 10.812583
# running time 249.125957
# Train_EnvstepsSoFar : 119001
# Train_AverageReturn : 10.812582780909679
# Train_BestReturn : 10.812582780909679
# TimeSinceStart : 249.12595653533936
# Training Loss : 0.2174254059791565
# Done logging...
#
#
#
#
# ********** Iteration 120000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 120001
# mean reward (100 episodes) 10.311230
# best mean reward 10.812583
# running time 251.132989
# Train_EnvstepsSoFar : 120001
# Train_AverageReturn : 10.311230292458609
# Train_BestReturn : 10.812582780909679
# TimeSinceStart : 251.1329894065857
# Training Loss : 0.16370122134685516
# Done logging...
#
#
#
#
# ********** Iteration 121000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 121001
# mean reward (100 episodes) 10.573507
# best mean reward 10.812583
# running time 253.315657
# Train_EnvstepsSoFar : 121001
# Train_AverageReturn : 10.573507053345535
# Train_BestReturn : 10.812582780909679
# TimeSinceStart : 253.31565713882446
# Training Loss : 2.611354351043701
# Done logging...
#
#
#
#
# ********** Iteration 122000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 122001
# mean reward (100 episodes) 11.167443
# best mean reward 11.167443
# running time 255.185072
# Train_EnvstepsSoFar : 122001
# ...
# Train_EnvstepsSoFar : 459001
# Train_AverageReturn : 70.6331917724009
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 907.3877489566803
# Training Loss : 0.3667365312576294
# Done logging...
#
#
#
#
# ********** Iteration 460000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 460001
# mean reward (100 episodes) 69.587017
# best mean reward 156.720935
# running time 909.782355
# Train_EnvstepsSoFar : 460001
# Train_AverageReturn : 69.5870170698642
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 909.782354593277
# Training Loss : 0.19868025183677673
# Done logging...
#
#
#
#
# ********** Iteration 461000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 461001
# mean reward (100 episodes) 71.402814
# best mean reward 156.720935
# running time 912.463128
# Train_EnvstepsSoFar : 461001
# Train_AverageReturn : 71.4028144919183
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 912.4631283283234
# Training Loss : 0.32766827940940857
# Done logging...
#
#
#
#
# ********** Iteration 462000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 462001
# mean reward (100 episodes) 72.766636
# best mean reward 156.720935
# running time 914.454463
# Train_EnvstepsSoFar : 462001
# Train_AverageReturn : 72.7666360398985
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 914.4544634819031
# Training Loss : 1.081429123878479
# Done logging...
#
#
#
#
# ********** Iteration 463000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 463001
# mean reward (100 episodes) 73.031975
# best mean reward 156.720935
# running time 917.354858
# Train_EnvstepsSoFar : 463001
# Train_AverageReturn : 73.03197459391205
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 917.3548581600189
# Training Loss : 0.3622882068157196
# Done logging...
#
#
#
#
# ********** Iteration 464000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 464001
# mean reward (100 episodes) 75.807465
# best mean reward 156.720935
# running time 920.549034
# Train_EnvstepsSoFar : 464001
# Train_AverageReturn : 75.8074654443422
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 920.5490336418152
# Training Loss : 0.16155172884464264
# Done logging...
#
#
#
#
# ********** Iteration 465000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 465001
# mean reward (100 episodes) 77.275073
# best mean reward 156.720935
# running time 922.535684
# Train_EnvstepsSoFar : 465001
# Train_AverageReturn : 77.27507292490063
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 922.5356843471527
# Training Loss : 0.21250776946544647
# Done logging...
#
#
#
#
# ********** Iteration 466000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 466001
# mean reward (100 episodes) 75.435295
# best mean reward 156.720935
# running time 925.269798
# Train_EnvstepsSoFar : 466001
# Train_AverageReturn : 75.43529459844393
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 925.2697978019714
# Training Loss : 0.21678021550178528
# Done logging...
#
#
#
#
# ********** Iteration 467000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 467001
# mean reward (100 episodes) 76.666556
# best mean reward 156.720935
# running time 928.842204
# Train_EnvstepsSoFar : 467001
# Train_AverageReturn : 76.66655556977797
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 928.842203617096
# Training Loss : 1.6310673952102661
# Done logging...
#
#
#
#
# ********** Iteration 468000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 468001
# mean reward (100 episodes) 77.957129
# best mean reward 156.720935
# running time 932.084157
# Train_EnvstepsSoFar : 468001
# Train_AverageReturn : 77.95712924171083
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 932.0841574668884
# Training Loss : 0.16297197341918945
# Done logging...
#
#
#
#
# ********** Iteration 469000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 469001
# mean reward (100 episodes) 80.362841
# best mean reward 156.720935
# running time 934.374599
# Train_EnvstepsSoFar : 469001
# Train_AverageReturn : 80.36284058353257
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 934.3745985031128
# Training Loss : 0.4100129008293152
# Done logging...
#
#
#
#
# ********** Iteration 470000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 470001
# mean reward (100 episodes) 83.201006
# best mean reward 156.720935
# running time 937.073005
# Train_EnvstepsSoFar : 470001
# Train_AverageReturn : 83.20100561544922
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 937.0730051994324
# Training Loss : 0.28173473477363586
# Done logging...
#
#
#
#
# ********** Iteration 471000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 471001
# mean reward (100 episodes) 80.532710
# best mean reward 156.720935
# running time 940.644787
# Train_EnvstepsSoFar : 471001
# Train_AverageReturn : 80.53271020449797
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 940.6447870731354
# Training Loss : 0.3935553729534149
# Done logging...
#
#
#
#
# ********** Iteration 472000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 472001
# mean reward (100 episodes) 84.664910
# best mean reward 156.720935
# running time 942.347991
# Train_EnvstepsSoFar : 472001
# Train_AverageReturn : 84.66491049869826
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 942.3479912281036
# Training Loss : 0.1272147297859192
# Done logging...
#
#
#
#
# ********** Iteration 473000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 473001
# mean reward (100 episodes) 79.698219
# best mean reward 156.720935
# running time 944.802505
# Train_EnvstepsSoFar : 473001
# Train_AverageReturn : 79.69821942924366
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 944.8025052547455
# Training Loss : 0.27469128370285034
# Done logging...
#
#
#
#
# ********** Iteration 474000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 474001
# mean reward (100 episodes) 79.431229
# best mean reward 156.720935
# running time 946.587302
# Train_EnvstepsSoFar : 474001
# Train_AverageReturn : 79.43122911229696
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 946.5873024463654
# Training Loss : 1.0266374349594116
# Done logging...
#
#
#
#
# ********** Iteration 475000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 475001
# mean reward (100 episodes) 78.277333
# best mean reward 156.720935
# running time 949.670087
# Train_EnvstepsSoFar : 475001
# Train_AverageReturn : 78.27733280799795
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 949.6700870990753
# Training Loss : 0.2178851068019867
# Done logging...
#
#
#
#
# ********** Iteration 476000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 476001
# mean reward (100 episodes) 78.367523
# best mean reward 156.720935
# running time 951.283946
# Train_EnvstepsSoFar : 476001
# Train_AverageReturn : 78.36752272764883
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 951.2839460372925
# Training Loss : 0.30887794494628906
# Done logging...
#
#
#
#
# ********** Iteration 477000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 477001
# mean reward (100 episodes) 80.072171
# best mean reward 156.720935
# running time 954.251990
# Train_EnvstepsSoFar : 477001
# Train_AverageReturn : 80.07217143555049
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 954.2519900798798
# Training Loss : 0.25559282302856445
# Done logging...
#
#
#
#
# ********** Iteration 478000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 478001
# mean reward (100 episodes) 80.283774
# best mean reward 156.720935
# running time 956.021776
# Train_EnvstepsSoFar : 478001
# Train_AverageReturn : 80.2837735455902
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 956.0217759609222
# Training Loss : 0.23677094280719757
# Done logging...
#
#
#
#
# ********** Iteration 479000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 479001
# mean reward (100 episodes) 78.583061
# best mean reward 156.720935
# running time 958.252053
# Train_EnvstepsSoFar : 479001
# Train_AverageReturn : 78.58306074836197
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 958.2520534992218
# Training Loss : 0.17163178324699402
# Done logging...
#
#
#
#
# ********** Iteration 480000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 480001
# mean reward (100 episodes) 89.501378
# best mean reward 156.720935
# running time 959.801875
# Train_EnvstepsSoFar : 480001
# Train_AverageReturn : 89.5013779910592
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 959.8018751144409
# Training Loss : 0.23361945152282715
# Done logging...
#
#
#
#
# ********** Iteration 481000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 481001
# mean reward (100 episodes) 99.442610
# best mean reward 156.720935
# running time 961.707030
# Train_EnvstepsSoFar : 481001
# Train_AverageReturn : 99.44261038393329
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 961.7070298194885
# Training Loss : 0.1835574507713318
# Done logging...
#
#
#
#
# ********** Iteration 482000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 482001
# mean reward (100 episodes) 104.021826
# best mean reward 156.720935
# running time 964.070104
# Train_EnvstepsSoFar : 482001
# Train_AverageReturn : 104.02182643982717
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 964.0701041221619
# Training Loss : 0.1962946355342865
# Done logging...
#
#
#
#
# ********** Iteration 483000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 483001
# mean reward (100 episodes) 105.724623
# best mean reward 156.720935
# running time 965.576767
# Train_EnvstepsSoFar : 483001
# Train_AverageReturn : 105.72462284491412
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 965.576767206192
# Training Loss : 0.1402781456708908
# Done logging...
#
#
#
#
# ********** Iteration 484000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 484001
# mean reward (100 episodes) 110.667914
# best mean reward 156.720935
# running time 967.570466
# Train_EnvstepsSoFar : 484001
# Train_AverageReturn : 110.6679139099031
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 967.5704662799835
# Training Loss : 0.1589755117893219
# Done logging...
#
#
#
#
# ********** Iteration 485000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 485001
# mean reward (100 episodes) 109.365046
# best mean reward 156.720935
# running time 969.488463
# Train_EnvstepsSoFar : 485001
# Train_AverageReturn : 109.36504608186702
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 969.4884634017944
# Training Loss : 0.20724427700042725
# Done logging...
#
#
#
#
# ********** Iteration 486000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 486001
# mean reward (100 episodes) 108.170910
# best mean reward 156.720935
# running time 970.973062
# Train_EnvstepsSoFar : 486001
# Train_AverageReturn : 108.17091036220253
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 970.9730615615845
# Training Loss : 0.12610465288162231
# Done logging...
#
#
#
#
# ********** Iteration 487000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 487001
# mean reward (100 episodes) 108.090095
# best mean reward 156.720935
# running time 972.886414
# Train_EnvstepsSoFar : 487001
# Train_AverageReturn : 108.0900954164395
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 972.8864135742188
# Training Loss : 0.28839823603630066
# Done logging...
#
#
#
#
# ********** Iteration 488000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 488001
# mean reward (100 episodes) 115.861661
# best mean reward 156.720935
# running time 974.524199
# Train_EnvstepsSoFar : 488001
# Train_AverageReturn : 115.86166131269309
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 974.5241985321045
# Training Loss : 0.12499626725912094
# Done logging...
#
#
#
#
# ********** Iteration 489000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 489001
# mean reward (100 episodes) 120.352754
# best mean reward 156.720935
# running time 976.096478
# Train_EnvstepsSoFar : 489001
# Train_AverageReturn : 120.35275438339539
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 976.0964784622192
# Training Loss : 0.25434109568595886
# Done logging...
#
#
#
#
# ********** Iteration 490000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 490001
# mean reward (100 episodes) 127.503425
# best mean reward 156.720935
# running time 978.161355
# Train_EnvstepsSoFar : 490001
# Train_AverageReturn : 127.50342533049637
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 978.1613545417786
# Training Loss : 1.8081787824630737
# Done logging...
#
#
#
#
# ********** Iteration 491000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 491001
# mean reward (100 episodes) 130.196647
# best mean reward 156.720935
# running time 979.773585
# Train_EnvstepsSoFar : 491001
# Train_AverageReturn : 130.19664667919616
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 979.7735850811005
# Training Loss : 0.12438881397247314
# Done logging...
#
#
#
#
# ********** Iteration 492000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 492001
# mean reward (100 episodes) 134.882541
# best mean reward 156.720935
# running time 981.227747
# Train_EnvstepsSoFar : 492001
# Train_AverageReturn : 134.88254103307798
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 981.2277474403381
# Training Loss : 1.3422789573669434
# Done logging...
#
#
#
#
# ********** Iteration 493000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 493001
# mean reward (100 episodes) 137.538281
# best mean reward 156.720935
# running time 982.625845
# Train_EnvstepsSoFar : 493001
# Train_AverageReturn : 137.53828065480312
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 982.6258451938629
# Training Loss : 0.1346382200717926
# Done logging...
#
#
#
#
# ********** Iteration 494000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 494001
# mean reward (100 episodes) 138.334663
# best mean reward 156.720935
# running time 984.912361
# Train_EnvstepsSoFar : 494001
# Train_AverageReturn : 138.33466255128272
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 984.912360906601
# Training Loss : 0.0974273532629013
# Done logging...
#
#
#
#
# ********** Iteration 495000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 495001
# mean reward (100 episodes) 143.215952
# best mean reward 156.720935
# running time 986.368600
# Train_EnvstepsSoFar : 495001
# Train_AverageReturn : 143.21595219142336
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 986.3686001300812
# Training Loss : 2.3566086292266846
# Done logging...
#
#
#
#
# ********** Iteration 496000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 496001
# mean reward (100 episodes) 143.103849
# best mean reward 156.720935
# running time 988.118943
# Train_EnvstepsSoFar : 496001
# Train_AverageReturn : 143.1038491895573
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 988.1189434528351
# Training Loss : 0.35361209511756897
# Done logging...
#
#
#
#
# ********** Iteration 497000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 497001
# mean reward (100 episodes) 152.201827
# best mean reward 156.720935
# running time 989.567680
# Train_EnvstepsSoFar : 497001
# Train_AverageReturn : 152.20182743708847
# Train_BestReturn : 156.72093511930146
# TimeSinceStart : 989.567679643631
# Training Loss : 0.2495831847190857
# Done logging...
#
#
#
#
# ********** Iteration 498000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 498001
# mean reward (100 episodes) 158.037384
# best mean reward 158.037384
# running time 990.968953
# Train_EnvstepsSoFar : 498001
# Train_AverageReturn : 158.03738436239695
# Train_BestReturn : 158.03738436239695
# TimeSinceStart : 990.9689528942108
# Training Loss : 0.28894171118736267
# Done logging...
#
#
#
#
# ********** Iteration 499000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 499001
# mean reward (100 episodes) 160.929393
# best mean reward 160.929393
# running time 992.530527
# Train_EnvstepsSoFar : 499001
# Train_AverageReturn : 160.92939293082725
# Train_BestReturn : 160.92939293082725
# TimeSinceStart : 992.5305273532867
# Training Loss : 0.13334979116916656
# Done logging...

# %%
### Visualize vanilla DQN results on Lunar Lander
# %load_ext tensorboard
# %tensorboard --logdir logs/dqn/LunarLander/vanilla_dqn
# Out:
#       <iframe id="tensorboard-frame-e50be4f7cb0cbabb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e50be4f7cb0cbabb");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Double DQN
# One potential issue with learning our Q functions with bootstrapping is _maximization bias_, where the learned Q-values tend to overestimate the actual expected future returns. The main idea is that when there is estimation error in the next state's Q-values, even if the values were correct on average, picking the action with the maximum Q-value would tend to select one where the value is overestimated. This overoptimistic value would then also get propagated via the Bellman backups to other states and actions, and can potentially slow down learning.
#
# Double DQN (https://arxiv.org/abs/1509.06461) proposes a simple solution to alleviate this _maximization bias_. Instead of taking the next action that maximizes the target network's Q-value, it selects the action to maximize the _current_ Q function at the next state, and then takes the target network's estimate of that action's value.
#
# Implement the double DQN target value in the update method in <code>critics/dqn_critic.py</code>.

# %%
#### Test DQN target value with double Q
dqn_args = dict(dqn_base_args_dict)

env_str = 'LunarLander'
dqn_args['env_name'] = '{}-v3'.format(env_str)
dqn_args['double_q'] = True
dqntrainer = DQN_Trainer(dqn_args)
dqnagent = dqntrainer.rl_trainer.agent
critic = dqnagent.critic

ob_dim = critic.ob_dim
ac_dim = 6
N = 5

np.random.seed(0)
obs = np.random.normal(size=(N, ob_dim))
acts = np.random.choice(ac_dim, size=(N,))
next_obs = np.random.normal(size=(N, ob_dim))
rewards = np.random.normal(size=N)
terminals = np.zeros(N)
terminals[0] = 1

first_weight_before = np.array(ptu.to_numpy(next(critic.q_net.parameters())))
print("Weight before update (first row)", first_weight_before[0])


loss = critic.update(obs, acts, next_obs, rewards, terminals)['Training Loss']
expected_loss = 0.93894196
loss_error = rel_error(loss, expected_loss)
print("Initial loss", loss)
print("Initial Loss Error", loss_error, "should be on the order of 1e-6 or lower")

for i in range(4):
    loss = critic.update(obs, acts, next_obs, rewards, terminals)['Training Loss']
    print(loss)

expected_loss = 0.7871182
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")


first_weight_after = np.array(ptu.to_numpy(next(critic.q_net.parameters())))
print("Weight after update (first row)", first_weight_after.shape)
# Test DQN gradient
print(first_weight_after[0])
weight_change_partial = first_weight_after[0] - first_weight_before[0]
print(weight_change_partial)
expected_weight_change = np.array([-0.0049137, -0.00500057, -0.00499138, -0.00491226, -0.00490116,  0.00489506,
 -0.00284088, -0.00171939,  0.00485736])


updated_weight_error = rel_error(weight_change_partial, expected_weight_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# LunarLander-v3
# Weight before update (first row) [ 0.07646339 -0.07932477  0.09140956 -0.01702595  0.1423959   0.07935759
#  -0.03831156 -0.2694876   0.0761048 ]
# Initial loss 0.93894196
# Initial Loss Error 2.3609519617425807e-09 should be on the order of 1e-6 or lower
# 0.8988525
# 0.8602768
# 0.8228415
# 0.7871182
# Loss Error 2.231287016432748e-09 should be on the order of 1e-6 or lower
# Weight after update (first row) (64, 9)
# [ 0.07154968 -0.08432534  0.08641818 -0.02193821  0.13749474  0.08425265
#  -0.04115245 -0.27120697  0.08096217]
# [-0.0049137  -0.00500057 -0.00499138 -0.00491226 -0.00490116  0.00489506
#  -0.00284088 -0.00171939  0.00485736]
# Weight Update Error 1.3418982564751781e-06 should be on the order of 1e-6 or lower
# /usr/local/envs/hw4/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# We can now also run some experiments on LunarLander with Double DQN. You may be able to see that double DQN performs slightly better and more stably, but as there is very high variance, dont' worry if you do not.

# %%
# Run with double DQN
dqn_args = dict(dqn_base_args_dict)

env_str = 'LunarLander'
dqn_args['env_name'] = '{}-v3'.format(env_str)
dqn_args['double_q'] = True

# Delete all previous logs
remove_folder('logs/dqn/{}/double_dqn'.format(env_str))

for seed in range(3):
    print("Running DQN experiment with seed", seed)
    dqn_args['seed'] = seed
    dqn_args['logdir'] = 'logs/dqn/{}/double_dqn/seed{}'.format(env_str, seed)
    dqntrainer = DQN_Trainer(dqn_args)
    dqntrainer.run_training_loop()
# Out:
# Folder logs/dqn/LunarLander/double_dqn does not exist yet. No old results to delete
# Running DQN experiment with seed 0
# ########################
# logging outputs to  logs/dqn/LunarLander/double_dqn/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# LunarLander-v3
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 1
# mean reward (100 episodes) nan
# best mean reward -inf
# running time 0.000484
# Train_EnvstepsSoFar : 1
# TimeSinceStart : 0.00048351287841796875
# Done logging...
#
#
#
#
# ********** Iteration 1000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 1001
# mean reward (100 episodes) -361.461461
# best mean reward -inf
# running time 0.275481
# Train_EnvstepsSoFar : 1001
# Train_AverageReturn : -361.46146136915615
# TimeSinceStart : 0.2754805088043213
# Done logging...
#
#
#
#
# ********** Iteration 2000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 2001
# mean reward (100 episodes) -317.903658
# best mean reward -inf
# running time 1.655884
# Train_EnvstepsSoFar : 2001
# Train_AverageReturn : -317.9036578665922
# TimeSinceStart : 1.655884027481079
# Training Loss : 0.4135153293609619
# Done logging...
#
#
#
#
# ********** Iteration 3000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 3001
# mean reward (100 episodes) -298.920655
# best mean reward -inf
# running time 2.913738
# Train_EnvstepsSoFar : 3001
# Train_AverageReturn : -298.920654803673
# TimeSinceStart : 2.913738250732422
# Training Loss : 0.4319166839122772
# Done logging...
#
#
#
#
# ********** Iteration 4000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 4001
# mean reward (100 episodes) -285.234054
# best mean reward -inf
# running time 4.302098
# Train_EnvstepsSoFar : 4001
# Train_AverageReturn : -285.234053546392
# TimeSinceStart : 4.302097797393799
# Training Loss : 0.2828696370124817
# Done logging...
#
#
#
#
# ********** Iteration 5000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 5001
# mean reward (100 episodes) -291.706300
# best mean reward -inf
# running time 5.668976
# Train_EnvstepsSoFar : 5001
# Train_AverageReturn : -291.7063004653358
# TimeSinceStart : 5.668975591659546
# Training Loss : 0.24406400322914124
# Done logging...
#
#
#
#
# ********** Iteration 6000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 6001
# mean reward (100 episodes) -287.044952
# best mean reward -inf
# running time 7.030757
# Train_EnvstepsSoFar : 6001
# Train_AverageReturn : -287.0449519395304
# TimeSinceStart : 7.030757188796997
# Training Loss : 0.8531655073165894
# Done logging...
#
#
#
#
# ********** Iteration 7000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 7001
# mean reward (100 episodes) -264.266909
# best mean reward -inf
# running time 8.388369
# Train_EnvstepsSoFar : 7001
# Train_AverageReturn : -264.2669088341674
# TimeSinceStart : 8.38836932182312
# Training Loss : 0.3158610463142395
# Done logging...
#
#
#
#
# ********** Iteration 8000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 8001
# mean reward (100 episodes) -256.346561
# best mean reward -inf
# running time 9.794906
# Train_EnvstepsSoFar : 8001
# Train_AverageReturn : -256.3465611206874
# TimeSinceStart : 9.79490613937378
# Training Loss : 0.6418590545654297
# Done logging...
#
#
#
#
# ********** Iteration 9000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 9001
# mean reward (100 episodes) -248.867814
# best mean reward -inf
# running time 11.140009
# Train_EnvstepsSoFar : 9001
# Train_AverageReturn : -248.86781416791817
# TimeSinceStart : 11.14000916481018
# Training Loss : 0.4056374430656433
# Done logging...
#
#
#
#
# ********** Iteration 10000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 10001
# mean reward (100 episodes) -240.372478
# best mean reward -inf
# running time 12.558488
# Train_EnvstepsSoFar : 10001
# Train_AverageReturn : -240.3724777553086
# TimeSinceStart : 12.558488130569458
# Training Loss : 0.5905476808547974
# Done logging...
#
#
#
#
# ********** Iteration 11000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 11001
# mean reward (100 episodes) -238.593000
# best mean reward -inf
# running time 13.906801
# Train_EnvstepsSoFar : 11001
# Train_AverageReturn : -238.59299963109592
# TimeSinceStart : 13.906801462173462
# Training Loss : 0.7354557514190674
# Done logging...
#
#
#
#
# ********** Iteration 12000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 12001
# mean reward (100 episodes) -225.133255
# best mean reward -inf
# running time 15.285951
# Train_EnvstepsSoFar : 12001
# Train_AverageReturn : -225.13325472512145
# TimeSinceStart : 15.285951375961304
# Training Loss : 0.7052761912345886
# Done logging...
#
#
#
#
# ********** Iteration 13000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 13001
# mean reward (100 episodes) -219.752696
# best mean reward -inf
# running time 16.679125
# Train_EnvstepsSoFar : 13001
# Train_AverageReturn : -219.75269586591693
# TimeSinceStart : 16.6791250705719
# Training Loss : 1.3060624599456787
# Done logging...
#
#
#
#
# ********** Iteration 14000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 14001
# mean reward (100 episodes) -216.761281
# best mean reward -inf
# running time 18.032502
# Train_EnvstepsSoFar : 14001
# Train_AverageReturn : -216.76128131481275
# TimeSinceStart : 18.03250241279602
# Training Loss : 3.252054214477539
# Done logging...
#
#
#
#
# ********** Iteration 15000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 15001
# mean reward (100 episodes) -218.263792
# best mean reward -inf
# running time 19.837140
# Train_EnvstepsSoFar : 15001
# Train_AverageReturn : -218.26379152167624
# TimeSinceStart : 19.83714008331299
# Training Loss : 0.4843840003013611
# Done logging...
#
#
#
#
# ********** Iteration 16000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 16001
# mean reward (100 episodes) -215.055546
# best mean reward -inf
# running time 21.995315
# Train_EnvstepsSoFar : 16001
# Train_AverageReturn : -215.0555460506422
# TimeSinceStart : 21.995314836502075
# Training Loss : 0.5536589622497559
# Done logging...
#
#
#
#
# ********** Iteration 17000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 17001
# mean reward (100 episodes) -211.593422
# best mean reward -211.593422
# running time 23.760775
# Train_EnvstepsSoFar : 17001
# Train_AverageReturn : -211.59342199652542
# Train_BestReturn : -211.59342199652542
# TimeSinceStart : 23.760774850845337
# Training Loss : 0.27918633818626404
# Done logging...
#
#
#
#
# ********** Iteration 18000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 18001
# mean reward (100 episodes) -194.697413
# best mean reward -194.697413
# running time 25.319301
# Train_EnvstepsSoFar : 18001
# Train_AverageReturn : -194.69741252384858
# Train_BestReturn : -194.69741252384858
# TimeSinceStart : 25.319300651550293
# Training Loss : 0.5550463199615479
# Done logging...
#
#
#
#
# ********** Iteration 19000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 19001
# mean reward (100 episodes) -192.472278
# best mean reward -192.472278
# running time 27.095553
# Train_EnvstepsSoFar : 19001
# Train_AverageReturn : -192.4722780995969
# Train_BestReturn : -192.4722780995969
# TimeSinceStart : 27.095553398132324
# Training Loss : 4.382301330566406
# Done logging...
#
#
#
#
# ********** Iteration 20000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 20001
# mean reward (100 episodes) -191.119084
# best mean reward -191.119084
# running time 29.614533
# Train_EnvstepsSoFar : 20001
# Train_AverageReturn : -191.11908366336894
# Train_BestReturn : -191.11908366336894
# TimeSinceStart : 29.614533185958862
# Training Loss : 0.18743517994880676
# Done logging...
#
#
#
#
# ********** Iteration 21000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 21001
# mean reward (100 episodes) -187.857101
# best mean reward -187.857101
# running time 31.750401
# Train_EnvstepsSoFar : 21001
# Train_AverageReturn : -187.85710097642615
# Train_BestReturn : -187.85710097642615
# TimeSinceStart : 31.750401258468628
# Training Loss : 1.2566125392913818
# Done logging...
#
#
#
#
# ********** Iteration 22000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 22001
# mean reward (100 episodes) -187.733538
# best mean reward -187.733538
# running time 34.426992
# Train_EnvstepsSoFar : 22001
# Train_AverageReturn : -187.73353849507888
# Train_BestReturn : -187.73353849507888
# TimeSinceStart : 34.4269917011261
# Training Loss : 1.1709873676300049
# Done logging...
#
#
#
#
# ********** Iteration 23000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 23001
# mean reward (100 episodes) -183.847527
# best mean reward -183.847527
# running time 36.202215
# Train_EnvstepsSoFar : 23001
# Train_AverageReturn : -183.84752730975822
# Train_BestReturn : -183.84752730975822
# TimeSinceStart : 36.20221543312073
# Training Loss : 0.3382469415664673
# Done logging...
#
#
#
#
# ********** Iteration 24000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 24001
# mean reward (100 episodes) -182.080098
# best mean reward -182.080098
# running time 38.420886
# Train_EnvstepsSoFar : 24001
# Train_AverageReturn : -182.08009843703243
# Train_BestReturn : -182.08009843703243
# TimeSinceStart : 38.420886278152466
# Training Loss : 0.32413628697395325
# Done logging...
#
#
#
#
# ********** Iteration 25000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 25001
# mean reward (100 episodes) -179.456547
# best mean reward -179.456547
# running time 40.942059
# Train_EnvstepsSoFar : 25001
# Train_AverageReturn : -179.4565474481936
# Train_BestReturn : -179.4565474481936
# TimeSinceStart : 40.94205856323242
# Training Loss : 0.8509070873260498
# Done logging...
#
#
#
#
# ********** Iteration 26000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 26001
# mean reward (100 episodes) -177.155673
# best mean reward -177.155673
# running time 43.032252
# Train_EnvstepsSoFar : 26001
# Train_AverageReturn : -177.1556731035929
# Train_BestReturn : -177.1556731035929
# TimeSinceStart : 43.032252073287964
# Training Loss : 0.48403432965278625
# Done logging...
#
#
#
#
# ********** Iteration 27000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 27001
# mean reward (100 episodes) -176.538507
# best mean reward -176.538507
# running time 46.227314
# Train_EnvstepsSoFar : 27001
# Train_AverageReturn : -176.5385070891388
# Train_BestReturn : -176.5385070891388
# TimeSinceStart : 46.22731351852417
# Training Loss : 0.5736523866653442
# Done logging...
#
#
#
#
# ********** Iteration 28000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 28001
# mean reward (100 episodes) -173.423966
# best mean reward -173.423966
# running time 48.100267
# Train_EnvstepsSoFar : 28001
# Train_AverageReturn : -173.42396579201395
# Train_BestReturn : -173.42396579201395
# TimeSinceStart : 48.10026717185974
# Training Loss : 1.7063089609146118
# Done logging...
#
#
#
#
# ********** Iteration 29000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 29001
# mean reward (100 episodes) -173.085074
# best mean reward -173.085074
# running time 50.262496
# Train_EnvstepsSoFar : 29001
# Train_AverageReturn : -173.08507379616836
# Train_BestReturn : -173.08507379616836
# TimeSinceStart : 50.26249599456787
# Training Loss : 0.49110060930252075
# Done logging...
#
#
#
#
# ********** Iteration 30000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 30001
# mean reward (100 episodes) -171.891300
# best mean reward -171.891300
# running time 53.378733
# Train_EnvstepsSoFar : 30001
# Train_AverageReturn : -171.8912996308411
# Train_BestReturn : -171.8912996308411
# TimeSinceStart : 53.37873315811157
# Training Loss : 1.6609910726547241
# Done logging...
#
#
#
#
# ********** Iteration 31000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 31001
# mean reward (100 episodes) -171.103501
# best mean reward -171.103501
# running time 56.556664
# Train_EnvstepsSoFar : 31001
# Train_AverageReturn : -171.10350147365318
# Train_BestReturn : -171.10350147365318
# TimeSinceStart : 56.55666375160217
# Training Loss : 3.8437342643737793
# Done logging...
#
#
#
#
# ********** Iteration 32000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 32001
# mean reward (100 episodes) -166.891506
# best mean reward -166.891506
# running time 58.556994
# Train_EnvstepsSoFar : 32001
# Train_AverageReturn : -166.8915063651071
# Train_BestReturn : -166.8915063651071
# TimeSinceStart : 58.55699396133423
# Training Loss : 0.4852733016014099
# Done logging...
#
#
#
#
# ********** Iteration 33000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 33001
# mean reward (100 episodes) -163.835556
# best mean reward -163.835556
# running time 61.025877
# Train_EnvstepsSoFar : 33001
# Train_AverageReturn : -163.83555585159104
# Train_BestReturn : -163.83555585159104
# TimeSinceStart : 61.02587652206421
# Training Loss : 0.7539230585098267
# Done logging...
#
#
#
#
# ********** Iteration 34000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 34001
# mean reward (100 episodes) -162.088340
# best mean reward -162.088340
# running time 63.069993
# Train_EnvstepsSoFar : 34001
# Train_AverageReturn : -162.08834006326038
# Train_BestReturn : -162.08834006326038
# TimeSinceStart : 63.069992780685425
# Training Loss : 0.33479955792427063
# Done logging...
#
#
#
#
# ********** Iteration 35000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 35001
# mean reward (100 episodes) -161.173981
# best mean reward -161.173981
# running time 64.985806
# Train_EnvstepsSoFar : 35001
# Train_AverageReturn : -161.17398081974324
# Train_BestReturn : -161.17398081974324
# TimeSinceStart : 64.98580598831177
# Training Loss : 0.5092544555664062
# Done logging...
#
#
#
#
# ********** Iteration 36000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 36001
# mean reward (100 episodes) -160.972697
# best mean reward -160.972697
# running time 67.143156
# Train_EnvstepsSoFar : 36001
# Train_AverageReturn : -160.9726974111002
# Train_BestReturn : -160.9726974111002
# TimeSinceStart : 67.14315557479858
# Training Loss : 7.468029975891113
# Done logging...
#
#
#
#
# ********** Iteration 37000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 37001
# mean reward (100 episodes) -157.626427
# best mean reward -157.626427
# running time 69.021055
# Train_EnvstepsSoFar : 37001
# Train_AverageReturn : -157.62642695260234
# Train_BestReturn : -157.62642695260234
# TimeSinceStart : 69.02105522155762
# Training Loss : 4.846614360809326
# Done logging...
#
#
#
#
# ********** Iteration 38000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 38001
# mean reward (100 episodes) -157.248308
# best mean reward -157.248308
# running time 70.909952
# Train_EnvstepsSoFar : 38001
# Train_AverageReturn : -157.2483076681774
# Train_BestReturn : -157.2483076681774
# TimeSinceStart : 70.90995168685913
# Training Loss : 0.44960877299308777
# Done logging...
#
#
#
#
# ********** Iteration 39000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 39001
# mean reward (100 episodes) -153.077519
# best mean reward -153.077519
# running time 73.923241
# Train_EnvstepsSoFar : 39001
# Train_AverageReturn : -153.07751893755486
# Train_BestReturn : -153.07751893755486
# TimeSinceStart : 73.92324137687683
# Training Loss : 3.613206148147583
# Done logging...
#
#
#
#
# ********** Iteration 40000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 40001
# mean reward (100 episodes) -151.432719
# best mean reward -151.432719
# running time 76.123105
# Train_EnvstepsSoFar : 40001
# Train_AverageReturn : -151.43271862404316
# Train_BestReturn : -151.43271862404316
# TimeSinceStart : 76.1231050491333
# Training Loss : 0.6655073761940002
# Done logging...
#
#
#
#
# ********** Iteration 41000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 41001
# mean reward (100 episodes) -149.308917
# best mean reward -149.308917
# running time 78.203942
# Train_EnvstepsSoFar : 41001
# Train_AverageReturn : -149.308917060366
# Train_BestReturn : -149.308917060366
# TimeSinceStart : 78.20394229888916
# Training Loss : 0.5196305513381958
# Done logging...
#
#
#
#
# ********** Iteration 42000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 42001
# mean reward (100 episodes) -147.082603
# best mean reward -147.082603
# running time 80.350468
# Train_EnvstepsSoFar : 42001
# Train_AverageReturn : -147.08260294006962
# Train_BestReturn : -147.08260294006962
# TimeSinceStart : 80.35046768188477
# Training Loss : 3.728381633758545
# Done logging...
#
#
#
#
# ********** Iteration 43000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 43001
# mean reward (100 episodes) -145.336368
# best mean reward -145.336368
# running time 82.279788
# Train_EnvstepsSoFar : 43001
# Train_AverageReturn : -145.3363684234571
# Train_BestReturn : -145.3363684234571
# TimeSinceStart : 82.27978777885437
# Training Loss : 0.3568827509880066
# Done logging...
#
#
#
#
# ********** Iteration 44000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 44001
# mean reward (100 episodes) -137.448411
# best mean reward -137.448411
# running time 84.192914
# Train_EnvstepsSoFar : 44001
# Train_AverageReturn : -137.44841100289736
# Train_BestReturn : -137.44841100289736
# TimeSinceStart : 84.19291424751282
# Training Loss : 0.7616961598396301
# Done logging...
#
#
#
#
# ********** Iteration 45000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 45001
# mean reward (100 episodes) -136.235411
# best mean reward -136.235411
# running time 86.489657
# Train_EnvstepsSoFar : 45001
# Train_AverageReturn : -136.2354105073835
# Train_BestReturn : -136.2354105073835
# TimeSinceStart : 86.48965668678284
# Training Loss : 0.34670716524124146
# Done logging...
#
#
#
#
# ********** Iteration 46000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 46001
# mean reward (100 episodes) -136.880534
# best mean reward -136.235411
# running time 88.634137
# Train_EnvstepsSoFar : 46001
# Train_AverageReturn : -136.88053360481422
# Train_BestReturn : -136.2354105073835
# TimeSinceStart : 88.63413667678833
# Training Loss : 0.483005553483963
# Done logging...
#
#
#
#
# ********** Iteration 47000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 47001
# mean reward (100 episodes) -133.754734
# best mean reward -133.754734
# running time 90.566374
# Train_EnvstepsSoFar : 47001
# Train_AverageReturn : -133.75473401021372
# Train_BestReturn : -133.75473401021372
# TimeSinceStart : 90.56637406349182
# Training Loss : 3.661254405975342
# Done logging...
#
#
#
#
# ********** Iteration 48000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 48001
# mean reward (100 episodes) -133.479623
# best mean reward -133.479623
# running time 92.617715
# Train_EnvstepsSoFar : 48001
# Train_AverageReturn : -133.4796225133521
# Train_BestReturn : -133.4796225133521
# TimeSinceStart : 92.61771512031555
# Training Loss : 0.48638036847114563
# Done logging...
#
#
#
#
# ********** Iteration 49000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 49001
# mean reward (100 episodes) -133.818081
# best mean reward -133.479623
# running time 94.687649
# Train_EnvstepsSoFar : 49001
# Train_AverageReturn : -133.81808130060878
# Train_BestReturn : -133.4796225133521
# TimeSinceStart : 94.68764853477478
# Training Loss : 0.4712386131286621
# Done logging...
#
#
#
#
# ********** Iteration 50000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 50001
# mean reward (100 episodes) -136.261005
# best mean reward -133.479623
# running time 96.592462
# Train_EnvstepsSoFar : 50001
# Train_AverageReturn : -136.26100453967572
# Train_BestReturn : -133.4796225133521
# TimeSinceStart : 96.59246182441711
# Training Loss : 0.4332355260848999
# Done logging...
#
#
#
#
# ********** Iteration 51000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 51001
# mean reward (100 episodes) -133.210195
# best mean reward -133.210195
# running time 98.655872
# Train_EnvstepsSoFar : 51001
# Train_AverageReturn : -133.2101950851495
# Train_BestReturn : -133.2101950851495
# TimeSinceStart : 98.65587186813354
# Training Loss : 0.747793972492218
# Done logging...
#
#
#
#
# ********** Iteration 52000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 52001
# mean reward (100 episodes) -133.574415
# best mean reward -133.210195
# running time 101.790733
# Train_EnvstepsSoFar : 52001
# Train_AverageReturn : -133.5744151695472
# Train_BestReturn : -133.2101950851495
# TimeSinceStart : 101.79073286056519
# Training Loss : 0.7929268479347229
# Done logging...
#
#
#
#
# ********** Iteration 53000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 53001
# mean reward (100 episodes) -133.018912
# best mean reward -133.018912
# running time 104.103960
# Train_EnvstepsSoFar : 53001
# Train_AverageReturn : -133.0189117909981
# Train_BestReturn : -133.0189117909981
# TimeSinceStart : 104.10396003723145
# Training Loss : 1.171819806098938
# Done logging...
#
#
#
#
# ********** Iteration 54000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 54001
# mean reward (100 episodes) -131.419085
# best mean reward -131.419085
# running time 106.196737
# Train_EnvstepsSoFar : 54001
# Train_AverageReturn : -131.41908460657137
# Train_BestReturn : -131.41908460657137
# TimeSinceStart : 106.19673728942871
# Training Loss : 0.660940945148468
# Done logging...
#
#
#
#
# ********** Iteration 55000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 55001
# mean reward (100 episodes) -128.693689
# best mean reward -128.693689
# running time 108.899076
# Train_EnvstepsSoFar : 55001
# Train_AverageReturn : -128.69368853039708
# Train_BestReturn : -128.69368853039708
# TimeSinceStart : 108.89907550811768
# Training Loss : 1.009391188621521
# Done logging...
#
#
#
#
# ********** Iteration 56000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 56001
# mean reward (100 episodes) -132.304078
# best mean reward -128.693689
# running time 111.238830
# Train_EnvstepsSoFar : 56001
# Train_AverageReturn : -132.30407817036695
# Train_BestReturn : -128.69368853039708
# TimeSinceStart : 111.23883032798767
# Training Loss : 0.3999251425266266
# Done logging...
#
#
#
#
# ********** Iteration 57000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 57001
# mean reward (100 episodes) -132.306428
# best mean reward -128.693689
# running time 113.538943
# Train_EnvstepsSoFar : 57001
# Train_AverageReturn : -132.30642806639628
# Train_BestReturn : -128.69368853039708
# TimeSinceStart : 113.53894329071045
# Training Loss : 0.3315901458263397
# Done logging...
#
#
#
#
# ********** Iteration 58000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 58001
# mean reward (100 episodes) -132.648791
# best mean reward -128.693689
# running time 115.702134
# Train_EnvstepsSoFar : 58001
# Train_AverageReturn : -132.6487912067179
# Train_BestReturn : -128.69368853039708
# TimeSinceStart : 115.70213437080383
# Training Loss : 0.29347142577171326
# Done logging...
#
#
#
#
# ********** Iteration 59000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 59001
# mean reward (100 episodes) -129.244530
# best mean reward -128.693689
# running time 117.917490
# Train_EnvstepsSoFar : 59001
# Train_AverageReturn : -129.24453025474472
# Train_BestReturn : -128.69368853039708
# TimeSinceStart : 117.91749048233032
# Training Loss : 0.41355031728744507
# Done logging...
#
#
#
#
# ********** Iteration 60000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 60001
# mean reward (100 episodes) -127.600223
# best mean reward -127.600223
# running time 120.099657
# Train_EnvstepsSoFar : 60001
# Train_AverageReturn : -127.60022319877824
# Train_BestReturn : -127.60022319877824
# TimeSinceStart : 120.09965658187866
# Training Loss : 0.2581297755241394
# Done logging...
#
#
#
#
# ********** Iteration 61000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 61001
# mean reward (100 episodes) -127.607565
# best mean reward -127.600223
# running time 122.575466
# Train_EnvstepsSoFar : 61001
# Train_AverageReturn : -127.60756474547901
# Train_BestReturn : -127.60022319877824
# TimeSinceStart : 122.57546615600586
# Training Loss : 0.39341041445732117
# Done logging...
#
#
#
#
# ********** Iteration 62000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 62001
# mean reward (100 episodes) -126.240761
# best mean reward -126.240761
# running time 124.892784
# Train_EnvstepsSoFar : 62001
# Train_AverageReturn : -126.24076086549431
# Train_BestReturn : -126.24076086549431
# TimeSinceStart : 124.89278411865234
# Training Loss : 0.3372546136379242
# Done logging...
#
#
#
#
# ********** Iteration 63000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 63001
# mean reward (100 episodes) -125.945960
# best mean reward -125.945960
# running time 127.427004
# Train_EnvstepsSoFar : 63001
# Train_AverageReturn : -125.94596030474493
# Train_BestReturn : -125.94596030474493
# TimeSinceStart : 127.42700409889221
# Training Loss : 0.356057733297348
# Done logging...
#
#
#
#
# ********** Iteration 64000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 64001
# mean reward (100 episodes) -126.333932
# best mean reward -125.945960
# running time 129.321512
# Train_EnvstepsSoFar : 64001
# Train_AverageReturn : -126.33393240093696
# Train_BestReturn : -125.94596030474493
# TimeSinceStart : 129.32151174545288
# Training Loss : 0.22342030704021454
# Done logging...
#
#
#
#
# ********** Iteration 65000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 65001
# mean reward (100 episodes) -126.326229
# best mean reward -125.945960
# running time 131.479155
# Train_EnvstepsSoFar : 65001
# Train_AverageReturn : -126.3262290105203
# Train_BestReturn : -125.94596030474493
# TimeSinceStart : 131.47915482521057
# Training Loss : 0.6647332310676575
# Done logging...
#
#
#
#
# ********** Iteration 66000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 66001
# mean reward (100 episodes) -122.888361
# best mean reward -122.888361
# running time 133.660784
# Train_EnvstepsSoFar : 66001
# Train_AverageReturn : -122.88836070305051
# Train_BestReturn : -122.88836070305051
# TimeSinceStart : 133.66078400611877
# Training Loss : 0.33932533860206604
# Done logging...
#
#
#
#
# ********** Iteration 67000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 67001
# mean reward (100 episodes) -121.802332
# best mean reward -121.802332
# running time 136.197912
# Train_EnvstepsSoFar : 67001
# Train_AverageReturn : -121.8023318943251
# Train_BestReturn : -121.8023318943251
# TimeSinceStart : 136.19791221618652
# Training Loss : 0.1677919626235962
# Done logging...
#
#
#
#
# ********** Iteration 68000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 68001
# mean reward (100 episodes) -114.568855
# best mean reward -114.568855
# running time 138.224714
# Train_EnvstepsSoFar : 68001
# Train_AverageReturn : -114.56885459509074
# Train_BestReturn : -114.56885459509074
# TimeSinceStart : 138.2247142791748
# Training Loss : 0.7260293960571289
# Done logging...
#
#
#
#
# ********** Iteration 69000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 69001
# mean reward (100 episodes) -117.420834
# best mean reward -114.568855
# running time 140.469088
# Train_EnvstepsSoFar : 69001
# Train_AverageReturn : -117.42083372532741
# Train_BestReturn : -114.56885459509074
# TimeSinceStart : 140.469087600708
# Training Loss : 0.25474777817726135
# Done logging...
#
#
#
#
# ********** Iteration 70000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 70001
# mean reward (100 episodes) -119.959858
# best mean reward -114.568855
# running time 142.957693
# Train_EnvstepsSoFar : 70001
# Train_AverageReturn : -119.95985834482171
# Train_BestReturn : -114.56885459509074
# TimeSinceStart : 142.9576930999756
# Training Loss : 0.13563047349452972
# Done logging...
#
#
#
#
# ********** Iteration 71000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 71001
# mean reward (100 episodes) -120.044574
# best mean reward -114.568855
# running time 145.514704
# Train_EnvstepsSoFar : 71001
# Train_AverageReturn : -120.04457372275974
# Train_BestReturn : -114.56885459509074
# TimeSinceStart : 145.51470351219177
# Training Loss : 0.2727651298046112
# Done logging...
#
#
#
#
# ********** Iteration 72000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 72001
# mean reward (100 episodes) -120.485592
# best mean reward -114.568855
# running time 147.845864
# Train_EnvstepsSoFar : 72001
# Train_AverageReturn : -120.48559160321273
# Train_BestReturn : -114.56885459509074
# TimeSinceStart : 147.84586358070374
# Training Loss : 0.2140192985534668
# Done logging...
#
#
#
#
# ********** Iteration 73000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 73001
# mean reward (100 episodes) -115.951612
# best mean reward -114.568855
# running time 150.026351
# Train_EnvstepsSoFar : 73001
# Train_AverageReturn : -115.95161176736292
# Train_BestReturn : -114.56885459509074
# TimeSinceStart : 150.02635097503662
# Training Loss : 0.35891401767730713
# Done logging...
#
#
#
#
# ********** Iteration 74000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 74001
# mean reward (100 episodes) -110.688854
# best mean reward -110.688854
# running time 152.084637
# Train_EnvstepsSoFar : 74001
# Train_AverageReturn : -110.68885369703088
# Train_BestReturn : -110.68885369703088
# TimeSinceStart : 152.08463716506958
# Training Loss : 0.18600903451442719
# Done logging...
#
#
#
#
# ********** Iteration 75000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 75001
# mean reward (100 episodes) -110.259328
# best mean reward -110.259328
# running time 154.453686
# Train_EnvstepsSoFar : 75001
# Train_AverageReturn : -110.25932809335818
# Train_BestReturn : -110.25932809335818
# TimeSinceStart : 154.45368599891663
# Training Loss : 0.19563458859920502
# Done logging...
#
#
#
#
# ********** Iteration 76000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 76001
# mean reward (100 episodes) -113.008555
# best mean reward -110.259328
# running time 157.912740
# Train_EnvstepsSoFar : 76001
# Train_AverageReturn : -113.00855504337534
# Train_BestReturn : -110.25932809335818
# TimeSinceStart : 157.91273999214172
# Training Loss : 0.30998945236206055
# Done logging...
#
#
#
#
# ********** Iteration 77000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 77001
# mean reward (100 episodes) -110.092047
# best mean reward -110.092047
# running time 162.125829
# Train_EnvstepsSoFar : 77001
# Train_AverageReturn : -110.09204706706616
# Train_BestReturn : -110.09204706706616
# TimeSinceStart : 162.12582921981812
# Training Loss : 0.18438738584518433
# Done logging...
#
#
#
#
# ********** Iteration 78000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 78001
# mean reward (100 episodes) -110.515282
# best mean reward -110.092047
# running time 165.083762
# Train_EnvstepsSoFar : 78001
# Train_AverageReturn : -110.51528200445665
# Train_BestReturn : -110.09204706706616
# TimeSinceStart : 165.08376169204712
# Training Loss : 0.06694471836090088
# Done logging...
#
#
#
#
# ********** Iteration 79000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 79001
# mean reward (100 episodes) -109.187793
# best mean reward -109.187793
# running time 167.731614
# Train_EnvstepsSoFar : 79001
# Train_AverageReturn : -109.1877927816599
# Train_BestReturn : -109.1877927816599
# TimeSinceStart : 167.73161387443542
# Training Loss : 0.2693077325820923
# Done logging...
#
#
#
#
# ********** Iteration 80000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 80001
# mean reward (100 episodes) -104.670794
# best mean reward -104.670794
# running time 169.515814
# Train_EnvstepsSoFar : 80001
# Train_AverageReturn : -104.67079434821545
# Train_BestReturn : -104.67079434821545
# TimeSinceStart : 169.5158143043518
# Training Loss : 0.223214790225029
# Done logging...
#
#
#
#
# ********** Iteration 81000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 81001
# mean reward (100 episodes) -101.208633
# best mean reward -101.208633
# running time 172.337894
# Train_EnvstepsSoFar : 81001
# Train_AverageReturn : -101.20863342381989
# Train_BestReturn : -101.20863342381989
# TimeSinceStart : 172.3378939628601
# Training Loss : 0.2970540225505829
# Done logging...
#
#
#
#
# ********** Iteration 82000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 82001
# mean reward (100 episodes) -102.020325
# best mean reward -101.208633
# running time 174.761404
# Train_EnvstepsSoFar : 82001
# Train_AverageReturn : -102.02032451596199
# Train_BestReturn : -101.20863342381989
# TimeSinceStart : 174.76140356063843
# Training Loss : 0.14950767159461975
# Done logging...
#
#
#
#
# ********** Iteration 83000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 83001
# mean reward (100 episodes) -99.068939
# best mean reward -99.068939
# running time 176.946626
# Train_EnvstepsSoFar : 83001
# Train_AverageReturn : -99.06893929758301
# Train_BestReturn : -99.06893929758301
# TimeSinceStart : 176.94662594795227
# Training Loss : 0.24646209180355072
# Done logging...
#
#
#
#
# ********** Iteration 84000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 84001
# mean reward (100 episodes) -100.664543
# best mean reward -99.068939
# running time 179.133088
# Train_EnvstepsSoFar : 84001
# Train_AverageReturn : -100.66454252877094
# Train_BestReturn : -99.06893929758301
# TimeSinceStart : 179.13308763504028
# Training Loss : 0.24060732126235962
# Done logging...
#
#
#
#
# ********** Iteration 85000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 85001
# mean reward (100 episodes) -97.267184
# best mean reward -97.267184
# running time 181.086959
# Train_EnvstepsSoFar : 85001
# Train_AverageReturn : -97.2671836160937
# Train_BestReturn : -97.2671836160937
# TimeSinceStart : 181.08695888519287
# Training Loss : 0.21209228038787842
# Done logging...
#
#
#
#
# ********** Iteration 86000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 86001
# mean reward (100 episodes) -95.956596
# best mean reward -95.956596
# running time 183.030685
# Train_EnvstepsSoFar : 86001
# Train_AverageReturn : -95.95659564952976
# Train_BestReturn : -95.95659564952976
# TimeSinceStart : 183.0306851863861
# Training Loss : 3.163217544555664
# Done logging...
#
#
#
#
# ********** Iteration 87000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 87001
# mean reward (100 episodes) -93.322229
# best mean reward -93.322229
# running time 184.924491
# Train_EnvstepsSoFar : 87001
# Train_AverageReturn : -93.322228878844
# Train_BestReturn : -93.322228878844
# TimeSinceStart : 184.92449140548706
# Training Loss : 0.17026256024837494
# Done logging...
#
#
#
#
# ********** Iteration 88000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 88001
# mean reward (100 episodes) -93.338237
# best mean reward -93.322229
# running time 186.770077
# Train_EnvstepsSoFar : 88001
# Train_AverageReturn : -93.33823675291083
# Train_BestReturn : -93.322228878844
# TimeSinceStart : 186.77007722854614
# Training Loss : 0.4950517416000366
# Done logging...
#
#
#
#
# ********** Iteration 89000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 89001
# mean reward (100 episodes) -96.555813
# best mean reward -93.322229
# running time 188.812238
# Train_EnvstepsSoFar : 89001
# Train_AverageReturn : -96.55581259623676
# Train_BestReturn : -93.322228878844
# TimeSinceStart : 188.812237739563
# Training Loss : 0.1491364687681198
# Done logging...
#
#
#
#
# ********** Iteration 90000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 90001
# mean reward (100 episodes) -95.434492
# best mean reward -93.322229
# running time 191.166932
# Train_EnvstepsSoFar : 90001
# Train_AverageReturn : -95.43449210309831
# Train_BestReturn : -93.322228878844
# TimeSinceStart : 191.1669316291809
# Training Loss : 0.18986807763576508
# Done logging...
#
#
#
#
# ********** Iteration 91000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 91001
# mean reward (100 episodes) -94.765821
# best mean reward -93.322229
# running time 193.532424
# Train_EnvstepsSoFar : 91001
# Train_AverageReturn : -94.76582075485022
# Train_BestReturn : -93.322228878844
# TimeSinceStart : 193.53242373466492
# Training Loss : 0.24086527526378632
# Done logging...
#
#
#
#
# ********** Iteration 92000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 92001
# mean reward (100 episodes) -90.885022
# best mean reward -90.885022
# running time 195.250410
# Train_EnvstepsSoFar : 92001
# Train_AverageReturn : -90.88502167776547
# Train_BestReturn : -90.88502167776547
# TimeSinceStart : 195.25041007995605
# Training Loss : 0.40379810333251953
# Done logging...
#
#
#
#
# ********** Iteration 93000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 93001
# mean reward (100 episodes) -91.223871
# best mean reward -90.885022
# running time 197.375561
# Train_EnvstepsSoFar : 93001
# Train_AverageReturn : -91.2238707378607
# Train_BestReturn : -90.88502167776547
# TimeSinceStart : 197.37556076049805
# Training Loss : 0.14825905859470367
# Done logging...
#
#
#
#
# ********** Iteration 94000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 94001
# mean reward (100 episodes) -89.183791
# best mean reward -89.183791
# running time 199.677922
# Train_EnvstepsSoFar : 94001
# Train_AverageReturn : -89.1837909905128
# Train_BestReturn : -89.1837909905128
# TimeSinceStart : 199.67792224884033
# Training Loss : 0.24505561590194702
# Done logging...
#
#
#
#
# ********** Iteration 95000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 95001
# mean reward (100 episodes) -89.227860
# best mean reward -89.183791
# running time 202.102550
# Train_EnvstepsSoFar : 95001
# Train_AverageReturn : -89.22785958839371
# Train_BestReturn : -89.1837909905128
# TimeSinceStart : 202.10255002975464
# Training Loss : 0.21522332727909088
# Done logging...
#
#
#
#
# ********** Iteration 96000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 96001
# mean reward (100 episodes) -89.673607
# best mean reward -89.183791
# running time 204.085523
# Train_EnvstepsSoFar : 96001
# Train_AverageReturn : -89.6736068521305
# Train_BestReturn : -89.1837909905128
# TimeSinceStart : 204.0855233669281
# Training Loss : 0.14082157611846924
# Done logging...
#
#
#
#
# ********** Iteration 97000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 97001
# mean reward (100 episodes) -88.653723
# best mean reward -88.653723
# running time 206.614342
# Train_EnvstepsSoFar : 97001
# Train_AverageReturn : -88.65372278062976
# Train_BestReturn : -88.65372278062976
# TimeSinceStart : 206.61434197425842
# Training Loss : 0.1699865758419037
# Done logging...
#
#
#
#
# ********** Iteration 98000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 98001
# mean reward (100 episodes) -85.301031
# best mean reward -85.301031
# running time 208.948397
# Train_EnvstepsSoFar : 98001
# Train_AverageReturn : -85.30103075539373
# Train_BestReturn : -85.30103075539373
# TimeSinceStart : 208.948397397995
# Training Loss : 0.15456180274486542
# Done logging...
#
#
#
#
# ********** Iteration 99000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 99001
# mean reward (100 episodes) -84.490732
# best mean reward -84.490732
# running time 211.695119
# Train_EnvstepsSoFar : 99001
# Train_AverageReturn : -84.49073158364155
# Train_BestReturn : -84.49073158364155
# TimeSinceStart : 211.69511914253235
# Training Loss : 0.2506476044654846
# Done logging...
#
#
#
#
# ********** Iteration 100000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 100001
# mean reward (100 episodes) -84.424599
# best mean reward -84.424599
# running time 214.805260
# Train_EnvstepsSoFar : 100001
# Train_AverageReturn : -84.42459912058368
# Train_BestReturn : -84.42459912058368
# TimeSinceStart : 214.80525970458984
# Training Loss : 0.36075448989868164
# Done logging...
#
#
#
#
# ********** Iteration 101000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 101001
# mean reward (100 episodes) -77.583329
# best mean reward -77.583329
# running time 217.336058
# Train_EnvstepsSoFar : 101001
# Train_AverageReturn : -77.583329004497
# Train_BestReturn : -77.583329004497
# TimeSinceStart : 217.33605813980103
# Training Loss : 0.15774673223495483
# Done logging...
#
#
#
#
# ********** Iteration 102000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 102001
# mean reward (100 episodes) -74.553681
# best mean reward -74.553681
# running time 220.360219
# Train_EnvstepsSoFar : 102001
# Train_AverageReturn : -74.55368087097344
# Train_BestReturn : -74.55368087097344
# TimeSinceStart : 220.3602192401886
# Training Loss : 0.16920030117034912
# Done logging...
#
#
#
#
# ********** Iteration 103000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 103001
# mean reward (100 episodes) -71.253871
# best mean reward -71.253871
# running time 222.802910
# Train_EnvstepsSoFar : 103001
# Train_AverageReturn : -71.25387148595058
# Train_BestReturn : -71.25387148595058
# TimeSinceStart : 222.8029100894928
# Training Loss : 0.17034399509429932
# Done logging...
#
#
#
#
# ********** Iteration 104000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 104001
# mean reward (100 episodes) -66.742892
# best mean reward -66.742892
# running time 224.804861
# Train_EnvstepsSoFar : 104001
# Train_AverageReturn : -66.74289194655483
# Train_BestReturn : -66.74289194655483
# TimeSinceStart : 224.804860830307
# Training Loss : 0.13889017701148987
# Done logging...
#
#
#
#
# ********** Iteration 105000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 105001
# mean reward (100 episodes) -66.457896
# best mean reward -66.457896
# running time 227.371520
# Train_EnvstepsSoFar : 105001
# Train_AverageReturn : -66.45789615227238
# Train_BestReturn : -66.45789615227238
# TimeSinceStart : 227.37152004241943
# Training Loss : 0.14671321213245392
# Done logging...
#
#
#
#
# ********** Iteration 106000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 106001
# mean reward (100 episodes) -66.348230
# best mean reward -66.348230
# running time 229.851063
# Train_EnvstepsSoFar : 106001
# Train_AverageReturn : -66.34822982104055
# Train_BestReturn : -66.34822982104055
# TimeSinceStart : 229.8510627746582
# Training Loss : 0.10440373420715332
# Done logging...
#
#
#
#
# ********** Iteration 107000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 107001
# mean reward (100 episodes) -64.046620
# best mean reward -64.046620
# running time 232.599952
# Train_EnvstepsSoFar : 107001
# Train_AverageReturn : -64.04661984932758
# Train_BestReturn : -64.04661984932758
# TimeSinceStart : 232.59995222091675
# Training Loss : 0.1476956158876419
# Done logging...
#
#
#
#
# ********** Iteration 108000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 108001
# mean reward (100 episodes) -63.156172
# best mean reward -63.156172
# running time 235.060884
# Train_EnvstepsSoFar : 108001
# Train_AverageReturn : -63.15617211802275
# Train_BestReturn : -63.15617211802275
# TimeSinceStart : 235.06088423728943
# Training Loss : 0.13547202944755554
# Done logging...
#
#
#
#
# ********** Iteration 109000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 109001
# mean reward (100 episodes) -59.430462
# best mean reward -59.430462
# running time 237.102741
# Train_EnvstepsSoFar : 109001
# Train_AverageReturn : -59.430462367231314
# Train_BestReturn : -59.430462367231314
# TimeSinceStart : 237.10274124145508
# Training Loss : 0.17462275922298431
# Done logging...
#
#
#
#
# ********** Iteration 110000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 110001
# mean reward (100 episodes) -57.947902
# best mean reward -57.947902
# running time 239.531318
# Train_EnvstepsSoFar : 110001
# Train_AverageReturn : -57.94790247702894
# Train_BestReturn : -57.94790247702894
# TimeSinceStart : 239.53131818771362
# Training Loss : 0.16837841272354126
# Done logging...
#
#
#
#
# ********** Iteration 111000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 111001
# mean reward (100 episodes) -55.075493
# best mean reward -55.075493
# running time 241.885575
# Train_EnvstepsSoFar : 111001
# Train_AverageReturn : -55.07549304609837
# Train_BestReturn : -55.07549304609837
# TimeSinceStart : 241.8855745792389
# Training Loss : 0.47736072540283203
# Done logging...
#
#
#
#
# ********** Iteration 112000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 112001
# mean reward (100 episodes) -55.223426
# best mean reward -55.075493
# running time 244.016803
# Train_EnvstepsSoFar : 112001
# Train_AverageReturn : -55.223425953276454
# Train_BestReturn : -55.07549304609837
# TimeSinceStart : 244.01680326461792
# Training Loss : 0.5676301717758179
# Done logging...
#
#
#
#
# ********** Iteration 113000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 113001
# mean reward (100 episodes) -53.438251
# best mean reward -53.438251
# running time 245.862661
# Train_EnvstepsSoFar : 113001
# Train_AverageReturn : -53.438250956664085
# Train_BestReturn : -53.438250956664085
# TimeSinceStart : 245.86266112327576
# Training Loss : 0.15484298765659332
# Done logging...
#
#
#
#
# ********** Iteration 114000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 114001
# mean reward (100 episodes) -52.619276
# best mean reward -52.619276
# running time 248.071532
# Train_EnvstepsSoFar : 114001
# Train_AverageReturn : -52.61927648229142
# Train_BestReturn : -52.61927648229142
# TimeSinceStart : 248.0715320110321
# Training Loss : 0.16105777025222778
# Done logging...
#
#
#
#
# ********** Iteration 115000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 115001
# mean reward (100 episodes) -56.193071
# best mean reward -52.619276
# running time 251.266235
# Train_EnvstepsSoFar : 115001
# Train_AverageReturn : -56.19307063548027
# Train_BestReturn : -52.61927648229142
# TimeSinceStart : 251.26623463630676
# Training Loss : 0.31180158257484436
# Done logging...
#
#
#
#
# ********** Iteration 116000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 116001
# mean reward (100 episodes) -55.215865
# best mean reward -52.619276
# running time 254.074522
# Train_EnvstepsSoFar : 116001
# Train_AverageReturn : -55.2158651419627
# Train_BestReturn : -52.61927648229142
# TimeSinceStart : 254.07452201843262
# Training Loss : 0.17694683372974396
# Done logging...
#
#
#
#
# ********** Iteration 117000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 117001
# mean reward (100 episodes) -51.756839
# best mean reward -51.756839
# running time 256.337597
# Train_EnvstepsSoFar : 117001
# Train_AverageReturn : -51.7568392507583
# Train_BestReturn : -51.7568392507583
# TimeSinceStart : 256.33759665489197
# Training Loss : 0.11427056789398193
# Done logging...
#
#
#
#
# ********** Iteration 118000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 118001
# mean reward (100 episodes) -53.197711
# best mean reward -51.756839
# running time 258.552253
# Train_EnvstepsSoFar : 118001
# Train_AverageReturn : -53.197710605012055
# Train_BestReturn : -51.7568392507583
# TimeSinceStart : 258.55225348472595
# Training Loss : 0.2774536907672882
# Done logging...
#
#
#
#
# ********** Iteration 119000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 119001
# mean reward (100 episodes) -51.286710
# best mean reward -51.286710
# running time 261.434235
# Train_EnvstepsSoFar : 119001
# Train_AverageReturn : -51.2867103166578
# Train_BestReturn : -51.2867103166578
# TimeSinceStart : 261.4342346191406
# Training Loss : 0.3730520009994507
# Done logging...
#
#
#
#
# ********** Iteration 120000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 120001
# mean reward (100 episodes) -51.011951
# best mean reward -51.011951
# running time 264.832894
# Train_EnvstepsSoFar : 120001
# Train_AverageReturn : -51.01195070488295
# Train_BestReturn : -51.01195070488295
# TimeSinceStart : 264.8328938484192
# Training Loss : 0.0908849760890007
# Done logging...
#
#
#
#
# ********** Iteration 121000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 121001
# mean reward (100 episodes) -48.944283
# best mean reward -48.944283
# running time 267.176986
# Train_EnvstepsSoFar : 121001
# Train_AverageReturn : -48.944282690681845
# Train_BestReturn : -48.944282690681845
# TimeSinceStart : 267.1769862174988
# Training Loss : 0.31027498841285706
# Done logging...
#
#
#
#
# ********** Iteration 122000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 122001
# mean reward (100 episodes) -46.094467
# best mean reward -46.094467
# running time 269.549345
# ...
# Train_AverageReturn : 163.7136623820067
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 899.1738307476044
# Training Loss : 0.23381662368774414
# Done logging...
#
#
#
#
# ********** Iteration 460000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 460001
# mean reward (100 episodes) 164.108500
# best mean reward 167.436119
# running time 900.684961
# Train_EnvstepsSoFar : 460001
# Train_AverageReturn : 164.10850028969963
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 900.684960603714
# Training Loss : 1.7839943170547485
# Done logging...
#
#
#
#
# ********** Iteration 461000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 461001
# mean reward (100 episodes) 164.416900
# best mean reward 167.436119
# running time 902.127841
# Train_EnvstepsSoFar : 461001
# Train_AverageReturn : 164.41690021679403
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 902.1278412342072
# Training Loss : 0.24226905405521393
# Done logging...
#
#
#
#
# ********** Iteration 462000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 462001
# mean reward (100 episodes) 157.692869
# best mean reward 167.436119
# running time 903.573914
# Train_EnvstepsSoFar : 462001
# Train_AverageReturn : 157.6928690718925
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 903.5739135742188
# Training Loss : 0.12036141753196716
# Done logging...
#
#
#
#
# ********** Iteration 463000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 463001
# mean reward (100 episodes) 158.757909
# best mean reward 167.436119
# running time 905.061936
# Train_EnvstepsSoFar : 463001
# Train_AverageReturn : 158.7579094200617
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 905.0619356632233
# Training Loss : 0.7569820880889893
# Done logging...
#
#
#
#
# ********** Iteration 464000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 464001
# mean reward (100 episodes) 157.252430
# best mean reward 167.436119
# running time 906.445300
# Train_EnvstepsSoFar : 464001
# Train_AverageReturn : 157.25243027522586
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 906.4453003406525
# Training Loss : 0.3454291522502899
# Done logging...
#
#
#
#
# ********** Iteration 465000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 465001
# mean reward (100 episodes) 155.418761
# best mean reward 167.436119
# running time 908.009766
# Train_EnvstepsSoFar : 465001
# Train_AverageReturn : 155.41876067102856
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 908.0097658634186
# Training Loss : 1.7523820400238037
# Done logging...
#
#
#
#
# ********** Iteration 466000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 466001
# mean reward (100 episodes) 156.351054
# best mean reward 167.436119
# running time 909.559797
# Train_EnvstepsSoFar : 466001
# Train_AverageReturn : 156.35105414531722
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 909.5597968101501
# Training Loss : 0.3460737466812134
# Done logging...
#
#
#
#
# ********** Iteration 467000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 467001
# mean reward (100 episodes) 152.333048
# best mean reward 167.436119
# running time 911.035333
# Train_EnvstepsSoFar : 467001
# Train_AverageReturn : 152.33304783982646
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 911.0353331565857
# Training Loss : 1.087191104888916
# Done logging...
#
#
#
#
# ********** Iteration 468000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 468001
# mean reward (100 episodes) 154.517513
# best mean reward 167.436119
# running time 912.469195
# Train_EnvstepsSoFar : 468001
# Train_AverageReturn : 154.51751275173947
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 912.46919465065
# Training Loss : 0.6208953857421875
# Done logging...
#
#
#
#
# ********** Iteration 469000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 469001
# mean reward (100 episodes) 151.647886
# best mean reward 167.436119
# running time 913.895451
# Train_EnvstepsSoFar : 469001
# Train_AverageReturn : 151.64788589755287
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 913.895450592041
# Training Loss : 0.35203370451927185
# Done logging...
#
#
#
#
# ********** Iteration 470000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 470001
# mean reward (100 episodes) 150.435358
# best mean reward 167.436119
# running time 915.380157
# Train_EnvstepsSoFar : 470001
# Train_AverageReturn : 150.4353579839325
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 915.3801567554474
# Training Loss : 2.0862369537353516
# Done logging...
#
#
#
#
# ********** Iteration 471000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 471001
# mean reward (100 episodes) 147.763969
# best mean reward 167.436119
# running time 916.847355
# Train_EnvstepsSoFar : 471001
# Train_AverageReturn : 147.76396933416459
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 916.8473551273346
# Training Loss : 3.4777488708496094
# Done logging...
#
#
#
#
# ********** Iteration 472000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 472001
# mean reward (100 episodes) 149.231873
# best mean reward 167.436119
# running time 918.347444
# Train_EnvstepsSoFar : 472001
# Train_AverageReturn : 149.23187348923875
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 918.347443819046
# Training Loss : 0.2551826238632202
# Done logging...
#
#
#
#
# ********** Iteration 473000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 473001
# mean reward (100 episodes) 146.792224
# best mean reward 167.436119
# running time 920.019873
# Train_EnvstepsSoFar : 473001
# Train_AverageReturn : 146.7922239936146
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 920.0198726654053
# Training Loss : 0.577196478843689
# Done logging...
#
#
#
#
# ********** Iteration 474000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 474001
# mean reward (100 episodes) 146.034044
# best mean reward 167.436119
# running time 921.552184
# Train_EnvstepsSoFar : 474001
# Train_AverageReturn : 146.0340440421891
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 921.552184343338
# Training Loss : 0.21622797846794128
# Done logging...
#
#
#
#
# ********** Iteration 475000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 475001
# mean reward (100 episodes) 150.402299
# best mean reward 167.436119
# running time 923.074228
# Train_EnvstepsSoFar : 475001
# Train_AverageReturn : 150.40229936452945
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 923.0742280483246
# Training Loss : 0.12410508841276169
# Done logging...
#
#
#
#
# ********** Iteration 476000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 476001
# mean reward (100 episodes) 146.650505
# best mean reward 167.436119
# running time 924.564531
# Train_EnvstepsSoFar : 476001
# Train_AverageReturn : 146.6505052353716
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 924.564531326294
# Training Loss : 0.12855395674705505
# Done logging...
#
#
#
#
# ********** Iteration 477000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 477001
# mean reward (100 episodes) 152.265034
# best mean reward 167.436119
# running time 926.024532
# Train_EnvstepsSoFar : 477001
# Train_AverageReturn : 152.2650343115058
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 926.0245323181152
# Training Loss : 0.44186222553253174
# Done logging...
#
#
#
#
# ********** Iteration 478000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 478001
# mean reward (100 episodes) 147.324003
# best mean reward 167.436119
# running time 927.512506
# Train_EnvstepsSoFar : 478001
# Train_AverageReturn : 147.324003464336
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 927.5125057697296
# Training Loss : 2.3399267196655273
# Done logging...
#
#
#
#
# ********** Iteration 479000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 479001
# mean reward (100 episodes) 150.690161
# best mean reward 167.436119
# running time 929.136937
# Train_EnvstepsSoFar : 479001
# Train_AverageReturn : 150.69016092403032
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 929.1369366645813
# Training Loss : 0.24774229526519775
# Done logging...
#
#
#
#
# ********** Iteration 480000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 480001
# mean reward (100 episodes) 150.981592
# best mean reward 167.436119
# running time 930.651621
# Train_EnvstepsSoFar : 480001
# Train_AverageReturn : 150.98159187248785
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 930.6516206264496
# Training Loss : 0.2728506028652191
# Done logging...
#
#
#
#
# ********** Iteration 481000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 481001
# mean reward (100 episodes) 151.030360
# best mean reward 167.436119
# running time 932.117909
# Train_EnvstepsSoFar : 481001
# Train_AverageReturn : 151.03036007982007
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 932.1179094314575
# Training Loss : 0.17699086666107178
# Done logging...
#
#
#
#
# ********** Iteration 482000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 482001
# mean reward (100 episodes) 149.975466
# best mean reward 167.436119
# running time 933.590795
# Train_EnvstepsSoFar : 482001
# Train_AverageReturn : 149.97546587017794
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 933.5907952785492
# Training Loss : 1.8010468482971191
# Done logging...
#
#
#
#
# ********** Iteration 483000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 483001
# mean reward (100 episodes) 150.899004
# best mean reward 167.436119
# running time 935.229088
# Train_EnvstepsSoFar : 483001
# Train_AverageReturn : 150.8990039780588
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 935.2290875911713
# Training Loss : 1.6237612962722778
# Done logging...
#
#
#
#
# ********** Iteration 484000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 484001
# mean reward (100 episodes) 148.212016
# best mean reward 167.436119
# running time 936.827971
# Train_EnvstepsSoFar : 484001
# Train_AverageReturn : 148.21201643033615
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 936.8279712200165
# Training Loss : 0.15541931986808777
# Done logging...
#
#
#
#
# ********** Iteration 485000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 485001
# mean reward (100 episodes) 146.579744
# best mean reward 167.436119
# running time 938.319868
# Train_EnvstepsSoFar : 485001
# Train_AverageReturn : 146.57974404358623
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 938.3198683261871
# Training Loss : 1.4725205898284912
# Done logging...
#
#
#
#
# ********** Iteration 486000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 486001
# mean reward (100 episodes) 146.637965
# best mean reward 167.436119
# running time 939.882132
# Train_EnvstepsSoFar : 486001
# Train_AverageReturn : 146.63796459945266
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 939.8821318149567
# Training Loss : 3.9940378665924072
# Done logging...
#
#
#
#
# ********** Iteration 487000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 487001
# mean reward (100 episodes) 146.184131
# best mean reward 167.436119
# running time 942.059722
# Train_EnvstepsSoFar : 487001
# Train_AverageReturn : 146.18413097348767
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 942.0597219467163
# Training Loss : 3.9603636264801025
# Done logging...
#
#
#
#
# ********** Iteration 488000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 488001
# mean reward (100 episodes) 146.688569
# best mean reward 167.436119
# running time 943.596783
# Train_EnvstepsSoFar : 488001
# Train_AverageReturn : 146.68856930232516
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 943.5967826843262
# Training Loss : 0.3727034032344818
# Done logging...
#
#
#
#
# ********** Iteration 489000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 489001
# mean reward (100 episodes) 146.388355
# best mean reward 167.436119
# running time 945.328581
# Train_EnvstepsSoFar : 489001
# Train_AverageReturn : 146.3883550640872
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 945.3285813331604
# Training Loss : 0.12260179221630096
# Done logging...
#
#
#
#
# ********** Iteration 490000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 490001
# mean reward (100 episodes) 147.737523
# best mean reward 167.436119
# running time 946.875176
# Train_EnvstepsSoFar : 490001
# Train_AverageReturn : 147.7375234649195
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 946.87517619133
# Training Loss : 0.23352757096290588
# Done logging...
#
#
#
#
# ********** Iteration 491000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 491001
# mean reward (100 episodes) 146.414555
# best mean reward 167.436119
# running time 948.377759
# Train_EnvstepsSoFar : 491001
# Train_AverageReturn : 146.41455488984687
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 948.3777594566345
# Training Loss : 1.3540416955947876
# Done logging...
#
#
#
#
# ********** Iteration 492000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 492001
# mean reward (100 episodes) 144.561052
# best mean reward 167.436119
# running time 950.170498
# Train_EnvstepsSoFar : 492001
# Train_AverageReturn : 144.561051671589
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 950.1704978942871
# Training Loss : 0.1336962878704071
# Done logging...
#
#
#
#
# ********** Iteration 493000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 493001
# mean reward (100 episodes) 145.062784
# best mean reward 167.436119
# running time 951.740071
# Train_EnvstepsSoFar : 493001
# Train_AverageReturn : 145.06278366428188
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 951.7400712966919
# Training Loss : 0.20154626667499542
# Done logging...
#
#
#
#
# ********** Iteration 494000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 494001
# mean reward (100 episodes) 145.533124
# best mean reward 167.436119
# running time 953.188074
# Train_EnvstepsSoFar : 494001
# Train_AverageReturn : 145.53312399710845
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 953.188074350357
# Training Loss : 0.32273149490356445
# Done logging...
#
#
#
#
# ********** Iteration 495000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 495001
# mean reward (100 episodes) 144.906825
# best mean reward 167.436119
# running time 954.643289
# Train_EnvstepsSoFar : 495001
# Train_AverageReturn : 144.90682530974385
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 954.6432888507843
# Training Loss : 1.1018753051757812
# Done logging...
#
#
#
#
# ********** Iteration 496000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 496001
# mean reward (100 episodes) 145.588881
# best mean reward 167.436119
# running time 956.143386
# Train_EnvstepsSoFar : 496001
# Train_AverageReturn : 145.58888085182923
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 956.1433856487274
# Training Loss : 1.1790521144866943
# Done logging...
#
#
#
#
# ********** Iteration 497000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 497001
# mean reward (100 episodes) 134.888806
# best mean reward 167.436119
# running time 957.781317
# Train_EnvstepsSoFar : 497001
# Train_AverageReturn : 134.88880612713427
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 957.7813165187836
# Training Loss : 0.3218729496002197
# Done logging...
#
#
#
#
# ********** Iteration 498000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 498001
# mean reward (100 episodes) 136.840388
# best mean reward 167.436119
# running time 959.244752
# Train_EnvstepsSoFar : 498001
# Train_AverageReturn : 136.84038760733532
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 959.2447521686554
# Training Loss : 1.150269627571106
# Done logging...
#
#
#
#
# ********** Iteration 499000 ************
#
# Training agent...
#
# Beginning logging procedure...
# Timestep 499001
# mean reward (100 episodes) 138.893453
# best mean reward 167.436119
# running time 960.782195
# Train_EnvstepsSoFar : 499001
# Train_AverageReturn : 138.8934532929087
# Train_BestReturn : 167.43611916945935
# TimeSinceStart : 960.7821946144104
# Training Loss : 0.15427228808403015
# Done logging...

# %%
### Visualize all DQN results on Lunar Lander
# %load_ext tensorboard
# %tensorboard --logdir logs/dqn/LunarLander/
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-2b47bd880937c4df" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2b47bd880937c4df");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
