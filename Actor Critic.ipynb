# %% [markdown]
# # Actor Critic Algorithms
# In the DQN algorithm, we learned a Q-function by minimizing Bellman errors for an implicit policy that always took the action that maximized the Q-function. However, this scheme requires a discrete action spaces to allow for us to easily compute the optimal action at each state, unlike generic policy gradient algorithms that also worked with continuous action spaces.
#
# In this section, we will explore actor-critic algorithms which maintain an explicit policy (actor) like the policy gradient algorithms, learns a Q-function (critic) capturing the values of the _current policy_, and uses this learned Q-function to update the policy. Using a learned critic can provide much lower variance updates for the policy compared to using Monte-Carlo retun estimates, and also allows us to reuse our data by training the actor and critic on _off-policy_ data for more sample efficiency. We can thus take many more policy updates with an actor critic algorithm using our learned critic, instead of needing to wait and gather fresh samples every time.

# %%
# As usual, a bit of setup
import os
import shutil
import time
import numpy as np
import torch

import deeprl.infrastructure.pytorch_util as ptu
from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import AC_Trainer

from deeprl.policies.MLP_policy import MLPPolicyAC

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))

# %%
ac_base_args_dict = dict(
    env_name = 'Hopper-v2', #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
    exp_name = 'test_ac', #@param
    save_params = False, #@param {type: "boolean"}
    
    ## PDF will tell you how to set ep_len
    ## and discount for each environment
    ep_len = 200, #@param {type: "integer"}
    discount = 0.99, #@param {type: "number"}

    # Training
    num_agent_train_steps_per_iter = 1000, #@param {type: "integer"})
    n_iter = 100, #@param {type: "integer"})

    # batches & buffers
    batch_size = 1000, #@param {type: "integer"})
    eval_batch_size = 1000, #@param {type: "integer"}
    train_batch_size = 256, #@param {type: "integer"}
    max_replay_buffer_size = 1000000, #@param {type: "integer"}

    #@markdown actor network
    n_layers = 2, #@param {type: "integer"}
    size = 256, #@param {type: "integer"}
    entropy_weight=0, #@param {type: "number"}
    learning_rate = 3e-4, #@param {type: "number"}
    
    # critic network
    critic_n_layers = 2, #@param {type: "integer"}
    critic_size = 256, #@param {type: "integer"}
    target_update_rate = 5e-3,

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# First fill out the target value calculation in the compute_target_value method of <code>critics/bootstrapped_continuous_critic.py</code>. Compared to the DQN critic, the key difference is that we are now estimating the value of the current policy, instead of the optimal policy as in DQN or Q-learning.
#
# To train our critic to evaluate the current policy $\pi$, we simply sample actions from the current policy in our target value. For each sample $(s,a,s')$, our loss will be
# $$L(Q_{\theta}(s, a), r(s,a) + \gamma \mathbb{E}_{a'\sim \pi(s')}[Q_{\bar \theta} (s', a')]),$$
# where $L$ is our loss function (for example squared error or the smooth L1 loss).
# In this assignment, we will simply sample a single action from the policy to estimate the target value.

# %%
# Test bellman error for policy evaluation
ac_dim = 3
ob_dim = 11
N = 5

np.random.seed(0)
obs = np.random.normal(size=(N, ob_dim))
acts = np.random.choice(ac_dim, size=(N,))
next_obs = np.random.normal(size=(N, ob_dim))
rewards = np.random.normal(size=N)
terminals = np.zeros(N)
terminals[0] = 1

ac_args = dict(ac_base_args_dict)

env_str = 'Hopper'
ac_args['env_name'] = '{}-v2'.format(env_str)
ac_args['entropy_weight'] = 0.1
actrainer = AC_Trainer(ac_args)
critic = actrainer.rl_trainer.agent.critic

class DummyDist:
    def sample(self):
        return ptu.from_numpy(1 + np.zeros(shape=(N, ac_dim)))

def dummy_actor(next_obs):
    return DummyDist()

# assumes you call actor(next_obs) to get the distribution, then call distribution.sample()
target_vals = critic.compute_target_value(ptu.from_numpy(next_obs), 
                                          ptu.from_numpy(rewards), 
                                          ptu.from_numpy(terminals), 
                                          dummy_actor)
target_vals = ptu.to_numpy(target_vals)
expected_targets = np.array([-0.9167948, -0.11123351, -0.36787638, -2.1131861,  -0.13868617])

target_error = rel_error(target_vals, expected_targets)
print("Target value error", target_error, "should be on the order of 1e-6 or lower")
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Target value error 1.7256281503042193e-08 should be on the order of 1e-6 or lower

# %% [markdown]
# For this section, we will also update our target network parameters as an exponential moving average of the critic parameters, instead of simply copying the current parameters periodically as in DQN. Generally, either method for target networks tends to work with appropriately chosen update rates.
#
# Fill out the update_target_parameter_ema method in <code>critics/bootstrapped_continuous_critic.py</code>.

# %%
# Test target network update
ac_args = dict(ac_base_args_dict)

env_str = 'Hopper'
ac_args['env_name'] = '{}-v2'.format(env_str)
ac_args['entropy_weight'] = 0.1
actrainer = AC_Trainer(ac_args)
critic = actrainer.rl_trainer.agent.critic

critic.target_update_rate = 0.5

# at initialization, target and critic networks are the same
for p in critic.critic_network.parameters():
    p.data += 1.
    
critic.update_target_network_ema()

for p, target_p in zip(critic.critic_network.parameters(), critic.target_network.parameters()):
    assert np.all(ptu.to_numpy((p-target_p)) == 0.5)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2

# %% [markdown]
# Next, we will implement the actor update using the learned critic instead of Monte Carlo returns.
#
# To update our policy at a particular state $s$, our previous policy gradient (using the reward to go estimator) took a step on the objective (treating $Q^{\pi}$ as a function that didn't depend on $\pi$ and using the results of a single trajectory to estimate $Q^\pi$)
# $$\mathbb E_{a \sim \pi_{\theta}(s)}[Q^{\pi_\theta}(s, a)],$$
# using the REINFORCE gradient estimator
# $$\mathbb E_{a \sim \pi_{\theta}(s)}[\nabla_{\theta} \log \pi_{\theta}(a\vert s) Q^{\pi}(s, a)].$$
# This estimator only relied on the estimated value $Q^{\pi_{\theta}}(s,a)$, so was very general and could be applied with Monte Carlo estimates of $Q^{\pi_\theta}$.
#
# One way to estimate policy gradients with an actor critic algorithm would be to directly replace the Monte Carlo estimate of $Q$ with the learned critic $Q_{\phi}$, and continue using the REINFORCE gradient estimator.
# However, we note that we can explicitly compute derivatives of our learned critic $Q(s, a)$ with respect to the action $a$, which can enable potentially better gradient estimates.
#
# In order to take advantage of this, we would also need to differentiate sampled actions $a$ with respect to our policy parameters, which we can through a technique known as the _reparameterization trick_ or the _pathwise_ estimator.
# The idea is that if our policy sampled actions according to $a \sim \mathcal N(\mu_{\theta}(s), \sigma^2_{\theta}(s))$, we can rewrite $a = f_{\theta}(z)$, where $z \sim \mathcal N(0, 1)$, and $f(z) = \mu_{\theta}(s) + z \cdot \sigma_{\theta}(s)$. Now all the randomness comes from sampling $z$, which doesn't depend on our policy, so we can now differentiate the sampled action $a$ with respect to our policy parameters $\theta$ by simply differentiating through the function $f$ applied at the random noise $z$.
#
# Using the chain rule then allows to directly estimate gradients of
# $$\mathbb{E}_{a \sim \pi_{\theta}(s)}[Q_{\phi}(s,a)]$$
# by drawing samples from $\pi$ and differentiating $Q_{\phi}(s,a)$ on the samples.
#
# Implement the actor update using this pathwise estimator in the update method of the MLPPolicyAC class in <code>policies/MLP_policy.py</code> (Hint: see the rsample function in for torch.distributions). Note that our implementation samples states uniformly from the entire replay buffer, not necessarily from the state distribution of the current policy. While this means we are no longer taking unbiased policy gradients (our estimates were already biased anyways due to using a learned critic), it works well in practice.

# %%
# Compute actor update using the policy gradient. 
# For this test to pass, make sure you only call sample once per actor update to not throw off 
# the actor samples expected for the updates in the this test.
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

np.random.seed(0)
obs = np.random.normal(size=(N, ob_dim))

policy = MLPPolicyAC(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25,
            entropy_weight=0.)

def dummy_critic(obs, acts):
    return torch.sum(acts + 1) + torch.sum(obs)

initial_loss = policy.update(obs, dummy_critic)['Actor Training Loss']
expected_initial_loss = -17.083496

print("Initial loss error", rel_error(expected_initial_loss, initial_loss), "should be on the order of 1e-6 or less.")
for i in range(5):
    loss = policy.update(obs, dummy_critic)['Actor Training Loss']
    print(loss)

expected_final_loss = -30.103575

print("Final loss error", rel_error(expected_final_loss, loss), "should be on the order of 1e-6 or less.")
# Out:
# Initial loss error 2.7438762975115168e-09 should be on the order of 1e-6 or less.
# -17.314678
# -22.621984
# -25.828485
# -29.670477
# -30.103575
# Final loss error 4.105698129439902e-09 should be on the order of 1e-6 or less.

# %% [markdown]
# Now we'll train our actor critic agent on the HalfCheetah task. You should see your policies generally get over 600 returns.
#
# We note that these actor critic algorithms, since they make use of off-policy updates, can be much more sample efficient than the basic policy gradient algorith we saw earlier. In our actor critic algorithms here, we only take 1000 new samples from the environment per iteration, while the policy gradient algorithms often needed many more samples per iteration to estimate the Monte Carlo returns (for example, we used 10000 in the Hopper experiments with policy gradient).

# %%
ac_args = dict(ac_base_args_dict)

env_str = 'HalfCheetah'
ac_args['env_name'] = '{}-v2'.format(env_str)
ac_args['n_iter'] = 50

# Delete all previous logs
remove_folder('logs/actor_critic/{}'.format(env_str))

for seed in range(3):
    print("Running actor critic experiment with seed", seed)
    ac_args['seed'] = seed
    ac_args['logdir'] = 'logs/actor_critic/{}/seed{}'.format(env_str, seed)
    actrainer = AC_Trainer(ac_args)
    actrainer.run_training_loop()
# Out:
# Clearing old results at logs/actor_critic/HalfCheetah
# Running actor critic experiment with seed 0
# ########################
# logging outputs to  logs/actor_critic/HalfCheetah/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
#
#
# ********** Iteration 0 ************
#
# Collecting initial random data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -107.34346771240234
# Eval_StdReturn : 2.2491707801818848
# Eval_MaxReturn : -105.41130065917969
# Eval_MinReturn : -111.75190734863281
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -55.866336822509766
# Train_StdReturn : 38.55010986328125
# Train_MaxReturn : 8.81280517578125
# Train_MinReturn : -142.16978454589844
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 10050
# TimeSinceStart : 12.129283666610718
# Critic Training Loss : 0.43065381050109863
# Critic Mean : 36.57166290283203
# Actor Training Loss : -37.04070281982422
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -18.513261795043945
# Eval_StdReturn : 21.56987762451172
# Eval_MaxReturn : 7.8823113441467285
# Eval_MinReturn : -54.27577209472656
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -106.61509704589844
# Train_StdReturn : 0.6874597072601318
# Train_MaxReturn : -105.6900634765625
# Train_MinReturn : -107.69103240966797
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 11055
# TimeSinceStart : 23.01577925682068
# Critic Training Loss : 0.7978291511535645
# Critic Mean : 27.2387752532959
# Actor Training Loss : -27.712234497070312
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -69.0085678100586
# Eval_StdReturn : 16.192668914794922
# Eval_MaxReturn : -58.81652069091797
# Eval_MinReturn : -100.94602966308594
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -7.834437370300293
# Train_StdReturn : 8.135968208312988
# Train_MaxReturn : 0.9183332920074463
# Train_MinReturn : -20.167688369750977
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 12060
# TimeSinceStart : 33.907922983169556
# Critic Training Loss : 0.45276394486427307
# Critic Mean : 30.429096221923828
# Actor Training Loss : -31.0446834564209
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -85.48051452636719
# Eval_StdReturn : 40.71966552734375
# Eval_MaxReturn : -4.961199760437012
# Eval_MinReturn : -113.3707046508789
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -79.40614318847656
# Train_StdReturn : 16.005897521972656
# Train_MaxReturn : -53.037906646728516
# Train_MinReturn : -100.22482299804688
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 13065
# TimeSinceStart : 45.92581510543823
# Critic Training Loss : 0.3232327103614807
# Critic Mean : 36.63151550292969
# Actor Training Loss : -37.2386360168457
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -48.30753707885742
# Eval_StdReturn : 11.454397201538086
# Eval_MaxReturn : -29.988496780395508
# Eval_MinReturn : -64.5969467163086
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -71.41313934326172
# Train_StdReturn : 45.10724639892578
# Train_MaxReturn : -2.18426513671875
# Train_MinReturn : -112.78073120117188
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 14070
# TimeSinceStart : 57.486595153808594
# Critic Training Loss : 0.6066479086875916
# Critic Mean : 41.962120056152344
# Actor Training Loss : -42.74384689331055
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.62235260009766
# Eval_StdReturn : 53.848331451416016
# Eval_MaxReturn : 162.06448364257812
# Eval_MinReturn : 24.997556686401367
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -35.659996032714844
# Train_StdReturn : 56.51465606689453
# Train_MaxReturn : 32.261104583740234
# Train_MinReturn : -127.18833923339844
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 15075
# TimeSinceStart : 71.47563290596008
# Critic Training Loss : 0.5665632486343384
# Critic Mean : 50.45063781738281
# Actor Training Loss : -51.30961227416992
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.8172149658203
# Eval_StdReturn : 30.47239875793457
# Eval_MaxReturn : 235.7799530029297
# Eval_MinReturn : 150.2812957763672
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 118.46971130371094
# Train_StdReturn : 29.143278121948242
# Train_MaxReturn : 153.9495086669922
# Train_MinReturn : 76.583251953125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 16080
# TimeSinceStart : 83.32628178596497
# Critic Training Loss : 0.43855398893356323
# Critic Mean : 65.83296966552734
# Actor Training Loss : -66.83380126953125
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 239.895751953125
# Eval_StdReturn : 46.9938850402832
# Eval_MaxReturn : 281.8722229003906
# Eval_MinReturn : 151.14385986328125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 193.28909301757812
# Train_StdReturn : 3.525495767593384
# Train_MaxReturn : 197.94119262695312
# Train_MinReturn : 187.6071319580078
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 17085
# TimeSinceStart : 95.32606625556946
# Critic Training Loss : 1.0284717082977295
# Critic Mean : 91.62690734863281
# Actor Training Loss : -92.81867980957031
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 232.86611938476562
# Eval_StdReturn : 18.749685287475586
# Eval_MaxReturn : 266.97796630859375
# Eval_MinReturn : 216.63894653320312
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 226.380615234375
# Train_StdReturn : 34.60499954223633
# Train_MaxReturn : 267.39288330078125
# Train_MinReturn : 173.55880737304688
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 18090
# TimeSinceStart : 107.801100730896
# Critic Training Loss : 0.901718258857727
# Critic Mean : 110.55978393554688
# Actor Training Loss : -111.89968872070312
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 313.74169921875
# Eval_StdReturn : 19.927799224853516
# Eval_MaxReturn : 336.9492492675781
# Eval_MinReturn : 283.42755126953125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 217.06692504882812
# Train_StdReturn : 26.9167537689209
# Train_MaxReturn : 249.89376831054688
# Train_MinReturn : 177.11801147460938
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 19095
# TimeSinceStart : 120.28256797790527
# Critic Training Loss : 1.231268286705017
# Critic Mean : 119.47540283203125
# Actor Training Loss : -120.62429809570312
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 328.755615234375
# Eval_StdReturn : 5.654193878173828
# Eval_MaxReturn : 337.9967956542969
# Eval_MinReturn : 322.46783447265625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 313.8316345214844
# Train_StdReturn : 24.63418197631836
# Train_MaxReturn : 345.3453063964844
# Train_MinReturn : 271.03350830078125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 20100
# TimeSinceStart : 132.28870010375977
# Critic Training Loss : 1.0426584482192993
# Critic Mean : 140.86050415039062
# Actor Training Loss : -142.19654846191406
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 310.3489990234375
# Eval_StdReturn : 37.509944915771484
# Eval_MaxReturn : 358.90399169921875
# Eval_MinReturn : 242.97518920898438
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 281.94317626953125
# Train_StdReturn : 25.947921752929688
# Train_MaxReturn : 309.2227478027344
# Train_MinReturn : 238.18807983398438
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 21105
# TimeSinceStart : 143.70818400382996
# Critic Training Loss : 0.4996653199195862
# Critic Mean : 148.91168212890625
# Actor Training Loss : -150.431884765625
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 275.91326904296875
# Eval_StdReturn : 31.245634078979492
# Eval_MaxReturn : 310.0576477050781
# Eval_MinReturn : 236.82144165039062
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 271.28094482421875
# Train_StdReturn : 74.48613739013672
# Train_MaxReturn : 329.58465576171875
# Train_MinReturn : 127.53236389160156
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 22110
# TimeSinceStart : 156.45046257972717
# Critic Training Loss : 1.8165106773376465
# Critic Mean : 158.0879364013672
# Actor Training Loss : -159.53518676757812
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 344.1882629394531
# Eval_StdReturn : 18.995012283325195
# Eval_MaxReturn : 361.73931884765625
# Eval_MinReturn : 310.02252197265625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 278.533203125
# Train_StdReturn : 21.97409439086914
# Train_MaxReturn : 308.3485107421875
# Train_MinReturn : 243.4703369140625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 23115
# TimeSinceStart : 168.8639063835144
# Critic Training Loss : 0.42663660645484924
# Critic Mean : 161.0686492919922
# Actor Training Loss : -162.49887084960938
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 352.8753662109375
# Eval_StdReturn : 10.949531555175781
# Eval_MaxReturn : 365.3570556640625
# Eval_MinReturn : 334.1494140625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 340.68914794921875
# Train_StdReturn : 27.2491397857666
# Train_MaxReturn : 367.5382385253906
# Train_MinReturn : 289.9910888671875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 24120
# TimeSinceStart : 181.87011742591858
# Critic Training Loss : 0.4619201123714447
# Critic Mean : 165.54525756835938
# Actor Training Loss : -167.10902404785156
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 355.8772888183594
# Eval_StdReturn : 22.183298110961914
# Eval_MaxReturn : 380.25030517578125
# Eval_MinReturn : 316.4866943359375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 365.1467590332031
# Train_StdReturn : 8.432412147521973
# Train_MaxReturn : 374.6591796875
# Train_MinReturn : 354.1171875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 25125
# TimeSinceStart : 194.76324820518494
# Critic Training Loss : 0.9810635447502136
# Critic Mean : 177.22344970703125
# Actor Training Loss : -178.63674926757812
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 386.9139404296875
# Eval_StdReturn : 30.215511322021484
# Eval_MaxReturn : 420.5892639160156
# Eval_MinReturn : 334.005126953125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 342.4431457519531
# Train_StdReturn : 23.56242561340332
# Train_MaxReturn : 375.32049560546875
# Train_MinReturn : 315.71893310546875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 26130
# TimeSinceStart : 209.52525901794434
# Critic Training Loss : 2.9616994857788086
# Critic Mean : 180.14239501953125
# Actor Training Loss : -181.62188720703125
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 417.4855041503906
# Eval_StdReturn : 31.69882583618164
# Eval_MaxReturn : 442.2770080566406
# Eval_MinReturn : 356.8969421386719
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 395.5558166503906
# Train_StdReturn : 15.442963600158691
# Train_MaxReturn : 417.147705078125
# Train_MinReturn : 369.43682861328125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 27135
# TimeSinceStart : 224.13808870315552
# Critic Training Loss : 1.0430848598480225
# Critic Mean : 182.40745544433594
# Actor Training Loss : -184.02743530273438
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 394.37200927734375
# Eval_StdReturn : 48.98025894165039
# Eval_MaxReturn : 441.0724182128906
# Eval_MinReturn : 306.43682861328125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 418.15350341796875
# Train_StdReturn : 51.18218231201172
# Train_MaxReturn : 451.587890625
# Train_MinReturn : 317.0400085449219
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 28140
# TimeSinceStart : 237.2010462284088
# Critic Training Loss : 1.691821813583374
# Critic Mean : 193.15989685058594
# Actor Training Loss : -194.5694122314453
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 429.37982177734375
# Eval_StdReturn : 69.59811401367188
# Eval_MaxReturn : 520.4970092773438
# Eval_MinReturn : 332.81195068359375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 436.6373596191406
# Train_StdReturn : 24.746381759643555
# Train_MaxReturn : 459.68896484375
# Train_MinReturn : 395.373046875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 29145
# TimeSinceStart : 248.93772959709167
# Critic Training Loss : 1.1839436292648315
# Critic Mean : 202.98446655273438
# Actor Training Loss : -204.42584228515625
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 443.6829528808594
# Eval_StdReturn : 60.762290954589844
# Eval_MaxReturn : 495.05511474609375
# Eval_MinReturn : 327.76947021484375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 383.058349609375
# Train_StdReturn : 134.9187774658203
# Train_MaxReturn : 496.4261169433594
# Train_MinReturn : 121.28556823730469
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 30150
# TimeSinceStart : 260.4067041873932
# Critic Training Loss : 1.3191982507705688
# Critic Mean : 210.6636962890625
# Actor Training Loss : -212.18934631347656
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 481.07977294921875
# Eval_StdReturn : 17.18080711364746
# Eval_MaxReturn : 495.89788818359375
# Eval_MinReturn : 448.56390380859375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 460.00244140625
# Train_StdReturn : 28.593475341796875
# Train_MaxReturn : 502.0858459472656
# Train_MinReturn : 421.03570556640625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 31155
# TimeSinceStart : 271.0825226306915
# Critic Training Loss : 2.3217668533325195
# Critic Mean : 216.78897094726562
# Actor Training Loss : -218.45040893554688
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 462.9207458496094
# Eval_StdReturn : 11.174640655517578
# Eval_MaxReturn : 477.0516052246094
# Eval_MinReturn : 446.13714599609375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 452.57440185546875
# Train_StdReturn : 45.00217056274414
# Train_MaxReturn : 480.6830749511719
# Train_MinReturn : 362.8201904296875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 32160
# TimeSinceStart : 282.604150056839
# Critic Training Loss : 1.3997284173965454
# Critic Mean : 219.39881896972656
# Actor Training Loss : -221.01663208007812
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 465.3412170410156
# Eval_StdReturn : 12.346623420715332
# Eval_MaxReturn : 482.6180419921875
# Eval_MinReturn : 444.88909912109375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 450.08770751953125
# Train_StdReturn : 57.90665817260742
# Train_MaxReturn : 499.19635009765625
# Train_MinReturn : 340.55072021484375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 33165
# TimeSinceStart : 293.75448203086853
# Critic Training Loss : 1.2663904428482056
# Critic Mean : 226.93521118164062
# Actor Training Loss : -228.18655395507812
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 473.4120178222656
# Eval_StdReturn : 14.034002304077148
# Eval_MaxReturn : 491.5294189453125
# Eval_MinReturn : 454.5967102050781
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 459.70709228515625
# Train_StdReturn : 13.078897476196289
# Train_MaxReturn : 481.4932861328125
# Train_MinReturn : 442.5558166503906
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 34170
# TimeSinceStart : 303.9986934661865
# Critic Training Loss : 4.262219429016113
# Critic Mean : 229.91917419433594
# Actor Training Loss : -231.44064331054688
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 491.85888671875
# Eval_StdReturn : 4.255520820617676
# Eval_MaxReturn : 496.4054260253906
# Eval_MinReturn : 485.5447998046875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 466.0914611816406
# Train_StdReturn : 7.213697910308838
# Train_MaxReturn : 477.3817443847656
# Train_MinReturn : 455.91534423828125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 35175
# TimeSinceStart : 314.60030126571655
# Critic Training Loss : 1.0938785076141357
# Critic Mean : 231.2725372314453
# Actor Training Loss : -232.99432373046875
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 503.7539978027344
# Eval_StdReturn : 13.022541046142578
# Eval_MaxReturn : 521.4832763671875
# Eval_MinReturn : 483.8525085449219
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 468.003173828125
# Train_StdReturn : 18.665512084960938
# Train_MaxReturn : 500.07977294921875
# Train_MinReturn : 443.6512756347656
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 36180
# TimeSinceStart : 325.5410602092743
# Critic Training Loss : 0.7672299742698669
# Critic Mean : 235.60150146484375
# Actor Training Loss : -237.11351013183594
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 490.769287109375
# Eval_StdReturn : 9.614439964294434
# Eval_MaxReturn : 503.1966552734375
# Eval_MinReturn : 477.9720153808594
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 493.86700439453125
# Train_StdReturn : 14.508975982666016
# Train_MaxReturn : 513.923095703125
# Train_MinReturn : 474.7003173828125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 37185
# TimeSinceStart : 336.1807565689087
# Critic Training Loss : 1.6663386821746826
# Critic Mean : 240.74313354492188
# Actor Training Loss : -242.2342071533203
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 504.5746154785156
# Eval_StdReturn : 19.65937042236328
# Eval_MaxReturn : 532.6013793945312
# Eval_MinReturn : 478.89190673828125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 503.02276611328125
# Train_StdReturn : 19.527362823486328
# Train_MaxReturn : 534.1950073242188
# Train_MinReturn : 473.4236145019531
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 38190
# TimeSinceStart : 347.7385847568512
# Critic Training Loss : 3.488438606262207
# Critic Mean : 244.03689575195312
# Actor Training Loss : -245.33975219726562
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 530.1817626953125
# Eval_StdReturn : 16.057268142700195
# Eval_MaxReturn : 551.1910400390625
# Eval_MinReturn : 516.1655883789062
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 475.707275390625
# Train_StdReturn : 47.6568489074707
# Train_MaxReturn : 517.8025512695312
# Train_MinReturn : 383.7829284667969
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 39195
# TimeSinceStart : 359.1080298423767
# Critic Training Loss : 2.508646249771118
# Critic Mean : 247.6492919921875
# Actor Training Loss : -249.10943603515625
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 471.84735107421875
# Eval_StdReturn : 30.69380760192871
# Eval_MaxReturn : 515.0728759765625
# Eval_MinReturn : 427.34844970703125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 521.9472045898438
# Train_StdReturn : 37.610382080078125
# Train_MaxReturn : 562.8526611328125
# Train_MinReturn : 454.51531982421875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 40200
# TimeSinceStart : 370.3879134654999
# Critic Training Loss : 1.8595153093338013
# Critic Mean : 253.08299255371094
# Actor Training Loss : -254.50115966796875
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 522.9613037109375
# Eval_StdReturn : 8.462320327758789
# Eval_MaxReturn : 533.033203125
# Eval_MinReturn : 509.75360107421875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 473.9969177246094
# Train_StdReturn : 20.179533004760742
# Train_MaxReturn : 495.13031005859375
# Train_MinReturn : 442.2422180175781
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 41205
# TimeSinceStart : 381.69975900650024
# Critic Training Loss : 3.720531702041626
# Critic Mean : 254.8148193359375
# Actor Training Loss : -256.26214599609375
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 523.0469970703125
# Eval_StdReturn : 19.099699020385742
# Eval_MaxReturn : 542.4657592773438
# Eval_MinReturn : 487.25543212890625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 525.3681640625
# Train_StdReturn : 19.42831802368164
# Train_MaxReturn : 545.10791015625
# Train_MinReturn : 488.5392150878906
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 42210
# TimeSinceStart : 392.9457850456238
# Critic Training Loss : 2.8693246841430664
# Critic Mean : 254.72605895996094
# Actor Training Loss : -256.0621643066406
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 472.37078857421875
# Eval_StdReturn : 11.586966514587402
# Eval_MaxReturn : 489.7231750488281
# Eval_MinReturn : 453.83837890625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 505.5084533691406
# Train_StdReturn : 18.909461975097656
# Train_MaxReturn : 524.796875
# Train_MinReturn : 472.8337707519531
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 43215
# TimeSinceStart : 404.9094624519348
# Critic Training Loss : 1.6841026544570923
# Critic Mean : 257.216064453125
# Actor Training Loss : -258.4388122558594
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 478.18231201171875
# Eval_StdReturn : 17.154273986816406
# Eval_MaxReturn : 499.63140869140625
# Eval_MinReturn : 453.4681701660156
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 470.486083984375
# Train_StdReturn : 15.175393104553223
# Train_MaxReturn : 488.817626953125
# Train_MinReturn : 448.9085693359375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 44220
# TimeSinceStart : 416.6824064254761
# Critic Training Loss : 0.5578607320785522
# Critic Mean : 258.7454833984375
# Actor Training Loss : -260.04425048828125
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 480.76324462890625
# Eval_StdReturn : 14.277609825134277
# Eval_MaxReturn : 499.3997802734375
# Eval_MinReturn : 460.0548095703125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 480.9314880371094
# Train_StdReturn : 14.021391868591309
# Train_MaxReturn : 493.5914306640625
# Train_MinReturn : 454.77996826171875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 45225
# TimeSinceStart : 429.09621262550354
# Critic Training Loss : 2.5803239345550537
# Critic Mean : 256.27789306640625
# Actor Training Loss : -257.71014404296875
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 500.7841796875
# Eval_StdReturn : 45.39221954345703
# Eval_MaxReturn : 542.7825927734375
# Eval_MinReturn : 415.0030517578125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 471.733154296875
# Train_StdReturn : 23.41061019897461
# Train_MaxReturn : 500.1507568359375
# Train_MinReturn : 430.2839050292969
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 46230
# TimeSinceStart : 439.98270058631897
# Critic Training Loss : 1.5455284118652344
# Critic Mean : 257.8708801269531
# Actor Training Loss : -259.22119140625
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 499.16107177734375
# Eval_StdReturn : 26.690872192382812
# Eval_MaxReturn : 541.9678344726562
# Eval_MinReturn : 470.14471435546875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 510.7696838378906
# Train_StdReturn : 40.958194732666016
# Train_MaxReturn : 545.860595703125
# Train_MinReturn : 435.15789794921875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 47235
# TimeSinceStart : 451.88470482826233
# Critic Training Loss : 3.3832876682281494
# Critic Mean : 255.76141357421875
# Actor Training Loss : -257.3182373046875
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 527.66064453125
# Eval_StdReturn : 15.656953811645508
# Eval_MaxReturn : 557.31396484375
# Eval_MinReturn : 514.725341796875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 475.36358642578125
# Train_StdReturn : 61.192867279052734
# Train_MaxReturn : 513.798583984375
# Train_MinReturn : 354.49786376953125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 48240
# TimeSinceStart : 464.0467495918274
# Critic Training Loss : 1.6299760341644287
# Critic Mean : 258.81170654296875
# Actor Training Loss : -260.094970703125
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 534.2569580078125
# Eval_StdReturn : 15.268488883972168
# Eval_MaxReturn : 554.0118408203125
# Eval_MinReturn : 507.154541015625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 520.343017578125
# Train_StdReturn : 14.845494270324707
# Train_MaxReturn : 538.1361083984375
# Train_MinReturn : 494.2430725097656
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 49245
# TimeSinceStart : 476.5279154777527
# Critic Training Loss : 1.6485450267791748
# Critic Mean : 259.458984375
# Actor Training Loss : -260.87237548828125
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 471.87774658203125
# Eval_StdReturn : 24.344013214111328
# Eval_MaxReturn : 507.5690002441406
# Eval_MinReturn : 437.2239990234375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 510.2568359375
# Train_StdReturn : 16.12205696105957
# Train_MaxReturn : 525.9866943359375
# Train_MinReturn : 484.83709716796875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 50250
# TimeSinceStart : 489.72327613830566
# Critic Training Loss : 0.551754355430603
# Critic Mean : 263.8415222167969
# Actor Training Loss : -265.19573974609375
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 541.1634521484375
# Eval_StdReturn : 22.54440689086914
# Eval_MaxReturn : 569.2066650390625
# Eval_MinReturn : 509.61651611328125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 481.7293395996094
# Train_StdReturn : 18.944387435913086
# Train_MaxReturn : 509.3871154785156
# Train_MinReturn : 459.8881530761719
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 51255
# TimeSinceStart : 502.1888527870178
# Critic Training Loss : 1.7010347843170166
# Critic Mean : 262.7624206542969
# Actor Training Loss : -264.112060546875
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 535.9407348632812
# Eval_StdReturn : 11.166170120239258
# Eval_MaxReturn : 547.89453125
# Eval_MinReturn : 519.37646484375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 509.4239196777344
# Train_StdReturn : 33.62826919555664
# Train_MaxReturn : 543.7365112304688
# Train_MinReturn : 460.7414855957031
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 52260
# TimeSinceStart : 513.9496688842773
# Critic Training Loss : 0.6554875373840332
# Critic Mean : 270.4078674316406
# Actor Training Loss : -271.5921630859375
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 544.9215087890625
# Eval_StdReturn : 15.618203163146973
# Eval_MaxReturn : 567.04931640625
# Eval_MinReturn : 520.9410400390625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 530.1593017578125
# Train_StdReturn : 19.62262535095215
# Train_MaxReturn : 557.4375
# Train_MinReturn : 508.4419860839844
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 53265
# TimeSinceStart : 524.5982058048248
# Critic Training Loss : 0.60533207654953
# Critic Mean : 269.53558349609375
# Actor Training Loss : -270.7700500488281
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 496.9603576660156
# Eval_StdReturn : 37.084354400634766
# Eval_MaxReturn : 527.392333984375
# Eval_MinReturn : 424.68841552734375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 539.0159912109375
# Train_StdReturn : 9.383200645446777
# Train_MaxReturn : 552.1782836914062
# Train_MinReturn : 527.6681518554688
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 54270
# TimeSinceStart : 533.8601326942444
# Critic Training Loss : 1.6622257232666016
# Critic Mean : 269.9315490722656
# Actor Training Loss : -271.1883850097656
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 526.7327880859375
# Eval_StdReturn : 12.561735153198242
# Eval_MaxReturn : 540.73828125
# Eval_MinReturn : 505.43035888671875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 497.6337890625
# Train_StdReturn : 27.618167877197266
# Train_MaxReturn : 535.4071044921875
# Train_MinReturn : 455.1820373535156
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 55275
# TimeSinceStart : 542.5165450572968
# Critic Training Loss : 1.670331597328186
# Critic Mean : 272.08697509765625
# Actor Training Loss : -273.1188049316406
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 523.3156127929688
# Eval_StdReturn : 14.871899604797363
# Eval_MaxReturn : 542.6763916015625
# Eval_MinReturn : 500.9270324707031
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 518.0701904296875
# Train_StdReturn : 14.312642097473145
# Train_MaxReturn : 543.66552734375
# Train_MinReturn : 499.39593505859375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 56280
# TimeSinceStart : 551.5402190685272
# Critic Training Loss : 1.412103295326233
# Critic Mean : 269.5378723144531
# Actor Training Loss : -270.8790283203125
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 523.39453125
# Eval_StdReturn : 8.442744255065918
# Eval_MaxReturn : 535.4934692382812
# Eval_MinReturn : 512.9894409179688
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 527.21435546875
# Train_StdReturn : 24.35929298400879
# Train_MaxReturn : 555.03759765625
# Train_MinReturn : 483.86541748046875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 57285
# TimeSinceStart : 560.4346716403961
# Critic Training Loss : 0.38365107774734497
# Critic Mean : 270.94769287109375
# Actor Training Loss : -272.31341552734375
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 502.7235412597656
# Eval_StdReturn : 27.799182891845703
# Eval_MaxReturn : 534.865234375
# Eval_MinReturn : 455.74798583984375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 523.9277954101562
# Train_StdReturn : 9.582351684570312
# Train_MaxReturn : 538.6096801757812
# Train_MinReturn : 515.1734008789062
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 58290
# TimeSinceStart : 569.1958131790161
# Critic Training Loss : 1.5429638624191284
# Critic Mean : 268.1203308105469
# Actor Training Loss : -270.0379333496094
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 521.2625732421875
# Eval_StdReturn : 9.093788146972656
# Eval_MaxReturn : 532.2670288085938
# Eval_MinReturn : 508.86669921875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 513.4926147460938
# Train_StdReturn : 14.17627239227295
# Train_MaxReturn : 529.7352294921875
# Train_MinReturn : 490.3584289550781
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 59295
# TimeSinceStart : 578.0391783714294
# Critic Training Loss : 4.9503679275512695
# Critic Mean : 272.51202392578125
# Actor Training Loss : -273.5878601074219
# Initial_DataCollection_AverageReturn : -55.866336822509766
# Done logging...
#
#
# Running actor critic experiment with seed 1
# ########################
# logging outputs to  logs/actor_critic/HalfCheetah/seed1
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
#
#
# ********** Iteration 0 ************
#
# Collecting initial random data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -101.62535095214844
# Eval_StdReturn : 4.892218112945557
# Eval_MaxReturn : -94.83905029296875
# Eval_MinReturn : -106.99482727050781
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -57.1893310546875
# Train_StdReturn : 35.802921295166016
# Train_MaxReturn : 25.553668975830078
# Train_MinReturn : -140.39804077148438
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 10050
# TimeSinceStart : 8.892401218414307
# Critic Training Loss : 0.6334373950958252
# Critic Mean : 17.115699768066406
# Actor Training Loss : -17.61271095275879
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -76.44679260253906
# Eval_StdReturn : 19.26387596130371
# Eval_MaxReturn : -54.99637985229492
# Eval_MinReturn : -111.27208709716797
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -103.32218933105469
# Train_StdReturn : 5.052402973175049
# Train_MaxReturn : -97.25869750976562
# Train_MinReturn : -111.77824401855469
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 11055
# TimeSinceStart : 17.299626111984253
# Critic Training Loss : 0.6378448605537415
# Critic Mean : 14.365479469299316
# Actor Training Loss : -14.834689140319824
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -85.43769073486328
# Eval_StdReturn : 15.031001091003418
# Eval_MaxReturn : -63.50678253173828
# Eval_MinReturn : -105.07005310058594
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -111.12007141113281
# Train_StdReturn : 36.166900634765625
# Train_MaxReturn : -46.59260559082031
# Train_MinReturn : -157.22955322265625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 12060
# TimeSinceStart : 26.799861431121826
# Critic Training Loss : 0.7701504826545715
# Critic Mean : 39.03846740722656
# Actor Training Loss : -39.75511169433594
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : -111.56108093261719
# Eval_StdReturn : 8.244311332702637
# Eval_MaxReturn : -96.69322204589844
# Eval_MinReturn : -119.79190063476562
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -70.85757446289062
# Train_StdReturn : 14.192402839660645
# Train_MaxReturn : -45.66138458251953
# Train_MinReturn : -86.0897216796875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 13065
# TimeSinceStart : 36.97859978675842
# Critic Training Loss : 0.5140719413757324
# Critic Mean : 45.79045867919922
# Actor Training Loss : -46.61121368408203
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 80.42036437988281
# Eval_StdReturn : 112.71273803710938
# Eval_MaxReturn : 145.25958251953125
# Eval_MinReturn : -144.45883178710938
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : -103.15875244140625
# Train_StdReturn : 6.51158332824707
# Train_MaxReturn : -95.17304229736328
# Train_MinReturn : -112.17060089111328
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 14070
# TimeSinceStart : 48.12552094459534
# Critic Training Loss : 0.6431431770324707
# Critic Mean : 48.504329681396484
# Actor Training Loss : -49.32646179199219
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 100.94180297851562
# Eval_StdReturn : 5.833705425262451
# Eval_MaxReturn : 107.69966125488281
# Eval_MinReturn : 92.43597412109375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 147.2571258544922
# Train_StdReturn : 10.074234962463379
# Train_MaxReturn : 162.9557647705078
# Train_MinReturn : 135.55743408203125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 15075
# TimeSinceStart : 59.472835063934326
# Critic Training Loss : 0.49993640184402466
# Critic Mean : 65.74933624267578
# Actor Training Loss : -66.66798400878906
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 121.85292053222656
# Eval_StdReturn : 80.65274047851562
# Eval_MaxReturn : 175.8348388671875
# Eval_MinReturn : -38.31562042236328
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 95.54731750488281
# Train_StdReturn : 10.224160194396973
# Train_MaxReturn : 108.85943603515625
# Train_MinReturn : 77.5447998046875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 16080
# TimeSinceStart : 70.81501579284668
# Critic Training Loss : 0.5876968502998352
# Critic Mean : 72.40731811523438
# Actor Training Loss : -73.36105346679688
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.78173065185547
# Eval_StdReturn : 82.22371673583984
# Eval_MaxReturn : 204.66612243652344
# Eval_MinReturn : -10.912174224853516
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 160.932861328125
# Train_StdReturn : 16.363574981689453
# Train_MaxReturn : 186.34225463867188
# Train_MinReturn : 142.12384033203125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 17085
# TimeSinceStart : 80.49629259109497
# Critic Training Loss : 0.27187952399253845
# Critic Mean : 81.8724365234375
# Actor Training Loss : -82.78013610839844
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 148.37533569335938
# Eval_StdReturn : 77.7292251586914
# Eval_MaxReturn : 245.37074279785156
# Eval_MinReturn : 63.220245361328125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 202.59974670410156
# Train_StdReturn : 104.66602325439453
# Train_MaxReturn : 291.1531982421875
# Train_MinReturn : 13.544054985046387
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 18090
# TimeSinceStart : 90.25966310501099
# Critic Training Loss : 1.2383259534835815
# Critic Mean : 102.60891723632812
# Actor Training Loss : -103.76165008544922
# Initial_DataCollection_AverageReturn : -57.1893310546875
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 248.00234985351562
# Eval_StdReturn : 8.346343994140625
# Eval_MaxReturn : 263.8525695800781
# Eval_MinReturn : 241.00933837890625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 173.09524536132812
# Train_StdReturn : 70.59986114501953
# ...
# Critic Training Loss : 1.2211076021194458
# Critic Mean : 232.9596405029297
# Actor Training Loss : -234.44053649902344
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 517.6622314453125
# Eval_StdReturn : 9.276490211486816
# Eval_MaxReturn : 528.5675048828125
# Eval_MinReturn : 501.05218505859375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 489.5865173339844
# Train_StdReturn : 10.952787399291992
# Train_MaxReturn : 502.55322265625
# Train_MinReturn : 472.5259094238281
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 40200
# TimeSinceStart : 391.6116590499878
# Critic Training Loss : 1.2401673793792725
# Critic Mean : 238.25762939453125
# Actor Training Loss : -239.8199462890625
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 499.8705139160156
# Eval_StdReturn : 16.908605575561523
# Eval_MaxReturn : 519.0989379882812
# Eval_MinReturn : 471.1495361328125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 514.4322509765625
# Train_StdReturn : 16.0352725982666
# Train_MaxReturn : 535.4398193359375
# Train_MinReturn : 498.1664123535156
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 41205
# TimeSinceStart : 403.3666524887085
# Critic Training Loss : 2.2747538089752197
# Critic Mean : 241.02020263671875
# Actor Training Loss : -242.54534912109375
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 506.30230712890625
# Eval_StdReturn : 5.798903465270996
# Eval_MaxReturn : 513.31005859375
# Eval_MinReturn : 496.4456787109375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 496.89154052734375
# Train_StdReturn : 17.929981231689453
# Train_MaxReturn : 515.2706909179688
# Train_MinReturn : 462.82843017578125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 42210
# TimeSinceStart : 415.2940368652344
# Critic Training Loss : 2.3639371395111084
# Critic Mean : 244.8877716064453
# Actor Training Loss : -246.33859252929688
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 508.32586669921875
# Eval_StdReturn : 7.405445575714111
# Eval_MaxReturn : 520.69873046875
# Eval_MinReturn : 498.2869873046875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 501.68585205078125
# Train_StdReturn : 6.261549949645996
# Train_MaxReturn : 509.922119140625
# Train_MinReturn : 490.9896240234375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 43215
# TimeSinceStart : 427.3739392757416
# Critic Training Loss : 3.3365700244903564
# Critic Mean : 249.0478057861328
# Actor Training Loss : -250.3584747314453
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 502.56829833984375
# Eval_StdReturn : 9.232381820678711
# Eval_MaxReturn : 516.2048950195312
# Eval_MinReturn : 487.1597595214844
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 501.7456970214844
# Train_StdReturn : 8.965612411499023
# Train_MaxReturn : 510.84747314453125
# Train_MinReturn : 485.4848937988281
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 44220
# TimeSinceStart : 441.02838015556335
# Critic Training Loss : 3.243018865585327
# Critic Mean : 249.84619140625
# Actor Training Loss : -251.25588989257812
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 519.6002197265625
# Eval_StdReturn : 11.188725471496582
# Eval_MaxReturn : 532.6779174804688
# Eval_MinReturn : 498.99151611328125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 498.97265625
# Train_StdReturn : 12.181840896606445
# Train_MaxReturn : 509.5579528808594
# Train_MinReturn : 475.62091064453125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 45225
# TimeSinceStart : 453.58908796310425
# Critic Training Loss : 0.3805581331253052
# Critic Mean : 252.09671020507812
# Actor Training Loss : -253.6558837890625
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 535.6867065429688
# Eval_StdReturn : 5.516261577606201
# Eval_MaxReturn : 542.524658203125
# Eval_MinReturn : 525.7325439453125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 520.774169921875
# Train_StdReturn : 7.166322708129883
# Train_MaxReturn : 530.4744873046875
# Train_MinReturn : 511.01324462890625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 46230
# TimeSinceStart : 466.9022023677826
# Critic Training Loss : 2.2931437492370605
# Critic Mean : 256.0279541015625
# Actor Training Loss : -257.31658935546875
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 499.79638671875
# Eval_StdReturn : 17.86708641052246
# Eval_MaxReturn : 521.7997436523438
# Eval_MinReturn : 468.178955078125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 410.83221435546875
# Train_StdReturn : 219.99693298339844
# Train_MaxReturn : 539.9599609375
# Train_MinReturn : -25.068103790283203
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 47235
# TimeSinceStart : 479.70640420913696
# Critic Training Loss : 1.5281105041503906
# Critic Mean : 255.14089965820312
# Actor Training Loss : -256.52752685546875
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 518.0147705078125
# Eval_StdReturn : 8.16294002532959
# Eval_MaxReturn : 531.6163940429688
# Eval_MinReturn : 507.5892028808594
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 487.82366943359375
# Train_StdReturn : 18.494413375854492
# Train_MaxReturn : 501.8612976074219
# Train_MinReturn : 451.30145263671875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 48240
# TimeSinceStart : 493.22707509994507
# Critic Training Loss : 3.45548152923584
# Critic Mean : 253.50079345703125
# Actor Training Loss : -255.11236572265625
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 530.7130737304688
# Eval_StdReturn : 8.030444145202637
# Eval_MaxReturn : 541.826171875
# Eval_MinReturn : 521.011474609375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 518.072509765625
# Train_StdReturn : 8.066218376159668
# Train_MaxReturn : 529.1253662109375
# Train_MinReturn : 505.5871887207031
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 49245
# TimeSinceStart : 505.4368369579315
# Critic Training Loss : 2.6039326190948486
# Critic Mean : 259.25494384765625
# Actor Training Loss : -260.5155334472656
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 559.6904296875
# Eval_StdReturn : 9.327413558959961
# Eval_MaxReturn : 576.7076416015625
# Eval_MinReturn : 549.85009765625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 527.1045532226562
# Train_StdReturn : 15.466949462890625
# Train_MaxReturn : 547.0159912109375
# Train_MinReturn : 500.09405517578125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 50250
# TimeSinceStart : 518.9392848014832
# Critic Training Loss : 5.1438069343566895
# Critic Mean : 260.1369934082031
# Actor Training Loss : -261.29547119140625
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 523.1878051757812
# Eval_StdReturn : 11.176640510559082
# Eval_MaxReturn : 538.5611572265625
# Eval_MinReturn : 510.2961120605469
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 553.3607788085938
# Train_StdReturn : 10.117440223693848
# Train_MaxReturn : 566.1024169921875
# Train_MinReturn : 539.291259765625
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 51255
# TimeSinceStart : 531.6236922740936
# Critic Training Loss : 0.35030806064605713
# Critic Mean : 258.3882751464844
# Actor Training Loss : -259.768310546875
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 550.5665283203125
# Eval_StdReturn : 18.393539428710938
# Eval_MaxReturn : 565.2613525390625
# Eval_MinReturn : 515.1580810546875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 519.0476684570312
# Train_StdReturn : 11.532299041748047
# Train_MaxReturn : 536.3018798828125
# Train_MinReturn : 503.46142578125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 52260
# TimeSinceStart : 544.4623286724091
# Critic Training Loss : 0.3568529188632965
# Critic Mean : 261.9062805175781
# Actor Training Loss : -263.32830810546875
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 550.0997314453125
# Eval_StdReturn : 9.950916290283203
# Eval_MaxReturn : 565.539306640625
# Eval_MinReturn : 538.7529296875
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 556.0101318359375
# Train_StdReturn : 26.113004684448242
# Train_MaxReturn : 584.90771484375
# Train_MinReturn : 506.8514099121094
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 53265
# TimeSinceStart : 556.6248509883881
# Critic Training Loss : 1.4079163074493408
# Critic Mean : 269.1317443847656
# Actor Training Loss : -270.52447509765625
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 564.5391845703125
# Eval_StdReturn : 8.6368408203125
# Eval_MaxReturn : 572.8931884765625
# Eval_MinReturn : 549.755615234375
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 546.2722778320312
# Train_StdReturn : 16.470577239990234
# Train_MaxReturn : 560.66162109375
# Train_MinReturn : 514.753662109375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 54270
# TimeSinceStart : 570.5470428466797
# Critic Training Loss : 1.4154908657073975
# Critic Mean : 269.52655029296875
# Actor Training Loss : -270.80999755859375
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 584.771484375
# Eval_StdReturn : 26.3498477935791
# Eval_MaxReturn : 606.6202392578125
# Eval_MinReturn : 535.8029174804688
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 565.3786010742188
# Train_StdReturn : 8.033767700195312
# Train_MaxReturn : 578.0806884765625
# Train_MinReturn : 553.1963500976562
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 55275
# TimeSinceStart : 583.8286488056183
# Critic Training Loss : 3.5129752159118652
# Critic Mean : 274.3475341796875
# Actor Training Loss : -275.595947265625
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 564.6691284179688
# Eval_StdReturn : 9.481378555297852
# Eval_MaxReturn : 574.6856689453125
# Eval_MinReturn : 551.303955078125
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 590.78759765625
# Train_StdReturn : 24.908512115478516
# Train_MaxReturn : 608.553955078125
# Train_MinReturn : 542.7451171875
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 56280
# TimeSinceStart : 596.1500449180603
# Critic Training Loss : 1.4210376739501953
# Critic Mean : 280.9722900390625
# Actor Training Loss : -282.27178955078125
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 561.5001831054688
# Eval_StdReturn : 13.641427993774414
# Eval_MaxReturn : 584.1134643554688
# Eval_MinReturn : 544.4241333007812
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 566.8923950195312
# Train_StdReturn : 11.920125961303711
# Train_MaxReturn : 578.4430541992188
# Train_MinReturn : 545.3009033203125
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 57285
# TimeSinceStart : 608.7542912960052
# Critic Training Loss : 2.480052947998047
# Critic Mean : 280.6704406738281
# Actor Training Loss : -282.0554504394531
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 559.2453002929688
# Eval_StdReturn : 9.15588092803955
# Eval_MaxReturn : 569.4208374023438
# Eval_MinReturn : 544.7193603515625
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 553.305419921875
# Train_StdReturn : 19.17233657836914
# Train_MaxReturn : 578.7742309570312
# Train_MinReturn : 524.823974609375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 58290
# TimeSinceStart : 621.1293165683746
# Critic Training Loss : 0.26444825530052185
# Critic Mean : 282.8207702636719
# Actor Training Loss : -284.2200012207031
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 575.532958984375
# Eval_StdReturn : 13.921103477478027
# Eval_MaxReturn : 596.379638671875
# Eval_MinReturn : 557.1981811523438
# Eval_AverageEpLen : 201.0
# Train_AverageReturn : 552.6790161132812
# Train_StdReturn : 14.538641929626465
# Train_MaxReturn : 565.0186767578125
# Train_MinReturn : 529.609130859375
# Train_AverageEpLen : 201.0
# Train_EnvstepsSoFar : 59295
# TimeSinceStart : 633.9627108573914
# Critic Training Loss : 3.789309024810791
# Critic Mean : 282.56634521484375
# Actor Training Loss : -283.9071044921875
# Initial_DataCollection_AverageReturn : -59.250770568847656
# Done logging...

# %%
### Visualize Actor Critic results on Halfheetah
# %load_ext tensorboard
# %tensorboard --logdir logs/actor_critic/HalfCheetah
# Out:
#       <iframe id="tensorboard-frame-84782b0b8eda45a5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-84782b0b8eda45a5");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
